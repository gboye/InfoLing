# %%
import os

# %%
for root, dirs, files in os.walk("/Users/gilles/Downloads/LNS3U5-TRS-Corr/"):
    files=[fichier for fichier in files if not fichier.startswith(".")]
    for file in files:
        splitFile= file.split("_assignsubmission_file_")
        repertoire=splitFile[0]
        fichier=splitFile[-1]
        print repertoire
        print fichier
        if not os.path.exists(root+repertoire):
            os.makedirs(root+repertoire)
#        print root+file
#        print root+repertoire+fichier
        os.rename(root+file,root+repertoire+"/"+fichier)
# Out:
# match 10 15.trico
# match 10 15.trico
# /Users/gilles/Downloads/LNS3U5-Exercice de transcription-72051/CLARISSE JACQUEMIN_93670_assignsubmission_file_match 10 15.trico
# /Users/gilles/Downloads/LNS3U5-Exercice de transcription-72051/CLARISSE JACQUEMIN_93670_assignsubmission_file_match 10 15.tricomatch 10 15.trico
# 2015-09-23-France-Roumanie.trs
# 2015-09-23-France-Roumanie.trs
# /Users/gilles/Downloads/LNS3U5-Exercice de transcription-72051/MARION TALOU_97708_assignsubmission_file_2015-09-23-France-Roumanie.trs
# /Users/gilles/Downloads/LNS3U5-Exercice de transcription-72051/MARION TALOU_97708_assignsubmission_file_2015-09-23-France-Roumanie.trs2015-09-23-France-Roumanie.trs
# transcription linguistique et corpus (3).pdf
# transcription linguistique et corpus (3).pdf
# /Users/gilles/Downloads/LNS3U5-Exercice de transcription-72051/MARINE BELHANI_95610_assignsubmission_file_transcription linguistique et corpus (3).pdf
# ...
