# %%
from lxml import etree
import bs4

# %%
fichierTRS="/Users/gilles/Copy/Cours/Bordeaux/L2-XML/XML-Ressources/TRS/Argonne.trs"
fichierBDL="/Users/gilles/Copy/Cours/Bordeaux/L2-XML/XML-Ressources/TRS/Argonne-BDL.xml"
fichierTRS="/Users/gilles/ownCloud/Python/workspace/XML-Talismane/AMOUR_EST_AVEUGLE_rencontre1.tal"
fichierTRS="/Users/gilles/ownCloud/Cours/Bordeaux/L2-XML/XML-Transcriber/Preshow - SKT T1 vs Misfits - World Championship 2017 - 14 de finale - League of Legends.trs"

# %%
xmlTRS=etree.parse(fichierTRS)
print etree.tostring(xmlTRS)
# Out:
# <!DOCTYPE Trans SYSTEM "trans-14.dtd">
# <Trans scribe="Jean" audio_filename="Preshow - SKT T1 vs Misfits - World Championship 2017 - 14 de finale - League of Legends" version="18" version_date="171124">
# <Speakers>
# <Speaker id="spk1" name="&quot;Bulii&quot; " check="no" dialect="native" accent="" scope="local" type="female"/>
# <Speaker id="spk2" name="Zaboutine" check="no" dialect="native" accent="" scope="local" type="male"/>
# <Speaker id="spk3" name="Noi" check="no" dialect="native" accent="" scope="local" type="male"/>
# <Speaker id="spk4" name="speaker#4" check="no" dialect="native" accent="" scope="local"/>
# </Speakers>
# <Episode>
# <Section type="report" startTime="0" endTime="1437.466">
# <Turn startTime="0" endTime="34.066">
# <Sync time="0"/>
#
# <Event desc="jingle" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="34.066" endTime="39.514">
# <Sync time="34.066"/>
# bonjour &#224; tous et bienvenue dans ce
# <Event desc="en" type="language" extent="begin"/>
# /preshow/
# <Event desc="en" type="language" extent="end"/>
#  des championnats du monde deux milles dix sept aujourd'hui on continue sur les quarts de finale
# </Turn>
# <Turn startTime="39.514" endTime="39.796">
# <Sync time="39.514"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="39.796" endTime="42.754">
# <Sync time="39.796"/>
# et pour en parler je serai en j- compagnie de Noi et Zaboutine comment allez vous
# </Turn>
# <Turn startTime="42.754" endTime="43.115">
# <Sync time="42.754"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="43.115" endTime="43.506">
# <Sync time="43.115"/>
# &#231;a va tr&#232;s bien
# </Turn>
# <Turn startTime="43.506" endTime="43.735">
# <Sync time="43.506"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="43.735" endTime="47.109">
# <Sync time="43.735"/>
# et bien euh tr&#232;s bien parce que un match euh ma foi qui nous int&#233;resse au plus haut point
# </Turn>
# <Turn startTime="47.109" endTime="47.338">
# <Sync time="47.109"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="47.338" endTime="50.904">
# <Sync time="47.338"/>
# ouais et on a d&#233;j&#224; eu un bo hier avec la qualification assez inattendue
# </Turn>
# <Turn startTime="50.904" endTime="51.14">
# <Sync time="50.904"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="51.14" endTime="52.74">
# <Sync time="51.14"/>
# d(e) Samsung contre Longzhu
# </Turn>
# <Turn startTime="52.74" endTime="53.031">
# <Sync time="52.74"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="53.031" endTime="57.617">
# <Sync time="53.031"/>
# on va revenir bri&#232;vement sur le match euh on bah on s'attendait pas du tout euh de &#231;a de la part de Longzhu
# </Turn>
# <Turn startTime="57.617" endTime="57.912">
# <Sync time="57.617"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="57.912" endTime="59.092">
# <Sync time="57.912"/>
#
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  g&#233;n&#233;ral de la part de l'&#233;quipe
# </Turn>
# <Turn startTime="59.092" endTime="59.727">
# <Sync time="59.092"/>
#
# </Turn>
# <Turn speaker="spk2 spk1" startTime="59.727" endTime="63.056">
# <Sync time="59.727"/>
# <Who nb="1"/>
# boh et &#224; part Jean Twitter euh qui est venu venu nous dire qui l'avait bien dit euh
# <Who nb="2"/>
# oui
# </Turn>
# <Turn startTime="63.056" endTime="63.428">
# <Sync time="63.056"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="63.428" endTime="69.165">
# <Sync time="63.428"/>
# tous les
# <Event desc="en" type="language" extent="begin"/>
# /coach/
# <Event desc="en" type="language" extent="end"/>
#  les p- joueurs qui ont jou&#233; en
# <Event desc="en" type="language" extent="begin"/>
# /scrim/
# <Event desc="en" type="language" extent="end"/>
#  les joueurs qu'on pas jou&#233; en
# <Event desc="en" type="language" extent="begin"/>
# /scrim/
# <Event desc="en" type="language" extent="end"/>
#  les analystes les commentateurs &#233;taient d'accord pour dire que Longzhu etait meilleur
# </Turn>
# <Turn startTime="69.165" endTime="69.686">
# <Sync time="69.165"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="69.686" endTime="74.297">
# <Sync time="69.686"/>
# pis il s'av&#232;re que les les leur
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  &#233;taient un petit peu approximatifs je pense du c&#244;t&#233; de Longzhu puis bah quand on sait pas jouer derri&#232;re aux
# <Event desc="en" type="language" extent="begin"/>
# /worlds/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="74.297" endTime="74.641">
# <Sync time="74.297"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="74.641" endTime="76.725">
# <Sync time="74.641"/>
# g&#233;n&#233;ralement on les gagne pas et &#231;a &#233;t&#233; assez bien montr&#233; je pense
# </Turn>
# <Turn speaker="spk1" startTime="76.725" endTime="78.91">
# <Sync time="76.725"/>
# et a une &#233;quipe qu'&#224; pas assez d'&#233;xp&#233;rience en bo cinq peut-&#234;tre
# </Turn>
# <Turn startTime="78.91" endTime="79.326">
# <Sync time="78.91"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="79.326" endTime="87.181">
# <Sync time="79.326"/>
# y a euh y a un peu de tout &#231;a y a un peu de stress un peu la pression du du
# <Event desc="en" type="language" extent="begin"/>
# /stage/
# <Event desc="en" type="language" extent="end"/>
#  euh moins d'exp&#233;rience euh effectivement les
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  avant tout les
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  euh je dirai mais bon je pense que
# </Turn>
# <Turn startTime="87.181" endTime="87.479">
# <Sync time="87.181"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="87.479" endTime="93.114">
# <Sync time="87.479"/>
# les
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  on bon on sait pas ce qu'il se passe dans la
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  donc peut pas
# <Event desc="en" type="language" extent="begin"/>
# /blame/
# <Event desc="en" type="language" extent="end"/>
#  le
# <Event desc="en" type="language" extent="begin"/>
# /coach/
# <Event desc="en" type="language" extent="end"/>
#  ca peut &#234;tre aussi les joueurs qui se sentaient pas de jouer telle ou telle chose qu'&#233;taient pas en confiance
# </Turn>
# <Turn startTime="93.114" endTime="93.627">
# <Sync time="93.114"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="93.627" endTime="96.363">
# <Sync time="93.627"/>
# mais ouais c'est ma deuxi&#232;me plus grosse d&#233;ception de l'ann&#233;e apr&#232;s KT Rolster quoi
# </Turn>
# <Turn startTime="96.363" endTime="96.793">
# <Sync time="96.363"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="96.793" endTime="98.129">
# <Sync time="96.793"/>
# <Who nb="1"/>
# c'est ch-
# <Event desc="rire" type="noise" extent="instantaneous"/>
#
# <Who nb="2"/>
# oui
# </Turn>
# <Turn speaker="spk1 spk3" startTime="98.129" endTime="98.605">
# <Sync time="98.129"/>
# <Who nb="1"/>
# mais d'un autre
# <Who nb="2"/>
# comment dire
# </Turn>
# <Turn speaker="spk1" startTime="98.605" endTime="109.445">
# <Sync time="98.605"/>
# c&#244;t&#233; alors &#231;a &#231;a m'a rassur&#233;e puisque je me suis dis au moins euh Samsung n'ont pas vol&#233; leur place aux KT puisque Samsung ont admirablement bien jou&#233; ils ont gal&#233;r&#233; toute l'ann&#233;e et hier j'avais vraiment la sensation de retrouver l'&#233;quipe qu'on avait pu voir en en deux milles seize
# </Turn>
# <Turn startTime="109.445" endTime="110.229">
# <Sync time="109.445"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="110.229" endTime="110.573">
# <Sync time="110.229"/>
# bah s-
# </Turn>
# <Turn startTime="110.573" endTime="110.799">
# <Sync time="110.573"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="110.799" endTime="117.426">
# <Sync time="110.799"/>
# c'est une &#233;quipe qui est assez forte en fin d'ann&#233;e en fait qui fini avait panache qui a une euh qui a une fin d'ann&#233;e g&#233;n&#233;ralement faite en
# <Event desc="en" type="language" extent="begin"/>
# /summer split/
# <Event desc="en" type="language" extent="end"/>
#  un peu difficile et qui qui monte en puissance euh
# </Turn>
# <Turn startTime="117.426" endTime="117.846">
# <Sync time="117.426"/>
#
# </Turn>
# <Turn speaker="spk2 spk1" startTime="117.846" endTime="120.686">
# <Sync time="117.846"/>
# <Who nb="1"/>
# je dirai c'est une &#233;quipe qui est pas bonne
# <Who nb="2"/>
# la route a &#233;t&#233; longue pour eux ils en ont tous parl&#233; c'est
# </Turn>
# <Turn speaker="spk2" startTime="120.686" endTime="125.419">
# <Sync time="120.686"/>
# je pense qu'ils savent pas du tout s'adapter &#224; un nouveau
# <Event desc="en" type="language" extent="begin"/>
# /patch/
# <Event desc="en" type="language" extent="end"/>
#  euh mais par contre ils sont tr&#232;s bons pour optimiser un
# <Event desc="en" type="language" extent="begin"/>
# /patch/
# <Event desc="en" type="language" extent="end"/>
#  existant parce qu'ils ont des joueurs d'exp&#233;rience
# </Turn>
# <Turn startTime="125.419" endTime="125.888">
# <Sync time="125.419"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="125.888" endTime="129.776">
# <Sync time="125.888"/>
# et &#231;a s'est vu encore une fois et une bien meilleure compr&#233;hension des conditions de victoire de la m&#233;ta actuelle avec euh
# </Turn>
# <Turn startTime="129.776" endTime="130.217">
# <Sync time="129.776"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="130.217" endTime="134.042">
# <Sync time="130.217"/>
# euh sam- Samsung &#231;a fait pas forc&#233;ment r&#234;ver beaucoup de monde en un point de vue du
# <Event desc="en" type="language" extent="begin"/>
# /game play/
# <Event desc="en" type="language" extent="end"/>
#  parce que c'est vraiment euh
# </Turn>
# <Turn startTime="134.042" endTime="134.375">
# <Sync time="134.042"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="134.375" endTime="137.034">
# <Sync time="134.375"/>
# euh la euh je dirai le manifeste de la de la m&#233;ta g&#233;n&#233;ralement quand ils jouent
# </Turn>
# <Turn startTime="137.034" endTime="137.42">
# <Sync time="137.034"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="137.42" endTime="142.195">
# <Sync time="137.42"/>
# mais g&#233;n&#233;ralement quand tu joues la m&#233;ta t'as cent fois plus de chance de gagner que l'adversaire et c'est ce qui p- franchement &#231;a s'est bien montr&#233; hier quoi
# </Turn>
# <Turn startTime="142.195" endTime="142.376">
# <Sync time="142.195"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="142.376" endTime="147.276">
# <Sync time="142.376"/>
# on va regarder euh le
# <Event desc="en" type="language" extent="begin"/>
# /bracket/
# <Event desc="en" type="language" extent="end"/>
#  pour voir o&#249; nous en sommes aujourd'hui puisque nous continuons ces quarts de finale avec
# </Turn>
# <Turn startTime="147.276" endTime="148.06">
# <Sync time="147.276"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="148.06" endTime="152.949">
# <Sync time="148.06"/>
# Misfits SKT (on) reviendra plus en d&#233;tails euh sur le match toute &#224; l'heure mais
# </Turn>
# <Turn startTime="152.949" endTime="153.702">
# <Sync time="152.949"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="153.702" endTime="156.376">
# <Sync time="153.702"/>
# on aura peut-&#234;tre plus qu'une &#233;quipe europ&#233;enne &#224; la fin de de cette matin&#233;e
# </Turn>
# <Turn startTime="156.376" endTime="157.513">
# <Sync time="156.376"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="157.513" endTime="162.503">
# <Sync time="157.513"/>
# bouah et non on aura qu'une s- ch- s- XXX peut-&#234;tre il est il est cool tu vois c'est bien pour l'espoir et tout
# </Turn>
# <Turn startTime="162.503" endTime="163.02">
# <Sync time="162.503"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="163.02" endTime="166.353">
# <Sync time="163.02"/>
# boh c'est le boss de fin euh SKT ils ont jamais perdu un bo cinq aux
# <Event desc="en" type="language" extent="begin"/>
# /worlds/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="166.353" endTime="166.78">
# <Sync time="166.353"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="166.78" endTime="170.134">
# <Sync time="166.78"/>
# ils ont gagn&#233; tous les
# <Event desc="en" type="language" extent="begin"/>
# /worlds/
# <Event desc="en" type="language" extent="end"/>
#  dans lesquels ils ont particip&#233; leur plus grand adversaire Longzhu est
# <Event desc="en" type="language" extent="begin"/>
# /out/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="170.134" endTime="171.356">
# <Sync time="170.134"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="171.356" endTime="172.511">
# <Sync time="171.356"/>
# &#231;a commence &#224; sentir bon quoi
# </Turn>
# <Turn startTime="172.511" endTime="173.17">
# <Sync time="172.511"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="173.17" endTime="179.961">
# <Sync time="173.17"/>
# b(en) pour moi c'est euh malheureusement hein euh faut &#234;tre honn&#234;te pour moi la vic- euh la la victoire de Samsung alors mis &#224; part le fait que j'aime Longzhu et que j'aime pas Samsung
# </Turn>
# <Turn startTime="179.961" endTime="180.326">
# <Sync time="179.961"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="180.326" endTime="185.49">
# <Sync time="180.326"/>
# <Who nb="1"/>
# pour moi &#231;a tue un petit peu la
# <Event desc="en" type="language" extent="begin"/>
# /hype/
# <Event desc="en" type="language" extent="end"/>
#  parce que &#231;a sent &#231;a sent tr&#232;s fort le
# <Event desc="en" type="language" extent="begin"/>
# /remake/
# <Event desc="en" type="language" extent="end"/>
#  euh deux mille seize
# <Who nb="2"/>
# XXX
# </Turn>
# <Turn speaker="spk3" startTime="185.49" endTime="189.983">
# <Sync time="185.49"/>
# sauf que je suis m&#234;me pas s&#251;r que Samsung puisse amener euh les SKT sur un bo cinq
# </Turn>
# <Turn startTime="189.983" endTime="190.552">
# <Sync time="189.983"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="190.552" endTime="195.126">
# <Sync time="190.552"/>
# euh l'effondrement de Longzhu (euh) pour moi p&#232;te un petit peu un petit peu de chose par la suite
# </Turn>
# <Turn startTime="195.126" endTime="195.466">
# <Sync time="195.126"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="195.466" endTime="198.782">
# <Sync time="195.466"/>
# donc euh je vais tout parier sur les &#233;quipes chinoises mais &#231;a c'est pour u- une autre journ&#233;e
# </Turn>
# <Turn startTime="198.782" endTime="199.191">
# <Sync time="198.782"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="199.191" endTime="202.767">
# <Sync time="199.191"/>
# apr&#232;s ouais pour rejoindre Zab euh bah moi j'ai mis trois z&#233;ro hein SKT Misfits je vois pas comment
# </Turn>
# <Turn startTime="202.767" endTime="203.243">
# <Sync time="202.767"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="203.243" endTime="203.677">
# <Sync time="203.243"/>
# et pourtant
# </Turn>
# <Turn startTime="203.677" endTime="204.225">
# <Sync time="203.677"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="204.225" endTime="205.197">
# <Sync time="204.225"/>
# Misfits est euh
# </Turn>
# <Turn startTime="205.197" endTime="205.523">
# <Sync time="205.197"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="205.523" endTime="209.854">
# <Sync time="205.523"/>
# <Who nb="1"/>
# excellent euh genre jamais on aurait cru qu'ils puissent aller aussi loin mais je vois pas comment ils prennent SKT
# <Who nb="2"/>
# mmh
# </Turn>
# <Turn startTime="209.854" endTime="210.007">
# <Sync time="209.854"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="210.007" endTime="214.165">
# <Sync time="210.007"/>
# justement on a une vid&#233;o qui (euh) r&#233;capitule leur deuxi&#232;me semaine puisque &#231;a s'est jou&#233; &#224; peu
# </Turn>
# <Turn startTime="214.165" endTime="214.644">
# <Sync time="214.165"/>
#
# </Turn>
# <Turn speaker="spk1 spk2" startTime="214.644" endTime="218.719">
# <Sync time="214.644"/>
# <Who nb="1"/>
# &#231;a s'est jou&#233; (euh) sur un
# <Event desc="en" type="language" extent="begin"/>
# /tiebreak/
# <Event desc="en" type="language" extent="end"/>
#  si je raconte pas (de) b&#234;tises
# <Who nb="2"/>
#
# <Event desc="en" type="language" extent="begin"/>
# /tiebreak/
# <Event desc="en" type="language" extent="end"/>
#  contre TSM
# </Turn>
# <Turn startTime="218.719" endTime="218.883">
# <Sync time="218.719"/>
#
# </Turn>
# <Turn speaker="spk1 spk2" startTime="218.883" endTime="221.599">
# <Sync time="218.883"/>
# <Who nb="1"/>
# c'est &#231;a
# <Who nb="2"/>
# euh qu'il gagne euh avec un peu de peur au ventre
# </Turn>
# <Turn startTime="221.599" endTime="222.123">
# <Sync time="221.599"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="222.123" endTime="228.528">
# <Sync time="222.123"/>
# une deuxi&#232;me semaine des Misfits qui &#233;tait euh somme toute int&#233;ressante mais pas non plus extraordinaire notamment euh contre
# <Event desc="en" type="language" extent="begin"/>
# /team/
# <Event desc="en" type="language" extent="end"/>
#  WE
# </Turn>
# <Turn startTime="228.528" endTime="229.059">
# <Sync time="228.528"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="229.059" endTime="234.216">
# <Sync time="229.059"/>
# qui met en avant en fait les le l(e) l'incapacit&#233; de Misfits &#224; r&#233;sister &#224; des grosses phases de pression en
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="234.216" endTime="234.668">
# <Sync time="234.216"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="234.668" endTime="240.664">
# <Sync time="234.668"/>
# et peut-&#234;tre euh quelques limitations aussi du du de l'axe PoE Maxlore qu'on avait d&#233;j&#224; remarqu&#233; lors de la finale de des championnats d'Europe
# </Turn>
# <Turn startTime="240.664" endTime="241.271">
# <Sync time="240.664"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="241.271" endTime="243.82">
# <Sync time="241.271"/>
# euh &#224; l'Accord Hotel Arena o&#249; ils avaient pris trois z&#233;ro contre euh
# </Turn>
# <Turn startTime="243.82" endTime="244.188">
# <Sync time="243.82"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="244.188" endTime="245.114">
# <Sync time="244.188"/>
# les Gdeux de Perkz
# </Turn>
# <Turn startTime="245.114" endTime="245.586">
# <Sync time="245.114"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="245.586" endTime="246.436">
# <Sync time="245.586"/>
# encore une fois euh
# </Turn>
# <Turn startTime="246.436" endTime="246.887">
# <Sync time="246.436"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="246.887" endTime="252.702">
# <Sync time="246.887"/>
# n'en d&#233;plaise aux aux aux
# <Event desc="en" type="language" extent="begin"/>
# /haters/
# <Event desc="en" type="language" extent="end"/>
#  de Gdeux je pense qu'une &#233;quipe comme Gdeux est bien plus pr&#234;te pour des bo cinq de de ce calibre que que Mifits
# </Turn>
# <Turn startTime="252.702" endTime="253.285">
# <Sync time="252.702"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="253.285" endTime="255.846">
# <Sync time="253.285"/>
# voil&#224; c'est Misfits qu'on aura aujourdh'hui et tant mieux pour eux pour leur exp&#233;rience
# </Turn>
# <Turn startTime="255.846" endTime="256.204">
# <Sync time="255.846"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="256.204" endTime="258.087">
# <Sync time="256.204"/>
# mais &#231;a risque d'&#234;tre un peu l&#233;ger face au meilleur joueur du monde
# </Turn>
# <Turn startTime="258.087" endTime="258.234">
# <Sync time="258.087"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="258.234" endTime="258.888" mode="spontaneous">
# <Sync time="258.234"/>
# mmh on a
# </Turn>
# <Turn mode="spontaneous" startTime="258.888" endTime="259.372">
# <Sync time="258.888"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="259.372" endTime="263.489">
# <Sync time="259.372"/>
# y- ils ont ce r&#244;le de rookie certes mais euh tous les joueurs ont progress&#233; d'une semaine &#224; l'autre
# </Turn>
# <Turn mode="spontaneous" startTime="263.489" endTime="263.878">
# <Sync time="263.489"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="263.878" endTime="267.365">
# <Sync time="263.878"/>
# euh &#224; voir si c'est quelque chose qu'ils arriveront &#224; mettre en place en cette semaine dans le cadre de bo cinq
# </Turn>
# <Turn mode="spontaneous" startTime="267.365" endTime="267.978">
# <Sync time="267.365"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="267.978" endTime="275.839">
# <Sync time="267.978"/>
# bah ce qui est bien c'est que c'est une &#233;quipe europ&#233;enne o&#249; o&#249; personne n'a &#233;t&#233; vraiment laiss&#233; derri&#232;re y a pas un joueur qu'on peut pointer du doigt en disant l&#224; vraiment euh il a pas r&#233;ussi &#224; monter au niveau des autres tout le monde est excellent
# </Turn>
# <Turn mode="spontaneous" startTime="275.839" endTime="276.24">
# <Sync time="275.839"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="276.24" endTime="278.66">
# <Sync time="276.24"/>
# avec toujours je trouve euh Ignar euh en t&#234;te de pont
# </Turn>
# <Turn mode="spontaneous" startTime="278.66" endTime="278.904">
# <Sync time="278.66"/>
#
# </Turn>
# <Turn speaker="spk1 spk2" mode="spontaneous" startTime="278.904" endTime="279.38">
# <Sync time="278.904"/>
# <Who nb="1"/>
# XXXX
# <Who nb="2"/>
# euh
# </Turn>
# <Turn speaker="spk2" startTime="279.38" endTime="284.207">
# <Sync time="279.38"/>
# notamment euh pour moi &#231;a va &#234;tre tr&#232;s important la capacit&#233; de Ignar &#224; faire bouger un
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#  notamment contre les SKT
# </Turn>
# <Turn mode="spontaneous" startTime="284.207" endTime="284.591">
# <Sync time="284.207"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="284.591" endTime="285.485">
# <Sync time="284.591"/>
# qui a montr&#233; des faiblesses
# </Turn>
# <Turn mode="spontaneous" startTime="285.485" endTime="285.82">
# <Sync time="285.485"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="285.82" endTime="289.973">
# <Sync time="285.82"/>
# mais oui c'(est) tout le monde joue bien tout le monde se surpasse euh on est dans la continuit&#233; de leur
# <Event desc="en" type="language" extent="begin"/>
# /play off/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn mode="spontaneous" startTime="289.973" endTime="290.368">
# <Sync time="289.973"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="290.368" endTime="291.563">
# <Sync time="290.368"/>
# euh toujours dans la surprise
# </Turn>
# <Turn mode="spontaneous" startTime="291.563" endTime="291.958">
# <Sync time="291.563"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="291.958" endTime="292.256">
# <Sync time="291.958"/>
# et
# </Turn>
# <Turn mode="spontaneous" startTime="292.256" endTime="292.449">
# <Sync time="292.256"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="292.449" endTime="294.716">
# <Sync time="292.449"/>
# ce qui est bien c'est que pour moi ils ont plusieurs cordes
# </Turn>
# <Turn mode="spontaneous" startTime="294.716" endTime="295.147">
# <Sync time="294.716"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="295.147" endTime="295.746">
# <Sync time="295.147"/>
# &#224; leur arc
# </Turn>
# <Turn mode="spontaneous" startTime="295.746" endTime="296.061">
# <Sync time="295.746"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="296.061" endTime="298.481">
# <Sync time="296.061"/>
# pour essayer de de g&#233;rer un peu TS af- pas TSM pardon
# </Turn>
# <Turn mode="spontaneous" startTime="298.481" endTime="299.128">
# <Sync time="298.481"/>
#
# </Turn>
# <Turn speaker="spk3 spk2" mode="spontaneous" startTime="299.128" endTime="300.32">
# <Sync time="299.128"/>
# <Who nb="1"/>
# qui va pas rester l&#224; euh SKT ouais
# <Who nb="2"/>
# SKT ouais
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="300.32" endTime="302.706">
# <Sync time="300.32"/>
#  on on aurait aim&#233; que ce soit TSM en quart de finale pour Misfits
# </Turn>
# <Turn mode="spontaneous" startTime="302.706" endTime="303.26">
# <Sync time="302.706"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="303.26" endTime="304.126">
# <Sync time="303.26"/>
# c'est quand m&#234;me plus facile
# </Turn>
# <Turn mode="spontaneous" startTime="304.126" endTime="304.657">
# <Sync time="304.126"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="304.657" endTime="305.041">
# <Sync time="304.657"/>
# (euh)
# </Turn>
# <Turn mode="spontaneous" startTime="305.041" endTime="305.283">
# <Sync time="305.041"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="305.283" endTime="305.939">
# <Sync time="305.283"/>
# Misfits
# </Turn>
# <Turn mode="spontaneous" startTime="305.939" endTime="306.385">
# <Sync time="305.939"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="306.385" endTime="307.915">
# <Sync time="306.385"/>
#  moi je pense que le bo peut &#234;tre tr&#232;s serr&#233;
# </Turn>
# <Turn mode="spontaneous" startTime="307.915" endTime="308.151">
# <Sync time="307.915"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="308.151" endTime="314.278">
# <Sync time="308.151"/>
# c'est moi j'ai pour &#231;a que j'ai de toute fa&#231;on j'ai vot&#233; quasiment que j'ai trois deux parce que je pense que tous les bo ont une possibilit&#233; d'&#234;tre serr&#233;s et apr&#232;s voil&#224; les les les bo comme hier prouvent que
# </Turn>
# <Turn mode="spontaneous" startTime="314.278" endTime="314.868">
# <Sync time="314.278"/>
#
# </Turn>
# <Turn speaker="spk2 spk1" mode="spontaneous" startTime="314.868" endTime="316.273">
# <Sync time="314.868"/>
# <Who nb="1"/>
# bah euh &#231;a s- fin
# <Who nb="2"/>
# mmh on est pas au bout de nos surprises
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="316.273" endTime="319.947">
# <Sync time="316.273"/>
# voil&#224; on est pas vraiment au bout de nos surprises parce que hier je pensais que le bureau bo serait tr&#232;s disput&#233; et que
# </Turn>
# <Turn mode="spontaneous" startTime="319.947" endTime="320.282">
# <Sync time="319.947"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="320.282" endTime="323.083">
# <Sync time="320.282"/>
# finalement Longzhu finirait par l'emporter ils ont j- ils sont jamais vraiment rentr&#233;s dedans
# </Turn>
# <Turn mode="spontaneous" startTime="323.083" endTime="323.518">
# <Sync time="323.083"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="323.518" endTime="328.038">
# <Sync time="323.518"/>
# SKT peut ils ont pas de
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke factor/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  &#231;a n'existe pas de choke fa- parce qu'il y a Peanut qui peut
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  y a Huni qui peut
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  mais
# </Turn>
# <Turn mode="spontaneous" startTime="328.038" endTime="328.529">
# <Sync time="328.038"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="328.529" endTime="332.277">
# <Sync time="328.529"/>
# bon SKT en soi en tant qu'&#233;quipe chockera jamais parce que Faker
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  jamais et Kkoma non plus
# </Turn>
# <Turn mode="spontaneous" startTime="332.277" endTime="332.459">
# <Sync time="332.277"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="332.459" endTime="337.155">
# <Sync time="332.459"/>
# c'est pas le m&#234;me
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  c'est &#224; dire que ils peuvent avoir une baisse de performance pendant la saison pour un manqe de travail etcetera et de fatigue
# </Turn>
# <Turn mode="spontaneous" startTime="337.155" endTime="337.47">
# <Sync time="337.155"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="337.47" endTime="341.615">
# <Sync time="337.47"/>
# mais une fois qu'ils sont dans leur rythme et qu'ils sont en pleine vitesse g&#233;n&#233;ralement ils ralentissent jamais
# </Turn>
# <Turn mode="spontaneous" startTime="341.615" endTime="342.512">
# <Sync time="341.615"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="342.512" endTime="346.362">
# <Sync time="342.512"/>
# donc j'aurai tendance &#224; penser que euh parce que moi je pensais je j'aurai tendance &#224; penser que
# </Turn>
# <Turn mode="spontaneous" startTime="346.362" endTime="346.941">
# <Sync time="346.362"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="346.941" endTime="352.987">
# <Sync time="346.941"/>
# ce serait a vraiment bien que Misfits rentre vraiment bien dans la
# <Event desc="en" type="language" extent="begin"/>
# /game/
# <Event desc="en" type="language" extent="end"/>
#  par exemple que SKT tente une
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  sans
# <Event desc="en" type="language" extent="begin"/>
# /push/
# <Event desc="en" type="language" extent="end"/>
#  comme ils en ont fait quelques unes avec les Fizz euh Fizz Twitch comme on le voit l&#224;
# </Turn>
# <Turn mode="spontaneous" startTime="352.987" endTime="353.554">
# <Sync time="352.987"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="353.554" endTime="356.984">
# <Sync time="353.554"/>
# et derri&#232;re voir euh voir si Misfits peut prendre une
# <Event desc="en" type="language" extent="begin"/>
# /game/
# <Event desc="en" type="language" extent="end"/>
#  voir deux
# </Turn>
# <Turn mode="spontaneous" startTime="356.984" endTime="357.313">
# <Sync time="356.984"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="357.313" endTime="359.138">
# <Sync time="357.313"/>
# pour qu'on ait un bo qui nous raconte une belle histoire
# </Turn>
# <Turn mode="spontaneous" startTime="359.138" endTime="359.544">
# <Sync time="359.138"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="359.544" endTime="359.979">
# <Sync time="359.544"/>
# mais faut bien &#234;tre
# </Turn>
# <Turn mode="spontaneous" startTime="359.979" endTime="360.349">
# <Sync time="359.979"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="360.349" endTime="361.385">
# <Sync time="360.349"/>
# convaincu d'un truc c'est que
# </Turn>
# <Turn mode="spontaneous" startTime="361.385" endTime="362.299">
# <Sync time="361.385"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="362.299" endTime="364.963">
# <Sync time="362.299"/>
# euh si si Misfits leur porte aujourd'hui ils auront fait ce que aucune &#233;quipe
# </Turn>
# <Turn mode="spontaneous" startTime="364.963" endTime="365.213">
# <Sync time="364.963"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="365.213" endTime="366.595">
# <Sync time="365.213"/>
# dans l'histoire de LOL n'a jamais r&#233;ussi &#224; faire
# </Turn>
# <Turn mode="spontaneous" startTime="366.595" endTime="366.893">
# <Sync time="366.595"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="366.893" endTime="367.186">
# <Sync time="366.893"/>
# c'est &#231;a
# </Turn>
# <Turn mode="spontaneous" startTime="367.186" endTime="367.49">
# <Sync time="367.186"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="367.49" endTime="372.407">
# <Sync time="367.49"/>
# m(ais) leur performance en soi pour l'instant est largement satisfaisante de la part de tous les joueurs c'est pas comme
# </Turn>
# <Turn mode="spontaneous" startTime="372.407" endTime="373.012">
# <Sync time="372.407"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="373.012" endTime="377.554">
# <Sync time="373.012"/>
#  Gdeux ou m&#234;me TSM ou m&#234;me la euh la totalit&#233; des
# <Event desc="en" type="language" extent="begin"/>
# /seed/
# <Event desc="en" type="language" extent="end"/>
#  un qui partent en se disant qu'ils auraient pu faire plus
# </Turn>
# <Turn mode="spontaneous" startTime="377.554" endTime="377.838">
# <Sync time="377.554"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="377.838" endTime="380.588">
# <Sync time="377.838"/>
# le parcours de Misfits est euh ab- comment dire euh admirable quoi qu'il arrive
# </Turn>
# <Turn mode="spontaneous" startTime="380.588" endTime="381.221">
# <Sync time="380.588"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="381.221" endTime="387.733">
# <Sync time="381.221"/>
# ah oui oui toute fa&#231;on euh d&#233;j&#224; le fait simple fait qu'il soit pass&#233; d(e)
# <Event desc="en" type="language" extent="begin"/>
# /challenger/
# <Event desc="en" type="language" extent="end"/>
#  euh l'ann&#233;e derni&#232;re euh &#224; quart de finale
# </Turn>
# <Turn mode="spontaneous" startTime="387.733" endTime="388.176">
# <Sync time="387.733"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="388.176" endTime="391.51">
# <Sync time="388.176"/>
# c'est euh c'est exceptionnel y avait que Origen qui l'avait fait ils &#233;taient euh
# </Turn>
# <Turn mode="spontaneous" startTime="391.51" endTime="391.831">
# <Sync time="391.51"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="391.831" endTime="393.1">
# <Sync time="391.831"/>
# ils &#233;taient constitu&#233; de v&#233;t&#233;rans
# </Turn>
# <Turn mode="spontaneous" startTime="393.1" endTime="393.512">
# <Sync time="393.1"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="393.512" endTime="395.399">
# <Sync time="393.512"/>
# l&#224; on a vraiment euh on a vraiment des
# <Event desc="en" type="language" extent="begin"/>
# /rookie/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn mode="spontaneous" startTime="395.399" endTime="395.87">
# <Sync time="395.399"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="395.87" endTime="398.631">
# <Sync time="395.87"/>
# euh apr&#232;s voil&#224; c'est pour (euh) pour Misfits
# </Turn>
# <Turn mode="spontaneous" startTime="398.631" endTime="399.145">
# <Sync time="398.631"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="399.145" endTime="405.309">
# <Sync time="399.145"/>
# euh &#231;a va &#234;tre dur d'ailleurs ce qui est bien c'est que Hans Sama r&#233;clamait de jouer contre Bang &#231;a veut dire que y a un an et demi il faisait des des Lyon
# <Event desc="en" type="language" extent="begin"/>
# /e-sport/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn mode="spontaneous" startTime="405.309" endTime="405.562">
# <Sync time="405.309"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="405.562" endTime="408.55">
# <Sync time="405.562"/>
# et maintenant il affronte son idole donc euh va y avoir quelque chose &#224; faire sur la dur&#233;e
# </Turn>
# <Turn mode="spontaneous" startTime="408.55" endTime="408.945">
# <Sync time="408.55"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="408.945" endTime="412.109">
# <Sync time="408.945"/>
# mais par contre euh effectivement je pense que SKT a montr&#233; des faiblesses
# </Turn>
# <Turn mode="spontaneous" startTime="412.109" endTime="412.317">
# <Sync time="412.109"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="412.317" endTime="413.12">
# <Sync time="412.317"/>
# alors c'est peut-&#234;tre pire
# </Turn>
# <Turn mode="spontaneous" startTime="413.12" endTime="413.398">
# <Sync time="413.12"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="413.398" endTime="414.329">
# <Sync time="413.398"/>
# que de finir en six z&#233;ro
# </Turn>
# <Turn mode="spontaneous" startTime="414.329" endTime="414.525">
# <Sync time="414.329"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="414.525" endTime="417.513">
# <Sync time="414.525"/>
# parce que Longzhu a pas montr&#233; de faiblesses quasiment pendant la phase de groupe
# </Turn>
# <Turn mode="spontaneous" startTime="417.513" endTime="417.857">
# <Sync time="417.513"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="417.857" endTime="419.154">
# <Sync time="417.857"/>
# et d'ailleurs c'est lamentablement &#233;chou&#233;
# </Turn>
# <Turn mode="spontaneous" startTime="419.154" endTime="419.5">
# <Sync time="419.154"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="419.5" endTime="421.893">
# <Sync time="419.5"/>
# euh SKT on le suit dans les
# <Event desc="en" type="language" extent="begin"/>
# /interview/
# <Event desc="en" type="language" extent="end"/>
#  ils savent
# </Turn>
# <Turn startTime="421.893" endTime="422.202">
# <Sync time="421.893"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="422.202" endTime="422.924">
# <Sync time="422.202"/>
# qu'en
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="422.924" endTime="423.404">
# <Sync time="422.924"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="423.404" endTime="423.994">
# <Sync time="423.404"/>
# y a des trous
# </Turn>
# <Turn startTime="423.994" endTime="424.092">
# <Sync time="423.994"/>
#
# </Turn>
# <Turn startTime="424.092" endTime="426.063">
# <Sync time="424.092"/>
# ils savent qu'en
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#  c'est friable
# <Sync time="425.861"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="426.063" endTime="430.114">
# <Sync time="426.063"/>
# et &#224; mon avis ils ont ultra boss&#233; &#231;a donc je suis m&#234;me pas s&#251;r en fait que cette petite porte d'entr&#233;e
# </Turn>
# <Turn startTime="430.114" endTime="430.499">
# <Sync time="430.114"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="430.499" endTime="431.858">
# <Sync time="430.499"/>
# soit encore disponible pour les Misfits hein
# </Turn>
# <Turn speaker="spk1" startTime="431.858" endTime="434.402">
# <Sync time="431.858"/>
# on reviendra euh plus tard sur le cas SKT puisque y a
# </Turn>
# <Turn startTime="434.402" endTime="434.76">
# <Sync time="434.402"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="434.76" endTime="440.134">
# <Sync time="434.76"/>
# plusieurs choses qui rentrent en compte notamment au niveau des performances des joueurs tu parlais d'Hans Sama j'aimerai qu'on se concentre euh sur lui aujourd'hui
# </Turn>
# <Turn startTime="440.134" endTime="440.569">
# <Sync time="440.134"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="440.569" endTime="443.246">
# <Sync time="440.569"/>
# puisque c'est notre grand /rookie/ de de la comp&#233;tition
# </Turn>
# <Turn startTime="443.246" endTime="443.533">
# <Sync time="443.246"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="443.533" endTime="443.997">
# <Sync time="443.533"/>
# fran&#231;ais
# </Turn>
# <Turn startTime="443.997" endTime="444.335">
# <Sync time="443.997"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="444.335" endTime="444.804">
# <Sync time="444.335"/>
# de sourcoit
# </Turn>
# <Turn startTime="444.804" endTime="445.279">
# <Sync time="444.804"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="445.279" endTime="451.413">
# <Sync time="445.279"/>
# comme tu le disais y a un y a un petit plus d'un an il &#233;tait aux Lyon /e-sport/ il faisait (son) parcours chez Mill&#233;nium il est rentr&#233; en /challenger series/
# </Turn>
# <Turn startTime="451.413" endTime="452.074">
# <Sync time="451.413"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="452.074" endTime="457.334">
# <Sync time="452.074"/>
# (et) l&#224; cette ann&#233;e il arrive et et aujourd'hui il est tr&#232;s content de pouvoir jouer contre son idole Bang justement
# </Turn>
# <Turn startTime="457.334" endTime="457.415">
# <Sync time="457.334"/>
#
# <Event desc="bb" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn startTime="457.415" endTime="457.724">
# <Sync time="457.415"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="457.724" endTime="461.75">
# <Sync time="457.724"/>
# bah y a un(e) un adage qui dit que le que le succ&#232;s c'est quand tes idoles deviennent tes rivaux
# </Turn>
# <Turn startTime="461.75" endTime="461.943">
# <Sync time="461.75"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="461.943" endTime="465.307">
# <Sync time="461.943"/>
# euh je pense que c'est tr&#232;s tr&#232;s bien euh applicable euh au cas de Hans Sama
# </Turn>
# <Turn startTime="465.307" endTime="466.02">
# <Sync time="465.307"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="466.02" endTime="467.171">
# <Sync time="466.02"/>
# Hans Sama euh il a
# </Turn>
# <Turn startTime="467.171" endTime="468.079">
# <Sync time="467.171"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="468.079" endTime="473.712">
# <Sync time="468.079"/>
# beaucoup encore de de d&#233;faut en tant que joueur mais l'avantage c'est qu'on progresse beaucoup plus vite quand on joue contre des joueurs qui s(ont) sensiblement plus fort que lui
# </Turn>
# <Turn startTime="473.712" endTime="474.198">
# <Sync time="473.712"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="474.198" endTime="480.027">
# <Sync time="474.198"/>
# (euh) &#231;a a d&#233;j&#224; &#233;t&#233; le cas quand il jouait contre Rekkles ou Zven ont peut-&#234;tre plus d'exp&#233;rience il est arriv&#233; &#224; leur niveau je pense qu'on tous cas dans ces /worlds/
# </Turn>
# <Turn startTime="480.027" endTime="480.482">
# <Sync time="480.027"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="480.482" endTime="482.976">
# <Sync time="480.482"/>
# il a fait une performance qui n'a rien &#224; envier &#224; ses alter ego europ&#233;ens
# </Turn>
# <Turn startTime="482.976" endTime="483.415">
# <Sync time="482.976"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="483.415" endTime="487.447">
# <Sync time="483.415"/>
# il va jou&#233; contre un des bases de fin de l'ADC hein je pense que Pray Bang et Deft
# </Turn>
# <Turn startTime="487.447" endTime="487.8">
# <Sync time="487.447"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="487.8" endTime="489.963">
# <Sync time="487.8"/>
# avec Ruler qui l'a montr&#233; aussi hier font patie vraiment des
# </Turn>
# <Turn startTime="489.963" endTime="490.387">
# <Sync time="489.963"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="490.387" endTime="493.951">
# <Sync time="490.387"/>
# des ADC cor&#233;ens monstrueux avec Uzi qu'il faut pas oublier en Chine qui pour l'instant est dans la forme de sa vie
# </Turn>
# <Turn startTime="493.951" endTime="494.58">
# <Sync time="493.951"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="494.58" endTime="496.873">
# <Sync time="494.58"/>
# je dirai qu'il a des d&#233;fauts comme peut-&#234;tre sa polyvalence
# </Turn>
# <Turn startTime="496.873" endTime="497.024">
# <Sync time="496.873"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="497.024" endTime="499.963">
# <Sync time="497.024"/>
# euh en terme de /draft/ si jamais SKT par exemple d&#233;cide de de priorit&#233;
# </Turn>
# <Turn startTime="499.963" endTime="500.203">
# <Sync time="499.963"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="500.203" endTime="502.397">
# <Sync time="500.203"/>
# prioriser le /pick/ Xayah il peut se retrouver dans une situation difficile
# </Turn>
# <Turn startTime="502.397" endTime="502.803">
# <Sync time="502.397"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="502.803" endTime="505.987">
# <Sync time="502.803"/>
# maintenant euh d'un point de vue m&#233;canique et vu que c'est un joueur qu'est docile
# </Turn>
# <Turn startTime="505.987" endTime="506.381">
# <Sync time="505.987"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="506.381" endTime="506.553">
# <Sync time="506.381"/>
# qui est
# </Turn>
# <Turn startTime="506.553" endTime="506.969">
# <Sync time="506.553"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="506.969" endTime="509.04">
# <Sync time="506.969"/>
# assez faible en &#233;go et qui est tr&#232;s travailleur
# </Turn>
# <Turn startTime="509.04" endTime="509.408">
# <Sync time="509.04"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="509.408" endTime="511.119">
# <Sync time="509.408"/>
# mais il a tendance &#224; r&#233;pondre pr&#233;sent dans les grands moments
# </Turn>
# <Turn startTime="511.119" endTime="511.468">
# <Sync time="511.119"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="511.468" endTime="517.122">
# <Sync time="511.468"/>
# et il a perdu un peu ce /choke factor/ que je lui trouvais l'ann&#233;e derni&#232;re notamment lors la qualification de Misfits en LCS o&#249; il &#233;tait il avait &#233;t&#233; tr&#232;s assez mauvais sur sa civi&#232;re
# </Turn>
# <Turn startTime="517.122" endTime="517.596">
# <Sync time="517.122"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="517.596" endTime="518.817">
# <Sync time="517.596"/>
# ah l&#224; il est il sait r&#233;pondre pr&#233;sent donc
# </Turn>
# <Turn startTime="518.817" endTime="519.17">
# <Sync time="518.817"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="519.17" endTime="521.943">
# <Sync time="519.17"/>
# moi je sais pas j- peut-&#234;tre l'avis de Noi aussi euh sur le sujet mais je pense que Hans sama
# </Turn>
# <Turn startTime="521.943" endTime="522.336">
# <Sync time="521.943"/>
#
# </Turn>
# <Turn speaker="spk2 spk1" startTime="522.336" endTime="525.349">
# <Sync time="522.336"/>
# <Who nb="1"/>
# c'est pas vraiment quelqu'un sur qui je peux je peux stresser aujourd'hui je pense qu'il va r&#233;pondre pr&#233;sent
# <Who nb="2"/>
# oui
# </Turn>
# <Turn speaker="spk1" startTime="525.349" endTime="531.418">
# <Sync time="525.349"/>
# c'est euh c'est l&#224; dessus que je voulais rebondir justement on on il a il tremblait un peu lors de la qualification c'est contre Origen si euh je me rappelle bien
# </Turn>
# <Turn startTime="531.418" endTime="532.386">
# <Sync time="531.418"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="532.386" endTime="536.696">
# <Sync time="532.386"/>
# on avait des doutes sur sa capacit&#233; &#224; rebondir en LCS au final il a fait un parcours admirable est-ce que on
# </Turn>
# <Turn startTime="536.696" endTime="537.057">
# <Sync time="536.696"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="537.057" endTime="538.347">
# <Sync time="537.057"/>
# peut s'attendre &#224; ce qu'il euh
# </Turn>
# <Turn startTime="538.347" endTime="538.935">
# <Sync time="538.347"/>
#
# </Turn>
# <Turn speaker="spk1 spk3" startTime="538.935" endTime="540.124">
# <Sync time="538.935"/>
# <Who nb="1"/>
# il arrive au niveau aujourd'hui parce que
# <Who nb="2"/>
# en fait y a
# </Turn>
# <Turn speaker="spk1" startTime="540.124" endTime="541.445">
# <Sync time="540.124"/>
# quand on regarde les stat du joueurs en fait elles sont
# </Turn>
# <Turn startTime="541.445" endTime="541.876">
# <Sync time="541.445"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="541.876" endTime="544.719">
# <Sync time="541.876"/>
# vraiment int&#233;ressantes et il se classe parmis les meilleurs ADC des /worlds/
# </Turn>
# <Turn startTime="544.719" endTime="544.912">
# <Sync time="544.719"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="544.912" endTime="547.12">
# <Sync time="544.912"/>
# <Who nb="1"/>
# en fait pour moi ce qui est bien c'est que au contraire
# <Who nb="2"/>
# &#224; l'heure qu'il est
# </Turn>
# <Turn startTime="547.12" endTime="547.339">
# <Sync time="547.12"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="547.339" endTime="552.36">
# <Sync time="547.339"/>
# le le fait de tomber sur SKT chand- euh triple champion du monde euh deux fois de suite peut-&#234;tre un troisi&#232;me
# </Turn>
# <Turn startTime="552.36" endTime="552.639">
# <Sync time="552.36"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="552.639" endTime="553.383">
# <Sync time="552.639"/>
# d'&#234;tre l'/underdogs/
# </Turn>
# <Turn startTime="553.383" endTime="553.622">
# <Sync time="553.383"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="553.622" endTime="554.014">
# <Sync time="553.622"/>
# c'est qu'y a
# </Turn>
# <Turn startTime="554.014" endTime="554.276">
# <Sync time="554.014"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="554.276" endTime="554.856">
# <Sync time="554.276"/>
# absolument
# </Turn>
# <Turn startTime="554.856" endTime="555.133">
# <Sync time="554.856"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="555.133" endTime="559.127">
# <Sync time="555.133"/>
# z&#233;ro pression ils peuvent se faire d&#233;monter trois z&#233;ro vingt minutes vingt minutes vingt minutes
# </Turn>
# <Turn startTime="559.127" endTime="559.503">
# <Sync time="559.127"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="559.503" endTime="560.118">
# <Sync time="559.503"/>
# c'est SKT
# </Turn>
# <Turn startTime="560.118" endTime="560.33">
# <Sync time="560.118"/>
#
# </Turn>
# <Turn startTime="560.33" endTime="561.493" speaker="spk3">
# <Sync time="560.33"/>
# contre une &#233;quipe qui &#233;tait l&#224; en /challenger/
# </Turn>
# ...
# <Sync time="1137.369"/>
# apr&#232;s (euh) le le Rakan il peut &#234;tre euh il peut &#234;tre puni ou alors peut y avoir une tentative de de punition
# </Turn>
# <Turn startTime="1142.346" endTime="1142.597">
# <Sync time="1142.346"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1142.597" endTime="1150.726">
# <Sync time="1142.597"/>
# donc moi mettre Hans Sama si tout le monde euh je me souviens parfaitement de sa
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  o&#249; euh vz- tout le monde &#233;tait en train de s'arrancher les cheveux derri&#232;re mais pourquoi cette
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  et j'&#233;tais l&#224; mais non moi j'aime bien euh Xayah euh
# </Turn>
# <Turn startTime="1150.726" endTime="1150.962">
# <Sync time="1150.726"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1150.962" endTime="1151.71">
# <Sync time="1150.962"/>
# parce que Hans Sama alors
# </Turn>
# <Turn startTime="1151.71" endTime="1151.996">
# <Sync time="1151.71"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1151.996" endTime="1152.619">
# <Sync time="1151.996"/>
# dans la logique
# </Turn>
# <Turn startTime="1152.619" endTime="1152.924">
# <Sync time="1152.619"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1152.924" endTime="1154.732">
# <Sync time="1152.924"/>
# on fait avec ce qu'on a et dans la r&#233;alit&#233; des choses
# </Turn>
# <Turn startTime="1154.732" endTime="1155.131">
# <Sync time="1154.732"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1155.131" endTime="1156.439">
# <Sync time="1155.131"/>
# euh Hans Sama a besoin
# </Turn>
# <Turn startTime="1156.439" endTime="1156.549">
# <Sync time="1156.439"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1156.549" endTime="1162.721">
# <Sync time="1156.549"/>
# euh un petit
# <Event desc="en" type="language" extent="begin"/>
# /pull/
# <Event desc="en" type="language" extent="end"/>
#  d'ADC et a besoin d'&#234;tre euh d'&#234;tre sur l'un deux pour &#234;tre vraiment efficace donc Xayah en fait partie Varus en fait partie par exemple
# </Turn>
# <Turn startTime="1162.721" endTime="1163.223">
# <Sync time="1162.721"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1163.223" endTime="1166.026">
# <Sync time="1163.223"/>
# euh donc avoir Xayah et apr&#232;s avoir un Ignard
# </Turn>
# <Turn startTime="1166.026" endTime="1166.148">
# <Sync time="1166.026"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1166.148" endTime="1168.94">
# <Sync time="1166.148"/>
# qui peut tr&#232;s bien contrer avec du Blitzcrank ou avec du Thresh
# </Turn>
# <Turn startTime="1168.94" endTime="1169.254">
# <Sync time="1168.94"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1169.254" endTime="1170.754">
# <Sync time="1169.254"/>
# pour mettre beaucoup de pression en
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="1170.754" endTime="1171.146">
# <Sync time="1170.754"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1171.146" endTime="1172.074">
# <Sync time="1171.146"/>
# moi c'est quelque chose
# </Turn>
# <Turn startTime="1172.074" endTime="1172.688">
# <Sync time="1172.074"/>
#
# </Turn>
# <Turn startTime="1172.688" endTime="1174.102" speaker="spk3">
# <Sync time="1172.688"/>
# que j'aimerai voir se qu'a tent&#233; Longzhu hier
# </Turn>
# <Turn startTime="1174.102" endTime="1174.381">
# <Sync time="1174.102"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1174.381" endTime="1175.72">
# <Sync time="1174.381"/>
# hier euh Longzhu notamment du c&#244;t&#233;
# </Turn>
# <Turn speaker="spk3 spk2" startTime="1175.72" endTime="1177.034">
# <Sync time="1175.72"/>
# <Who nb="1"/>
# de XX on a tent&#233; euh
# <Who nb="2"/>
# quelle efficacit&#233; d'ailleurs
# </Turn>
# <Turn speaker="spk2" startTime="1177.034" endTime="1177.568">
# <Sync time="1177.034"/>
# de cette
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="1177.568" endTime="1177.636">
# <Sync time="1177.568"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1177.636" endTime="1177.927">
# <Sync time="1177.636"/>
# ouais
# </Turn>
# <Turn startTime="1177.927" endTime="1178.793">
# <Sync time="1177.927"/>
#
# <Event desc="b" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1178.793" endTime="1182.221">
# <Sync time="1178.793"/>
# c'est parce qu'il y a aussi une sejl- euh une Sej- eht Tristana qu'a &#233;t&#233; laiss&#233;e trois fois de suite on peut pas
# </Turn>
# <Turn speaker="spk3 spk1" startTime="1182.221" endTime="1182.826">
# <Sync time="1182.221"/>
# <Who nb="1"/>
# estamputer (???) un
# <Who nb="2"/>
# ah oui
# </Turn>
# <Turn speaker="spk3 spk1" startTime="1182.826" endTime="1183.44">
# <Sync time="1182.826"/>
# <Who nb="1"/>
# pic de Tresh
#
# <Who nb="2"/>
# &#231;a arrive
# </Turn>
# <Turn speaker="spk2 spk2" startTime="1183.44" endTime="1183.778">
# <Sync time="1183.44"/>
# <Who nb="1"/>
# toute fa&#231;on euh
#
# <Who nb="2"/>
# oui
# </Turn>
# <Turn speaker="spk2" startTime="1183.778" endTime="1189.39">
# <Sync time="1183.778"/>
# c'est c'est c'est Sej- Tristana c'est c'est c'est massivement pic et au &#231;a en
# <Event desc="en" type="language" extent="begin"/>
# /mid lane/
# <Event desc="en" type="language" extent="end"/>
#  de de cent pour cent on pas sur de Janna Gragas ou quoi que ce soit donc
# </Turn>
# <Turn startTime="1189.39" endTime="1189.904">
# <Sync time="1189.39"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1189.904" endTime="1189.995">
# <Sync time="1189.904"/>
# muh
# </Turn>
# <Turn startTime="1189.995" endTime="1190.272">
# <Sync time="1189.995"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1190.272" endTime="1190.559">
# <Sync time="1190.272"/>
# fin
# </Turn>
# <Turn startTime="1190.559" endTime="1190.76">
# <Sync time="1190.559"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1190.76" endTime="1196.897">
# <Sync time="1190.76"/>
# moi je peux pas dire que la
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  euh Samsung elle &#233;t&#233; op&#233;e tu vois juste ils avaient une
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  en face bah on prend des Tresh au lieu de prendre des encensoirs &#224; dents alors qu'on a des Rakan
# </Turn>
# <Turn startTime="1196.897" endTime="1197.336">
# <Sync time="1196.897"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1197.336" endTime="1198.561">
# <Sync time="1197.336"/>
# et on prend des Rakan contre des Taric
# </Turn>
# <Turn speaker="spk3" startTime="1198.561" endTime="1200.876">
# <Sync time="1198.561"/>
# mais je p- mais je pense pas que Tresh s(oit) soit injouable dans la m&#233;ta hein
# </Turn>
# <Turn startTime="1200.876" endTime="1201.032">
# <Sync time="1200.876"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1201.032" endTime="1202.512">
# <Sync time="1201.032"/>
# c'est c'est c'est tout &#224; fait jouable
# </Turn>
# <Turn startTime="1202.512" endTime="1203.013">
# <Sync time="1202.512"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1203.013" endTime="1203.962">
# <Sync time="1203.013"/>
# quand t'es meilleur que ton adversaire
# </Turn>
# <Turn startTime="1203.962" endTime="1204.972">
# <Sync time="1203.962"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1204.972" endTime="1205.064">
# <Sync time="1204.972"/>
# s-
# </Turn>
# <Turn startTime="1205.064" endTime="1205.382">
# <Sync time="1205.064"/>
#
# <Event desc="bb" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="1205.382" endTime="1206.061">
# <Sync time="1205.382"/>
# <Who nb="1"/>
# l&#224; o&#249; ils ont mal jou&#233;
# <Who nb="2"/>
# quand t'arrives &#224;
# </Turn>
# <Turn speaker="spk1" startTime="1206.061" endTime="1207.601">
# <Sync time="1206.061"/>
# faire la diff&#233;rence en
# <Event desc="en" type="language" extent="begin"/>
# /lanes/
# <Event desc="en" type="language" extent="end"/>
#  qui
# </Turn>
# <Turn speaker="spk1 spk3" startTime="1207.601" endTime="1209.433">
# <Sync time="1207.601"/>
# <Who nb="1"/>
# n'a pas vraiment &#233;t&#233; l&#224; pour XXX
# <Who nb="2"/>
# ouais et l&#224; ils ont mal jou&#233; mais apr&#232;s c'est un pari
# </Turn>
# <Turn speaker="spk3" startTime="1209.433" endTime="1212.918">
# <Sync time="1209.433"/>
# que tu gagnes ou que tu ken pas mais euh &#224; euh dire que c'est pas une strat&#233;gie viable pour moi c'est pas le cas
# </Turn>
# <Turn startTime="1212.918" endTime="1213.236">
# <Sync time="1212.918"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1213.236" endTime="1216.638">
# <Sync time="1213.236"/>
# et pour moi au contraire essayer de jouer une strat&#233;gie de
# <Event desc="en" type="language" extent="begin"/>
# /team fight/
# <Event desc="en" type="language" extent="end"/>
#
# <Event desc="en" type="language" extent="begin"/>
# /late game/
# <Event desc="en" type="language" extent="end"/>
#  contre euh SKT
# </Turn>
# <Turn startTime="1216.638" endTime="1216.848">
# <Sync time="1216.638"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1216.848" endTime="1218.332">
# <Sync time="1216.848"/>
# sachant que la seule faiblesse qu'ils ont montr&#233;e
# </Turn>
# <Turn startTime="1218.332" endTime="1218.633">
# <Sync time="1218.332"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1218.633" endTime="1219.547">
# <Sync time="1218.633"/>
# c'est de l'
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="1219.547" endTime="1219.904">
# <Sync time="1219.547"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="1219.904" endTime="1220.34">
# <Sync time="1219.904"/>
# <Who nb="1"/>
# (euh)
# <Who nb="2"/>
# oui
# </Turn>
# <Turn speaker="spk1" startTime="1220.34" endTime="1221.18">
# <Sync time="1220.34"/>
# au niveau de toutes les stats
# </Turn>
# <Turn startTime="1221.18" endTime="1221.489">
# <Sync time="1221.18"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1221.489" endTime="1224.335">
# <Sync time="1221.489"/>
# bah autant profiter alors je pense que ay- malheureusement y aura m&#234;me plus cette faiblesse
# </Turn>
# <Turn startTime="1224.335" endTime="1224.633">
# <Sync time="1224.335"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1224.633" endTime="1226.369">
# <Sync time="1224.633"/>
# mais je pense qu'il faut au moins pour la premi&#232;re game
# </Turn>
# <Turn startTime="1226.369" endTime="1226.713">
# <Sync time="1226.369"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1226.713" endTime="1228.214">
# <Sync time="1226.713"/>
# pour la premi&#232;re game faut au moins tenter le
# <Event desc="en" type="language" extent="begin"/>
# /line pressure/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="1228.214" endTime="1228.34">
# <Sync time="1228.214"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="1228.34" endTime="1231.011">
# <Sync time="1228.34"/>
# c'est la seule fen&#234;tre &#224; saisir est-ce qu'y a d'autres
# <Event desc="toux en fond" type="noise" extent="begin"/>
# faiblesses
# <Event desc="toux en fond" type="noise" extent="end"/>
#  d'SKT &#224; l'heure qu'il est
# </Turn>
# <Turn startTime="1231.011" endTime="1231.494">
# <Sync time="1231.011"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn startTime="1231.494" endTime="1231.49">
#
# <Sync time="1231.341"/>
#
# <Event desc="bb" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn startTime="1231.49" endTime="1231.895">
# <Sync time="1231.49"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1231.895" endTime="1233.096">
# <Sync time="1231.895"/>
# c'est qu'y a une faiblesse
# </Turn>
# <Turn startTime="1233.096" endTime="1233.214">
# <Sync time="1233.096"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1233.214" endTime="1234.18">
# <Sync time="1233.214"/>
# (euh)
# </Turn>
# <Turn startTime="1234.18" endTime="1234.25">
# <Sync time="1234.18"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1234.25" endTime="1235.93">
# <Sync time="1234.25"/>
# de SKT c'est (euh) le top
# </Turn>
# <Turn startTime="1235.93" endTime="1236.261">
# <Sync time="1235.93"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1236.261" endTime="1236.836">
# <Sync time="1236.261"/>
# le
# <Event desc="en" type="language" extent="begin"/>
# /top jungle/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="1236.836" endTime="1237.548">
# <Sync time="1236.836"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1237.548" endTime="1241.698">
# <Sync time="1237.548"/>
# encore une fois je pense que dans toutes les
# <Event desc="en" type="language" extent="begin"/>
# /game/
# <Event desc="en" type="language" extent="end"/>
#  de Misfits c'est quelque chose que sur lequel j'essaie de revenir assez souvent
# </Turn>
# <Turn startTime="1241.698" endTime="1242.22">
# <Sync time="1241.698"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1242.22" endTime="1246.73">
# <Sync time="1242.22"/>
# (euh) Misfits ils ont quelque ils ont un joueur qui sait tout jouer &#224; la
# <Event desc="en" type="language" extent="begin"/>
# /top lane/
# <Event desc="en" type="language" extent="end"/>
#  qui s'appelle Alphari qui pour l'instant est
# </Turn>
# <Turn startTime="1246.73" endTime="1247.437">
# <Sync time="1246.73"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1247.437" endTime="1248.386">
# <Sync time="1247.437"/>
# largement /underrated/
# </Turn>
# <Turn startTime="1248.386" endTime="1248.639">
# <Sync time="1248.386"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1248.639" endTime="1251.006">
# <Sync time="1248.639"/>
# je pense que (son) sa carri&#232;re elle fait que commencer et
# </Turn>
# <Turn startTime="1251.006" endTime="1251.237">
# <Sync time="1251.006"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1251.237" endTime="1254.356">
# <Sync time="1251.237"/>
# je pense qu'il d&#233;tr&#244;nera par exemple p- Odoamn&#233; et Vizicsacsi ou Soaz en en Europe euh
# </Turn>
# <Turn startTime="1254.356" endTime="1254.791">
# <Sync time="1254.356"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1254.791" endTime="1256.832">
# <Sync time="1254.791"/>
# vu vu sa polyvalence et sa compr&#233;hension du jeu
# </Turn>
# <Turn startTime="1256.832" endTime="1257.355">
# <Sync time="1256.832"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1257.355" endTime="1257.708">
# <Sync time="1257.355"/>
#
# </Turn>
# <Turn startTime="1257.708" endTime="1257.813">
# <Sync time="1257.708"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1257.813" endTime="1259.906">
# <Sync time="1257.813"/>
# si Maxlore met l'emphase sur le
# <Event desc="en" type="language" extent="begin"/>
# /top side/
# <Event desc="en" type="language" extent="end"/>
#  et qui
# </Turn>
# <Turn startTime="1259.906" endTime="1260.167">
# <Sync time="1259.906"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1260.167" endTime="1261.951">
# <Sync time="1260.167"/>
# notamment en comptant en en contre d'un pic
# </Turn>
# <Turn startTime="1261.951" endTime="1262.375">
# <Sync time="1261.951"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1262.375" endTime="1263.303">
# <Sync time="1262.375"/>
# euh agressif d'Huni
# </Turn>
# <Turn startTime="1263.303" endTime="1263.701">
# <Sync time="1263.303"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1263.701" endTime="1265.534">
# <Sync time="1263.701"/>
# o&#249; il va essayer de justement de jouer un peu /cocky/
# </Turn>
# <Turn startTime="1265.534" endTime="1265.954">
# <Sync time="1265.534"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1265.954" endTime="1437.466">
# <Sync time="1265.954"/>
# euh un n-
# </Turn>
# </Section>
# </Episode>
# </Trans>

# %%
rootTRS=xmlTRS.getroot()
print etree.tostring(rootTRS)
# Out:
# <Trans scribe="Jean" audio_filename="Preshow - SKT T1 vs Misfits - World Championship 2017 - 14 de finale - League of Legends" version="18" version_date="171124">
# <Speakers>
# <Speaker id="spk1" name="&quot;Bulii&quot; " check="no" dialect="native" accent="" scope="local" type="female"/>
# <Speaker id="spk2" name="Zaboutine" check="no" dialect="native" accent="" scope="local" type="male"/>
# <Speaker id="spk3" name="Noi" check="no" dialect="native" accent="" scope="local" type="male"/>
# <Speaker id="spk4" name="speaker#4" check="no" dialect="native" accent="" scope="local"/>
# </Speakers>
# <Episode>
# <Section type="report" startTime="0" endTime="1437.466">
# <Turn startTime="0" endTime="34.066">
# <Sync time="0"/>
#
# <Event desc="jingle" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="34.066" endTime="39.514">
# <Sync time="34.066"/>
# bonjour &#224; tous et bienvenue dans ce
# <Event desc="en" type="language" extent="begin"/>
# /preshow/
# <Event desc="en" type="language" extent="end"/>
#  des championnats du monde deux milles dix sept aujourd'hui on continue sur les quarts de finale
# </Turn>
# <Turn startTime="39.514" endTime="39.796">
# <Sync time="39.514"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="39.796" endTime="42.754">
# <Sync time="39.796"/>
# et pour en parler je serai en j- compagnie de Noi et Zaboutine comment allez vous
# </Turn>
# <Turn startTime="42.754" endTime="43.115">
# <Sync time="42.754"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="43.115" endTime="43.506">
# <Sync time="43.115"/>
# &#231;a va tr&#232;s bien
# </Turn>
# <Turn startTime="43.506" endTime="43.735">
# <Sync time="43.506"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="43.735" endTime="47.109">
# <Sync time="43.735"/>
# et bien euh tr&#232;s bien parce que un match euh ma foi qui nous int&#233;resse au plus haut point
# </Turn>
# <Turn startTime="47.109" endTime="47.338">
# <Sync time="47.109"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="47.338" endTime="50.904">
# <Sync time="47.338"/>
# ouais et on a d&#233;j&#224; eu un bo hier avec la qualification assez inattendue
# </Turn>
# <Turn startTime="50.904" endTime="51.14">
# <Sync time="50.904"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="51.14" endTime="52.74">
# <Sync time="51.14"/>
# d(e) Samsung contre Longzhu
# </Turn>
# <Turn startTime="52.74" endTime="53.031">
# <Sync time="52.74"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="53.031" endTime="57.617">
# <Sync time="53.031"/>
# on va revenir bri&#232;vement sur le match euh on bah on s'attendait pas du tout euh de &#231;a de la part de Longzhu
# </Turn>
# <Turn startTime="57.617" endTime="57.912">
# <Sync time="57.617"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="57.912" endTime="59.092">
# <Sync time="57.912"/>
#
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  g&#233;n&#233;ral de la part de l'&#233;quipe
# </Turn>
# <Turn startTime="59.092" endTime="59.727">
# <Sync time="59.092"/>
#
# </Turn>
# <Turn speaker="spk2 spk1" startTime="59.727" endTime="63.056">
# <Sync time="59.727"/>
# <Who nb="1"/>
# boh et &#224; part Jean Twitter euh qui est venu venu nous dire qui l'avait bien dit euh
# <Who nb="2"/>
# oui
# </Turn>
# <Turn startTime="63.056" endTime="63.428">
# <Sync time="63.056"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="63.428" endTime="69.165">
# <Sync time="63.428"/>
# tous les
# <Event desc="en" type="language" extent="begin"/>
# /coach/
# <Event desc="en" type="language" extent="end"/>
#  les p- joueurs qui ont jou&#233; en
# <Event desc="en" type="language" extent="begin"/>
# /scrim/
# <Event desc="en" type="language" extent="end"/>
#  les joueurs qu'on pas jou&#233; en
# <Event desc="en" type="language" extent="begin"/>
# /scrim/
# <Event desc="en" type="language" extent="end"/>
#  les analystes les commentateurs &#233;taient d'accord pour dire que Longzhu etait meilleur
# </Turn>
# <Turn startTime="69.165" endTime="69.686">
# <Sync time="69.165"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="69.686" endTime="74.297">
# <Sync time="69.686"/>
# pis il s'av&#232;re que les les leur
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  &#233;taient un petit peu approximatifs je pense du c&#244;t&#233; de Longzhu puis bah quand on sait pas jouer derri&#232;re aux
# <Event desc="en" type="language" extent="begin"/>
# /worlds/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="74.297" endTime="74.641">
# <Sync time="74.297"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="74.641" endTime="76.725">
# <Sync time="74.641"/>
# g&#233;n&#233;ralement on les gagne pas et &#231;a &#233;t&#233; assez bien montr&#233; je pense
# </Turn>
# <Turn speaker="spk1" startTime="76.725" endTime="78.91">
# <Sync time="76.725"/>
# et a une &#233;quipe qu'&#224; pas assez d'&#233;xp&#233;rience en bo cinq peut-&#234;tre
# </Turn>
# <Turn startTime="78.91" endTime="79.326">
# <Sync time="78.91"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="79.326" endTime="87.181">
# <Sync time="79.326"/>
# y a euh y a un peu de tout &#231;a y a un peu de stress un peu la pression du du
# <Event desc="en" type="language" extent="begin"/>
# /stage/
# <Event desc="en" type="language" extent="end"/>
#  euh moins d'exp&#233;rience euh effectivement les
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  avant tout les
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  euh je dirai mais bon je pense que
# </Turn>
# <Turn startTime="87.181" endTime="87.479">
# <Sync time="87.181"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="87.479" endTime="93.114">
# <Sync time="87.479"/>
# les
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  on bon on sait pas ce qu'il se passe dans la
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  donc peut pas
# <Event desc="en" type="language" extent="begin"/>
# /blame/
# <Event desc="en" type="language" extent="end"/>
#  le
# <Event desc="en" type="language" extent="begin"/>
# /coach/
# <Event desc="en" type="language" extent="end"/>
#  ca peut &#234;tre aussi les joueurs qui se sentaient pas de jouer telle ou telle chose qu'&#233;taient pas en confiance
# </Turn>
# <Turn startTime="93.114" endTime="93.627">
# <Sync time="93.114"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="93.627" endTime="96.363">
# <Sync time="93.627"/>
# mais ouais c'est ma deuxi&#232;me plus grosse d&#233;ception de l'ann&#233;e apr&#232;s KT Rolster quoi
# </Turn>
# <Turn startTime="96.363" endTime="96.793">
# <Sync time="96.363"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="96.793" endTime="98.129">
# <Sync time="96.793"/>
# <Who nb="1"/>
# c'est ch-
# <Event desc="rire" type="noise" extent="instantaneous"/>
#
# <Who nb="2"/>
# oui
# </Turn>
# <Turn speaker="spk1 spk3" startTime="98.129" endTime="98.605">
# <Sync time="98.129"/>
# <Who nb="1"/>
# mais d'un autre
# <Who nb="2"/>
# comment dire
# </Turn>
# <Turn speaker="spk1" startTime="98.605" endTime="109.445">
# <Sync time="98.605"/>
# c&#244;t&#233; alors &#231;a &#231;a m'a rassur&#233;e puisque je me suis dis au moins euh Samsung n'ont pas vol&#233; leur place aux KT puisque Samsung ont admirablement bien jou&#233; ils ont gal&#233;r&#233; toute l'ann&#233;e et hier j'avais vraiment la sensation de retrouver l'&#233;quipe qu'on avait pu voir en en deux milles seize
# </Turn>
# <Turn startTime="109.445" endTime="110.229">
# <Sync time="109.445"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="110.229" endTime="110.573">
# <Sync time="110.229"/>
# bah s-
# </Turn>
# <Turn startTime="110.573" endTime="110.799">
# <Sync time="110.573"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="110.799" endTime="117.426">
# <Sync time="110.799"/>
# c'est une &#233;quipe qui est assez forte en fin d'ann&#233;e en fait qui fini avait panache qui a une euh qui a une fin d'ann&#233;e g&#233;n&#233;ralement faite en
# <Event desc="en" type="language" extent="begin"/>
# /summer split/
# <Event desc="en" type="language" extent="end"/>
#  un peu difficile et qui qui monte en puissance euh
# </Turn>
# <Turn startTime="117.426" endTime="117.846">
# <Sync time="117.426"/>
#
# </Turn>
# <Turn speaker="spk2 spk1" startTime="117.846" endTime="120.686">
# <Sync time="117.846"/>
# <Who nb="1"/>
# je dirai c'est une &#233;quipe qui est pas bonne
# <Who nb="2"/>
# la route a &#233;t&#233; longue pour eux ils en ont tous parl&#233; c'est
# </Turn>
# <Turn speaker="spk2" startTime="120.686" endTime="125.419">
# <Sync time="120.686"/>
# je pense qu'ils savent pas du tout s'adapter &#224; un nouveau
# <Event desc="en" type="language" extent="begin"/>
# /patch/
# <Event desc="en" type="language" extent="end"/>
#  euh mais par contre ils sont tr&#232;s bons pour optimiser un
# <Event desc="en" type="language" extent="begin"/>
# /patch/
# <Event desc="en" type="language" extent="end"/>
#  existant parce qu'ils ont des joueurs d'exp&#233;rience
# </Turn>
# <Turn startTime="125.419" endTime="125.888">
# <Sync time="125.419"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="125.888" endTime="129.776">
# <Sync time="125.888"/>
# et &#231;a s'est vu encore une fois et une bien meilleure compr&#233;hension des conditions de victoire de la m&#233;ta actuelle avec euh
# </Turn>
# <Turn startTime="129.776" endTime="130.217">
# <Sync time="129.776"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="130.217" endTime="134.042">
# <Sync time="130.217"/>
# euh sam- Samsung &#231;a fait pas forc&#233;ment r&#234;ver beaucoup de monde en un point de vue du
# <Event desc="en" type="language" extent="begin"/>
# /game play/
# <Event desc="en" type="language" extent="end"/>
#  parce que c'est vraiment euh
# </Turn>
# <Turn startTime="134.042" endTime="134.375">
# <Sync time="134.042"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="134.375" endTime="137.034">
# <Sync time="134.375"/>
# euh la euh je dirai le manifeste de la de la m&#233;ta g&#233;n&#233;ralement quand ils jouent
# </Turn>
# <Turn startTime="137.034" endTime="137.42">
# <Sync time="137.034"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="137.42" endTime="142.195">
# <Sync time="137.42"/>
# mais g&#233;n&#233;ralement quand tu joues la m&#233;ta t'as cent fois plus de chance de gagner que l'adversaire et c'est ce qui p- franchement &#231;a s'est bien montr&#233; hier quoi
# </Turn>
# <Turn startTime="142.195" endTime="142.376">
# <Sync time="142.195"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="142.376" endTime="147.276">
# <Sync time="142.376"/>
# on va regarder euh le
# <Event desc="en" type="language" extent="begin"/>
# /bracket/
# <Event desc="en" type="language" extent="end"/>
#  pour voir o&#249; nous en sommes aujourd'hui puisque nous continuons ces quarts de finale avec
# </Turn>
# <Turn startTime="147.276" endTime="148.06">
# <Sync time="147.276"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="148.06" endTime="152.949">
# <Sync time="148.06"/>
# Misfits SKT (on) reviendra plus en d&#233;tails euh sur le match toute &#224; l'heure mais
# </Turn>
# <Turn startTime="152.949" endTime="153.702">
# <Sync time="152.949"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="153.702" endTime="156.376">
# <Sync time="153.702"/>
# on aura peut-&#234;tre plus qu'une &#233;quipe europ&#233;enne &#224; la fin de de cette matin&#233;e
# </Turn>
# <Turn startTime="156.376" endTime="157.513">
# <Sync time="156.376"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="157.513" endTime="162.503">
# <Sync time="157.513"/>
# bouah et non on aura qu'une s- ch- s- XXX peut-&#234;tre il est il est cool tu vois c'est bien pour l'espoir et tout
# </Turn>
# <Turn startTime="162.503" endTime="163.02">
# <Sync time="162.503"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="163.02" endTime="166.353">
# <Sync time="163.02"/>
# boh c'est le boss de fin euh SKT ils ont jamais perdu un bo cinq aux
# <Event desc="en" type="language" extent="begin"/>
# /worlds/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="166.353" endTime="166.78">
# <Sync time="166.353"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="166.78" endTime="170.134">
# <Sync time="166.78"/>
# ils ont gagn&#233; tous les
# <Event desc="en" type="language" extent="begin"/>
# /worlds/
# <Event desc="en" type="language" extent="end"/>
#  dans lesquels ils ont particip&#233; leur plus grand adversaire Longzhu est
# <Event desc="en" type="language" extent="begin"/>
# /out/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="170.134" endTime="171.356">
# <Sync time="170.134"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="171.356" endTime="172.511">
# <Sync time="171.356"/>
# &#231;a commence &#224; sentir bon quoi
# </Turn>
# <Turn startTime="172.511" endTime="173.17">
# <Sync time="172.511"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="173.17" endTime="179.961">
# <Sync time="173.17"/>
# b(en) pour moi c'est euh malheureusement hein euh faut &#234;tre honn&#234;te pour moi la vic- euh la la victoire de Samsung alors mis &#224; part le fait que j'aime Longzhu et que j'aime pas Samsung
# </Turn>
# <Turn startTime="179.961" endTime="180.326">
# <Sync time="179.961"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="180.326" endTime="185.49">
# <Sync time="180.326"/>
# <Who nb="1"/>
# pour moi &#231;a tue un petit peu la
# <Event desc="en" type="language" extent="begin"/>
# /hype/
# <Event desc="en" type="language" extent="end"/>
#  parce que &#231;a sent &#231;a sent tr&#232;s fort le
# <Event desc="en" type="language" extent="begin"/>
# /remake/
# <Event desc="en" type="language" extent="end"/>
#  euh deux mille seize
# <Who nb="2"/>
# XXX
# </Turn>
# <Turn speaker="spk3" startTime="185.49" endTime="189.983">
# <Sync time="185.49"/>
# sauf que je suis m&#234;me pas s&#251;r que Samsung puisse amener euh les SKT sur un bo cinq
# </Turn>
# <Turn startTime="189.983" endTime="190.552">
# <Sync time="189.983"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="190.552" endTime="195.126">
# <Sync time="190.552"/>
# euh l'effondrement de Longzhu (euh) pour moi p&#232;te un petit peu un petit peu de chose par la suite
# </Turn>
# <Turn startTime="195.126" endTime="195.466">
# <Sync time="195.126"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="195.466" endTime="198.782">
# <Sync time="195.466"/>
# donc euh je vais tout parier sur les &#233;quipes chinoises mais &#231;a c'est pour u- une autre journ&#233;e
# </Turn>
# <Turn startTime="198.782" endTime="199.191">
# <Sync time="198.782"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="199.191" endTime="202.767">
# <Sync time="199.191"/>
# apr&#232;s ouais pour rejoindre Zab euh bah moi j'ai mis trois z&#233;ro hein SKT Misfits je vois pas comment
# </Turn>
# <Turn startTime="202.767" endTime="203.243">
# <Sync time="202.767"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="203.243" endTime="203.677">
# <Sync time="203.243"/>
# et pourtant
# </Turn>
# <Turn startTime="203.677" endTime="204.225">
# <Sync time="203.677"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="204.225" endTime="205.197">
# <Sync time="204.225"/>
# Misfits est euh
# </Turn>
# <Turn startTime="205.197" endTime="205.523">
# <Sync time="205.197"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="205.523" endTime="209.854">
# <Sync time="205.523"/>
# <Who nb="1"/>
# excellent euh genre jamais on aurait cru qu'ils puissent aller aussi loin mais je vois pas comment ils prennent SKT
# <Who nb="2"/>
# mmh
# </Turn>
# <Turn startTime="209.854" endTime="210.007">
# <Sync time="209.854"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="210.007" endTime="214.165">
# <Sync time="210.007"/>
# justement on a une vid&#233;o qui (euh) r&#233;capitule leur deuxi&#232;me semaine puisque &#231;a s'est jou&#233; &#224; peu
# </Turn>
# <Turn startTime="214.165" endTime="214.644">
# <Sync time="214.165"/>
#
# </Turn>
# <Turn speaker="spk1 spk2" startTime="214.644" endTime="218.719">
# <Sync time="214.644"/>
# <Who nb="1"/>
# &#231;a s'est jou&#233; (euh) sur un
# <Event desc="en" type="language" extent="begin"/>
# /tiebreak/
# <Event desc="en" type="language" extent="end"/>
#  si je raconte pas (de) b&#234;tises
# <Who nb="2"/>
#
# <Event desc="en" type="language" extent="begin"/>
# /tiebreak/
# <Event desc="en" type="language" extent="end"/>
#  contre TSM
# </Turn>
# <Turn startTime="218.719" endTime="218.883">
# <Sync time="218.719"/>
#
# </Turn>
# <Turn speaker="spk1 spk2" startTime="218.883" endTime="221.599">
# <Sync time="218.883"/>
# <Who nb="1"/>
# c'est &#231;a
# <Who nb="2"/>
# euh qu'il gagne euh avec un peu de peur au ventre
# </Turn>
# <Turn startTime="221.599" endTime="222.123">
# <Sync time="221.599"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="222.123" endTime="228.528">
# <Sync time="222.123"/>
# une deuxi&#232;me semaine des Misfits qui &#233;tait euh somme toute int&#233;ressante mais pas non plus extraordinaire notamment euh contre
# <Event desc="en" type="language" extent="begin"/>
# /team/
# <Event desc="en" type="language" extent="end"/>
#  WE
# </Turn>
# <Turn startTime="228.528" endTime="229.059">
# <Sync time="228.528"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="229.059" endTime="234.216">
# <Sync time="229.059"/>
# qui met en avant en fait les le l(e) l'incapacit&#233; de Misfits &#224; r&#233;sister &#224; des grosses phases de pression en
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="234.216" endTime="234.668">
# <Sync time="234.216"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="234.668" endTime="240.664">
# <Sync time="234.668"/>
# et peut-&#234;tre euh quelques limitations aussi du du de l'axe PoE Maxlore qu'on avait d&#233;j&#224; remarqu&#233; lors de la finale de des championnats d'Europe
# </Turn>
# <Turn startTime="240.664" endTime="241.271">
# <Sync time="240.664"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="241.271" endTime="243.82">
# <Sync time="241.271"/>
# euh &#224; l'Accord Hotel Arena o&#249; ils avaient pris trois z&#233;ro contre euh
# </Turn>
# <Turn startTime="243.82" endTime="244.188">
# <Sync time="243.82"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="244.188" endTime="245.114">
# <Sync time="244.188"/>
# les Gdeux de Perkz
# </Turn>
# <Turn startTime="245.114" endTime="245.586">
# <Sync time="245.114"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="245.586" endTime="246.436">
# <Sync time="245.586"/>
# encore une fois euh
# </Turn>
# <Turn startTime="246.436" endTime="246.887">
# <Sync time="246.436"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="246.887" endTime="252.702">
# <Sync time="246.887"/>
# n'en d&#233;plaise aux aux aux
# <Event desc="en" type="language" extent="begin"/>
# /haters/
# <Event desc="en" type="language" extent="end"/>
#  de Gdeux je pense qu'une &#233;quipe comme Gdeux est bien plus pr&#234;te pour des bo cinq de de ce calibre que que Mifits
# </Turn>
# <Turn startTime="252.702" endTime="253.285">
# <Sync time="252.702"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="253.285" endTime="255.846">
# <Sync time="253.285"/>
# voil&#224; c'est Misfits qu'on aura aujourdh'hui et tant mieux pour eux pour leur exp&#233;rience
# </Turn>
# <Turn startTime="255.846" endTime="256.204">
# <Sync time="255.846"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="256.204" endTime="258.087">
# <Sync time="256.204"/>
# mais &#231;a risque d'&#234;tre un peu l&#233;ger face au meilleur joueur du monde
# </Turn>
# <Turn startTime="258.087" endTime="258.234">
# <Sync time="258.087"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="258.234" endTime="258.888" mode="spontaneous">
# <Sync time="258.234"/>
# mmh on a
# </Turn>
# <Turn mode="spontaneous" startTime="258.888" endTime="259.372">
# <Sync time="258.888"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="259.372" endTime="263.489">
# <Sync time="259.372"/>
# y- ils ont ce r&#244;le de rookie certes mais euh tous les joueurs ont progress&#233; d'une semaine &#224; l'autre
# </Turn>
# <Turn mode="spontaneous" startTime="263.489" endTime="263.878">
# <Sync time="263.489"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="263.878" endTime="267.365">
# <Sync time="263.878"/>
# euh &#224; voir si c'est quelque chose qu'ils arriveront &#224; mettre en place en cette semaine dans le cadre de bo cinq
# </Turn>
# <Turn mode="spontaneous" startTime="267.365" endTime="267.978">
# <Sync time="267.365"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="267.978" endTime="275.839">
# <Sync time="267.978"/>
# bah ce qui est bien c'est que c'est une &#233;quipe europ&#233;enne o&#249; o&#249; personne n'a &#233;t&#233; vraiment laiss&#233; derri&#232;re y a pas un joueur qu'on peut pointer du doigt en disant l&#224; vraiment euh il a pas r&#233;ussi &#224; monter au niveau des autres tout le monde est excellent
# </Turn>
# <Turn mode="spontaneous" startTime="275.839" endTime="276.24">
# <Sync time="275.839"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="276.24" endTime="278.66">
# <Sync time="276.24"/>
# avec toujours je trouve euh Ignar euh en t&#234;te de pont
# </Turn>
# <Turn mode="spontaneous" startTime="278.66" endTime="278.904">
# <Sync time="278.66"/>
#
# </Turn>
# <Turn speaker="spk1 spk2" mode="spontaneous" startTime="278.904" endTime="279.38">
# <Sync time="278.904"/>
# <Who nb="1"/>
# XXXX
# <Who nb="2"/>
# euh
# </Turn>
# <Turn speaker="spk2" startTime="279.38" endTime="284.207">
# <Sync time="279.38"/>
# notamment euh pour moi &#231;a va &#234;tre tr&#232;s important la capacit&#233; de Ignar &#224; faire bouger un
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#  notamment contre les SKT
# </Turn>
# <Turn mode="spontaneous" startTime="284.207" endTime="284.591">
# <Sync time="284.207"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="284.591" endTime="285.485">
# <Sync time="284.591"/>
# qui a montr&#233; des faiblesses
# </Turn>
# <Turn mode="spontaneous" startTime="285.485" endTime="285.82">
# <Sync time="285.485"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="285.82" endTime="289.973">
# <Sync time="285.82"/>
# mais oui c'(est) tout le monde joue bien tout le monde se surpasse euh on est dans la continuit&#233; de leur
# <Event desc="en" type="language" extent="begin"/>
# /play off/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn mode="spontaneous" startTime="289.973" endTime="290.368">
# <Sync time="289.973"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="290.368" endTime="291.563">
# <Sync time="290.368"/>
# euh toujours dans la surprise
# </Turn>
# <Turn mode="spontaneous" startTime="291.563" endTime="291.958">
# <Sync time="291.563"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="291.958" endTime="292.256">
# <Sync time="291.958"/>
# et
# </Turn>
# <Turn mode="spontaneous" startTime="292.256" endTime="292.449">
# <Sync time="292.256"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="292.449" endTime="294.716">
# <Sync time="292.449"/>
# ce qui est bien c'est que pour moi ils ont plusieurs cordes
# </Turn>
# <Turn mode="spontaneous" startTime="294.716" endTime="295.147">
# <Sync time="294.716"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="295.147" endTime="295.746">
# <Sync time="295.147"/>
# &#224; leur arc
# </Turn>
# <Turn mode="spontaneous" startTime="295.746" endTime="296.061">
# <Sync time="295.746"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="296.061" endTime="298.481">
# <Sync time="296.061"/>
# pour essayer de de g&#233;rer un peu TS af- pas TSM pardon
# </Turn>
# <Turn mode="spontaneous" startTime="298.481" endTime="299.128">
# <Sync time="298.481"/>
#
# </Turn>
# <Turn speaker="spk3 spk2" mode="spontaneous" startTime="299.128" endTime="300.32">
# <Sync time="299.128"/>
# <Who nb="1"/>
# qui va pas rester l&#224; euh SKT ouais
# <Who nb="2"/>
# SKT ouais
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="300.32" endTime="302.706">
# <Sync time="300.32"/>
#  on on aurait aim&#233; que ce soit TSM en quart de finale pour Misfits
# </Turn>
# <Turn mode="spontaneous" startTime="302.706" endTime="303.26">
# <Sync time="302.706"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="303.26" endTime="304.126">
# <Sync time="303.26"/>
# c'est quand m&#234;me plus facile
# </Turn>
# <Turn mode="spontaneous" startTime="304.126" endTime="304.657">
# <Sync time="304.126"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="304.657" endTime="305.041">
# <Sync time="304.657"/>
# (euh)
# </Turn>
# <Turn mode="spontaneous" startTime="305.041" endTime="305.283">
# <Sync time="305.041"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="305.283" endTime="305.939">
# <Sync time="305.283"/>
# Misfits
# </Turn>
# <Turn mode="spontaneous" startTime="305.939" endTime="306.385">
# <Sync time="305.939"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="306.385" endTime="307.915">
# <Sync time="306.385"/>
#  moi je pense que le bo peut &#234;tre tr&#232;s serr&#233;
# </Turn>
# <Turn mode="spontaneous" startTime="307.915" endTime="308.151">
# <Sync time="307.915"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="308.151" endTime="314.278">
# <Sync time="308.151"/>
# c'est moi j'ai pour &#231;a que j'ai de toute fa&#231;on j'ai vot&#233; quasiment que j'ai trois deux parce que je pense que tous les bo ont une possibilit&#233; d'&#234;tre serr&#233;s et apr&#232;s voil&#224; les les les bo comme hier prouvent que
# </Turn>
# <Turn mode="spontaneous" startTime="314.278" endTime="314.868">
# <Sync time="314.278"/>
#
# </Turn>
# <Turn speaker="spk2 spk1" mode="spontaneous" startTime="314.868" endTime="316.273">
# <Sync time="314.868"/>
# <Who nb="1"/>
# bah euh &#231;a s- fin
# <Who nb="2"/>
# mmh on est pas au bout de nos surprises
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="316.273" endTime="319.947">
# <Sync time="316.273"/>
# voil&#224; on est pas vraiment au bout de nos surprises parce que hier je pensais que le bureau bo serait tr&#232;s disput&#233; et que
# </Turn>
# <Turn mode="spontaneous" startTime="319.947" endTime="320.282">
# <Sync time="319.947"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="320.282" endTime="323.083">
# <Sync time="320.282"/>
# finalement Longzhu finirait par l'emporter ils ont j- ils sont jamais vraiment rentr&#233;s dedans
# </Turn>
# <Turn mode="spontaneous" startTime="323.083" endTime="323.518">
# <Sync time="323.083"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="323.518" endTime="328.038">
# <Sync time="323.518"/>
# SKT peut ils ont pas de
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke factor/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  &#231;a n'existe pas de choke fa- parce qu'il y a Peanut qui peut
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  y a Huni qui peut
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  mais
# </Turn>
# <Turn mode="spontaneous" startTime="328.038" endTime="328.529">
# <Sync time="328.038"/>
#
# </Turn>
# <Turn speaker="spk2" mode="spontaneous" startTime="328.529" endTime="332.277">
# <Sync time="328.529"/>
# bon SKT en soi en tant qu'&#233;quipe chockera jamais parce que Faker
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  jamais et Kkoma non plus
# </Turn>
# <Turn mode="spontaneous" startTime="332.277" endTime="332.459">
# <Sync time="332.277"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="332.459" endTime="337.155">
# <Sync time="332.459"/>
# c'est pas le m&#234;me
# <Event desc="en" type="language" extent="begin"/>
#
# <Event desc="?" type="lexical" extent="begin"/>
# /choke/
# <Event desc="?" type="lexical" extent="end"/>
#
# <Event desc="en" type="language" extent="end"/>
#  c'est &#224; dire que ils peuvent avoir une baisse de performance pendant la saison pour un manqe de travail etcetera et de fatigue
# </Turn>
# <Turn mode="spontaneous" startTime="337.155" endTime="337.47">
# <Sync time="337.155"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="337.47" endTime="341.615">
# <Sync time="337.47"/>
# mais une fois qu'ils sont dans leur rythme et qu'ils sont en pleine vitesse g&#233;n&#233;ralement ils ralentissent jamais
# </Turn>
# <Turn mode="spontaneous" startTime="341.615" endTime="342.512">
# <Sync time="341.615"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="342.512" endTime="346.362">
# <Sync time="342.512"/>
# donc j'aurai tendance &#224; penser que euh parce que moi je pensais je j'aurai tendance &#224; penser que
# </Turn>
# <Turn mode="spontaneous" startTime="346.362" endTime="346.941">
# <Sync time="346.362"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="346.941" endTime="352.987">
# <Sync time="346.941"/>
# ce serait a vraiment bien que Misfits rentre vraiment bien dans la
# <Event desc="en" type="language" extent="begin"/>
# /game/
# <Event desc="en" type="language" extent="end"/>
#  par exemple que SKT tente une
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  sans
# <Event desc="en" type="language" extent="begin"/>
# /push/
# <Event desc="en" type="language" extent="end"/>
#  comme ils en ont fait quelques unes avec les Fizz euh Fizz Twitch comme on le voit l&#224;
# </Turn>
# <Turn mode="spontaneous" startTime="352.987" endTime="353.554">
# <Sync time="352.987"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="353.554" endTime="356.984">
# <Sync time="353.554"/>
# et derri&#232;re voir euh voir si Misfits peut prendre une
# <Event desc="en" type="language" extent="begin"/>
# /game/
# <Event desc="en" type="language" extent="end"/>
#  voir deux
# </Turn>
# <Turn mode="spontaneous" startTime="356.984" endTime="357.313">
# <Sync time="356.984"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="357.313" endTime="359.138">
# <Sync time="357.313"/>
# pour qu'on ait un bo qui nous raconte une belle histoire
# </Turn>
# <Turn mode="spontaneous" startTime="359.138" endTime="359.544">
# <Sync time="359.138"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="359.544" endTime="359.979">
# <Sync time="359.544"/>
# mais faut bien &#234;tre
# </Turn>
# <Turn mode="spontaneous" startTime="359.979" endTime="360.349">
# <Sync time="359.979"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="360.349" endTime="361.385">
# <Sync time="360.349"/>
# convaincu d'un truc c'est que
# </Turn>
# <Turn mode="spontaneous" startTime="361.385" endTime="362.299">
# <Sync time="361.385"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="362.299" endTime="364.963">
# <Sync time="362.299"/>
# euh si si Misfits leur porte aujourd'hui ils auront fait ce que aucune &#233;quipe
# </Turn>
# <Turn mode="spontaneous" startTime="364.963" endTime="365.213">
# <Sync time="364.963"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="365.213" endTime="366.595">
# <Sync time="365.213"/>
# dans l'histoire de LOL n'a jamais r&#233;ussi &#224; faire
# </Turn>
# <Turn mode="spontaneous" startTime="366.595" endTime="366.893">
# <Sync time="366.595"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="366.893" endTime="367.186">
# <Sync time="366.893"/>
# c'est &#231;a
# </Turn>
# <Turn mode="spontaneous" startTime="367.186" endTime="367.49">
# <Sync time="367.186"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="367.49" endTime="372.407">
# <Sync time="367.49"/>
# m(ais) leur performance en soi pour l'instant est largement satisfaisante de la part de tous les joueurs c'est pas comme
# </Turn>
# <Turn mode="spontaneous" startTime="372.407" endTime="373.012">
# <Sync time="372.407"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="373.012" endTime="377.554">
# <Sync time="373.012"/>
#  Gdeux ou m&#234;me TSM ou m&#234;me la euh la totalit&#233; des
# <Event desc="en" type="language" extent="begin"/>
# /seed/
# <Event desc="en" type="language" extent="end"/>
#  un qui partent en se disant qu'ils auraient pu faire plus
# </Turn>
# <Turn mode="spontaneous" startTime="377.554" endTime="377.838">
# <Sync time="377.554"/>
#
# </Turn>
# <Turn speaker="spk1" mode="spontaneous" startTime="377.838" endTime="380.588">
# <Sync time="377.838"/>
# le parcours de Misfits est euh ab- comment dire euh admirable quoi qu'il arrive
# </Turn>
# <Turn mode="spontaneous" startTime="380.588" endTime="381.221">
# <Sync time="380.588"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="381.221" endTime="387.733">
# <Sync time="381.221"/>
# ah oui oui toute fa&#231;on euh d&#233;j&#224; le fait simple fait qu'il soit pass&#233; d(e)
# <Event desc="en" type="language" extent="begin"/>
# /challenger/
# <Event desc="en" type="language" extent="end"/>
#  euh l'ann&#233;e derni&#232;re euh &#224; quart de finale
# </Turn>
# <Turn mode="spontaneous" startTime="387.733" endTime="388.176">
# <Sync time="387.733"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="388.176" endTime="391.51">
# <Sync time="388.176"/>
# c'est euh c'est exceptionnel y avait que Origen qui l'avait fait ils &#233;taient euh
# </Turn>
# <Turn mode="spontaneous" startTime="391.51" endTime="391.831">
# <Sync time="391.51"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="391.831" endTime="393.1">
# <Sync time="391.831"/>
# ils &#233;taient constitu&#233; de v&#233;t&#233;rans
# </Turn>
# <Turn mode="spontaneous" startTime="393.1" endTime="393.512">
# <Sync time="393.1"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="393.512" endTime="395.399">
# <Sync time="393.512"/>
# l&#224; on a vraiment euh on a vraiment des
# <Event desc="en" type="language" extent="begin"/>
# /rookie/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn mode="spontaneous" startTime="395.399" endTime="395.87">
# <Sync time="395.399"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="395.87" endTime="398.631">
# <Sync time="395.87"/>
# euh apr&#232;s voil&#224; c'est pour (euh) pour Misfits
# </Turn>
# <Turn mode="spontaneous" startTime="398.631" endTime="399.145">
# <Sync time="398.631"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="399.145" endTime="405.309">
# <Sync time="399.145"/>
# euh &#231;a va &#234;tre dur d'ailleurs ce qui est bien c'est que Hans Sama r&#233;clamait de jouer contre Bang &#231;a veut dire que y a un an et demi il faisait des des Lyon
# <Event desc="en" type="language" extent="begin"/>
# /e-sport/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn mode="spontaneous" startTime="405.309" endTime="405.562">
# <Sync time="405.309"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="405.562" endTime="408.55">
# <Sync time="405.562"/>
# et maintenant il affronte son idole donc euh va y avoir quelque chose &#224; faire sur la dur&#233;e
# </Turn>
# <Turn mode="spontaneous" startTime="408.55" endTime="408.945">
# <Sync time="408.55"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="408.945" endTime="412.109">
# <Sync time="408.945"/>
# mais par contre euh effectivement je pense que SKT a montr&#233; des faiblesses
# </Turn>
# <Turn mode="spontaneous" startTime="412.109" endTime="412.317">
# <Sync time="412.109"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="412.317" endTime="413.12">
# <Sync time="412.317"/>
# alors c'est peut-&#234;tre pire
# </Turn>
# <Turn mode="spontaneous" startTime="413.12" endTime="413.398">
# <Sync time="413.12"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="413.398" endTime="414.329">
# <Sync time="413.398"/>
# que de finir en six z&#233;ro
# </Turn>
# <Turn mode="spontaneous" startTime="414.329" endTime="414.525">
# <Sync time="414.329"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="414.525" endTime="417.513">
# <Sync time="414.525"/>
# parce que Longzhu a pas montr&#233; de faiblesses quasiment pendant la phase de groupe
# </Turn>
# <Turn mode="spontaneous" startTime="417.513" endTime="417.857">
# <Sync time="417.513"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="417.857" endTime="419.154">
# <Sync time="417.857"/>
# et d'ailleurs c'est lamentablement &#233;chou&#233;
# </Turn>
# <Turn mode="spontaneous" startTime="419.154" endTime="419.5">
# <Sync time="419.154"/>
#
# </Turn>
# <Turn speaker="spk3" mode="spontaneous" startTime="419.5" endTime="421.893">
# <Sync time="419.5"/>
# euh SKT on le suit dans les
# <Event desc="en" type="language" extent="begin"/>
# /interview/
# <Event desc="en" type="language" extent="end"/>
#  ils savent
# </Turn>
# <Turn startTime="421.893" endTime="422.202">
# <Sync time="421.893"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="422.202" endTime="422.924">
# <Sync time="422.202"/>
# qu'en
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="422.924" endTime="423.404">
# <Sync time="422.924"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="423.404" endTime="423.994">
# <Sync time="423.404"/>
# y a des trous
# </Turn>
# <Turn startTime="423.994" endTime="424.092">
# <Sync time="423.994"/>
#
# </Turn>
# <Turn startTime="424.092" endTime="426.063">
# <Sync time="424.092"/>
# ils savent qu'en
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#  c'est friable
# <Sync time="425.861"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="426.063" endTime="430.114">
# <Sync time="426.063"/>
# et &#224; mon avis ils ont ultra boss&#233; &#231;a donc je suis m&#234;me pas s&#251;r en fait que cette petite porte d'entr&#233;e
# </Turn>
# <Turn startTime="430.114" endTime="430.499">
# <Sync time="430.114"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="430.499" endTime="431.858">
# <Sync time="430.499"/>
# soit encore disponible pour les Misfits hein
# </Turn>
# <Turn speaker="spk1" startTime="431.858" endTime="434.402">
# <Sync time="431.858"/>
# on reviendra euh plus tard sur le cas SKT puisque y a
# </Turn>
# <Turn startTime="434.402" endTime="434.76">
# <Sync time="434.402"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="434.76" endTime="440.134">
# <Sync time="434.76"/>
# plusieurs choses qui rentrent en compte notamment au niveau des performances des joueurs tu parlais d'Hans Sama j'aimerai qu'on se concentre euh sur lui aujourd'hui
# </Turn>
# <Turn startTime="440.134" endTime="440.569">
# <Sync time="440.134"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="440.569" endTime="443.246">
# <Sync time="440.569"/>
# puisque c'est notre grand /rookie/ de de la comp&#233;tition
# </Turn>
# <Turn startTime="443.246" endTime="443.533">
# <Sync time="443.246"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="443.533" endTime="443.997">
# <Sync time="443.533"/>
# fran&#231;ais
# </Turn>
# <Turn startTime="443.997" endTime="444.335">
# <Sync time="443.997"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="444.335" endTime="444.804">
# <Sync time="444.335"/>
# de sourcoit
# </Turn>
# <Turn startTime="444.804" endTime="445.279">
# <Sync time="444.804"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="445.279" endTime="451.413">
# <Sync time="445.279"/>
# comme tu le disais y a un y a un petit plus d'un an il &#233;tait aux Lyon /e-sport/ il faisait (son) parcours chez Mill&#233;nium il est rentr&#233; en /challenger series/
# </Turn>
# <Turn startTime="451.413" endTime="452.074">
# <Sync time="451.413"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="452.074" endTime="457.334">
# <Sync time="452.074"/>
# (et) l&#224; cette ann&#233;e il arrive et et aujourd'hui il est tr&#232;s content de pouvoir jouer contre son idole Bang justement
# </Turn>
# <Turn startTime="457.334" endTime="457.415">
# <Sync time="457.334"/>
#
# <Event desc="bb" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn startTime="457.415" endTime="457.724">
# <Sync time="457.415"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="457.724" endTime="461.75">
# <Sync time="457.724"/>
# bah y a un(e) un adage qui dit que le que le succ&#232;s c'est quand tes idoles deviennent tes rivaux
# </Turn>
# <Turn startTime="461.75" endTime="461.943">
# <Sync time="461.75"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="461.943" endTime="465.307">
# <Sync time="461.943"/>
# euh je pense que c'est tr&#232;s tr&#232;s bien euh applicable euh au cas de Hans Sama
# </Turn>
# <Turn startTime="465.307" endTime="466.02">
# <Sync time="465.307"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="466.02" endTime="467.171">
# <Sync time="466.02"/>
# Hans Sama euh il a
# </Turn>
# <Turn startTime="467.171" endTime="468.079">
# <Sync time="467.171"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="468.079" endTime="473.712">
# <Sync time="468.079"/>
# beaucoup encore de de d&#233;faut en tant que joueur mais l'avantage c'est qu'on progresse beaucoup plus vite quand on joue contre des joueurs qui s(ont) sensiblement plus fort que lui
# </Turn>
# <Turn startTime="473.712" endTime="474.198">
# <Sync time="473.712"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="474.198" endTime="480.027">
# <Sync time="474.198"/>
# (euh) &#231;a a d&#233;j&#224; &#233;t&#233; le cas quand il jouait contre Rekkles ou Zven ont peut-&#234;tre plus d'exp&#233;rience il est arriv&#233; &#224; leur niveau je pense qu'on tous cas dans ces /worlds/
# </Turn>
# <Turn startTime="480.027" endTime="480.482">
# <Sync time="480.027"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="480.482" endTime="482.976">
# <Sync time="480.482"/>
# il a fait une performance qui n'a rien &#224; envier &#224; ses alter ego europ&#233;ens
# </Turn>
# <Turn startTime="482.976" endTime="483.415">
# <Sync time="482.976"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="483.415" endTime="487.447">
# <Sync time="483.415"/>
# il va jou&#233; contre un des bases de fin de l'ADC hein je pense que Pray Bang et Deft
# </Turn>
# <Turn startTime="487.447" endTime="487.8">
# <Sync time="487.447"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="487.8" endTime="489.963">
# <Sync time="487.8"/>
# avec Ruler qui l'a montr&#233; aussi hier font patie vraiment des
# </Turn>
# <Turn startTime="489.963" endTime="490.387">
# <Sync time="489.963"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="490.387" endTime="493.951">
# <Sync time="490.387"/>
# des ADC cor&#233;ens monstrueux avec Uzi qu'il faut pas oublier en Chine qui pour l'instant est dans la forme de sa vie
# </Turn>
# <Turn startTime="493.951" endTime="494.58">
# <Sync time="493.951"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="494.58" endTime="496.873">
# <Sync time="494.58"/>
# je dirai qu'il a des d&#233;fauts comme peut-&#234;tre sa polyvalence
# </Turn>
# <Turn startTime="496.873" endTime="497.024">
# <Sync time="496.873"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="497.024" endTime="499.963">
# <Sync time="497.024"/>
# euh en terme de /draft/ si jamais SKT par exemple d&#233;cide de de priorit&#233;
# </Turn>
# <Turn startTime="499.963" endTime="500.203">
# <Sync time="499.963"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="500.203" endTime="502.397">
# <Sync time="500.203"/>
# prioriser le /pick/ Xayah il peut se retrouver dans une situation difficile
# </Turn>
# <Turn startTime="502.397" endTime="502.803">
# <Sync time="502.397"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="502.803" endTime="505.987">
# <Sync time="502.803"/>
# maintenant euh d'un point de vue m&#233;canique et vu que c'est un joueur qu'est docile
# </Turn>
# <Turn startTime="505.987" endTime="506.381">
# <Sync time="505.987"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="506.381" endTime="506.553">
# <Sync time="506.381"/>
# qui est
# </Turn>
# <Turn startTime="506.553" endTime="506.969">
# <Sync time="506.553"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="506.969" endTime="509.04">
# <Sync time="506.969"/>
# assez faible en &#233;go et qui est tr&#232;s travailleur
# </Turn>
# <Turn startTime="509.04" endTime="509.408">
# <Sync time="509.04"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="509.408" endTime="511.119">
# <Sync time="509.408"/>
# mais il a tendance &#224; r&#233;pondre pr&#233;sent dans les grands moments
# </Turn>
# <Turn startTime="511.119" endTime="511.468">
# <Sync time="511.119"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="511.468" endTime="517.122">
# <Sync time="511.468"/>
# et il a perdu un peu ce /choke factor/ que je lui trouvais l'ann&#233;e derni&#232;re notamment lors la qualification de Misfits en LCS o&#249; il &#233;tait il avait &#233;t&#233; tr&#232;s assez mauvais sur sa civi&#232;re
# </Turn>
# <Turn startTime="517.122" endTime="517.596">
# <Sync time="517.122"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="517.596" endTime="518.817">
# <Sync time="517.596"/>
# ah l&#224; il est il sait r&#233;pondre pr&#233;sent donc
# </Turn>
# <Turn startTime="518.817" endTime="519.17">
# <Sync time="518.817"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="519.17" endTime="521.943">
# <Sync time="519.17"/>
# moi je sais pas j- peut-&#234;tre l'avis de Noi aussi euh sur le sujet mais je pense que Hans sama
# </Turn>
# <Turn startTime="521.943" endTime="522.336">
# <Sync time="521.943"/>
#
# </Turn>
# <Turn speaker="spk2 spk1" startTime="522.336" endTime="525.349">
# <Sync time="522.336"/>
# <Who nb="1"/>
# c'est pas vraiment quelqu'un sur qui je peux je peux stresser aujourd'hui je pense qu'il va r&#233;pondre pr&#233;sent
# <Who nb="2"/>
# oui
# </Turn>
# <Turn speaker="spk1" startTime="525.349" endTime="531.418">
# <Sync time="525.349"/>
# c'est euh c'est l&#224; dessus que je voulais rebondir justement on on il a il tremblait un peu lors de la qualification c'est contre Origen si euh je me rappelle bien
# </Turn>
# <Turn startTime="531.418" endTime="532.386">
# <Sync time="531.418"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="532.386" endTime="536.696">
# <Sync time="532.386"/>
# on avait des doutes sur sa capacit&#233; &#224; rebondir en LCS au final il a fait un parcours admirable est-ce que on
# </Turn>
# <Turn startTime="536.696" endTime="537.057">
# <Sync time="536.696"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="537.057" endTime="538.347">
# <Sync time="537.057"/>
# peut s'attendre &#224; ce qu'il euh
# </Turn>
# <Turn startTime="538.347" endTime="538.935">
# <Sync time="538.347"/>
#
# </Turn>
# <Turn speaker="spk1 spk3" startTime="538.935" endTime="540.124">
# <Sync time="538.935"/>
# <Who nb="1"/>
# il arrive au niveau aujourd'hui parce que
# <Who nb="2"/>
# en fait y a
# </Turn>
# <Turn speaker="spk1" startTime="540.124" endTime="541.445">
# <Sync time="540.124"/>
# quand on regarde les stat du joueurs en fait elles sont
# </Turn>
# <Turn startTime="541.445" endTime="541.876">
# <Sync time="541.445"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="541.876" endTime="544.719">
# <Sync time="541.876"/>
# vraiment int&#233;ressantes et il se classe parmis les meilleurs ADC des /worlds/
# </Turn>
# <Turn startTime="544.719" endTime="544.912">
# <Sync time="544.719"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="544.912" endTime="547.12">
# <Sync time="544.912"/>
# <Who nb="1"/>
# en fait pour moi ce qui est bien c'est que au contraire
# <Who nb="2"/>
# &#224; l'heure qu'il est
# </Turn>
# <Turn startTime="547.12" endTime="547.339">
# <Sync time="547.12"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="547.339" endTime="552.36">
# <Sync time="547.339"/>
# le le fait de tomber sur SKT chand- euh triple champion du monde euh deux fois de suite peut-&#234;tre un troisi&#232;me
# </Turn>
# <Turn startTime="552.36" endTime="552.639">
# <Sync time="552.36"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="552.639" endTime="553.383">
# <Sync time="552.639"/>
# d'&#234;tre l'/underdogs/
# </Turn>
# <Turn startTime="553.383" endTime="553.622">
# <Sync time="553.383"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="553.622" endTime="554.014">
# <Sync time="553.622"/>
# c'est qu'y a
# </Turn>
# <Turn startTime="554.014" endTime="554.276">
# <Sync time="554.014"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="554.276" endTime="554.856">
# <Sync time="554.276"/>
# absolument
# </Turn>
# <Turn startTime="554.856" endTime="555.133">
# <Sync time="554.856"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="555.133" endTime="559.127">
# <Sync time="555.133"/>
# z&#233;ro pression ils peuvent se faire d&#233;monter trois z&#233;ro vingt minutes vingt minutes vingt minutes
# </Turn>
# <Turn startTime="559.127" endTime="559.503">
# <Sync time="559.127"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="559.503" endTime="560.118">
# <Sync time="559.503"/>
# c'est SKT
# </Turn>
# <Turn startTime="560.118" endTime="560.33">
# <Sync time="560.118"/>
#
# </Turn>
# <Turn startTime="560.33" endTime="561.493" speaker="spk3">
# <Sync time="560.33"/>
# contre une &#233;quipe qui &#233;tait l&#224; en /challenger/
# </Turn>
# <Turn startTime="561.493" endTime="561.928">
# <Sync time="561.493"/>
#
# ...
# <Sync time="1137.369"/>
# apr&#232;s (euh) le le Rakan il peut &#234;tre euh il peut &#234;tre puni ou alors peut y avoir une tentative de de punition
# </Turn>
# <Turn startTime="1142.346" endTime="1142.597">
# <Sync time="1142.346"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1142.597" endTime="1150.726">
# <Sync time="1142.597"/>
# donc moi mettre Hans Sama si tout le monde euh je me souviens parfaitement de sa
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  o&#249; euh vz- tout le monde &#233;tait en train de s'arrancher les cheveux derri&#232;re mais pourquoi cette
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  et j'&#233;tais l&#224; mais non moi j'aime bien euh Xayah euh
# </Turn>
# <Turn startTime="1150.726" endTime="1150.962">
# <Sync time="1150.726"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1150.962" endTime="1151.71">
# <Sync time="1150.962"/>
# parce que Hans Sama alors
# </Turn>
# <Turn startTime="1151.71" endTime="1151.996">
# <Sync time="1151.71"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1151.996" endTime="1152.619">
# <Sync time="1151.996"/>
# dans la logique
# </Turn>
# <Turn startTime="1152.619" endTime="1152.924">
# <Sync time="1152.619"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1152.924" endTime="1154.732">
# <Sync time="1152.924"/>
# on fait avec ce qu'on a et dans la r&#233;alit&#233; des choses
# </Turn>
# <Turn startTime="1154.732" endTime="1155.131">
# <Sync time="1154.732"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1155.131" endTime="1156.439">
# <Sync time="1155.131"/>
# euh Hans Sama a besoin
# </Turn>
# <Turn startTime="1156.439" endTime="1156.549">
# <Sync time="1156.439"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1156.549" endTime="1162.721">
# <Sync time="1156.549"/>
# euh un petit
# <Event desc="en" type="language" extent="begin"/>
# /pull/
# <Event desc="en" type="language" extent="end"/>
#  d'ADC et a besoin d'&#234;tre euh d'&#234;tre sur l'un deux pour &#234;tre vraiment efficace donc Xayah en fait partie Varus en fait partie par exemple
# </Turn>
# <Turn startTime="1162.721" endTime="1163.223">
# <Sync time="1162.721"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1163.223" endTime="1166.026">
# <Sync time="1163.223"/>
# euh donc avoir Xayah et apr&#232;s avoir un Ignard
# </Turn>
# <Turn startTime="1166.026" endTime="1166.148">
# <Sync time="1166.026"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1166.148" endTime="1168.94">
# <Sync time="1166.148"/>
# qui peut tr&#232;s bien contrer avec du Blitzcrank ou avec du Thresh
# </Turn>
# <Turn startTime="1168.94" endTime="1169.254">
# <Sync time="1168.94"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1169.254" endTime="1170.754">
# <Sync time="1169.254"/>
# pour mettre beaucoup de pression en
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="1170.754" endTime="1171.146">
# <Sync time="1170.754"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1171.146" endTime="1172.074">
# <Sync time="1171.146"/>
# moi c'est quelque chose
# </Turn>
# <Turn startTime="1172.074" endTime="1172.688">
# <Sync time="1172.074"/>
#
# </Turn>
# <Turn startTime="1172.688" endTime="1174.102" speaker="spk3">
# <Sync time="1172.688"/>
# que j'aimerai voir se qu'a tent&#233; Longzhu hier
# </Turn>
# <Turn startTime="1174.102" endTime="1174.381">
# <Sync time="1174.102"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1174.381" endTime="1175.72">
# <Sync time="1174.381"/>
# hier euh Longzhu notamment du c&#244;t&#233;
# </Turn>
# <Turn speaker="spk3 spk2" startTime="1175.72" endTime="1177.034">
# <Sync time="1175.72"/>
# <Who nb="1"/>
# de XX on a tent&#233; euh
# <Who nb="2"/>
# quelle efficacit&#233; d'ailleurs
# </Turn>
# <Turn speaker="spk2" startTime="1177.034" endTime="1177.568">
# <Sync time="1177.034"/>
# de cette
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="1177.568" endTime="1177.636">
# <Sync time="1177.568"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1177.636" endTime="1177.927">
# <Sync time="1177.636"/>
# ouais
# </Turn>
# <Turn startTime="1177.927" endTime="1178.793">
# <Sync time="1177.927"/>
#
# <Event desc="b" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1178.793" endTime="1182.221">
# <Sync time="1178.793"/>
# c'est parce qu'il y a aussi une sejl- euh une Sej- eht Tristana qu'a &#233;t&#233; laiss&#233;e trois fois de suite on peut pas
# </Turn>
# <Turn speaker="spk3 spk1" startTime="1182.221" endTime="1182.826">
# <Sync time="1182.221"/>
# <Who nb="1"/>
# estamputer (???) un
# <Who nb="2"/>
# ah oui
# </Turn>
# <Turn speaker="spk3 spk1" startTime="1182.826" endTime="1183.44">
# <Sync time="1182.826"/>
# <Who nb="1"/>
# pic de Tresh
#
# <Who nb="2"/>
# &#231;a arrive
# </Turn>
# <Turn speaker="spk2 spk2" startTime="1183.44" endTime="1183.778">
# <Sync time="1183.44"/>
# <Who nb="1"/>
# toute fa&#231;on euh
#
# <Who nb="2"/>
# oui
# </Turn>
# <Turn speaker="spk2" startTime="1183.778" endTime="1189.39">
# <Sync time="1183.778"/>
# c'est c'est c'est Sej- Tristana c'est c'est c'est massivement pic et au &#231;a en
# <Event desc="en" type="language" extent="begin"/>
# /mid lane/
# <Event desc="en" type="language" extent="end"/>
#  de de cent pour cent on pas sur de Janna Gragas ou quoi que ce soit donc
# </Turn>
# <Turn startTime="1189.39" endTime="1189.904">
# <Sync time="1189.39"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1189.904" endTime="1189.995">
# <Sync time="1189.904"/>
# muh
# </Turn>
# <Turn startTime="1189.995" endTime="1190.272">
# <Sync time="1189.995"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1190.272" endTime="1190.559">
# <Sync time="1190.272"/>
# fin
# </Turn>
# <Turn startTime="1190.559" endTime="1190.76">
# <Sync time="1190.559"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1190.76" endTime="1196.897">
# <Sync time="1190.76"/>
# moi je peux pas dire que la
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  euh Samsung elle &#233;t&#233; op&#233;e tu vois juste ils avaient une
# <Event desc="en" type="language" extent="begin"/>
# /draft/
# <Event desc="en" type="language" extent="end"/>
#  en face bah on prend des Tresh au lieu de prendre des encensoirs &#224; dents alors qu'on a des Rakan
# </Turn>
# <Turn startTime="1196.897" endTime="1197.336">
# <Sync time="1196.897"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1197.336" endTime="1198.561">
# <Sync time="1197.336"/>
# et on prend des Rakan contre des Taric
# </Turn>
# <Turn speaker="spk3" startTime="1198.561" endTime="1200.876">
# <Sync time="1198.561"/>
# mais je p- mais je pense pas que Tresh s(oit) soit injouable dans la m&#233;ta hein
# </Turn>
# <Turn startTime="1200.876" endTime="1201.032">
# <Sync time="1200.876"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1201.032" endTime="1202.512">
# <Sync time="1201.032"/>
# c'est c'est c'est tout &#224; fait jouable
# </Turn>
# <Turn startTime="1202.512" endTime="1203.013">
# <Sync time="1202.512"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1203.013" endTime="1203.962">
# <Sync time="1203.013"/>
# quand t'es meilleur que ton adversaire
# </Turn>
# <Turn startTime="1203.962" endTime="1204.972">
# <Sync time="1203.962"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1204.972" endTime="1205.064">
# <Sync time="1204.972"/>
# s-
# </Turn>
# <Turn startTime="1205.064" endTime="1205.382">
# <Sync time="1205.064"/>
#
# <Event desc="bb" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="1205.382" endTime="1206.061">
# <Sync time="1205.382"/>
# <Who nb="1"/>
# l&#224; o&#249; ils ont mal jou&#233;
# <Who nb="2"/>
# quand t'arrives &#224;
# </Turn>
# <Turn speaker="spk1" startTime="1206.061" endTime="1207.601">
# <Sync time="1206.061"/>
# faire la diff&#233;rence en
# <Event desc="en" type="language" extent="begin"/>
# /lanes/
# <Event desc="en" type="language" extent="end"/>
#  qui
# </Turn>
# <Turn speaker="spk1 spk3" startTime="1207.601" endTime="1209.433">
# <Sync time="1207.601"/>
# <Who nb="1"/>
# n'a pas vraiment &#233;t&#233; l&#224; pour XXX
# <Who nb="2"/>
# ouais et l&#224; ils ont mal jou&#233; mais apr&#232;s c'est un pari
# </Turn>
# <Turn speaker="spk3" startTime="1209.433" endTime="1212.918">
# <Sync time="1209.433"/>
# que tu gagnes ou que tu ken pas mais euh &#224; euh dire que c'est pas une strat&#233;gie viable pour moi c'est pas le cas
# </Turn>
# <Turn startTime="1212.918" endTime="1213.236">
# <Sync time="1212.918"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1213.236" endTime="1216.638">
# <Sync time="1213.236"/>
# et pour moi au contraire essayer de jouer une strat&#233;gie de
# <Event desc="en" type="language" extent="begin"/>
# /team fight/
# <Event desc="en" type="language" extent="end"/>
#
# <Event desc="en" type="language" extent="begin"/>
# /late game/
# <Event desc="en" type="language" extent="end"/>
#  contre euh SKT
# </Turn>
# <Turn startTime="1216.638" endTime="1216.848">
# <Sync time="1216.638"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1216.848" endTime="1218.332">
# <Sync time="1216.848"/>
# sachant que la seule faiblesse qu'ils ont montr&#233;e
# </Turn>
# <Turn startTime="1218.332" endTime="1218.633">
# <Sync time="1218.332"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1218.633" endTime="1219.547">
# <Sync time="1218.633"/>
# c'est de l'
# <Event desc="en" type="language" extent="begin"/>
# /early game/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="1219.547" endTime="1219.904">
# <Sync time="1219.547"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3 spk1" startTime="1219.904" endTime="1220.34">
# <Sync time="1219.904"/>
# <Who nb="1"/>
# (euh)
# <Who nb="2"/>
# oui
# </Turn>
# <Turn speaker="spk1" startTime="1220.34" endTime="1221.18">
# <Sync time="1220.34"/>
# au niveau de toutes les stats
# </Turn>
# <Turn startTime="1221.18" endTime="1221.489">
# <Sync time="1221.18"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1221.489" endTime="1224.335">
# <Sync time="1221.489"/>
# bah autant profiter alors je pense que ay- malheureusement y aura m&#234;me plus cette faiblesse
# </Turn>
# <Turn startTime="1224.335" endTime="1224.633">
# <Sync time="1224.335"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1224.633" endTime="1226.369">
# <Sync time="1224.633"/>
# mais je pense qu'il faut au moins pour la premi&#232;re game
# </Turn>
# <Turn startTime="1226.369" endTime="1226.713">
# <Sync time="1226.369"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1226.713" endTime="1228.214">
# <Sync time="1226.713"/>
# pour la premi&#232;re game faut au moins tenter le
# <Event desc="en" type="language" extent="begin"/>
# /line pressure/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="1228.214" endTime="1228.34">
# <Sync time="1228.214"/>
#
# </Turn>
# <Turn speaker="spk1" startTime="1228.34" endTime="1231.011">
# <Sync time="1228.34"/>
# c'est la seule fen&#234;tre &#224; saisir est-ce qu'y a d'autres
# <Event desc="toux en fond" type="noise" extent="begin"/>
# faiblesses
# <Event desc="toux en fond" type="noise" extent="end"/>
#  d'SKT &#224; l'heure qu'il est
# </Turn>
# <Turn startTime="1231.011" endTime="1231.494">
# <Sync time="1231.011"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn startTime="1231.494" endTime="1231.49">
#
# <Sync time="1231.341"/>
#
# <Event desc="bb" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn startTime="1231.49" endTime="1231.895">
# <Sync time="1231.49"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1231.895" endTime="1233.096">
# <Sync time="1231.895"/>
# c'est qu'y a une faiblesse
# </Turn>
# <Turn startTime="1233.096" endTime="1233.214">
# <Sync time="1233.096"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1233.214" endTime="1234.18">
# <Sync time="1233.214"/>
# (euh)
# </Turn>
# <Turn startTime="1234.18" endTime="1234.25">
# <Sync time="1234.18"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1234.25" endTime="1235.93">
# <Sync time="1234.25"/>
# de SKT c'est (euh) le top
# </Turn>
# <Turn startTime="1235.93" endTime="1236.261">
# <Sync time="1235.93"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1236.261" endTime="1236.836">
# <Sync time="1236.261"/>
# le
# <Event desc="en" type="language" extent="begin"/>
# /top jungle/
# <Event desc="en" type="language" extent="end"/>
#
# </Turn>
# <Turn startTime="1236.836" endTime="1237.548">
# <Sync time="1236.836"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1237.548" endTime="1241.698">
# <Sync time="1237.548"/>
# encore une fois je pense que dans toutes les
# <Event desc="en" type="language" extent="begin"/>
# /game/
# <Event desc="en" type="language" extent="end"/>
#  de Misfits c'est quelque chose que sur lequel j'essaie de revenir assez souvent
# </Turn>
# <Turn startTime="1241.698" endTime="1242.22">
# <Sync time="1241.698"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1242.22" endTime="1246.73">
# <Sync time="1242.22"/>
# (euh) Misfits ils ont quelque ils ont un joueur qui sait tout jouer &#224; la
# <Event desc="en" type="language" extent="begin"/>
# /top lane/
# <Event desc="en" type="language" extent="end"/>
#  qui s'appelle Alphari qui pour l'instant est
# </Turn>
# <Turn startTime="1246.73" endTime="1247.437">
# <Sync time="1246.73"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1247.437" endTime="1248.386">
# <Sync time="1247.437"/>
# largement /underrated/
# </Turn>
# <Turn startTime="1248.386" endTime="1248.639">
# <Sync time="1248.386"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1248.639" endTime="1251.006">
# <Sync time="1248.639"/>
# je pense que (son) sa carri&#232;re elle fait que commencer et
# </Turn>
# <Turn startTime="1251.006" endTime="1251.237">
# <Sync time="1251.006"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1251.237" endTime="1254.356">
# <Sync time="1251.237"/>
# je pense qu'il d&#233;tr&#244;nera par exemple p- Odoamn&#233; et Vizicsacsi ou Soaz en en Europe euh
# </Turn>
# <Turn startTime="1254.356" endTime="1254.791">
# <Sync time="1254.356"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1254.791" endTime="1256.832">
# <Sync time="1254.791"/>
# vu vu sa polyvalence et sa compr&#233;hension du jeu
# </Turn>
# <Turn startTime="1256.832" endTime="1257.355">
# <Sync time="1256.832"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1257.355" endTime="1257.708">
# <Sync time="1257.355"/>
#
# </Turn>
# <Turn startTime="1257.708" endTime="1257.813">
# <Sync time="1257.708"/>
#
# </Turn>
# <Turn speaker="spk3" startTime="1257.813" endTime="1259.906">
# <Sync time="1257.813"/>
# si Maxlore met l'emphase sur le
# <Event desc="en" type="language" extent="begin"/>
# /top side/
# <Event desc="en" type="language" extent="end"/>
#  et qui
# </Turn>
# <Turn startTime="1259.906" endTime="1260.167">
# <Sync time="1259.906"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1260.167" endTime="1261.951">
# <Sync time="1260.167"/>
# notamment en comptant en en contre d'un pic
# </Turn>
# <Turn startTime="1261.951" endTime="1262.375">
# <Sync time="1261.951"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1262.375" endTime="1263.303">
# <Sync time="1262.375"/>
# euh agressif d'Huni
# </Turn>
# <Turn startTime="1263.303" endTime="1263.701">
# <Sync time="1263.303"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1263.701" endTime="1265.534">
# <Sync time="1263.701"/>
# o&#249; il va essayer de justement de jouer un peu /cocky/
# </Turn>
# <Turn startTime="1265.534" endTime="1265.954">
# <Sync time="1265.534"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# </Turn>
# <Turn speaker="spk2" startTime="1265.954" endTime="1437.466">
# <Sync time="1265.954"/>
# euh un n-
# </Turn>
# </Section>
# </Episode>
# </Trans>

# %%
for element in rootTRS.xpath('//Turn[Event[@extent="begin"]]'):
    for event in element.xpath('//Event[@extent="begin" or @extent="end"]'):
        print etree.tostring(event)
# Out:
# <Event desc="dis" type="pronounce" extent="begin"/>
# 6	euh	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 7	assez	assez	ADV	ADV		8	mod	8	mod
# 8	mate	mat	ADJ	ADJ	n=s|g=f|	4	ats	4	ats
# 9	de	de	P	P		8	de_obj	8	de_obj
# 10	peau	peau	NC	NC	n=s|g=f|	9	prep	9	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	un-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	un	un	DET	DET	n=s|g=m|	8	det	8	det
# 7	beau	beau	ADJ	ADJ	n=s|g=m|	8	mod	8	mod
# 8	regard	regard	NC	NC	n=s|g=m|	4	prep	4	prep
# 9	parce_que	parce_que	CS	CS		1	mod	1	mod
# 10	le	le	DET	DET	n=s|g=m|	11	det	11	det
# 11	regard	regard	NC	NC	n=s|g=m|	13	suj	13	suj
# 12	&#195;&#167;a	&#195;&#167;a	PRO	PRO	n=s|	13	suj	13	suj
# 13	compte	compter	V	V	n=s|t=PS|p=13|	9	sub	9	sub
# 14	beaucoup	beaucoup	ADV	ADV		13	mod	13	mod
# 15	pour	pour	P	P		13	mod	13	mod
# 16	moi	moi	NC	NC	n=s|g=m|	15	prep	15	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 9	euh-	_	ADV	ADV	_	11	mod	11	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	bien	bien	ADV	ADV		11	mod	11	mod
# 11	propres	propre	ADJ	ADJ	n=p|	12	mod	12	mod
# 12	hein	_	NC	NC	_	5	mod	5	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 8	je-	_	NPP	NPP	_	7	dep_coord	7	dep_coord
# 9	je-	_	NPP	NPP	_	8	mod	8	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	je	je	CLS	CLS	n=s|p=1|	11	suj	11	suj
# 11	sais	savoir	V	V	n=s|t=P|p=12|	2	mod	2	mod
# 12	rien	rien	PRO	PRO	n=s|g=m|	11	obj	11	obj
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	je-	_	NC	NC	_	6	mod	6	mod
# 3	je-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 4	j'	je	CLS	CLS	n=s|p=1|	6	suj	6	suj
# 5	en	en	CLO	CLO		6	aff	6	aff
# 6	sais	savoir	V	V	n=s|t=P|p=12|	1	dep_coord	1	dep_coord
# 7	rien	rien	PRO	PRO	n=s|g=m|	6	obj	6	obj
# 8	ouaich	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 22	je	je	CLS	CLS	n=s|p=1|	23	suj	23	suj
# 23	vais-	_	V	V	_	21	dep_coord	21	dep_coord
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	je	je	CLS	CLS	n=s|p=1|	25	suj	25	suj
# 25	vais	aller	V	V	n=s|t=P|p=1|	23	mod	23	mod
# 26	te	te	CLO	CLO	n=s|p=2|	27	obj	27	obj
# 27	dire	dire	VINF	VINF	t=W|	25	obj	25	obj
# 28	un	un	DET	DET	n=s|g=m|	29	det	29	det
# 29	truc-	_	NC	NC	_	27	obj	27	obj
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 30	je	je	CLS	CLS	n=s|p=1|	31	suj	31	suj
# 31	vais	aller	V	V	n=s|t=P|p=1|	25	mod	25	mod
# 32	te	te	CLO	CLO	n=s|p=2|	33	aff	33	aff
# 33	dire	dire	VINF	VINF	t=W|	31	obj	31	obj
# 34	un	un	DET	DET	n=s|g=m|	35	det	35	det
# 35	truc	truc	NC	NC	n=s|g=m|	33	obj	33	obj
# 36	attend	attendre	V	V	n=s|t=P|p=3|	31	mod	31	mod
# 37	Shaniss	_	NPP	NPP	_	39	suj	39	suj
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 38	&#195;&#169;coute-	_	NPP	NPP	_	37	mod	37	mod
# 39	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	31	mod	31	mod
# 40	moi-	_	ADV	ADV	_	39	mod	39	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 41	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	39	mod	39	mod
# 42	moi	moi	PRO	PRO	n=s|p=1|	41	obj	41	obj
# 43	je	je	CLS	CLS	n=s|p=1|	44	suj	44	suj
# 44	suis	&#195;&#170;tre	V	V	n=s|t=P|p=1|	42	mod_rel	42	mod_rel
# 45	s&#195;&#187;r	s&#195;&#187;r	ADJ	ADJ	n=s|g=m|	44	ats	44	ats
# 46	et	et	CC	CC		44	coord	44	coord
# 47	certain-	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 48	je	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 49	su-	_	NPP	NPP	_	0	_	0	_
# 50	(	(	PONCT	PONCT		49	ponct	49	ponct
# 51	re	_	NPP	NPP	_	49	mod	49	mod
# 52	)	)	PONCT	PONCT		51	ponct	51	ponct
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 1	tu	taire	VPP	VPP	n=s|g=m|t=K|	0	_	0	_
# 2	as-	_	ADV	ADV	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	la	la	DET	DET	n=s|g=f|	4	det	4	det
# 4	fille	fille	NC	NC	n=s|g=f|	1	obj	1	obj
# 5	qui	qui	PROREL	PROREL	n=s|	6	suj	6	suj
# 6	a	avoir	V	V	n=s|t=P|p=3|	4	mod_rel	4	mod_rel
# 7	du	de	P+D	P+D	n=s|g=m|	6	de_obj	6	de_obj
# 8	caract&#195;&#168;re	caract&#195;&#168;re	NC	NC	n=s|g=m|	7	prep	7	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	j-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	je	je	CLS	CLS	n=s|p=1|	4	suj	4	suj
# 4	crois	croire	V	V	n=s|t=P|p=12|	1	mod	1	mod
# 5	que	que	CS	CS		4	obj	4	obj
# 6	tu	tu	CLS	CLS	n=s|p=2|	8	suj	8	suj
# 7	me	me	CLO	CLO	n=s|p=1|	8	aff	8	aff
# 8	prends	prendre	V	V	n=s|t=P|p=12|	5	sub	5	sub
# 9	un	un	DET	DET	n=s|g=m|	18	det	18	det
# 10	petit	petit	ADJ	ADJ	n=s|g=m|	18	mod	18	mod
# 11	peu	peu	ADV	ADV		12	mod	12	mod
# 12	pour	pour	P	P		10	mod	10	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 13	une-	_	ADV	ADV	_	15	mod	15	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 14	une	une	DET	DET	n=s|g=f|	15	det	15	det
# 15	pimb&#195;&#168;che	_	NC	NC	_	12	prep	12	prep
# 16	un_peu	un_peu	ADV	ADV		18	mod	18	mod
# 17	une	une	DET	DET	n=s|g=f|	18	det	18	det
# 18	b&#195;&#170;-b&#195;&#170;te	_	NC	NC	_	8	obj	8	obj
# 19	hein	_	ADJ	ADJ	_	18	mod	18	mod
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 3	euh	_	NC	NC	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 4	euh	_	NC	NC	_	1	prep	1	prep
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	quand-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	quand	quand	CS	CS		15	mod	15	mod
# 7	je	je	CLS	CLS	n=s|p=1|	10	suj	10	suj
# 8	l'	l'	CLO	CLO	n=s|p=3|	10	obj	10	obj
# 9	ai	avoir	V	V	n=s|t=P|p=1|	10	aux_tps	10	aux_tps
# 10	touch&#195;&#169;e	toucher	VPP	VPP	n=s|g=f|t=K|	6	sub	6	sub
# 11	ah	_	ADV	ADV	_	10	mod	10	mod
# 12	ben	_	ADV	ADV	_	10	mod	10	mod
# 13	j'	je	CLS	CLS	n=s|p=1|	15	suj	15	suj
# 14	ai	avoir	V	V	n=s|t=P|p=1|	15	aux_tps	15	aux_tps
# 15	senti	sentir	VPP	VPP	n=s|g=m|t=K|	0	root	0	root
# 16	qu'	que	CS	CS		15	obj	15	obj
# 17	elle	elle	CLS	CLS	n=s|g=f|p=3|	18	suj	18	suj
# 18	avait	avoir	V	V	n=s|t=II|p=3|	16	sub	16	sub
# 19	un	un	DET	DET	n=s|g=m|	21	det	21	det
# 20	beau	beau	ADJ	ADJ	n=s|g=m|	21	mod	21	mod
# 21	corps	corps	NC	NC	g=m|	18	obj	18	obj
# 22	j'	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 23	ai	avoir	V	V	n=s|t=P|p=1|	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	euh	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 6	euh	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 7	assez	assez	ADV	ADV		8	mod	8	mod
# 8	mate	mat	ADJ	ADJ	n=s|g=f|	4	ats	4	ats
# 9	de	de	P	P		8	de_obj	8	de_obj
# 10	peau	peau	NC	NC	n=s|g=f|	9	prep	9	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	un-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	un	un	DET	DET	n=s|g=m|	8	det	8	det
# 7	beau	beau	ADJ	ADJ	n=s|g=m|	8	mod	8	mod
# 8	regard	regard	NC	NC	n=s|g=m|	4	prep	4	prep
# 9	parce_que	parce_que	CS	CS		1	mod	1	mod
# 10	le	le	DET	DET	n=s|g=m|	11	det	11	det
# 11	regard	regard	NC	NC	n=s|g=m|	13	suj	13	suj
# 12	&#195;&#167;a	&#195;&#167;a	PRO	PRO	n=s|	13	suj	13	suj
# 13	compte	compter	V	V	n=s|t=PS|p=13|	9	sub	9	sub
# 14	beaucoup	beaucoup	ADV	ADV		13	mod	13	mod
# 15	pour	pour	P	P		13	mod	13	mod
# 16	moi	moi	NC	NC	n=s|g=m|	15	prep	15	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 9	euh-	_	ADV	ADV	_	11	mod	11	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	bien	bien	ADV	ADV		11	mod	11	mod
# 11	propres	propre	ADJ	ADJ	n=p|	12	mod	12	mod
# 12	hein	_	NC	NC	_	5	mod	5	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 8	je-	_	NPP	NPP	_	7	dep_coord	7	dep_coord
# 9	je-	_	NPP	NPP	_	8	mod	8	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	je	je	CLS	CLS	n=s|p=1|	11	suj	11	suj
# 11	sais	savoir	V	V	n=s|t=P|p=12|	2	mod	2	mod
# 12	rien	rien	PRO	PRO	n=s|g=m|	11	obj	11	obj
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	je-	_	NC	NC	_	6	mod	6	mod
# 3	je-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 4	j'	je	CLS	CLS	n=s|p=1|	6	suj	6	suj
# 5	en	en	CLO	CLO		6	aff	6	aff
# 6	sais	savoir	V	V	n=s|t=P|p=12|	1	dep_coord	1	dep_coord
# 7	rien	rien	PRO	PRO	n=s|g=m|	6	obj	6	obj
# 8	ouaich	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 22	je	je	CLS	CLS	n=s|p=1|	23	suj	23	suj
# 23	vais-	_	V	V	_	21	dep_coord	21	dep_coord
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	je	je	CLS	CLS	n=s|p=1|	25	suj	25	suj
# 25	vais	aller	V	V	n=s|t=P|p=1|	23	mod	23	mod
# 26	te	te	CLO	CLO	n=s|p=2|	27	obj	27	obj
# 27	dire	dire	VINF	VINF	t=W|	25	obj	25	obj
# 28	un	un	DET	DET	n=s|g=m|	29	det	29	det
# 29	truc-	_	NC	NC	_	27	obj	27	obj
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 30	je	je	CLS	CLS	n=s|p=1|	31	suj	31	suj
# 31	vais	aller	V	V	n=s|t=P|p=1|	25	mod	25	mod
# 32	te	te	CLO	CLO	n=s|p=2|	33	aff	33	aff
# 33	dire	dire	VINF	VINF	t=W|	31	obj	31	obj
# 34	un	un	DET	DET	n=s|g=m|	35	det	35	det
# 35	truc	truc	NC	NC	n=s|g=m|	33	obj	33	obj
# 36	attend	attendre	V	V	n=s|t=P|p=3|	31	mod	31	mod
# 37	Shaniss	_	NPP	NPP	_	39	suj	39	suj
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 38	&#195;&#169;coute-	_	NPP	NPP	_	37	mod	37	mod
# 39	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	31	mod	31	mod
# 40	moi-	_	ADV	ADV	_	39	mod	39	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 41	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	39	mod	39	mod
# 42	moi	moi	PRO	PRO	n=s|p=1|	41	obj	41	obj
# 43	je	je	CLS	CLS	n=s|p=1|	44	suj	44	suj
# 44	suis	&#195;&#170;tre	V	V	n=s|t=P|p=1|	42	mod_rel	42	mod_rel
# 45	s&#195;&#187;r	s&#195;&#187;r	ADJ	ADJ	n=s|g=m|	44	ats	44	ats
# 46	et	et	CC	CC		44	coord	44	coord
# 47	certain-	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 48	je	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 49	su-	_	NPP	NPP	_	0	_	0	_
# 50	(	(	PONCT	PONCT		49	ponct	49	ponct
# 51	re	_	NPP	NPP	_	49	mod	49	mod
# 52	)	)	PONCT	PONCT		51	ponct	51	ponct
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 1	tu	taire	VPP	VPP	n=s|g=m|t=K|	0	_	0	_
# 2	as-	_	ADV	ADV	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	la	la	DET	DET	n=s|g=f|	4	det	4	det
# 4	fille	fille	NC	NC	n=s|g=f|	1	obj	1	obj
# 5	qui	qui	PROREL	PROREL	n=s|	6	suj	6	suj
# 6	a	avoir	V	V	n=s|t=P|p=3|	4	mod_rel	4	mod_rel
# 7	du	de	P+D	P+D	n=s|g=m|	6	de_obj	6	de_obj
# 8	caract&#195;&#168;re	caract&#195;&#168;re	NC	NC	n=s|g=m|	7	prep	7	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	j-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	je	je	CLS	CLS	n=s|p=1|	4	suj	4	suj
# 4	crois	croire	V	V	n=s|t=P|p=12|	1	mod	1	mod
# 5	que	que	CS	CS		4	obj	4	obj
# 6	tu	tu	CLS	CLS	n=s|p=2|	8	suj	8	suj
# 7	me	me	CLO	CLO	n=s|p=1|	8	aff	8	aff
# 8	prends	prendre	V	V	n=s|t=P|p=12|	5	sub	5	sub
# 9	un	un	DET	DET	n=s|g=m|	18	det	18	det
# 10	petit	petit	ADJ	ADJ	n=s|g=m|	18	mod	18	mod
# 11	peu	peu	ADV	ADV		12	mod	12	mod
# 12	pour	pour	P	P		10	mod	10	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 13	une-	_	ADV	ADV	_	15	mod	15	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 14	une	une	DET	DET	n=s|g=f|	15	det	15	det
# 15	pimb&#195;&#168;che	_	NC	NC	_	12	prep	12	prep
# 16	un_peu	un_peu	ADV	ADV		18	mod	18	mod
# 17	une	une	DET	DET	n=s|g=f|	18	det	18	det
# 18	b&#195;&#170;-b&#195;&#170;te	_	NC	NC	_	8	obj	8	obj
# 19	hein	_	ADJ	ADJ	_	18	mod	18	mod
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 3	euh	_	NC	NC	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 4	euh	_	NC	NC	_	1	prep	1	prep
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	quand-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	quand	quand	CS	CS		15	mod	15	mod
# 7	je	je	CLS	CLS	n=s|p=1|	10	suj	10	suj
# 8	l'	l'	CLO	CLO	n=s|p=3|	10	obj	10	obj
# 9	ai	avoir	V	V	n=s|t=P|p=1|	10	aux_tps	10	aux_tps
# 10	touch&#195;&#169;e	toucher	VPP	VPP	n=s|g=f|t=K|	6	sub	6	sub
# 11	ah	_	ADV	ADV	_	10	mod	10	mod
# 12	ben	_	ADV	ADV	_	10	mod	10	mod
# 13	j'	je	CLS	CLS	n=s|p=1|	15	suj	15	suj
# 14	ai	avoir	V	V	n=s|t=P|p=1|	15	aux_tps	15	aux_tps
# 15	senti	sentir	VPP	VPP	n=s|g=m|t=K|	0	root	0	root
# 16	qu'	que	CS	CS		15	obj	15	obj
# 17	elle	elle	CLS	CLS	n=s|g=f|p=3|	18	suj	18	suj
# 18	avait	avoir	V	V	n=s|t=II|p=3|	16	sub	16	sub
# 19	un	un	DET	DET	n=s|g=m|	21	det	21	det
# 20	beau	beau	ADJ	ADJ	n=s|g=m|	21	mod	21	mod
# 21	corps	corps	NC	NC	g=m|	18	obj	18	obj
# 22	j'	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 23	ai	avoir	V	V	n=s|t=P|p=1|	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	euh	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 6	euh	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 7	assez	assez	ADV	ADV		8	mod	8	mod
# 8	mate	mat	ADJ	ADJ	n=s|g=f|	4	ats	4	ats
# 9	de	de	P	P		8	de_obj	8	de_obj
# 10	peau	peau	NC	NC	n=s|g=f|	9	prep	9	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	un-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	un	un	DET	DET	n=s|g=m|	8	det	8	det
# 7	beau	beau	ADJ	ADJ	n=s|g=m|	8	mod	8	mod
# 8	regard	regard	NC	NC	n=s|g=m|	4	prep	4	prep
# 9	parce_que	parce_que	CS	CS		1	mod	1	mod
# 10	le	le	DET	DET	n=s|g=m|	11	det	11	det
# 11	regard	regard	NC	NC	n=s|g=m|	13	suj	13	suj
# 12	&#195;&#167;a	&#195;&#167;a	PRO	PRO	n=s|	13	suj	13	suj
# 13	compte	compter	V	V	n=s|t=PS|p=13|	9	sub	9	sub
# 14	beaucoup	beaucoup	ADV	ADV		13	mod	13	mod
# 15	pour	pour	P	P		13	mod	13	mod
# 16	moi	moi	NC	NC	n=s|g=m|	15	prep	15	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 9	euh-	_	ADV	ADV	_	11	mod	11	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	bien	bien	ADV	ADV		11	mod	11	mod
# 11	propres	propre	ADJ	ADJ	n=p|	12	mod	12	mod
# 12	hein	_	NC	NC	_	5	mod	5	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 8	je-	_	NPP	NPP	_	7	dep_coord	7	dep_coord
# 9	je-	_	NPP	NPP	_	8	mod	8	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	je	je	CLS	CLS	n=s|p=1|	11	suj	11	suj
# 11	sais	savoir	V	V	n=s|t=P|p=12|	2	mod	2	mod
# 12	rien	rien	PRO	PRO	n=s|g=m|	11	obj	11	obj
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	je-	_	NC	NC	_	6	mod	6	mod
# 3	je-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 4	j'	je	CLS	CLS	n=s|p=1|	6	suj	6	suj
# 5	en	en	CLO	CLO		6	aff	6	aff
# 6	sais	savoir	V	V	n=s|t=P|p=12|	1	dep_coord	1	dep_coord
# 7	rien	rien	PRO	PRO	n=s|g=m|	6	obj	6	obj
# 8	ouaich	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 22	je	je	CLS	CLS	n=s|p=1|	23	suj	23	suj
# 23	vais-	_	V	V	_	21	dep_coord	21	dep_coord
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	je	je	CLS	CLS	n=s|p=1|	25	suj	25	suj
# 25	vais	aller	V	V	n=s|t=P|p=1|	23	mod	23	mod
# 26	te	te	CLO	CLO	n=s|p=2|	27	obj	27	obj
# 27	dire	dire	VINF	VINF	t=W|	25	obj	25	obj
# 28	un	un	DET	DET	n=s|g=m|	29	det	29	det
# 29	truc-	_	NC	NC	_	27	obj	27	obj
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 30	je	je	CLS	CLS	n=s|p=1|	31	suj	31	suj
# 31	vais	aller	V	V	n=s|t=P|p=1|	25	mod	25	mod
# 32	te	te	CLO	CLO	n=s|p=2|	33	aff	33	aff
# 33	dire	dire	VINF	VINF	t=W|	31	obj	31	obj
# 34	un	un	DET	DET	n=s|g=m|	35	det	35	det
# 35	truc	truc	NC	NC	n=s|g=m|	33	obj	33	obj
# 36	attend	attendre	V	V	n=s|t=P|p=3|	31	mod	31	mod
# 37	Shaniss	_	NPP	NPP	_	39	suj	39	suj
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 38	&#195;&#169;coute-	_	NPP	NPP	_	37	mod	37	mod
# 39	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	31	mod	31	mod
# 40	moi-	_	ADV	ADV	_	39	mod	39	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 41	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	39	mod	39	mod
# 42	moi	moi	PRO	PRO	n=s|p=1|	41	obj	41	obj
# 43	je	je	CLS	CLS	n=s|p=1|	44	suj	44	suj
# 44	suis	&#195;&#170;tre	V	V	n=s|t=P|p=1|	42	mod_rel	42	mod_rel
# 45	s&#195;&#187;r	s&#195;&#187;r	ADJ	ADJ	n=s|g=m|	44	ats	44	ats
# 46	et	et	CC	CC		44	coord	44	coord
# 47	certain-	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 48	je	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 49	su-	_	NPP	NPP	_	0	_	0	_
# 50	(	(	PONCT	PONCT		49	ponct	49	ponct
# 51	re	_	NPP	NPP	_	49	mod	49	mod
# 52	)	)	PONCT	PONCT		51	ponct	51	ponct
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 1	tu	taire	VPP	VPP	n=s|g=m|t=K|	0	_	0	_
# 2	as-	_	ADV	ADV	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	la	la	DET	DET	n=s|g=f|	4	det	4	det
# 4	fille	fille	NC	NC	n=s|g=f|	1	obj	1	obj
# 5	qui	qui	PROREL	PROREL	n=s|	6	suj	6	suj
# 6	a	avoir	V	V	n=s|t=P|p=3|	4	mod_rel	4	mod_rel
# 7	du	de	P+D	P+D	n=s|g=m|	6	de_obj	6	de_obj
# 8	caract&#195;&#168;re	caract&#195;&#168;re	NC	NC	n=s|g=m|	7	prep	7	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	j-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	je	je	CLS	CLS	n=s|p=1|	4	suj	4	suj
# 4	crois	croire	V	V	n=s|t=P|p=12|	1	mod	1	mod
# 5	que	que	CS	CS		4	obj	4	obj
# 6	tu	tu	CLS	CLS	n=s|p=2|	8	suj	8	suj
# 7	me	me	CLO	CLO	n=s|p=1|	8	aff	8	aff
# 8	prends	prendre	V	V	n=s|t=P|p=12|	5	sub	5	sub
# 9	un	un	DET	DET	n=s|g=m|	18	det	18	det
# 10	petit	petit	ADJ	ADJ	n=s|g=m|	18	mod	18	mod
# 11	peu	peu	ADV	ADV		12	mod	12	mod
# 12	pour	pour	P	P		10	mod	10	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 13	une-	_	ADV	ADV	_	15	mod	15	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 14	une	une	DET	DET	n=s|g=f|	15	det	15	det
# 15	pimb&#195;&#168;che	_	NC	NC	_	12	prep	12	prep
# 16	un_peu	un_peu	ADV	ADV		18	mod	18	mod
# 17	une	une	DET	DET	n=s|g=f|	18	det	18	det
# 18	b&#195;&#170;-b&#195;&#170;te	_	NC	NC	_	8	obj	8	obj
# 19	hein	_	ADJ	ADJ	_	18	mod	18	mod
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 3	euh	_	NC	NC	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 4	euh	_	NC	NC	_	1	prep	1	prep
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	quand-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	quand	quand	CS	CS		15	mod	15	mod
# 7	je	je	CLS	CLS	n=s|p=1|	10	suj	10	suj
# 8	l'	l'	CLO	CLO	n=s|p=3|	10	obj	10	obj
# 9	ai	avoir	V	V	n=s|t=P|p=1|	10	aux_tps	10	aux_tps
# 10	touch&#195;&#169;e	toucher	VPP	VPP	n=s|g=f|t=K|	6	sub	6	sub
# 11	ah	_	ADV	ADV	_	10	mod	10	mod
# 12	ben	_	ADV	ADV	_	10	mod	10	mod
# 13	j'	je	CLS	CLS	n=s|p=1|	15	suj	15	suj
# 14	ai	avoir	V	V	n=s|t=P|p=1|	15	aux_tps	15	aux_tps
# 15	senti	sentir	VPP	VPP	n=s|g=m|t=K|	0	root	0	root
# 16	qu'	que	CS	CS		15	obj	15	obj
# 17	elle	elle	CLS	CLS	n=s|g=f|p=3|	18	suj	18	suj
# 18	avait	avoir	V	V	n=s|t=II|p=3|	16	sub	16	sub
# 19	un	un	DET	DET	n=s|g=m|	21	det	21	det
# 20	beau	beau	ADJ	ADJ	n=s|g=m|	21	mod	21	mod
# 21	corps	corps	NC	NC	g=m|	18	obj	18	obj
# 22	j'	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 23	ai	avoir	V	V	n=s|t=P|p=1|	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	euh	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 6	euh	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 7	assez	assez	ADV	ADV		8	mod	8	mod
# 8	mate	mat	ADJ	ADJ	n=s|g=f|	4	ats	4	ats
# 9	de	de	P	P		8	de_obj	8	de_obj
# 10	peau	peau	NC	NC	n=s|g=f|	9	prep	9	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	un-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	un	un	DET	DET	n=s|g=m|	8	det	8	det
# 7	beau	beau	ADJ	ADJ	n=s|g=m|	8	mod	8	mod
# 8	regard	regard	NC	NC	n=s|g=m|	4	prep	4	prep
# 9	parce_que	parce_que	CS	CS		1	mod	1	mod
# 10	le	le	DET	DET	n=s|g=m|	11	det	11	det
# 11	regard	regard	NC	NC	n=s|g=m|	13	suj	13	suj
# 12	&#195;&#167;a	&#195;&#167;a	PRO	PRO	n=s|	13	suj	13	suj
# 13	compte	compter	V	V	n=s|t=PS|p=13|	9	sub	9	sub
# 14	beaucoup	beaucoup	ADV	ADV		13	mod	13	mod
# 15	pour	pour	P	P		13	mod	13	mod
# 16	moi	moi	NC	NC	n=s|g=m|	15	prep	15	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 9	euh-	_	ADV	ADV	_	11	mod	11	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	bien	bien	ADV	ADV		11	mod	11	mod
# 11	propres	propre	ADJ	ADJ	n=p|	12	mod	12	mod
# 12	hein	_	NC	NC	_	5	mod	5	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 8	je-	_	NPP	NPP	_	7	dep_coord	7	dep_coord
# 9	je-	_	NPP	NPP	_	8	mod	8	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	je	je	CLS	CLS	n=s|p=1|	11	suj	11	suj
# 11	sais	savoir	V	V	n=s|t=P|p=12|	2	mod	2	mod
# 12	rien	rien	PRO	PRO	n=s|g=m|	11	obj	11	obj
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	je-	_	NC	NC	_	6	mod	6	mod
# 3	je-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 4	j'	je	CLS	CLS	n=s|p=1|	6	suj	6	suj
# 5	en	en	CLO	CLO		6	aff	6	aff
# 6	sais	savoir	V	V	n=s|t=P|p=12|	1	dep_coord	1	dep_coord
# 7	rien	rien	PRO	PRO	n=s|g=m|	6	obj	6	obj
# 8	ouaich	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 22	je	je	CLS	CLS	n=s|p=1|	23	suj	23	suj
# 23	vais-	_	V	V	_	21	dep_coord	21	dep_coord
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	je	je	CLS	CLS	n=s|p=1|	25	suj	25	suj
# 25	vais	aller	V	V	n=s|t=P|p=1|	23	mod	23	mod
# 26	te	te	CLO	CLO	n=s|p=2|	27	obj	27	obj
# 27	dire	dire	VINF	VINF	t=W|	25	obj	25	obj
# 28	un	un	DET	DET	n=s|g=m|	29	det	29	det
# 29	truc-	_	NC	NC	_	27	obj	27	obj
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 30	je	je	CLS	CLS	n=s|p=1|	31	suj	31	suj
# 31	vais	aller	V	V	n=s|t=P|p=1|	25	mod	25	mod
# 32	te	te	CLO	CLO	n=s|p=2|	33	aff	33	aff
# 33	dire	dire	VINF	VINF	t=W|	31	obj	31	obj
# 34	un	un	DET	DET	n=s|g=m|	35	det	35	det
# 35	truc	truc	NC	NC	n=s|g=m|	33	obj	33	obj
# 36	attend	attendre	V	V	n=s|t=P|p=3|	31	mod	31	mod
# 37	Shaniss	_	NPP	NPP	_	39	suj	39	suj
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 38	&#195;&#169;coute-	_	NPP	NPP	_	37	mod	37	mod
# 39	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	31	mod	31	mod
# 40	moi-	_	ADV	ADV	_	39	mod	39	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 41	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	39	mod	39	mod
# 42	moi	moi	PRO	PRO	n=s|p=1|	41	obj	41	obj
# 43	je	je	CLS	CLS	n=s|p=1|	44	suj	44	suj
# 44	suis	&#195;&#170;tre	V	V	n=s|t=P|p=1|	42	mod_rel	42	mod_rel
# 45	s&#195;&#187;r	s&#195;&#187;r	ADJ	ADJ	n=s|g=m|	44	ats	44	ats
# 46	et	et	CC	CC		44	coord	44	coord
# 47	certain-	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 48	je	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 49	su-	_	NPP	NPP	_	0	_	0	_
# 50	(	(	PONCT	PONCT		49	ponct	49	ponct
# 51	re	_	NPP	NPP	_	49	mod	49	mod
# 52	)	)	PONCT	PONCT		51	ponct	51	ponct
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 1	tu	taire	VPP	VPP	n=s|g=m|t=K|	0	_	0	_
# 2	as-	_	ADV	ADV	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	la	la	DET	DET	n=s|g=f|	4	det	4	det
# 4	fille	fille	NC	NC	n=s|g=f|	1	obj	1	obj
# 5	qui	qui	PROREL	PROREL	n=s|	6	suj	6	suj
# 6	a	avoir	V	V	n=s|t=P|p=3|	4	mod_rel	4	mod_rel
# 7	du	de	P+D	P+D	n=s|g=m|	6	de_obj	6	de_obj
# 8	caract&#195;&#168;re	caract&#195;&#168;re	NC	NC	n=s|g=m|	7	prep	7	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	j-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	je	je	CLS	CLS	n=s|p=1|	4	suj	4	suj
# 4	crois	croire	V	V	n=s|t=P|p=12|	1	mod	1	mod
# 5	que	que	CS	CS		4	obj	4	obj
# 6	tu	tu	CLS	CLS	n=s|p=2|	8	suj	8	suj
# 7	me	me	CLO	CLO	n=s|p=1|	8	aff	8	aff
# 8	prends	prendre	V	V	n=s|t=P|p=12|	5	sub	5	sub
# 9	un	un	DET	DET	n=s|g=m|	18	det	18	det
# 10	petit	petit	ADJ	ADJ	n=s|g=m|	18	mod	18	mod
# 11	peu	peu	ADV	ADV		12	mod	12	mod
# 12	pour	pour	P	P		10	mod	10	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 13	une-	_	ADV	ADV	_	15	mod	15	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 14	une	une	DET	DET	n=s|g=f|	15	det	15	det
# 15	pimb&#195;&#168;che	_	NC	NC	_	12	prep	12	prep
# 16	un_peu	un_peu	ADV	ADV		18	mod	18	mod
# 17	une	une	DET	DET	n=s|g=f|	18	det	18	det
# 18	b&#195;&#170;-b&#195;&#170;te	_	NC	NC	_	8	obj	8	obj
# 19	hein	_	ADJ	ADJ	_	18	mod	18	mod
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 3	euh	_	NC	NC	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 4	euh	_	NC	NC	_	1	prep	1	prep
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	quand-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	quand	quand	CS	CS		15	mod	15	mod
# 7	je	je	CLS	CLS	n=s|p=1|	10	suj	10	suj
# 8	l'	l'	CLO	CLO	n=s|p=3|	10	obj	10	obj
# 9	ai	avoir	V	V	n=s|t=P|p=1|	10	aux_tps	10	aux_tps
# 10	touch&#195;&#169;e	toucher	VPP	VPP	n=s|g=f|t=K|	6	sub	6	sub
# 11	ah	_	ADV	ADV	_	10	mod	10	mod
# 12	ben	_	ADV	ADV	_	10	mod	10	mod
# 13	j'	je	CLS	CLS	n=s|p=1|	15	suj	15	suj
# 14	ai	avoir	V	V	n=s|t=P|p=1|	15	aux_tps	15	aux_tps
# 15	senti	sentir	VPP	VPP	n=s|g=m|t=K|	0	root	0	root
# 16	qu'	que	CS	CS		15	obj	15	obj
# 17	elle	elle	CLS	CLS	n=s|g=f|p=3|	18	suj	18	suj
# 18	avait	avoir	V	V	n=s|t=II|p=3|	16	sub	16	sub
# 19	un	un	DET	DET	n=s|g=m|	21	det	21	det
# 20	beau	beau	ADJ	ADJ	n=s|g=m|	21	mod	21	mod
# 21	corps	corps	NC	NC	g=m|	18	obj	18	obj
# 22	j'	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 23	ai	avoir	V	V	n=s|t=P|p=1|	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	euh	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 6	euh	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 7	assez	assez	ADV	ADV		8	mod	8	mod
# 8	mate	mat	ADJ	ADJ	n=s|g=f|	4	ats	4	ats
# 9	de	de	P	P		8	de_obj	8	de_obj
# 10	peau	peau	NC	NC	n=s|g=f|	9	prep	9	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	un-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	un	un	DET	DET	n=s|g=m|	8	det	8	det
# 7	beau	beau	ADJ	ADJ	n=s|g=m|	8	mod	8	mod
# 8	regard	regard	NC	NC	n=s|g=m|	4	prep	4	prep
# 9	parce_que	parce_que	CS	CS		1	mod	1	mod
# 10	le	le	DET	DET	n=s|g=m|	11	det	11	det
# 11	regard	regard	NC	NC	n=s|g=m|	13	suj	13	suj
# 12	&#195;&#167;a	&#195;&#167;a	PRO	PRO	n=s|	13	suj	13	suj
# 13	compte	compter	V	V	n=s|t=PS|p=13|	9	sub	9	sub
# 14	beaucoup	beaucoup	ADV	ADV		13	mod	13	mod
# 15	pour	pour	P	P		13	mod	13	mod
# 16	moi	moi	NC	NC	n=s|g=m|	15	prep	15	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 9	euh-	_	ADV	ADV	_	11	mod	11	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	bien	bien	ADV	ADV		11	mod	11	mod
# 11	propres	propre	ADJ	ADJ	n=p|	12	mod	12	mod
# 12	hein	_	NC	NC	_	5	mod	5	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 8	je-	_	NPP	NPP	_	7	dep_coord	7	dep_coord
# 9	je-	_	NPP	NPP	_	8	mod	8	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	je	je	CLS	CLS	n=s|p=1|	11	suj	11	suj
# 11	sais	savoir	V	V	n=s|t=P|p=12|	2	mod	2	mod
# 12	rien	rien	PRO	PRO	n=s|g=m|	11	obj	11	obj
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	je-	_	NC	NC	_	6	mod	6	mod
# 3	je-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 4	j'	je	CLS	CLS	n=s|p=1|	6	suj	6	suj
# 5	en	en	CLO	CLO		6	aff	6	aff
# 6	sais	savoir	V	V	n=s|t=P|p=12|	1	dep_coord	1	dep_coord
# 7	rien	rien	PRO	PRO	n=s|g=m|	6	obj	6	obj
# 8	ouaich	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 22	je	je	CLS	CLS	n=s|p=1|	23	suj	23	suj
# 23	vais-	_	V	V	_	21	dep_coord	21	dep_coord
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	je	je	CLS	CLS	n=s|p=1|	25	suj	25	suj
# 25	vais	aller	V	V	n=s|t=P|p=1|	23	mod	23	mod
# 26	te	te	CLO	CLO	n=s|p=2|	27	obj	27	obj
# 27	dire	dire	VINF	VINF	t=W|	25	obj	25	obj
# 28	un	un	DET	DET	n=s|g=m|	29	det	29	det
# 29	truc-	_	NC	NC	_	27	obj	27	obj
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 30	je	je	CLS	CLS	n=s|p=1|	31	suj	31	suj
# 31	vais	aller	V	V	n=s|t=P|p=1|	25	mod	25	mod
# 32	te	te	CLO	CLO	n=s|p=2|	33	aff	33	aff
# 33	dire	dire	VINF	VINF	t=W|	31	obj	31	obj
# 34	un	un	DET	DET	n=s|g=m|	35	det	35	det
# 35	truc	truc	NC	NC	n=s|g=m|	33	obj	33	obj
# 36	attend	attendre	V	V	n=s|t=P|p=3|	31	mod	31	mod
# 37	Shaniss	_	NPP	NPP	_	39	suj	39	suj
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 38	&#195;&#169;coute-	_	NPP	NPP	_	37	mod	37	mod
# 39	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	31	mod	31	mod
# 40	moi-	_	ADV	ADV	_	39	mod	39	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 41	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	39	mod	39	mod
# 42	moi	moi	PRO	PRO	n=s|p=1|	41	obj	41	obj
# 43	je	je	CLS	CLS	n=s|p=1|	44	suj	44	suj
# 44	suis	&#195;&#170;tre	V	V	n=s|t=P|p=1|	42	mod_rel	42	mod_rel
# 45	s&#195;&#187;r	s&#195;&#187;r	ADJ	ADJ	n=s|g=m|	44	ats	44	ats
# 46	et	et	CC	CC		44	coord	44	coord
# 47	certain-	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 48	je	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 49	su-	_	NPP	NPP	_	0	_	0	_
# 50	(	(	PONCT	PONCT		49	ponct	49	ponct
# 51	re	_	NPP	NPP	_	49	mod	49	mod
# 52	)	)	PONCT	PONCT		51	ponct	51	ponct
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 1	tu	taire	VPP	VPP	n=s|g=m|t=K|	0	_	0	_
# 2	as-	_	ADV	ADV	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	la	la	DET	DET	n=s|g=f|	4	det	4	det
# 4	fille	fille	NC	NC	n=s|g=f|	1	obj	1	obj
# 5	qui	qui	PROREL	PROREL	n=s|	6	suj	6	suj
# 6	a	avoir	V	V	n=s|t=P|p=3|	4	mod_rel	4	mod_rel
# 7	du	de	P+D	P+D	n=s|g=m|	6	de_obj	6	de_obj
# 8	caract&#195;&#168;re	caract&#195;&#168;re	NC	NC	n=s|g=m|	7	prep	7	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	j-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	je	je	CLS	CLS	n=s|p=1|	4	suj	4	suj
# 4	crois	croire	V	V	n=s|t=P|p=12|	1	mod	1	mod
# 5	que	que	CS	CS		4	obj	4	obj
# 6	tu	tu	CLS	CLS	n=s|p=2|	8	suj	8	suj
# 7	me	me	CLO	CLO	n=s|p=1|	8	aff	8	aff
# 8	prends	prendre	V	V	n=s|t=P|p=12|	5	sub	5	sub
# 9	un	un	DET	DET	n=s|g=m|	18	det	18	det
# 10	petit	petit	ADJ	ADJ	n=s|g=m|	18	mod	18	mod
# 11	peu	peu	ADV	ADV		12	mod	12	mod
# 12	pour	pour	P	P		10	mod	10	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 13	une-	_	ADV	ADV	_	15	mod	15	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 14	une	une	DET	DET	n=s|g=f|	15	det	15	det
# 15	pimb&#195;&#168;che	_	NC	NC	_	12	prep	12	prep
# 16	un_peu	un_peu	ADV	ADV		18	mod	18	mod
# 17	une	une	DET	DET	n=s|g=f|	18	det	18	det
# 18	b&#195;&#170;-b&#195;&#170;te	_	NC	NC	_	8	obj	8	obj
# 19	hein	_	ADJ	ADJ	_	18	mod	18	mod
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 3	euh	_	NC	NC	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 4	euh	_	NC	NC	_	1	prep	1	prep
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	quand-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	quand	quand	CS	CS		15	mod	15	mod
# 7	je	je	CLS	CLS	n=s|p=1|	10	suj	10	suj
# 8	l'	l'	CLO	CLO	n=s|p=3|	10	obj	10	obj
# 9	ai	avoir	V	V	n=s|t=P|p=1|	10	aux_tps	10	aux_tps
# 10	touch&#195;&#169;e	toucher	VPP	VPP	n=s|g=f|t=K|	6	sub	6	sub
# 11	ah	_	ADV	ADV	_	10	mod	10	mod
# 12	ben	_	ADV	ADV	_	10	mod	10	mod
# 13	j'	je	CLS	CLS	n=s|p=1|	15	suj	15	suj
# 14	ai	avoir	V	V	n=s|t=P|p=1|	15	aux_tps	15	aux_tps
# 15	senti	sentir	VPP	VPP	n=s|g=m|t=K|	0	root	0	root
# 16	qu'	que	CS	CS		15	obj	15	obj
# 17	elle	elle	CLS	CLS	n=s|g=f|p=3|	18	suj	18	suj
# 18	avait	avoir	V	V	n=s|t=II|p=3|	16	sub	16	sub
# 19	un	un	DET	DET	n=s|g=m|	21	det	21	det
# 20	beau	beau	ADJ	ADJ	n=s|g=m|	21	mod	21	mod
# 21	corps	corps	NC	NC	g=m|	18	obj	18	obj
# 22	j'	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 23	ai	avoir	V	V	n=s|t=P|p=1|	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	euh	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 6	euh	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 7	assez	assez	ADV	ADV		8	mod	8	mod
# 8	mate	mat	ADJ	ADJ	n=s|g=f|	4	ats	4	ats
# 9	de	de	P	P		8	de_obj	8	de_obj
# 10	peau	peau	NC	NC	n=s|g=f|	9	prep	9	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	un-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	un	un	DET	DET	n=s|g=m|	8	det	8	det
# 7	beau	beau	ADJ	ADJ	n=s|g=m|	8	mod	8	mod
# 8	regard	regard	NC	NC	n=s|g=m|	4	prep	4	prep
# 9	parce_que	parce_que	CS	CS		1	mod	1	mod
# 10	le	le	DET	DET	n=s|g=m|	11	det	11	det
# 11	regard	regard	NC	NC	n=s|g=m|	13	suj	13	suj
# 12	&#195;&#167;a	&#195;&#167;a	PRO	PRO	n=s|	13	suj	13	suj
# 13	compte	compter	V	V	n=s|t=PS|p=13|	9	sub	9	sub
# 14	beaucoup	beaucoup	ADV	ADV		13	mod	13	mod
# 15	pour	pour	P	P		13	mod	13	mod
# 16	moi	moi	NC	NC	n=s|g=m|	15	prep	15	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 9	euh-	_	ADV	ADV	_	11	mod	11	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	bien	bien	ADV	ADV		11	mod	11	mod
# 11	propres	propre	ADJ	ADJ	n=p|	12	mod	12	mod
# 12	hein	_	NC	NC	_	5	mod	5	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 8	je-	_	NPP	NPP	_	7	dep_coord	7	dep_coord
# 9	je-	_	NPP	NPP	_	8	mod	8	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	je	je	CLS	CLS	n=s|p=1|	11	suj	11	suj
# 11	sais	savoir	V	V	n=s|t=P|p=12|	2	mod	2	mod
# 12	rien	rien	PRO	PRO	n=s|g=m|	11	obj	11	obj
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	je-	_	NC	NC	_	6	mod	6	mod
# 3	je-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 4	j'	je	CLS	CLS	n=s|p=1|	6	suj	6	suj
# 5	en	en	CLO	CLO		6	aff	6	aff
# 6	sais	savoir	V	V	n=s|t=P|p=12|	1	dep_coord	1	dep_coord
# 7	rien	rien	PRO	PRO	n=s|g=m|	6	obj	6	obj
# 8	ouaich	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 22	je	je	CLS	CLS	n=s|p=1|	23	suj	23	suj
# 23	vais-	_	V	V	_	21	dep_coord	21	dep_coord
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	je	je	CLS	CLS	n=s|p=1|	25	suj	25	suj
# 25	vais	aller	V	V	n=s|t=P|p=1|	23	mod	23	mod
# 26	te	te	CLO	CLO	n=s|p=2|	27	obj	27	obj
# 27	dire	dire	VINF	VINF	t=W|	25	obj	25	obj
# 28	un	un	DET	DET	n=s|g=m|	29	det	29	det
# 29	truc-	_	NC	NC	_	27	obj	27	obj
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 30	je	je	CLS	CLS	n=s|p=1|	31	suj	31	suj
# 31	vais	aller	V	V	n=s|t=P|p=1|	25	mod	25	mod
# 32	te	te	CLO	CLO	n=s|p=2|	33	aff	33	aff
# 33	dire	dire	VINF	VINF	t=W|	31	obj	31	obj
# 34	un	un	DET	DET	n=s|g=m|	35	det	35	det
# 35	truc	truc	NC	NC	n=s|g=m|	33	obj	33	obj
# 36	attend	attendre	V	V	n=s|t=P|p=3|	31	mod	31	mod
# 37	Shaniss	_	NPP	NPP	_	39	suj	39	suj
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 38	&#195;&#169;coute-	_	NPP	NPP	_	37	mod	37	mod
# 39	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	31	mod	31	mod
# 40	moi-	_	ADV	ADV	_	39	mod	39	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 41	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	39	mod	39	mod
# 42	moi	moi	PRO	PRO	n=s|p=1|	41	obj	41	obj
# 43	je	je	CLS	CLS	n=s|p=1|	44	suj	44	suj
# 44	suis	&#195;&#170;tre	V	V	n=s|t=P|p=1|	42	mod_rel	42	mod_rel
# 45	s&#195;&#187;r	s&#195;&#187;r	ADJ	ADJ	n=s|g=m|	44	ats	44	ats
# 46	et	et	CC	CC		44	coord	44	coord
# 47	certain-	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 48	je	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 49	su-	_	NPP	NPP	_	0	_	0	_
# 50	(	(	PONCT	PONCT		49	ponct	49	ponct
# 51	re	_	NPP	NPP	_	49	mod	49	mod
# 52	)	)	PONCT	PONCT		51	ponct	51	ponct
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 1	tu	taire	VPP	VPP	n=s|g=m|t=K|	0	_	0	_
# 2	as-	_	ADV	ADV	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	la	la	DET	DET	n=s|g=f|	4	det	4	det
# 4	fille	fille	NC	NC	n=s|g=f|	1	obj	1	obj
# 5	qui	qui	PROREL	PROREL	n=s|	6	suj	6	suj
# 6	a	avoir	V	V	n=s|t=P|p=3|	4	mod_rel	4	mod_rel
# 7	du	de	P+D	P+D	n=s|g=m|	6	de_obj	6	de_obj
# 8	caract&#195;&#168;re	caract&#195;&#168;re	NC	NC	n=s|g=m|	7	prep	7	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	j-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	je	je	CLS	CLS	n=s|p=1|	4	suj	4	suj
# 4	crois	croire	V	V	n=s|t=P|p=12|	1	mod	1	mod
# 5	que	que	CS	CS		4	obj	4	obj
# 6	tu	tu	CLS	CLS	n=s|p=2|	8	suj	8	suj
# 7	me	me	CLO	CLO	n=s|p=1|	8	aff	8	aff
# 8	prends	prendre	V	V	n=s|t=P|p=12|	5	sub	5	sub
# 9	un	un	DET	DET	n=s|g=m|	18	det	18	det
# 10	petit	petit	ADJ	ADJ	n=s|g=m|	18	mod	18	mod
# 11	peu	peu	ADV	ADV		12	mod	12	mod
# 12	pour	pour	P	P		10	mod	10	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 13	une-	_	ADV	ADV	_	15	mod	15	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 14	une	une	DET	DET	n=s|g=f|	15	det	15	det
# 15	pimb&#195;&#168;che	_	NC	NC	_	12	prep	12	prep
# 16	un_peu	un_peu	ADV	ADV		18	mod	18	mod
# 17	une	une	DET	DET	n=s|g=f|	18	det	18	det
# 18	b&#195;&#170;-b&#195;&#170;te	_	NC	NC	_	8	obj	8	obj
# 19	hein	_	ADJ	ADJ	_	18	mod	18	mod
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 3	euh	_	NC	NC	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 4	euh	_	NC	NC	_	1	prep	1	prep
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	quand-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	quand	quand	CS	CS		15	mod	15	mod
# 7	je	je	CLS	CLS	n=s|p=1|	10	suj	10	suj
# 8	l'	l'	CLO	CLO	n=s|p=3|	10	obj	10	obj
# 9	ai	avoir	V	V	n=s|t=P|p=1|	10	aux_tps	10	aux_tps
# 10	touch&#195;&#169;e	toucher	VPP	VPP	n=s|g=f|t=K|	6	sub	6	sub
# 11	ah	_	ADV	ADV	_	10	mod	10	mod
# 12	ben	_	ADV	ADV	_	10	mod	10	mod
# 13	j'	je	CLS	CLS	n=s|p=1|	15	suj	15	suj
# 14	ai	avoir	V	V	n=s|t=P|p=1|	15	aux_tps	15	aux_tps
# 15	senti	sentir	VPP	VPP	n=s|g=m|t=K|	0	root	0	root
# 16	qu'	que	CS	CS		15	obj	15	obj
# 17	elle	elle	CLS	CLS	n=s|g=f|p=3|	18	suj	18	suj
# 18	avait	avoir	V	V	n=s|t=II|p=3|	16	sub	16	sub
# 19	un	un	DET	DET	n=s|g=m|	21	det	21	det
# 20	beau	beau	ADJ	ADJ	n=s|g=m|	21	mod	21	mod
# 21	corps	corps	NC	NC	g=m|	18	obj	18	obj
# 22	j'	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 23	ai	avoir	V	V	n=s|t=P|p=1|	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	euh	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 6	euh	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 7	assez	assez	ADV	ADV		8	mod	8	mod
# 8	mate	mat	ADJ	ADJ	n=s|g=f|	4	ats	4	ats
# 9	de	de	P	P		8	de_obj	8	de_obj
# 10	peau	peau	NC	NC	n=s|g=f|	9	prep	9	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	un-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	un	un	DET	DET	n=s|g=m|	8	det	8	det
# 7	beau	beau	ADJ	ADJ	n=s|g=m|	8	mod	8	mod
# 8	regard	regard	NC	NC	n=s|g=m|	4	prep	4	prep
# 9	parce_que	parce_que	CS	CS		1	mod	1	mod
# 10	le	le	DET	DET	n=s|g=m|	11	det	11	det
# 11	regard	regard	NC	NC	n=s|g=m|	13	suj	13	suj
# 12	&#195;&#167;a	&#195;&#167;a	PRO	PRO	n=s|	13	suj	13	suj
# 13	compte	compter	V	V	n=s|t=PS|p=13|	9	sub	9	sub
# 14	beaucoup	beaucoup	ADV	ADV		13	mod	13	mod
# 15	pour	pour	P	P		13	mod	13	mod
# 16	moi	moi	NC	NC	n=s|g=m|	15	prep	15	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 9	euh-	_	ADV	ADV	_	11	mod	11	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	bien	bien	ADV	ADV		11	mod	11	mod
# 11	propres	propre	ADJ	ADJ	n=p|	12	mod	12	mod
# 12	hein	_	NC	NC	_	5	mod	5	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 8	je-	_	NPP	NPP	_	7	dep_coord	7	dep_coord
# 9	je-	_	NPP	NPP	_	8	mod	8	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	je	je	CLS	CLS	n=s|p=1|	11	suj	11	suj
# 11	sais	savoir	V	V	n=s|t=P|p=12|	2	mod	2	mod
# 12	rien	rien	PRO	PRO	n=s|g=m|	11	obj	11	obj
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	je-	_	NC	NC	_	6	mod	6	mod
# 3	je-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 4	j'	je	CLS	CLS	n=s|p=1|	6	suj	6	suj
# 5	en	en	CLO	CLO		6	aff	6	aff
# 6	sais	savoir	V	V	n=s|t=P|p=12|	1	dep_coord	1	dep_coord
# 7	rien	rien	PRO	PRO	n=s|g=m|	6	obj	6	obj
# 8	ouaich	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 22	je	je	CLS	CLS	n=s|p=1|	23	suj	23	suj
# 23	vais-	_	V	V	_	21	dep_coord	21	dep_coord
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	je	je	CLS	CLS	n=s|p=1|	25	suj	25	suj
# 25	vais	aller	V	V	n=s|t=P|p=1|	23	mod	23	mod
# 26	te	te	CLO	CLO	n=s|p=2|	27	obj	27	obj
# 27	dire	dire	VINF	VINF	t=W|	25	obj	25	obj
# 28	un	un	DET	DET	n=s|g=m|	29	det	29	det
# 29	truc-	_	NC	NC	_	27	obj	27	obj
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 30	je	je	CLS	CLS	n=s|p=1|	31	suj	31	suj
# 31	vais	aller	V	V	n=s|t=P|p=1|	25	mod	25	mod
# 32	te	te	CLO	CLO	n=s|p=2|	33	aff	33	aff
# 33	dire	dire	VINF	VINF	t=W|	31	obj	31	obj
# 34	un	un	DET	DET	n=s|g=m|	35	det	35	det
# 35	truc	truc	NC	NC	n=s|g=m|	33	obj	33	obj
# 36	attend	attendre	V	V	n=s|t=P|p=3|	31	mod	31	mod
# 37	Shaniss	_	NPP	NPP	_	39	suj	39	suj
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 38	&#195;&#169;coute-	_	NPP	NPP	_	37	mod	37	mod
# 39	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	31	mod	31	mod
# 40	moi-	_	ADV	ADV	_	39	mod	39	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 41	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	39	mod	39	mod
# 42	moi	moi	PRO	PRO	n=s|p=1|	41	obj	41	obj
# 43	je	je	CLS	CLS	n=s|p=1|	44	suj	44	suj
# 44	suis	&#195;&#170;tre	V	V	n=s|t=P|p=1|	42	mod_rel	42	mod_rel
# 45	s&#195;&#187;r	s&#195;&#187;r	ADJ	ADJ	n=s|g=m|	44	ats	44	ats
# 46	et	et	CC	CC		44	coord	44	coord
# 47	certain-	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 48	je	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 49	su-	_	NPP	NPP	_	0	_	0	_
# 50	(	(	PONCT	PONCT		49	ponct	49	ponct
# 51	re	_	NPP	NPP	_	49	mod	49	mod
# 52	)	)	PONCT	PONCT		51	ponct	51	ponct
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 1	tu	taire	VPP	VPP	n=s|g=m|t=K|	0	_	0	_
# 2	as-	_	ADV	ADV	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	la	la	DET	DET	n=s|g=f|	4	det	4	det
# 4	fille	fille	NC	NC	n=s|g=f|	1	obj	1	obj
# 5	qui	qui	PROREL	PROREL	n=s|	6	suj	6	suj
# 6	a	avoir	V	V	n=s|t=P|p=3|	4	mod_rel	4	mod_rel
# 7	du	de	P+D	P+D	n=s|g=m|	6	de_obj	6	de_obj
# 8	caract&#195;&#168;re	caract&#195;&#168;re	NC	NC	n=s|g=m|	7	prep	7	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	j-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	je	je	CLS	CLS	n=s|p=1|	4	suj	4	suj
# 4	crois	croire	V	V	n=s|t=P|p=12|	1	mod	1	mod
# 5	que	que	CS	CS		4	obj	4	obj
# 6	tu	tu	CLS	CLS	n=s|p=2|	8	suj	8	suj
# 7	me	me	CLO	CLO	n=s|p=1|	8	aff	8	aff
# 8	prends	prendre	V	V	n=s|t=P|p=12|	5	sub	5	sub
# 9	un	un	DET	DET	n=s|g=m|	18	det	18	det
# 10	petit	petit	ADJ	ADJ	n=s|g=m|	18	mod	18	mod
# 11	peu	peu	ADV	ADV		12	mod	12	mod
# 12	pour	pour	P	P		10	mod	10	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 13	une-	_	ADV	ADV	_	15	mod	15	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 14	une	une	DET	DET	n=s|g=f|	15	det	15	det
# 15	pimb&#195;&#168;che	_	NC	NC	_	12	prep	12	prep
# 16	un_peu	un_peu	ADV	ADV		18	mod	18	mod
# 17	une	une	DET	DET	n=s|g=f|	18	det	18	det
# 18	b&#195;&#170;-b&#195;&#170;te	_	NC	NC	_	8	obj	8	obj
# 19	hein	_	ADJ	ADJ	_	18	mod	18	mod
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 3	euh	_	NC	NC	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 4	euh	_	NC	NC	_	1	prep	1	prep
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	quand-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	quand	quand	CS	CS		15	mod	15	mod
# 7	je	je	CLS	CLS	n=s|p=1|	10	suj	10	suj
# 8	l'	l'	CLO	CLO	n=s|p=3|	10	obj	10	obj
# 9	ai	avoir	V	V	n=s|t=P|p=1|	10	aux_tps	10	aux_tps
# 10	touch&#195;&#169;e	toucher	VPP	VPP	n=s|g=f|t=K|	6	sub	6	sub
# 11	ah	_	ADV	ADV	_	10	mod	10	mod
# 12	ben	_	ADV	ADV	_	10	mod	10	mod
# 13	j'	je	CLS	CLS	n=s|p=1|	15	suj	15	suj
# 14	ai	avoir	V	V	n=s|t=P|p=1|	15	aux_tps	15	aux_tps
# 15	senti	sentir	VPP	VPP	n=s|g=m|t=K|	0	root	0	root
# 16	qu'	que	CS	CS		15	obj	15	obj
# 17	elle	elle	CLS	CLS	n=s|g=f|p=3|	18	suj	18	suj
# 18	avait	avoir	V	V	n=s|t=II|p=3|	16	sub	16	sub
# 19	un	un	DET	DET	n=s|g=m|	21	det	21	det
# 20	beau	beau	ADJ	ADJ	n=s|g=m|	21	mod	21	mod
# 21	corps	corps	NC	NC	g=m|	18	obj	18	obj
# 22	j'	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 23	ai	avoir	V	V	n=s|t=P|p=1|	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	euh	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 6	euh	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 7	assez	assez	ADV	ADV		8	mod	8	mod
# 8	mate	mat	ADJ	ADJ	n=s|g=f|	4	ats	4	ats
# 9	de	de	P	P		8	de_obj	8	de_obj
# 10	peau	peau	NC	NC	n=s|g=f|	9	prep	9	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	un-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	un	un	DET	DET	n=s|g=m|	8	det	8	det
# 7	beau	beau	ADJ	ADJ	n=s|g=m|	8	mod	8	mod
# 8	regard	regard	NC	NC	n=s|g=m|	4	prep	4	prep
# 9	parce_que	parce_que	CS	CS		1	mod	1	mod
# 10	le	le	DET	DET	n=s|g=m|	11	det	11	det
# 11	regard	regard	NC	NC	n=s|g=m|	13	suj	13	suj
# 12	&#195;&#167;a	&#195;&#167;a	PRO	PRO	n=s|	13	suj	13	suj
# 13	compte	compter	V	V	n=s|t=PS|p=13|	9	sub	9	sub
# 14	beaucoup	beaucoup	ADV	ADV		13	mod	13	mod
# 15	pour	pour	P	P		13	mod	13	mod
# 16	moi	moi	NC	NC	n=s|g=m|	15	prep	15	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 9	euh-	_	ADV	ADV	_	11	mod	11	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	bien	bien	ADV	ADV		11	mod	11	mod
# 11	propres	propre	ADJ	ADJ	n=p|	12	mod	12	mod
# 12	hein	_	NC	NC	_	5	mod	5	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 8	je-	_	NPP	NPP	_	7	dep_coord	7	dep_coord
# 9	je-	_	NPP	NPP	_	8	mod	8	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	je	je	CLS	CLS	n=s|p=1|	11	suj	11	suj
# 11	sais	savoir	V	V	n=s|t=P|p=12|	2	mod	2	mod
# 12	rien	rien	PRO	PRO	n=s|g=m|	11	obj	11	obj
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	je-	_	NC	NC	_	6	mod	6	mod
# 3	je-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 4	j'	je	CLS	CLS	n=s|p=1|	6	suj	6	suj
# 5	en	en	CLO	CLO		6	aff	6	aff
# 6	sais	savoir	V	V	n=s|t=P|p=12|	1	dep_coord	1	dep_coord
# 7	rien	rien	PRO	PRO	n=s|g=m|	6	obj	6	obj
# 8	ouaich	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 22	je	je	CLS	CLS	n=s|p=1|	23	suj	23	suj
# 23	vais-	_	V	V	_	21	dep_coord	21	dep_coord
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	je	je	CLS	CLS	n=s|p=1|	25	suj	25	suj
# 25	vais	aller	V	V	n=s|t=P|p=1|	23	mod	23	mod
# 26	te	te	CLO	CLO	n=s|p=2|	27	obj	27	obj
# 27	dire	dire	VINF	VINF	t=W|	25	obj	25	obj
# 28	un	un	DET	DET	n=s|g=m|	29	det	29	det
# 29	truc-	_	NC	NC	_	27	obj	27	obj
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 30	je	je	CLS	CLS	n=s|p=1|	31	suj	31	suj
# 31	vais	aller	V	V	n=s|t=P|p=1|	25	mod	25	mod
# 32	te	te	CLO	CLO	n=s|p=2|	33	aff	33	aff
# 33	dire	dire	VINF	VINF	t=W|	31	obj	31	obj
# 34	un	un	DET	DET	n=s|g=m|	35	det	35	det
# 35	truc	truc	NC	NC	n=s|g=m|	33	obj	33	obj
# 36	attend	attendre	V	V	n=s|t=P|p=3|	31	mod	31	mod
# 37	Shaniss	_	NPP	NPP	_	39	suj	39	suj
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 38	&#195;&#169;coute-	_	NPP	NPP	_	37	mod	37	mod
# 39	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	31	mod	31	mod
# 40	moi-	_	ADV	ADV	_	39	mod	39	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 41	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	39	mod	39	mod
# 42	moi	moi	PRO	PRO	n=s|p=1|	41	obj	41	obj
# 43	je	je	CLS	CLS	n=s|p=1|	44	suj	44	suj
# 44	suis	&#195;&#170;tre	V	V	n=s|t=P|p=1|	42	mod_rel	42	mod_rel
# 45	s&#195;&#187;r	s&#195;&#187;r	ADJ	ADJ	n=s|g=m|	44	ats	44	ats
# 46	et	et	CC	CC		44	coord	44	coord
# 47	certain-	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 48	je	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 49	su-	_	NPP	NPP	_	0	_	0	_
# 50	(	(	PONCT	PONCT		49	ponct	49	ponct
# 51	re	_	NPP	NPP	_	49	mod	49	mod
# 52	)	)	PONCT	PONCT		51	ponct	51	ponct
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 1	tu	taire	VPP	VPP	n=s|g=m|t=K|	0	_	0	_
# 2	as-	_	ADV	ADV	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	la	la	DET	DET	n=s|g=f|	4	det	4	det
# 4	fille	fille	NC	NC	n=s|g=f|	1	obj	1	obj
# 5	qui	qui	PROREL	PROREL	n=s|	6	suj	6	suj
# 6	a	avoir	V	V	n=s|t=P|p=3|	4	mod_rel	4	mod_rel
# 7	du	de	P+D	P+D	n=s|g=m|	6	de_obj	6	de_obj
# 8	caract&#195;&#168;re	caract&#195;&#168;re	NC	NC	n=s|g=m|	7	prep	7	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	j-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	je	je	CLS	CLS	n=s|p=1|	4	suj	4	suj
# 4	crois	croire	V	V	n=s|t=P|p=12|	1	mod	1	mod
# 5	que	que	CS	CS		4	obj	4	obj
# 6	tu	tu	CLS	CLS	n=s|p=2|	8	suj	8	suj
# 7	me	me	CLO	CLO	n=s|p=1|	8	aff	8	aff
# 8	prends	prendre	V	V	n=s|t=P|p=12|	5	sub	5	sub
# 9	un	un	DET	DET	n=s|g=m|	18	det	18	det
# 10	petit	petit	ADJ	ADJ	n=s|g=m|	18	mod	18	mod
# 11	peu	peu	ADV	ADV		12	mod	12	mod
# 12	pour	pour	P	P		10	mod	10	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 13	une-	_	ADV	ADV	_	15	mod	15	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 14	une	une	DET	DET	n=s|g=f|	15	det	15	det
# 15	pimb&#195;&#168;che	_	NC	NC	_	12	prep	12	prep
# 16	un_peu	un_peu	ADV	ADV		18	mod	18	mod
# 17	une	une	DET	DET	n=s|g=f|	18	det	18	det
# 18	b&#195;&#170;-b&#195;&#170;te	_	NC	NC	_	8	obj	8	obj
# 19	hein	_	ADJ	ADJ	_	18	mod	18	mod
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 3	euh	_	NC	NC	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 4	euh	_	NC	NC	_	1	prep	1	prep
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	quand-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	quand	quand	CS	CS		15	mod	15	mod
# 7	je	je	CLS	CLS	n=s|p=1|	10	suj	10	suj
# 8	l'	l'	CLO	CLO	n=s|p=3|	10	obj	10	obj
# 9	ai	avoir	V	V	n=s|t=P|p=1|	10	aux_tps	10	aux_tps
# 10	touch&#195;&#169;e	toucher	VPP	VPP	n=s|g=f|t=K|	6	sub	6	sub
# 11	ah	_	ADV	ADV	_	10	mod	10	mod
# 12	ben	_	ADV	ADV	_	10	mod	10	mod
# 13	j'	je	CLS	CLS	n=s|p=1|	15	suj	15	suj
# 14	ai	avoir	V	V	n=s|t=P|p=1|	15	aux_tps	15	aux_tps
# 15	senti	sentir	VPP	VPP	n=s|g=m|t=K|	0	root	0	root
# 16	qu'	que	CS	CS		15	obj	15	obj
# 17	elle	elle	CLS	CLS	n=s|g=f|p=3|	18	suj	18	suj
# 18	avait	avoir	V	V	n=s|t=II|p=3|	16	sub	16	sub
# 19	un	un	DET	DET	n=s|g=m|	21	det	21	det
# 20	beau	beau	ADJ	ADJ	n=s|g=m|	21	mod	21	mod
# 21	corps	corps	NC	NC	g=m|	18	obj	18	obj
# 22	j'	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 23	ai	avoir	V	V	n=s|t=P|p=1|	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	euh	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 6	euh	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 7	assez	assez	ADV	ADV		8	mod	8	mod
# 8	mate	mat	ADJ	ADJ	n=s|g=f|	4	ats	4	ats
# 9	de	de	P	P		8	de_obj	8	de_obj
# 10	peau	peau	NC	NC	n=s|g=f|	9	prep	9	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	un-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	un	un	DET	DET	n=s|g=m|	8	det	8	det
# 7	beau	beau	ADJ	ADJ	n=s|g=m|	8	mod	8	mod
# 8	regard	regard	NC	NC	n=s|g=m|	4	prep	4	prep
# 9	parce_que	parce_que	CS	CS		1	mod	1	mod
# 10	le	le	DET	DET	n=s|g=m|	11	det	11	det
# 11	regard	regard	NC	NC	n=s|g=m|	13	suj	13	suj
# 12	&#195;&#167;a	&#195;&#167;a	PRO	PRO	n=s|	13	suj	13	suj
# 13	compte	compter	V	V	n=s|t=PS|p=13|	9	sub	9	sub
# 14	beaucoup	beaucoup	ADV	ADV		13	mod	13	mod
# 15	pour	pour	P	P		13	mod	13	mod
# 16	moi	moi	NC	NC	n=s|g=m|	15	prep	15	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 9	euh-	_	ADV	ADV	_	11	mod	11	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	bien	bien	ADV	ADV		11	mod	11	mod
# 11	propres	propre	ADJ	ADJ	n=p|	12	mod	12	mod
# 12	hein	_	NC	NC	_	5	mod	5	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 8	je-	_	NPP	NPP	_	7	dep_coord	7	dep_coord
# 9	je-	_	NPP	NPP	_	8	mod	8	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 10	je	je	CLS	CLS	n=s|p=1|	11	suj	11	suj
# 11	sais	savoir	V	V	n=s|t=P|p=12|	2	mod	2	mod
# 12	rien	rien	PRO	PRO	n=s|g=m|	11	obj	11	obj
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	je-	_	NC	NC	_	6	mod	6	mod
# 3	je-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 4	j'	je	CLS	CLS	n=s|p=1|	6	suj	6	suj
# 5	en	en	CLO	CLO		6	aff	6	aff
# 6	sais	savoir	V	V	n=s|t=P|p=12|	1	dep_coord	1	dep_coord
# 7	rien	rien	PRO	PRO	n=s|g=m|	6	obj	6	obj
# 8	ouaich	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 22	je	je	CLS	CLS	n=s|p=1|	23	suj	23	suj
# 23	vais-	_	V	V	_	21	dep_coord	21	dep_coord
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	je	je	CLS	CLS	n=s|p=1|	25	suj	25	suj
# 25	vais	aller	V	V	n=s|t=P|p=1|	23	mod	23	mod
# 26	te	te	CLO	CLO	n=s|p=2|	27	obj	27	obj
# 27	dire	dire	VINF	VINF	t=W|	25	obj	25	obj
# 28	un	un	DET	DET	n=s|g=m|	29	det	29	det
# 29	truc-	_	NC	NC	_	27	obj	27	obj
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 30	je	je	CLS	CLS	n=s|p=1|	31	suj	31	suj
# 31	vais	aller	V	V	n=s|t=P|p=1|	25	mod	25	mod
# 32	te	te	CLO	CLO	n=s|p=2|	33	aff	33	aff
# 33	dire	dire	VINF	VINF	t=W|	31	obj	31	obj
# 34	un	un	DET	DET	n=s|g=m|	35	det	35	det
# 35	truc	truc	NC	NC	n=s|g=m|	33	obj	33	obj
# 36	attend	attendre	V	V	n=s|t=P|p=3|	31	mod	31	mod
# 37	Shaniss	_	NPP	NPP	_	39	suj	39	suj
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 38	&#195;&#169;coute-	_	NPP	NPP	_	37	mod	37	mod
# 39	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	31	mod	31	mod
# 40	moi-	_	ADV	ADV	_	39	mod	39	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 41	&#195;&#169;coute	&#195;&#169;couter	V	V	n=s|t=PS|p=13|	39	mod	39	mod
# 42	moi	moi	PRO	PRO	n=s|p=1|	41	obj	41	obj
# 43	je	je	CLS	CLS	n=s|p=1|	44	suj	44	suj
# 44	suis	&#195;&#170;tre	V	V	n=s|t=P|p=1|	42	mod_rel	42	mod_rel
# 45	s&#195;&#187;r	s&#195;&#187;r	ADJ	ADJ	n=s|g=m|	44	ats	44	ats
# 46	et	et	CC	CC		44	coord	44	coord
# 47	certain-	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 48	je	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 49	su-	_	NPP	NPP	_	0	_	0	_
# 50	(	(	PONCT	PONCT		49	ponct	49	ponct
# 51	re	_	NPP	NPP	_	49	mod	49	mod
# 52	)	)	PONCT	PONCT		51	ponct	51	ponct
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 1	tu	taire	VPP	VPP	n=s|g=m|t=K|	0	_	0	_
# 2	as-	_	ADV	ADV	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	la	la	DET	DET	n=s|g=f|	4	det	4	det
# 4	fille	fille	NC	NC	n=s|g=f|	1	obj	1	obj
# 5	qui	qui	PROREL	PROREL	n=s|	6	suj	6	suj
# 6	a	avoir	V	V	n=s|t=P|p=3|	4	mod_rel	4	mod_rel
# 7	du	de	P+D	P+D	n=s|g=m|	6	de_obj	6	de_obj
# 8	caract&#195;&#168;re	caract&#195;&#168;re	NC	NC	n=s|g=m|	7	prep	7	prep
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 2	j-	_	ADV	ADV	_	4	mod	4	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 3	je	je	CLS	CLS	n=s|p=1|	4	suj	4	suj
# 4	crois	croire	V	V	n=s|t=P|p=12|	1	mod	1	mod
# 5	que	que	CS	CS		4	obj	4	obj
# 6	tu	tu	CLS	CLS	n=s|p=2|	8	suj	8	suj
# 7	me	me	CLO	CLO	n=s|p=1|	8	aff	8	aff
# 8	prends	prendre	V	V	n=s|t=P|p=12|	5	sub	5	sub
# 9	un	un	DET	DET	n=s|g=m|	18	det	18	det
# 10	petit	petit	ADJ	ADJ	n=s|g=m|	18	mod	18	mod
# 11	peu	peu	ADV	ADV		12	mod	12	mod
# 12	pour	pour	P	P		10	mod	10	mod
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 13	une-	_	ADV	ADV	_	15	mod	15	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 14	une	une	DET	DET	n=s|g=f|	15	det	15	det
# 15	pimb&#195;&#168;che	_	NC	NC	_	12	prep	12	prep
# 16	un_peu	un_peu	ADV	ADV		18	mod	18	mod
# 17	une	une	DET	DET	n=s|g=f|	18	det	18	det
# 18	b&#195;&#170;-b&#195;&#170;te	_	NC	NC	_	8	obj	8	obj
# 19	hein	_	ADJ	ADJ	_	18	mod	18	mod
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 3	euh	_	NC	NC	_	1	mod	1	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 4	euh	_	NC	NC	_	1	prep	1	prep
#
# <Event desc="dis" type="pronounce" extent="end"/>
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 5	quand-	_	ADV	ADV	_	6	mod	6	mod
#
# <Event desc="dis" type="pronounce" extent="end"/>
# 6	quand	quand	CS	CS		15	mod	15	mod
# 7	je	je	CLS	CLS	n=s|p=1|	10	suj	10	suj
# 8	l'	l'	CLO	CLO	n=s|p=3|	10	obj	10	obj
# 9	ai	avoir	V	V	n=s|t=P|p=1|	10	aux_tps	10	aux_tps
# 10	touch&#195;&#169;e	toucher	VPP	VPP	n=s|g=f|t=K|	6	sub	6	sub
# 11	ah	_	ADV	ADV	_	10	mod	10	mod
# 12	ben	_	ADV	ADV	_	10	mod	10	mod
# 13	j'	je	CLS	CLS	n=s|p=1|	15	suj	15	suj
# 14	ai	avoir	V	V	n=s|t=P|p=1|	15	aux_tps	15	aux_tps
# 15	senti	sentir	VPP	VPP	n=s|g=m|t=K|	0	root	0	root
# 16	qu'	que	CS	CS		15	obj	15	obj
# 17	elle	elle	CLS	CLS	n=s|g=f|p=3|	18	suj	18	suj
# 18	avait	avoir	V	V	n=s|t=II|p=3|	16	sub	16	sub
# 19	un	un	DET	DET	n=s|g=m|	21	det	21	det
# 20	beau	beau	ADJ	ADJ	n=s|g=m|	21	mod	21	mod
# 21	corps	corps	NC	NC	g=m|	18	obj	18	obj
# 22	j'	je	CLS	CLS	n=s|p=1|	0	_	0	_
# 23	ai	avoir	V	V	n=s|t=P|p=1|	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="begin"/>
# 24	euh	_	ADV	ADV	_	0	_	0	_
#
# <Event desc="dis" type="pronounce" extent="end"/>
