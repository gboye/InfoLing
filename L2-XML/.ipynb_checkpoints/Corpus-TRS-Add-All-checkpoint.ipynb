# %%
# -*- coding: utf-8 -*-

# %%
import time
import sys
import codecs
import re
import pdb # ajouter pdb.set_trace() à l'endroit où on veut le débugueur
from lxml import etree
import bs4

# %% [markdown]
# #Modifier pour permettre le traitement d'un répertoire ou d'une arborescence plutôt qu'un seul fichier à la fois.

# %%
import glob

# %% [markdown]
# #Préparation de l'environnement pour le script
# - *dossier* doit être le répertoire où se trouvent vos fichiers (devrait finir par un /)
# - *fichierTRS* contient la liste des noms de vos fichiers TRS à traiter (rempli automatiquement)
# - *fichierLexique* doit être le nom du fichier BDLEXIQUE
# - *fichierExceptions* doit être le nom de votre fichier INCONNUS

# %%
dossier="/Users/gilles/Copy/Cours/Bordeaux/XML/XML-Ressources/"
fichiersTRS=glob.glob(dossier+"*.trs")
fichierLexique=dossier+"bdlexique.txt"
fichierExceptions=dossier+"inconnus.txt"
fichier_exceptions=True

# %% [markdown]
# Si vous n'avez pas de fichier *inconnus.txt*
# >mettez *fichier_exceptions=False* au dessus

# %% [markdown]
# #Modif GB 12/04/14
# - mise en texte des deux blocs de traitement de la ligne de commande

# %%
lexicon=codecs.open(fichierLexique,"r",encoding='utf8')
bdlexique=lexicon.readlines()
lexicon.close()
exceptions=codecs.open(fichierExceptions,"r",encoding='utf8')
inconnus=exceptions.readlines()
exceptions.close()

# %%
facultatives = 0

# %%
phon={}
result=[]
nouvellesExceptions = []
output=[]

# %% [markdown]
# ### Préparation des fichiers

# %% [markdown]
# algorithme
#
# ajouter chaque ligne du fichier à phrases[]

# %%
def lowerAccents(chaine):
    return chaine.lower()

# %% [markdown]
# ### Normaliser le mot en cours
#
# algorithme
#
# + la ponctuation est remplacée par un espace
# + les espaces aux extrémités sont effacés
# + le mot est mis en minuscules

# %%
def trimer(mot):
    mot=lowerAccents(mot)
    for p in u',;.:-?!()“”‘’‛‟′″´˝"«»':
        mot=mot.replace(p, ' ')
    mot=mot.strip()
    return mot

# %%
def listerMotsCorpus(rootTRS):
    phrases=[]
    motsPhrases=[]
    elementsPhrases=[]
    motsCorpus=set()
    nPhrases=0
    for ligne in rootTRS.xpath("//Turn//text()"):
        line=ligne.strip()
    #    print nPhrases, line
        phrases.append(line)
        elements=re.findall(ur"[\wâàéèêëîïôùûüçÂÀÉÈÊËÎÏÔÙÛÜÇæœÆŒ]+['’]?|[-.…,—–()\[\]\/#\"“”‘«»<>'’=~]| [;!?:]", line)
        mots=[x for x in elements if not x in u"-.…,—–()\[\]\/#\"“”‘«»<>'’=~" and not x in [" ;"," !"," ?"," :"]]
        elements=[x for x in elements if x!=" "]
        elementsPhrases.append(elements)
        phrasePropre = u""
        for mot in mots:
            mot = trimer(mot)
            phrasePropre += mot+u" "
            motsCorpus.add(mot)
        phraseMots = phrasePropre.strip()
        phraseMots = phrasePropre.split()        
        motsPhrases.append(phraseMots)
        nPhrases+=1
    return (motsCorpus,motsPhrases,elementsPhrases)

# %% [markdown]
# algorithme
#
# extraire de BDLex 0.forme fléchie, 1.phonétique, 2.liaison, 3.cat-gram, 4.genre+nombre

# %% [markdown]
# algorithme
#
# extraire du fichier d'exceptions les mêmes données que pour BDLex

# %% [markdown]
# #Modif GB 12/04/14
# - fait une liste des exceptions lues pour ne pas les rajouter à la fin
# - éviter de tenir compte des exceptions non renseignées
#  - les mots du fichier exceptions sans transcriptions étaient transcrits par une chaine vide...

# %% [markdown]
# ## Fonctions

# %% [markdown]
# ### Vérifier si le mot existe
#
# algorithme
#
# + si le mot est dans BDLex, ok
# + s'il y a un espace dans le mot,
#     * le mot est divisé en deux et
#     * si les mots existent dans bdlex, ok
#     * sinon les mots sont ajoutés aux nouvelles exceptions et mis entre étoiles
# + s'il y a un apostrophe dans le mot,
#     * le mot est divisé en deux
#     * si les mots existent dans bdlex, ok
#     * sinon les mots sont ajoutés aux nouvelles exceptions et mis entre étoiles
# + dans les autres cas, le mot est ajouté aux nouvelles exceptions et mis entre étoiles

# %%
def verifier_mot(mot):
        sampa=""
        if mot in phon.keys():
            sampa += phon[mot][0]
        elif " " in mot:
            mots = mot.split()
            for mot in mots:
                if mot in phon.keys():
                    sampa += phon[mot][0]+" "
                elif mot != "":
                    nouvellesExceptions.append(mot)
                    sampa += "***"+mot+"*** "
        elif "'" in mot:
            mots = mot.split("'")
            mots[0]=mots[0]+"'"
            for mot in mots:
                if mot in phon.keys():
                    sampa += phon[mot][0]+" "
                elif mot != "":
                    nouvellesExceptions.append(mot)
                    sampa += "***"+mot+"*** "
        elif mot != "": 
            nouvellesExceptions.append(mot)
            sampa="***"+mot+"*** "
        return sampa

# %% [markdown]
# ### 2. traduire le SAMPA de BDLexique en API

# %% [markdown]
# #Modif GB 12/04/14
# - ajout du r et du â
# - ajout des exemples associés en dessous

# %%
# traduire SAMPA-BDLex en API

def sampa2api(sampa):
    if isinstance(sampa,str):
        api=sampa.decode("utf8")
    else:
        api=sampa
    api=api.replace(u'S',u'ʃ') 
    api=api.replace(u'Z',u'ʒ')
    api=api.replace(u'N',u'ŋ')
    api=api.replace(u'J',u'ɲ')
    api=api.replace(u'r',u'ʁ') 
    api=api.replace(u'H',u'ɥ')
    api=api.replace(u'E',u'ɛ')
    api=api.replace(u'2',u'ø')
    api=api.replace(u'9',u'œ')
    api=api.replace(u'6',u'ə')
    api=api.replace(u'O',u'ɔ')
    api=api.replace(u'è',u'e')   
    api=api.replace(u'ò',u'o')    
    api=api.replace(u'â',u'ɑ̃')   
    api=api.replace(u'ê',u'ɛ̃')   
    api=api.replace(u'û',u'œ̃')  
    api=api.replace(u'ô',u'ɔ̃')       
    api=api.replace(u'@',u'ə')
    api=api.replace(u'n"',u'n') 
    api=api.replace(u't"',u't') 
    api=api.replace(u'z"',u'z') 
    api=api.replace(u'R"',u'ʁ') 
    api=api.replace(u'p"',u'p') 
    return api

# %% [markdown]
# ### 4. Vérifier si la liaison est possible

# %% [markdown]
# algorithme
#
# + si le mot courant et le suivant ne sont pas dans lexicon, pas de liaison
# + si le mot a une consonne dans le champ de la voyelle de liaison, check1 est vrai
# + si le mot suivant commence par une voyelle, check2 est vrai
#
#   si check1 et check2 sont vrais, il y a liaison

# %%
def liaison_possible(phrase ,mot , mot_numero):
    check1=0
    check2=0
    if mot in phon and phrase[mot_numero+1] in phon:
        consonnes=['k"', '(kt)"', 'n"', 'p"', 'R"', '@t"', 't"', '-V', '+V', '@z"', 'z"']
        phoneme=phon[mot][2]
        for phoneme in consonnes:
            check1=1
        
        voyelles=["H", "j", "w", "E", "a", "2", "9", "6", "@", "y", "u", "O", u"ò", "o", "e", u"è", u"ê", u"û", u"ô", "i"]
        mot_suivant=phon[phrase[mot_numero+1]][1]
        for v in voyelles:
            if mot_suivant.startswith(v):
                check2=1

    if check1 and check2 :
        return True
    else:
        return False

# %% [markdown]
# ### 5. vérifier si la liaison est obligatoire

# %% [markdown]
# algorithme
#
# + si le mot courant et le suivant sont dans un des cas de figure, il y a liaison
# + sinon pas de liaison

# %%
def liaison_obligatoire(phrase, mot, mot_numero):
    determinant=["d", "P"]
    nom=["N", "G", "M"]
    adjectif=["J", "G", "M"]
    pronompers=["P"]
    verbe=["V"]
    catgram_mot1=phon[phrase[mot_numero]][3]
    catgram_mot2=phon[phrase[mot_numero+1]][3]

    if catgram_mot1 in determinant and catgram_mot2 in nom :
        return True

    elif catgram_mot1 in determinant and catgram_mot2 in adjectif :
        return True
 
    elif catgram_mot1 in pronompers and catgram_mot2 in verbe :
        return True

    elif catgram_mot1 in verbe and catgram_mot2 in pronompers :
        return True

    else:
        return False

# %% [markdown]
# Cas de figure possibles:
#
# - DET + N
#     * ri + N:   d'animal,
#     * di + N:   certains éléphants
#     * rd + N:   les animaux
#     * dd + N:   ces étés, cet été
#     * dp + N:   ton anorak
#     * rc + N:   aux armes
# - DET + ADJ:
#     * ri + ADJ:   d'énormes
#     * di + ADJ:   plusieurs immenses
#     * rd + ADJ:   les immenses
#     * dd + ADJ:   cet immense
#     * dp + ADJ:   son immense
#     * rc + ADJ:   aux immenses
# - PERS + V:
#     * SS + V:   m'épate
# - V + PRO PERS:
#     * V + SS:   vont-ils

# %% [markdown]
# algorithme
#
# + si le mot courant et le suivant sont dans un des cas de figure, il y a liaison
# + sinon pas de liaison

# %%
# vérifier si la liaison est facultative
def liaison_facultative(phrase, mot, mot_numero):
    #pdb.set_trace()
    nom=["N", "G", "M"]
    pluriel=["MP", "FP"]
    adjectif=["J", "G", "M"]
    verbe=["V"]
    pronompers=["P"]
    adverbe=["A"]
    preposition=["p"]
    catgram_mot1=phon[phrase[mot_numero]][3]
    catgram_mot2=phon[phrase[mot_numero+1]][3]
    genre_mot1=phon[phrase[mot_numero]][4]
    
    if (catgram_mot1 in nom) and (phon[phrase[mot_numero]][4] in pluriel) and (catgram_mot2 in adjectif) : 
        return True

    elif (catgram_mot1 in verbe) and (catgram_mot2 not in pronompers):
        return True

    elif catgram_mot1 in adverbe :
        return True
    
    elif catgram_mot1 in preposition : 
        return True

    else :
        return False

# %% [markdown]
# Cas de figure possibles :
#
# - N pl + ADJ:
#     * N + ADJ: monstres énormes
#     * G + ADJ: rivaux énormes
# - VERBE + TOUT-SAUF-PRO-PERS:
#     * V + N sont éléphants
#     * V + G sommes abdicaires
#     * V + V sommes assis
#     * V + A sommes admirablement
#     * V + p sommes autour de
#     * V + di ont aucune
#     * V + rc sommes au
# - ADV + QQCH:
#     * ADV + N vraiment abruti
#     * ADV + G vraiment abandonné
#     * ADV + V vraiment aimé
#     * ADV + J vraiment étonnant
#     * ADV + ss vraiment ils
#     * ADV + A vraiment étonnamment
#     * ADV + p vraiment attendu
#     * ADV + di vraiment autre
#     * ADV + rc vraiment au
# - PREP + QQCH:
#     * PREP + N très amoureux
#     * PREP + G très abandonné
#     * PREP + V très aimé
#     * PREP + J très étonnant
#     * PREP + SS très ils
#     * PREP + A très étonnamment
#     * PREP + p très attendu
#     * PREP + di très autre
#     * PREP + rc très au

# %% [markdown]
# ## Traitement

# %% [markdown]
# + Partie 1
# *chaque phrase est prise individuellement,
#     * découpée en blocs,
#         * qui sont chacuns trimés si ce sont des mots
#         * s'il y a plusieurs mots dans le bloc, ils sont séparés
#     + Partie 2
#     * pour chaque couple de mots
#         * si la liaison est possible,
#             * et qu'elle est obligatoire, l'api avec la liaison est généré
#             * et qu'elle est facultative,
#                 * si l'utilisateur l'a choisi, l'api avec la liaison est généré
#                 * sinon l'api sans la liaison est généré
#
#         + Partie 3
#         * si la liaison n'est pas possible,
#             * si le mot est dans bdlex, l'api est généré
#             * sinon le mot est laissé tel quel (il a déjà les étoiles)
#
#     * pour le dernier mot de la phrase,
#         * si le mot est dans bdlex, l'api est généré
#         * sinon le mot est laissé tel quel (il a déjà les étoiles)
#
# + Partie 4
# * le message à l'utilisateur et la phrase en api est imprimée

# %% [markdown]
# #Modif GB 12/04/14
# - suppression du délai dans la boucle
#  - pour 1500 lignes => 3 secondes sans ralentisseur, 1503 secondes avec

# %%
from lxml.builder import E

# %% [markdown]
# #Début de l'enchassement en XML (7/12/15)
# - récupérer la ponctuation et les sauts de lignes pour rendre le texte lisible
# - ajouter le reste des informations du lexique dans la balise

# %%
def enchasseBDLexique(nphrase,nmot,liaison=False):
    mot=motsPhrases[nphrase][nmot]
    if mot in phon: 
        phono=sampa2api(phon[mot][1])
        if liaison:
            phono+=sampa2api(phon[mot][2])
        cat=phon[mot][3]
        if cat in [u"J",u"K"]:
            cat=u"Adj"
        ms=phon[mot][4]
        vs=phon[mot][5]
        lexeme=phon[mot][6].upper()
        if u" " in vs:
            vs=u""
    else:
        phono=verifier_mot(mot)[:-1]
        cat=u"???"
        ms=""
        vs=""
        lexeme="???"
    result=E.motBDL(mot,{"cat":cat,"ms":ms,"vs":vs,"phon":phono,"lexeme":lexeme})
#    print etree.tostring(result,encoding="utf8")
#    print (cat,ms,vs,phono,mot)
#    u'<mot cat="%s" ms="%s" vs="%s" phon="%s">%s</mot>' % (cat,ms,vs,phono,mot)
    return result
    
def enchasseXML(mot, phono):
    if isinstance(phono,str):
        phono=phono.decode("utf8")
    result=E.motBDL(mot,{"phon":phono})
#    u'<mot phon="%s">%s</mot>' % (phono, mot)
    return result

def enchasseTour(phrase):
    result=E.tour(phrase)
    return result

def enchasseNonMot(nonmot):
    result=E.punct(nonmot)
#    u'<punct>%s</punct>' % (nonmot)
    return result

# %%
def traitementTRS(rootTRS):
    a=1
    nPhrase=0
    for ligne in rootTRS.xpath("//Turn//text()"):
        phrase=ligne.strip()
        api=E.tour()
        mot_numero=0
        element_numero=0
        while mot_numero <= len(motsPhrases[nPhrase])-2:
            while motsPhrases[nPhrase][mot_numero]!=elementsPhrases[nPhrase][element_numero].lower():
                api.append(enchasseNonMot(elementsPhrases[nPhrase][element_numero]))
                element_numero+=1
            if liaison_possible(motsPhrases[nPhrase], motsPhrases[nPhrase][mot_numero], mot_numero):

                if liaison_obligatoire(motsPhrases[nPhrase], motsPhrases[nPhrase][mot_numero], mot_numero):
                    api.append(enchasseBDLexique(nPhrase,mot_numero,True))

                elif liaison_facultative(motsPhrases[nPhrase], motsPhrases[nPhrase][mot_numero], mot_numero):
                    if facultatives:
                        api.append(enchasseBDLexique(nPhrase,mot_numero,True))
                    else :
                        api.append(enchasseBDLexique(nPhrase,mot_numero))
                else:
                    api.append(enchasseBDLexique(nPhrase,mot_numero))
            else:
                api.append(enchasseBDLexique(nPhrase,mot_numero))
            mot_numero = mot_numero+1
            element_numero+=1
        if len(motsPhrases[nPhrase])>0 and mot_numero==len(motsPhrases[nPhrase])-1:
            api.append(enchasseBDLexique(nPhrase,len(motsPhrases[nPhrase])-1))
        a=a+1
        if phrase!="":
            ligne.getparent().addnext(api)
#            print nPhrase,ligne,etree.tostring(ligne.getparent().getparent())
        nPhrase+=1

# %% [markdown]
# #Modif GB 12/04/14
# - Insertion d'un set sur les nouvellesExceptions pour éviter les entrées multiples
# - Ajout d'un test pour vérifier que les nouvellesExceptions sont nouvelles
#
# #TO DO
# - Ajouter un message pour dire que le résultat a été concaténé au fichier existant si c'est le cas.

# %%
def extraireMotsTRS(motsCorpus,phon):
    for entry in bdlexique:
        entry=entry.strip()
        p=entry.split(u';')
        if p[0].lower() in motsCorpus:
            if p[2]=="@" and not p[3] in ["N","V","J","K"]:
                p[1]+=p[2]
                p[2]=""
                if len(p)<7:
                    for i in range(len(p)+1,7):
                        p.append("")
            phon[p[0].lower()]=(p[0],p[1],p[2],p[3],p[4],p[5],p[6])
    return phon

# %%
if fichier_exceptions:
    oldExceptions=[]
    for entry in inconnus:
        entry=entry.strip()
        p=entry.split(";")
        if len(p[1])!=0:
            if len(p)<7:
                for i in range(len(p)+1,7):
                    p.append("")
            phon[p[0].lower()]=(p[0],p[1],p[2],p[3],p[4],p[5],p[6])
        oldExceptions.append(p[0].lower())

# %%
#1.2.b. mettre les phrases phonémisées dans un fichier
enteteXML=[
            u'<?xml version="1.0" encoding="UTF8" standalone="yes"?>',
            u'<?xml-stylesheet type="text/xsl" href="phonemise-TRS.xsl"?>',
            u'<!DOCTYPE Trans SYSTEM "trans-14-corpus.dtd">'
          ]

#print [etree.tostring(rootTRS,pretty_print=True,encoding="utf8").decode("utf8")]

for fichierTRS in fichiersTRS:
    fichierBDL=fichierTRS[:-4]+"-BDL.xml"
    xmlTRS=etree.parse(fichierTRS)
    rootTRS=xmlTRS.getroot()
    (motsCorpus,motsPhrases,elementsPhrases)=listerMotsCorpus(rootTRS)
    phon=extraireMotsTRS(motsCorpus,phon)
    traitementTRS(rootTRS)
    with codecs.open(fichierBDL, "w", encoding='utf8') as f:
        for ligne in enteteXML:
            f.write(ligne+u"\n")
        f.write(etree.tostring(rootTRS,pretty_print=True,encoding="utf8").decode("utf8"))
# Out:
# 4
# euh
# <Turn speaker="spk1" startTime="1.882" endTime="2.281">
# <Sync time="1.882"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 10
# heum
# <Turn speaker="spk1" startTime="4.449" endTime="6.392">
# <Sync time="4.449"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  qu'est c'que tu &#233;tudes?
# </Turn>
#
# 11
#  qu'est c'que tu études?
# <Turn speaker="spk1" startTime="4.449" endTime="6.392">
# <Sync time="4.449"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="QUE" phon="k" vs="" ms="" cat="c">qu'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="QUE" phon="k&#601;" vs="" ms="" cat="c">que</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FP" cat="N">&#233;tudes</motBDL></tour>
#  qu'est c'que tu &#233;tudes?
# </Turn>
#
# 15
# ben moi chuis en physique en physique et ingénieurie
# <Turn speaker="spk2" startTime="6.624" endTime="9.879">
# <Sync time="6.624"/><tour><motBDL lexeme="BEN" phon="b&#603;&#771;" vs="Ma" ms="" cat="A">ben</motBDL><motBDL lexeme="MOI" phon="mwa" vs="st" ms="iS1" cat="P">moi</motBDL><motBDL lexeme="???" phon="***chuis***" vs="" ms="" cat="???">chuis</motBDL><motBDL lexeme="EN" phon="&#593;&#771;" vs="" ms="" cat="p">en</motBDL><motBDL lexeme="PHYSIQUE" phon="fizik&#601;" vs="" ms="FS" cat="G">physique</motBDL><motBDL lexeme="EN" phon="&#593;&#771;" vs="" ms="" cat="p">en</motBDL><motBDL lexeme="PHYSIQUE" phon="fizik&#601;" vs="" ms="FS" cat="G">physique</motBDL><motBDL lexeme="ET" phon="e" vs="cc" ms="" cat="c">et</motBDL><motBDL lexeme="???" phon="***ing&#233;nieurie***" vs="" ms="" cat="???">ing&#233;nieurie</motBDL></tour>
# ben moi chuis en physique en physique et ing&#233;nieurie
# </Turn>
#
# 18
# comme
# <Turn speaker="spk2 spk1" startTime="9.879" endTime="10.567">
# <Sync time="9.879"/>
# <Who nb="1"/><tour><motBDL lexeme="COMME" phon="k&#596;m&#601;" vs="" ms="" cat="c">comme</motBDL></tour>
# comme
# <Event desc="disflu" type="pronounce" extent="begin"/>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Who nb="2"/>
#
# <Event desc="pi" type="pronounce" extent="instantaneous"/>
#
# </Turn>
#
# 19
# euh
# <Turn speaker="spk2 spk1" startTime="9.879" endTime="10.567">
# <Sync time="9.879"/>
# <Who nb="1"/><tour><motBDL lexeme="COMME" phon="k&#596;m&#601;" vs="" ms="" cat="c">comme</motBDL></tour>
# comme
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Who nb="2"/>
#
# <Event desc="pi" type="pronounce" extent="instantaneous"/>
#
# </Turn>
#
# 26
# comme
# <Turn speaker="spk2" startTime="11.556" endTime="12.434">
# <Sync time="11.556"/><tour><motBDL lexeme="COMME" phon="k&#596;m&#601;" vs="" ms="" cat="c">comme</motBDL></tour>
# comme
# <Event desc="disflu" type="noise" extent="begin"/>
# euh
# <Event desc="disflu" type="noise" extent="end"/>
#  comment y s'appelle
# </Turn>
#
# 27
# euh
# <Turn speaker="spk2" startTime="11.556" endTime="12.434">
# <Sync time="11.556"/><tour><motBDL lexeme="COMME" phon="k&#596;m&#601;" vs="" ms="" cat="c">comme</motBDL></tour>
# comme
# <Event desc="disflu" type="noise" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="noise" extent="end"/>
#  comment y s'appelle
# </Turn>
#
# 28
#  comment y s'appelle
# <Turn speaker="spk2" startTime="11.556" endTime="12.434">
# <Sync time="11.556"/><tour><motBDL lexeme="COMME" phon="k&#596;m&#601;" vs="" ms="" cat="c">comme</motBDL></tour>
# comme
# <Event desc="disflu" type="noise" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="noise" extent="end"/><tour><motBDL lexeme="COMMENT" phon="kom&#593;&#771;" vs="Ma" ms="" cat="A">comment</motBDL><motBDL lexeme="Y" phon="i" vs="" ms="003" cat="P">y</motBDL><motBDL lexeme="SE" phon="s" vs="sr" ms="ij3" cat="P">s'</motBDL><motBDL lexeme="APPELER" phon="ap&#603;l" vs="ps" ms="3S" cat="V">appelle</motBDL></tour>
#  comment y s'appelle
# </Turn>
#
# 33
# euh
# <Turn speaker="spk1" startTime="13.214" endTime="13.674">
# <Sync time="13.214"/>
#
# <Event desc="disflu" type="noise" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="noise" extent="end"/>
#
# </Turn>
#
# 36
# Julien
# <Turn speaker="spk2" startTime="13.674" endTime="14.096">
# <Sync time="13.674"/><tour><motBDL lexeme="JULIEN" phon="&#658;ylj&#603;&#771;" vs="" ms="MS" cat="Adj">julien</motBDL></tour>
# Julien
# </Turn>
#
# 39
# voilà
# <Turn speaker="spk2 spk1" startTime="14.096" endTime="15.317">
# <Sync time="14.096"/>
# <Who nb="1"/><tour><motBDL lexeme="VOIL&#192;" phon="vwala" vs="" ms="" cat="p">voil&#224;</motBDL></tour>
# voil&#224;
# <Who nb="2"/>
# Julien ouais ok
# </Turn>
#
# 40
# Julien ouais ok
# <Turn speaker="spk2 spk1" startTime="14.096" endTime="15.317">
# <Sync time="14.096"/>
# <Who nb="1"/><tour><motBDL lexeme="VOIL&#192;" phon="vwala" vs="" ms="" cat="p">voil&#224;</motBDL></tour>
# voil&#224;
# <Who nb="2"/><tour><motBDL lexeme="JULIEN" phon="&#658;ylj&#603;&#771;" vs="" ms="MS" cat="Adj">julien</motBDL><motBDL lexeme="OUAIS" phon="we" vs="" ms="" cat="i">ouais</motBDL><motBDL lexeme="OK" phon="oke" vs="" ms="" cat="i">ok</motBDL></tour>
# Julien ouais ok
# </Turn>
#
# 44
# et toi
# <Turn speaker="spk2" startTime="15.553" endTime="15.922">
# <Sync time="15.553"/><tour><motBDL lexeme="ET" phon="e" vs="cc" ms="" cat="c">et</motBDL><motBDL lexeme="TOI" phon="twa" vs="st" ms="iS2" cat="P">toi</motBDL></tour>
# et toi
# </Turn>
#
# 46
# alors
# <Turn speaker="spk1" startTime="15.922" endTime="17.96">
# <Sync time="15.922"/><tour><motBDL lexeme="ALORS" phon="al&#596;&#641;" vs="Tp" ms="" cat="A">alors</motBDL></tour>
# alors
# <Event desc="pi" type="pronounce" extent="instantaneous"/>
#  moi &#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 47
#  moi étude
# <Turn speaker="spk1" startTime="15.922" endTime="17.96">
# <Sync time="15.922"/><tour><motBDL lexeme="ALORS" phon="al&#596;&#641;" vs="Tp" ms="" cat="A">alors</motBDL></tour>
# alors
# <Event desc="pi" type="pronounce" extent="instantaneous"/><tour><motBDL lexeme="MOI" phon="mwa" vs="st" ms="iS1" cat="P">moi</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
#  moi &#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 48
# euh
# <Turn speaker="spk1" startTime="15.922" endTime="17.96">
# <Sync time="15.922"/><tour><motBDL lexeme="ALORS" phon="al&#596;&#641;" vs="Tp" ms="" cat="A">alors</motBDL></tour>
# alors
# <Event desc="pi" type="pronounce" extent="instantaneous"/><tour><motBDL lexeme="MOI" phon="mwa" vs="st" ms="iS1" cat="P">moi</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
#  moi &#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 53
# ah
# <Turn speaker="spk1" startTime="18.226" endTime="18.34">
# <Sync time="18.226"/><tour><motBDL lexeme="AH" phon="a" vs="" ms="" cat="i">ah</motBDL></tour>
# ah
# </Turn>
#
# 57
# j'ai étude langue
# <Turn speaker="spk1" startTime="18.549" endTime="19.751">
# <Sync time="18.549"/><tour><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="AVOIR" phon="e" vs="pi" ms="1S" cat="V">ai</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL><motBDL lexeme="LANGUE" phon="l&#593;&#771;g" vs="" ms="FS" cat="N">langue</motBDL></tour>
# j'ai &#233;tude langue
# </Turn>
#
# 61
# ouais
# <Turn speaker="spk2" startTime="20.23" endTime="20.42">
# <Sync time="20.23"/><tour><motBDL lexeme="OUAIS" phon="we" vs="" ms="" cat="i">ouais</motBDL></tour>
# ouais
# </Turn>
#
# 65
# oui et j'étude anglais français
# <Turn speaker="spk1" startTime="20.766" endTime="22.899">
# <Sync time="20.766"/><tour><motBDL lexeme="OUI" phon="wi" vs="" ms="Mj" cat="N">oui</motBDL><motBDL lexeme="ET" phon="e" vs="cc" ms="" cat="c">et</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL><motBDL lexeme="ANGLAIS" phon="&#593;&#771;gle" vs="" ms="MP" cat="G">anglais</motBDL><motBDL lexeme="FRAN&#199;AIS" phon="f&#641;&#593;&#771;se" vs="" ms="MP" cat="G">fran&#231;ais</motBDL></tour>
# oui et j'&#233;tude anglais fran&#231;ais
# </Turn>
#
# 69
# français il y a
# <Turn speaker="spk1" startTime="23.545" endTime="24.458">
# <Sync time="23.545"/><tour><motBDL lexeme="FRAN&#199;AIS" phon="f&#641;&#593;&#771;se" vs="" ms="MP" cat="G">fran&#231;ais</motBDL><motBDL lexeme="IL" phon="il" vs="ss" ms="MS3" cat="P">il</motBDL><motBDL lexeme="Y" phon="i" vs="" ms="003" cat="P">y</motBDL><motBDL lexeme="AVOIR" phon="a" vs="pi" ms="3S" cat="V">a</motBDL></tour>
# fran&#231;ais il y a
# </Turn>
#
# 73
# deux ans que je l'étude
# <Turn speaker="spk1" startTime="25.009" endTime="26.131">
# <Sync time="25.009"/><tour><motBDL lexeme="DEUX" phon="d&#248;" vs="" ms="Mj" cat="N">deux</motBDL><motBDL lexeme="AN" phon="&#593;&#771;" vs="" ms="MP" cat="N">ans</motBDL><motBDL lexeme="QUE" phon="k&#601;" vs="" ms="" cat="c">que</motBDL><motBDL lexeme="JE" phon="&#658;&#601;" vs="ss" ms="iS1" cat="P">je</motBDL><motBDL lexeme="LE" phon="l" vs="sd" ms="MS3" cat="P">l'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
# deux ans que je l'&#233;tude
# </Turn>
#
# 78
# heum
# <Turn speaker="spk2" startTime="26.644" endTime="26.857">
# <Sync time="26.644"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 81
# et c'est la première fois que je viens en France
# <Turn speaker="spk1" startTime="26.857" endTime="29.465">
# <Sync time="26.857"/><tour><motBDL lexeme="ET" phon="e" vs="cc" ms="" cat="c">et</motBDL><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="LA" phon="la" vs="rd" ms="FS" cat="d">la</motBDL><motBDL lexeme="PREMI&#200;RE" phon="p&#641;&#601;mj&#603;&#641;" vs="" ms="FS" cat="N">premi&#232;re</motBDL><motBDL lexeme="FOIS" phon="fwa" vs="" ms="FP" cat="N">fois</motBDL><motBDL lexeme="QUE" phon="k&#601;" vs="" ms="" cat="c">que</motBDL><motBDL lexeme="JE" phon="&#658;&#601;" vs="ss" ms="iS1" cat="P">je</motBDL><motBDL lexeme="VENIR" phon="vj&#603;&#771;" vs="pI" ms="2S" cat="V">viens</motBDL><motBDL lexeme="EN" phon="&#593;&#771;" vs="" ms="" cat="p">en</motBDL><motBDL lexeme="???" phon="***france***" vs="" ms="" cat="???">france</motBDL></tour>
# et c'est la premi&#232;re fois que je viens en France
# </Turn>
#
# 85
# et
# <Turn speaker="spk1" startTime="30.207" endTime="30.838">
# <Sync time="30.207"/><tour><motBDL lexeme="ET" phon="e" vs="cc" ms="" cat="c">et</motBDL></tour>
# et
# </Turn>
#
# 89
# moi j'étude
# <Turn speaker="spk1" startTime="31.96" endTime="36.679">
# <Sync time="31.96"/><tour><motBDL lexeme="MOI" phon="mwa" vs="st" ms="iS1" cat="P">moi</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
# moi j'&#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  ici j'&#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  aux cours de LEA
# <Event desc="tx" type="noise" extent="instantaneous"/>
#
# </Turn>
#
# 90
# heum
# <Turn speaker="spk1" startTime="31.96" endTime="36.679">
# <Sync time="31.96"/><tour><motBDL lexeme="MOI" phon="mwa" vs="st" ms="iS1" cat="P">moi</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
# moi j'&#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  ici j'&#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  aux cours de LEA
# <Event desc="tx" type="noise" extent="instantaneous"/>
#
# </Turn>
#
# 91
#  ici j'étude
# <Turn speaker="spk1" startTime="31.96" endTime="36.679">
# <Sync time="31.96"/><tour><motBDL lexeme="MOI" phon="mwa" vs="st" ms="iS1" cat="P">moi</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
# moi j'&#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="ICI" phon="isi" vs="Li" ms="" cat="A">ici</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
#  ici j'&#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  aux cours de LEA
# <Event desc="tx" type="noise" extent="instantaneous"/>
#
# </Turn>
#
# 92
# heum
# <Turn speaker="spk1" startTime="31.96" endTime="36.679">
# <Sync time="31.96"/><tour><motBDL lexeme="MOI" phon="mwa" vs="st" ms="iS1" cat="P">moi</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
# moi j'&#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="ICI" phon="isi" vs="Li" ms="" cat="A">ici</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
#  ici j'&#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  aux cours de LEA
# <Event desc="tx" type="noise" extent="instantaneous"/>
#
# </Turn>
#
# 93
#  aux cours de LEA
# <Turn speaker="spk1" startTime="31.96" endTime="36.679">
# <Sync time="31.96"/><tour><motBDL lexeme="MOI" phon="mwa" vs="st" ms="iS1" cat="P">moi</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
# moi j'&#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="ICI" phon="isi" vs="Li" ms="" cat="A">ici</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL></tour>
#  ici j'&#233;tude
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="AUX" phon="o" vs="rc" ms="MP" cat="d">aux</motBDL><motBDL lexeme="COURS" phon="ku&#641;" vs="" ms="MP" cat="N">cours</motBDL><motBDL lexeme="DE" phon="d&#601;" vs="" ms="" cat="p">de</motBDL><motBDL lexeme="???" phon="***lea***" vs="" ms="" cat="???">lea</motBDL></tour>
#  aux cours de LEA
# <Event desc="tx" type="noise" extent="instantaneous"/>
#
# </Turn>
#
# 98
# que c'est langue étrangère appliquée
# <Turn speaker="spk1" startTime="37.348" endTime="39.291">
# <Sync time="37.348"/><tour><motBDL lexeme="QUE" phon="k&#601;" vs="" ms="" cat="c">que</motBDL><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="LANGUE" phon="l&#593;&#771;g" vs="" ms="FS" cat="N">langue</motBDL><motBDL lexeme="&#201;TRANGER" phon="et&#641;&#593;&#771;&#658;&#603;&#641;&#601;" vs="" ms="FS" cat="G">&#233;trang&#232;re</motBDL><motBDL lexeme="APPLIQUER" phon="aplike" vs="" ms="FS" cat="Adj">appliqu&#233;e</motBDL></tour>
# que c'est langue &#233;trang&#232;re appliqu&#233;e
# </Turn>
#
# 102
# ouais
# <Turn speaker="spk2" startTime="39.523" endTime="39.736">
# <Sync time="39.523"/><tour><motBDL lexeme="OUAIS" phon="we" vs="" ms="" cat="i">ouais</motBDL></tour>
# ouais
# </Turn>
#
# 104
# et j'ai fait aussi des russe
# <Turn speaker="spk1" startTime="39.736" endTime="41.145">
# <Sync time="39.736"/><tour><motBDL lexeme="ET" phon="e" vs="cc" ms="" cat="c">et</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="AVOIR" phon="e" vs="pi" ms="1S" cat="V">ai</motBDL><motBDL lexeme="FAIT" phon="fe" vs="" ms="MS" cat="Adj">fait</motBDL><motBDL lexeme="AUSSI" phon="osi" vs="cc" ms="" cat="c">aussi</motBDL><motBDL lexeme="DES" phon="de" vs="" ms="iP" cat="d">des</motBDL><motBDL lexeme="RUSSE" phon="&#641;ys&#601;" vs="" ms="FS" cat="G">russe</motBDL></tour>
# et j'ai fait aussi des russe
# </Turn>
#
# 108
# du russe
# <Turn speaker="spk1" startTime="41.335" endTime="41.812">
# <Sync time="41.335"/><tour><motBDL lexeme="DU" phon="dy" vs="" ms="" cat="p">du</motBDL><motBDL lexeme="RUSSE" phon="&#641;ys&#601;" vs="" ms="FS" cat="G">russe</motBDL></tour>
# du russe
# </Turn>
#
# 112
# et du civilisation russe
# <Turn speaker="spk1" startTime="42.121" endTime="43.399">
# <Sync time="42.121"/><tour><motBDL lexeme="ET" phon="e" vs="cc" ms="" cat="c">et</motBDL><motBDL lexeme="DU" phon="dy" vs="" ms="" cat="p">du</motBDL><motBDL lexeme="CIVILISATION" phon="sivilizasj&#596;&#771;" vs="" ms="FS" cat="N">civilisation</motBDL><motBDL lexeme="RUSSE" phon="&#641;ys&#601;" vs="" ms="FS" cat="G">russe</motBDL></tour>
# et du civilisation russe
# </Turn>
#
# 116
# c'est cool
# <Turn speaker="spk1" startTime="43.821" endTime="44.353">
# <Sync time="43.821"/><tour><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="COOL" phon="kul" vs="" ms="ij" cat="Adj">cool</motBDL></tour>
# c'est cool
# </Turn>
#
# 120
# c'est cool parce que
# <Turn speaker="spk1" startTime="44.639" endTime="46.164">
# <Sync time="44.639"/><tour><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="COOL" phon="kul" vs="" ms="ij" cat="Adj">cool</motBDL><motBDL lexeme="???" phon="***parce***" vs="" ms="" cat="???">parce</motBDL><motBDL lexeme="QUE" phon="k&#601;" vs="" ms="" cat="c">que</motBDL></tour>
# c'est cool parce que
# </Turn>
#
# 124
# euh
# <Turn speaker="spk1" startTime="46.164" endTime="49.02">
# <Sync time="46.164"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#  nous regardons
# <Event desc="disflu" type="pronounce" extent="begin"/>
# de
# <Event desc="disflu" type="pronounce" extent="end"/>
#  des films
# </Turn>
#
# 125
#  nous regardons
# <Turn speaker="spk1" startTime="46.164" endTime="49.02">
# <Sync time="46.164"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="NOUS" phon="nu" vs="" ms="iP1" cat="P">nous</motBDL><motBDL lexeme="REGARDER" phon="&#641;&#601;ga&#641;d&#596;&#771;" vs="pI" ms="1P" cat="V">regardons</motBDL></tour>
#  nous regardons
# <Event desc="disflu" type="pronounce" extent="begin"/>
# de
# <Event desc="disflu" type="pronounce" extent="end"/>
#  des films
# </Turn>
#
# 126
# de
# <Turn speaker="spk1" startTime="46.164" endTime="49.02">
# <Sync time="46.164"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="NOUS" phon="nu" vs="" ms="iP1" cat="P">nous</motBDL><motBDL lexeme="REGARDER" phon="&#641;&#601;ga&#641;d&#596;&#771;" vs="pI" ms="1P" cat="V">regardons</motBDL></tour>
#  nous regardons
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="DE" phon="d&#601;" vs="" ms="" cat="p">de</motBDL></tour>
# de
# <Event desc="disflu" type="pronounce" extent="end"/>
#  des films
# </Turn>
#
# 127
#  des films
# <Turn speaker="spk1" startTime="46.164" endTime="49.02">
# <Sync time="46.164"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="NOUS" phon="nu" vs="" ms="iP1" cat="P">nous</motBDL><motBDL lexeme="REGARDER" phon="&#641;&#601;ga&#641;d&#596;&#771;" vs="pI" ms="1P" cat="V">regardons</motBDL></tour>
#  nous regardons
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="DE" phon="d&#601;" vs="" ms="" cat="p">de</motBDL></tour>
# de
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="DES" phon="de" vs="" ms="iP" cat="d">des</motBDL><motBDL lexeme="FILM" phon="film" vs="" ms="MP" cat="N">films</motBDL></tour>
#  des films
# </Turn>
#
# 131
# des
# <Turn speaker="spk1" startTime="49.347" endTime="50.838">
# <Sync time="49.347"/><tour><motBDL lexeme="DES" phon="de" vs="" ms="iP" cat="d">des</motBDL></tour>
# des
# <Event desc="it" type="language" extent="begin"/>
# propaganda
# <Event desc="it" type="language" extent="end"/>
#  russe
# </Turn>
#
# 132
# propaganda
# <Turn speaker="spk1" startTime="49.347" endTime="50.838">
# <Sync time="49.347"/><tour><motBDL lexeme="DES" phon="de" vs="" ms="iP" cat="d">des</motBDL></tour>
# des
# <Event desc="it" type="language" extent="begin"/><tour><motBDL lexeme="???" phon="***propaganda***" vs="" ms="" cat="???">propaganda</motBDL></tour>
# propaganda
# <Event desc="it" type="language" extent="end"/>
#  russe
# </Turn>
#
# 133
#  russe
# <Turn speaker="spk1" startTime="49.347" endTime="50.838">
# <Sync time="49.347"/><tour><motBDL lexeme="DES" phon="de" vs="" ms="iP" cat="d">des</motBDL></tour>
# des
# <Event desc="it" type="language" extent="begin"/><tour><motBDL lexeme="???" phon="***propaganda***" vs="" ms="" cat="???">propaganda</motBDL></tour>
# propaganda
# <Event desc="it" type="language" extent="end"/><tour><motBDL lexeme="RUSSE" phon="&#641;ys&#601;" vs="" ms="FS" cat="G">russe</motBDL></tour>
#  russe
# </Turn>
#
# 139
# tout ces tout
# <Turn speaker="spk1" startTime="51.1" endTime="55.077">
# <Sync time="51.1"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="TOUT" phon="tu" vs="di" ms="MS" cat="d">tout</motBDL><motBDL lexeme="CES" phon="se" vs="dd" ms="iP" cat="d">ces</motBDL><motBDL lexeme="TOUT" phon="tu" vs="di" ms="MS" cat="d">tout</motBDL></tour>
# tout ces tout
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/>
# rou-
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/>
# propagand-
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="it" type="language" extent="begin"/>
# propaganda
# <Event desc="it" type="language" extent="end"/>
#  se dit comme &#231;a
# </Turn>
#
# 141
# rou-
# <Turn speaker="spk1" startTime="51.1" endTime="55.077">
# <Sync time="51.1"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="TOUT" phon="tu" vs="di" ms="MS" cat="d">tout</motBDL><motBDL lexeme="CES" phon="se" vs="dd" ms="iP" cat="d">ces</motBDL><motBDL lexeme="TOUT" phon="tu" vs="di" ms="MS" cat="d">tout</motBDL></tour>
# tout ces tout
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***rou***" vs="" ms="" cat="???">rou</motBDL></tour>
# rou-
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/>
# propagand-
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="it" type="language" extent="begin"/>
# propaganda
# <Event desc="it" type="language" extent="end"/>
#  se dit comme &#231;a
# </Turn>
#
# 143
# propagand-
# <Turn speaker="spk1" startTime="51.1" endTime="55.077">
# <Sync time="51.1"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="TOUT" phon="tu" vs="di" ms="MS" cat="d">tout</motBDL><motBDL lexeme="CES" phon="se" vs="dd" ms="iP" cat="d">ces</motBDL><motBDL lexeme="TOUT" phon="tu" vs="di" ms="MS" cat="d">tout</motBDL></tour>
# tout ces tout
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***rou***" vs="" ms="" cat="???">rou</motBDL></tour>
# rou-
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***propagand***" vs="" ms="" cat="???">propagand</motBDL></tour>
# propagand-
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="it" type="language" extent="begin"/>
# propaganda
# <Event desc="it" type="language" extent="end"/>
#  se dit comme &#231;a
# </Turn>
#
# 145
# propaganda
# <Turn speaker="spk1" startTime="51.1" endTime="55.077">
# <Sync time="51.1"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="TOUT" phon="tu" vs="di" ms="MS" cat="d">tout</motBDL><motBDL lexeme="CES" phon="se" vs="dd" ms="iP" cat="d">ces</motBDL><motBDL lexeme="TOUT" phon="tu" vs="di" ms="MS" cat="d">tout</motBDL></tour>
# tout ces tout
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***rou***" vs="" ms="" cat="???">rou</motBDL></tour>
# rou-
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***propagand***" vs="" ms="" cat="???">propagand</motBDL></tour>
# propagand-
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="it" type="language" extent="begin"/><tour><motBDL lexeme="???" phon="***propaganda***" vs="" ms="" cat="???">propaganda</motBDL></tour>
# propaganda
# <Event desc="it" type="language" extent="end"/>
#  se dit comme &#231;a
# </Turn>
#
# 146
#  se dit comme ça
# <Turn speaker="spk1" startTime="51.1" endTime="55.077">
# <Sync time="51.1"/>
#
# <Event desc="i" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="TOUT" phon="tu" vs="di" ms="MS" cat="d">tout</motBDL><motBDL lexeme="CES" phon="se" vs="dd" ms="iP" cat="d">ces</motBDL><motBDL lexeme="TOUT" phon="tu" vs="di" ms="MS" cat="d">tout</motBDL></tour>
# tout ces tout
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***rou***" vs="" ms="" cat="???">rou</motBDL></tour>
# rou-
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***propagand***" vs="" ms="" cat="???">propagand</motBDL></tour>
# propagand-
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="it" type="language" extent="begin"/><tour><motBDL lexeme="???" phon="***propaganda***" vs="" ms="" cat="???">propaganda</motBDL></tour>
# propaganda
# <Event desc="it" type="language" extent="end"/><tour><motBDL lexeme="SE" phon="s&#601;" vs="sr" ms="ij3" cat="P">se</motBDL><motBDL lexeme="DIT" phon="di" vs="" ms="MS" cat="M">dit</motBDL><motBDL lexeme="COMME" phon="k&#596;m&#601;" vs="" ms="" cat="c">comme</motBDL><motBDL lexeme="&#199;A" phon="sa" vs="de" ms="003" cat="P">&#231;a</motBDL></tour>
#  se dit comme &#231;a
# </Turn>
#
# 150
# oui oui
# <Turn speaker="spk2" startTime="55.324" endTime="55.686">
# <Sync time="55.324"/><tour><motBDL lexeme="OUI" phon="wi" vs="" ms="Mj" cat="N">oui</motBDL><motBDL lexeme="OUI" phon="wi" vs="" ms="Mj" cat="N">oui</motBDL></tour>
# oui oui
# </Turn>
#
# 153
# propaguande
# <Turn speaker="spk1 spk2" startTime="55.686" endTime="56.469">
# <Sync time="55.686"/>
# <Who nb="1"/><tour><motBDL lexeme="???" phon="***propaguande***" vs="" ms="" cat="???">propaguande</motBDL></tour>
# propaguande
# <Who nb="2"/>
# propaguande
# </Turn>
#
# 154
# propaguande
# <Turn speaker="spk1 spk2" startTime="55.686" endTime="56.469">
# <Sync time="55.686"/>
# <Who nb="1"/><tour><motBDL lexeme="???" phon="***propaguande***" vs="" ms="" cat="???">propaguande</motBDL></tour>
# propaguande
# <Who nb="2"/><tour><motBDL lexeme="???" phon="***propaguande***" vs="" ms="" cat="???">propaguande</motBDL></tour>
# propaguande
# </Turn>
#
# 158
# propagande oui
# <Turn speaker="spk1" startTime="56.792" endTime="59.096">
# <Sync time="56.792"/><tour><motBDL lexeme="PROPAGANDE" phon="p&#641;opag&#593;&#771;d" vs="" ms="FS" cat="N">propagande</motBDL><motBDL lexeme="OUI" phon="wi" vs="" ms="Mj" cat="N">oui</motBDL></tour>
# propagande oui
# <Event desc="i" type="noise" extent="instantaneous"/>
#  oui c'est cool &#231;a
# </Turn>
#
# 159
#  oui c'est cool ça
# <Turn speaker="spk1" startTime="56.792" endTime="59.096">
# <Sync time="56.792"/><tour><motBDL lexeme="PROPAGANDE" phon="p&#641;opag&#593;&#771;d" vs="" ms="FS" cat="N">propagande</motBDL><motBDL lexeme="OUI" phon="wi" vs="" ms="Mj" cat="N">oui</motBDL></tour>
# propagande oui
# <Event desc="i" type="noise" extent="instantaneous"/><tour><motBDL lexeme="OUI" phon="wi" vs="" ms="Mj" cat="N">oui</motBDL><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="COOL" phon="kul" vs="" ms="ij" cat="Adj">cool</motBDL><motBDL lexeme="&#199;A" phon="sa" vs="de" ms="003" cat="P">&#231;a</motBDL></tour>
#  oui c'est cool &#231;a
# </Turn>
#
# 163
# c'est la première fois que j'étude russe
# <Turn speaker="spk1" startTime="59.743" endTime="63.625">
# <Sync time="59.743"/><tour><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="LA" phon="la" vs="rd" ms="FS" cat="d">la</motBDL><motBDL lexeme="PREMI&#200;RE" phon="p&#641;&#601;mj&#603;&#641;" vs="" ms="FS" cat="N">premi&#232;re</motBDL><motBDL lexeme="FOIS" phon="fwa" vs="" ms="FP" cat="N">fois</motBDL><motBDL lexeme="QUE" phon="k&#601;" vs="" ms="" cat="c">que</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL><motBDL lexeme="RUSSE" phon="&#641;ys&#601;" vs="" ms="FS" cat="G">russe</motBDL></tour>
# c'est la premi&#232;re fois que j'&#233;tude russe
# <Event desc="disflu" type="pronounce" extent="begin"/>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#  c'est difficile mais
# </Turn>
#
# 164
# euh
# <Turn speaker="spk1" startTime="59.743" endTime="63.625">
# <Sync time="59.743"/><tour><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="LA" phon="la" vs="rd" ms="FS" cat="d">la</motBDL><motBDL lexeme="PREMI&#200;RE" phon="p&#641;&#601;mj&#603;&#641;" vs="" ms="FS" cat="N">premi&#232;re</motBDL><motBDL lexeme="FOIS" phon="fwa" vs="" ms="FP" cat="N">fois</motBDL><motBDL lexeme="QUE" phon="k&#601;" vs="" ms="" cat="c">que</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL><motBDL lexeme="RUSSE" phon="&#641;ys&#601;" vs="" ms="FS" cat="G">russe</motBDL></tour>
# c'est la premi&#232;re fois que j'&#233;tude russe
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/>
#  c'est difficile mais
# </Turn>
#
# 166
#  c'est difficile mais
# <Turn speaker="spk1" startTime="59.743" endTime="63.625">
# <Sync time="59.743"/><tour><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="LA" phon="la" vs="rd" ms="FS" cat="d">la</motBDL><motBDL lexeme="PREMI&#200;RE" phon="p&#641;&#601;mj&#603;&#641;" vs="" ms="FS" cat="N">premi&#232;re</motBDL><motBDL lexeme="FOIS" phon="fwa" vs="" ms="FP" cat="N">fois</motBDL><motBDL lexeme="QUE" phon="k&#601;" vs="" ms="" cat="c">que</motBDL><motBDL lexeme="JE" phon="&#658;" vs="ss" ms="iS1" cat="P">j'</motBDL><motBDL lexeme="&#201;TUDE" phon="etyd" vs="" ms="FS" cat="N">&#233;tude</motBDL><motBDL lexeme="RUSSE" phon="&#641;ys&#601;" vs="" ms="FS" cat="G">russe</motBDL></tour>
# c'est la premi&#232;re fois que j'&#233;tude russe
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="r" type="noise" extent="instantaneous"/><tour><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="DIFFICILE" phon="difisil&#601;" vs="" ms="FS" cat="G">difficile</motBDL><motBDL lexeme="MAIS" phon="me" vs="" ms="" cat="i">mais</motBDL></tour>
#  c'est difficile mais
# </Turn>
#
# 171
# c'est interressant
# <Turn speaker="spk1" startTime="64.253" endTime="65.093">
# <Sync time="64.253"/><tour><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="???" phon="***interressant***" vs="" ms="" cat="???">interressant</motBDL></tour>
# c'est interressant
# </Turn>
#
# 176
# euh
# <Turn speaker="spk1" startTime="65.55" endTime="65.994">
# <Sync time="65.55"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 181
# en plus nous avons
# <Turn speaker="spk1" startTime="66.207" endTime="67.294">
# <Sync time="66.207"/><tour><motBDL lexeme="EN" phon="&#593;&#771;" vs="" ms="" cat="p">en</motBDL><motBDL lexeme="PLUS" phon="ply" vs="" ms="" cat="A">plus</motBDL><motBDL lexeme="NOUS" phon="nuz" vs="" ms="iP1" cat="P">nous</motBDL><motBDL lexeme="AVOIR" phon="av&#596;&#771;" vs="pi" ms="1P" cat="V">avons</motBDL></tour>
# en plus nous avons
# </Turn>
#
# 185
# un très belle
# <Turn speaker="spk1" startTime="67.789" endTime="68.705">
# <Sync time="67.789"/><tour><motBDL lexeme="UN" phon="&#339;&#771;" vs="do" ms="ij" cat="d">un</motBDL><motBDL lexeme="TR&#200;S" phon="t&#641;e" vs="Qt" ms="" cat="A">tr&#232;s</motBDL><motBDL lexeme="BELLE" phon="b&#603;l" vs="" ms="FS" cat="N">belle</motBDL></tour>
# un tr&#232;s belle
# </Turn>
#
# 190
# heum
# <Turn speaker="spk1" startTime="68.991" endTime="69.736">
# <Sync time="68.991"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 195
# professeur
# <Turn speaker="spk1" startTime="70.497" endTime="71.261">
# <Sync time="70.497"/><tour><motBDL lexeme="PROFESSEUR" phon="p&#641;ofes&#339;&#641;" vs="" ms="FS" cat="N">professeur</motBDL></tour>
# professeur
# </Turn>
#
# 199
# hum hum
# <Turn speaker="spk2" startTime="71.565" endTime="71.813">
# <Sync time="71.565"/><tour><motBDL lexeme="HUM" phon="&#339;m" vs="" ms="" cat="i">hum</motBDL><motBDL lexeme="HUM" phon="&#339;m" vs="" ms="" cat="i">hum</motBDL></tour>
# hum hum
# </Turn>
#
# 204
# euh
# <Turn speaker="spk1" startTime="72.14" endTime="76.65">
# <Sync time="72.14"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/>
# une une
# <Event desc="disflu" type="pronounce" extent="end"/>
#  une
# <Event desc="disflu" type="pronounce" extent="begin"/>
# mad-
# <Event desc="disflu" type="pronounce" extent="end"/>
#  madame non ouais madame
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  une femme
# </Turn>
#
# 206
# une une
# <Turn speaker="spk1" startTime="72.14" endTime="76.65">
# <Sync time="72.14"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
# une une
# <Event desc="disflu" type="pronounce" extent="end"/>
#  une
# <Event desc="disflu" type="pronounce" extent="begin"/>
# mad-
# <Event desc="disflu" type="pronounce" extent="end"/>
#  madame non ouais madame
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  une femme
# </Turn>
#
# 207
#  une
# <Turn speaker="spk1" startTime="72.14" endTime="76.65">
# <Sync time="72.14"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
# une une
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
#  une
# <Event desc="disflu" type="pronounce" extent="begin"/>
# mad-
# <Event desc="disflu" type="pronounce" extent="end"/>
#  madame non ouais madame
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  une femme
# </Turn>
#
# 208
# mad-
# <Turn speaker="spk1" startTime="72.14" endTime="76.65">
# <Sync time="72.14"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
# une une
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
#  une
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***mad***" vs="" ms="" cat="???">mad</motBDL></tour>
# mad-
# <Event desc="disflu" type="pronounce" extent="end"/>
#  madame non ouais madame
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  une femme
# </Turn>
#
# 209
#  madame non ouais madame
# <Turn speaker="spk1" startTime="72.14" endTime="76.65">
# <Sync time="72.14"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
# une une
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
#  une
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***mad***" vs="" ms="" cat="???">mad</motBDL></tour>
# mad-
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="MADAME" phon="madam" vs="" ms="FS" cat="N">madame</motBDL><motBDL lexeme="NON" phon="n&#596;&#771;" vs="Ng" ms="" cat="A">non</motBDL><motBDL lexeme="OUAIS" phon="we" vs="" ms="" cat="i">ouais</motBDL><motBDL lexeme="MADAME" phon="madam" vs="" ms="FS" cat="N">madame</motBDL></tour>
#  madame non ouais madame
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  une femme
# </Turn>
#
# 210
# heum
# <Turn speaker="spk1" startTime="72.14" endTime="76.65">
# <Sync time="72.14"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
# une une
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
#  une
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***mad***" vs="" ms="" cat="???">mad</motBDL></tour>
# mad-
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="MADAME" phon="madam" vs="" ms="FS" cat="N">madame</motBDL><motBDL lexeme="NON" phon="n&#596;&#771;" vs="Ng" ms="" cat="A">non</motBDL><motBDL lexeme="OUAIS" phon="we" vs="" ms="" cat="i">ouais</motBDL><motBDL lexeme="MADAME" phon="madam" vs="" ms="FS" cat="N">madame</motBDL></tour>
#  madame non ouais madame
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#  une femme
# </Turn>
#
# 211
#  une femme
# <Turn speaker="spk1" startTime="72.14" endTime="76.65">
# <Sync time="72.14"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
# une une
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL></tour>
#  une
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***mad***" vs="" ms="" cat="???">mad</motBDL></tour>
# mad-
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="MADAME" phon="madam" vs="" ms="FS" cat="N">madame</motBDL><motBDL lexeme="NON" phon="n&#596;&#771;" vs="Ng" ms="" cat="A">non</motBDL><motBDL lexeme="OUAIS" phon="we" vs="" ms="" cat="i">ouais</motBDL><motBDL lexeme="MADAME" phon="madam" vs="" ms="FS" cat="N">madame</motBDL></tour>
#  madame non ouais madame
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="UNE" phon="yn&#601;" vs="" ms="FS" cat="d">une</motBDL><motBDL lexeme="FEMME" phon="fam" vs="" ms="FS" cat="N">femme</motBDL></tour>
#  une femme
# </Turn>
#
# 215
# ouais
# <Turn speaker="spk2" startTime="76.958" endTime="77.183">
# <Sync time="76.958"/><tour><motBDL lexeme="OUAIS" phon="we" vs="" ms="" cat="i">ouais</motBDL></tour>
# ouais
# </Turn>
#
# 217
# très belle c'est
# <Turn speaker="spk1" startTime="77.183" endTime="81.426">
# <Sync time="77.183"/><tour><motBDL lexeme="TR&#200;S" phon="t&#641;e" vs="Qt" ms="" cat="A">tr&#232;s</motBDL><motBDL lexeme="BELLE" phon="b&#603;l" vs="" ms="FS" cat="N">belle</motBDL><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL></tour>
# tr&#232;s belle c'est
# <Event desc="i" type="noise" extent="instantaneous"/>
#  c'est comme dire c'est
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="bb" type="noise" extent="instantaneous"/>
#
# </Turn>
#
# 218
#  c'est comme dire c'est
# <Turn speaker="spk1" startTime="77.183" endTime="81.426">
# <Sync time="77.183"/><tour><motBDL lexeme="TR&#200;S" phon="t&#641;e" vs="Qt" ms="" cat="A">tr&#232;s</motBDL><motBDL lexeme="BELLE" phon="b&#603;l" vs="" ms="FS" cat="N">belle</motBDL><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL></tour>
# tr&#232;s belle c'est
# <Event desc="i" type="noise" extent="instantaneous"/><tour><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="COMME" phon="k&#596;m&#601;" vs="" ms="" cat="c">comme</motBDL><motBDL lexeme="DIRE" phon="di&#641;" vs="inf" ms="" cat="V">dire</motBDL><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL></tour>
#  c'est comme dire c'est
# <Event desc="disflu" type="pronounce" extent="begin"/>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="bb" type="noise" extent="instantaneous"/>
#
# </Turn>
#
# 219
# heum
# <Turn speaker="spk1" startTime="77.183" endTime="81.426">
# <Sync time="77.183"/><tour><motBDL lexeme="TR&#200;S" phon="t&#641;e" vs="Qt" ms="" cat="A">tr&#232;s</motBDL><motBDL lexeme="BELLE" phon="b&#603;l" vs="" ms="FS" cat="N">belle</motBDL><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL></tour>
# tr&#232;s belle c'est
# <Event desc="i" type="noise" extent="instantaneous"/><tour><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="COMME" phon="k&#596;m&#601;" vs="" ms="" cat="c">comme</motBDL><motBDL lexeme="DIRE" phon="di&#641;" vs="inf" ms="" cat="V">dire</motBDL><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL></tour>
#  c'est comme dire c'est
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="???" phon="***heum***" vs="" ms="" cat="???">heum</motBDL></tour>
# heum
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# <Event desc="bb" type="noise" extent="instantaneous"/>
#
# </Turn>
#
# 226
# euh
# ...
# vu que
# <Event desc="disflu" type="pronounce" extent="begin"/>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 1955
# euh
# <Turn speaker="spk1" startTime="803.66" endTime="804.707">
# <Sync time="803.66"/><tour><motBDL lexeme="VU" phon="vy" vs="" ms="" cat="p">vu</motBDL><motBDL lexeme="QUE" phon="k&#601;" vs="" ms="" cat="c">que</motBDL></tour>
# vu que
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 1960
# pour
# <Turn speaker="spk1" startTime="805.539" endTime="806.367">
# <Sync time="805.539"/><tour><motBDL lexeme="POUR" phon="pu&#641;" vs="" ms="" cat="p">pour</motBDL></tour>
# pour
# <Event desc="disflu" type="pronounce" extent="begin"/>
#  euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 1961
#  euh
# <Turn speaker="spk1" startTime="805.539" endTime="806.367">
# <Sync time="805.539"/><tour><motBDL lexeme="POUR" phon="pu&#641;" vs="" ms="" cat="p">pour</motBDL></tour>
# pour
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
#  euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 1966
# hum
# <Turn speaker="spk1" startTime="807.648" endTime="808.408">
# <Sync time="807.648"/><tour><motBDL lexeme="HUM" phon="&#339;m" vs="" ms="" cat="i">hum</motBDL></tour>
# hum
# </Turn>
#
# 1971
# pour
# <Turn speaker="spk1" startTime="809.658" endTime="812.398">
# <Sync time="809.658"/><tour><motBDL lexeme="POUR" phon="pu&#641;" vs="" ms="" cat="p">pour</motBDL></tour>
# pour
# <Event desc="disflu" type="pronounce" extent="begin"/>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#  pour
# <Event desc="disflu" type="pronounce" extent="begin"/>
# s-
# <Event desc="disflu" type="pronounce" extent="end"/>
#  ceux qui
# </Turn>
#
# 1972
# euh
# <Turn speaker="spk1" startTime="809.658" endTime="812.398">
# <Sync time="809.658"/><tour><motBDL lexeme="POUR" phon="pu&#641;" vs="" ms="" cat="p">pour</motBDL></tour>
# pour
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#  pour
# <Event desc="disflu" type="pronounce" extent="begin"/>
# s-
# <Event desc="disflu" type="pronounce" extent="end"/>
#  ceux qui
# </Turn>
#
# 1973
#  pour
# <Turn speaker="spk1" startTime="809.658" endTime="812.398">
# <Sync time="809.658"/><tour><motBDL lexeme="POUR" phon="pu&#641;" vs="" ms="" cat="p">pour</motBDL></tour>
# pour
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="POUR" phon="pu&#641;" vs="" ms="" cat="p">pour</motBDL></tour>
#  pour
# <Event desc="disflu" type="pronounce" extent="begin"/>
# s-
# <Event desc="disflu" type="pronounce" extent="end"/>
#  ceux qui
# </Turn>
#
# 1974
# s-
# <Turn speaker="spk1" startTime="809.658" endTime="812.398">
# <Sync time="809.658"/><tour><motBDL lexeme="POUR" phon="pu&#641;" vs="" ms="" cat="p">pour</motBDL></tour>
# pour
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="POUR" phon="pu&#641;" vs="" ms="" cat="p">pour</motBDL></tour>
#  pour
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="S" phon="&#603;s" vs="" ms="Mj" cat="N">s</motBDL></tour>
# s-
# <Event desc="disflu" type="pronounce" extent="end"/>
#  ceux qui
# </Turn>
#
# 1975
#  ceux qui
# <Turn speaker="spk1" startTime="809.658" endTime="812.398">
# <Sync time="809.658"/><tour><motBDL lexeme="POUR" phon="pu&#641;" vs="" ms="" cat="p">pour</motBDL></tour>
# pour
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="POUR" phon="pu&#641;" vs="" ms="" cat="p">pour</motBDL></tour>
#  pour
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="S" phon="&#603;s" vs="" ms="Mj" cat="N">s</motBDL></tour>
# s-
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="CEUX" phon="s&#248;" vs="de" ms="MP3" cat="P">ceux</motBDL><motBDL lexeme="QUI" phon="ki" vs="" ms="ij3" cat="P">qui</motBDL></tour>
#  ceux qui
# </Turn>
#
# 1979
# qui ont payés avec hum seize dix sept dix huit
# <Turn speaker="spk1" startTime="812.74" endTime="815.63">
# <Sync time="812.74"/><tour><motBDL lexeme="QUI" phon="ki" vs="" ms="ij3" cat="P">qui</motBDL><motBDL lexeme="AVOIR" phon="&#596;&#771;" vs="pi" ms="3P" cat="V">ont</motBDL><motBDL lexeme="PAYER1" phon="peje" vs="" ms="MP" cat="Adj">pay&#233;s</motBDL><motBDL lexeme="AVEC" phon="av&#603;k" vs="" ms="" cat="p">avec</motBDL><motBDL lexeme="HUM" phon="&#339;m" vs="" ms="" cat="i">hum</motBDL><motBDL lexeme="SEIZE" phon="s&#603;z" vs="" ms="Mj" cat="N">seize</motBDL><motBDL lexeme="DIX" phon="dis" vs="" ms="Mj" cat="N">dix</motBDL><motBDL lexeme="SEPT" phon="s&#603;t" vs="" ms="Mj" cat="N">sept</motBDL><motBDL lexeme="DIX" phon="dis" vs="" ms="Mj" cat="N">dix</motBDL><motBDL lexeme="HUIT" phon="&#613;it" vs="" ms="Mj" cat="N">huit</motBDL></tour>
# qui ont pay&#233;s avec hum seize dix sept dix huit
# <Event desc="disflu" type="pronounce" extent="begin"/>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 1980
# euh
# <Turn speaker="spk1" startTime="812.74" endTime="815.63">
# <Sync time="812.74"/><tour><motBDL lexeme="QUI" phon="ki" vs="" ms="ij3" cat="P">qui</motBDL><motBDL lexeme="AVOIR" phon="&#596;&#771;" vs="pi" ms="3P" cat="V">ont</motBDL><motBDL lexeme="PAYER1" phon="peje" vs="" ms="MP" cat="Adj">pay&#233;s</motBDL><motBDL lexeme="AVEC" phon="av&#603;k" vs="" ms="" cat="p">avec</motBDL><motBDL lexeme="HUM" phon="&#339;m" vs="" ms="" cat="i">hum</motBDL><motBDL lexeme="SEIZE" phon="s&#603;z" vs="" ms="Mj" cat="N">seize</motBDL><motBDL lexeme="DIX" phon="dis" vs="" ms="Mj" cat="N">dix</motBDL><motBDL lexeme="SEPT" phon="s&#603;t" vs="" ms="Mj" cat="N">sept</motBDL><motBDL lexeme="DIX" phon="dis" vs="" ms="Mj" cat="N">dix</motBDL><motBDL lexeme="HUIT" phon="&#613;it" vs="" ms="Mj" cat="N">huit</motBDL></tour>
# qui ont pay&#233;s avec hum seize dix sept dix huit
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 1985
# euros
# <Turn speaker="spk1" startTime="815.82" endTime="816.181">
# <Sync time="815.82"/><tour><motBDL lexeme="EURO" phon="&#601;&#641;o" vs="" ms="MP" cat="N">euros</motBDL></tour>
# euros
# </Turn>
#
# 1989
# hum hum
# <Turn speaker="spk2" startTime="816.525" endTime="816.713">
# <Sync time="816.525"/><tour><motBDL lexeme="HUM" phon="&#339;m" vs="" ms="" cat="i">hum</motBDL><motBDL lexeme="HUM" phon="&#339;m" vs="" ms="" cat="i">hum</motBDL></tour>
# hum hum
# </Turn>
#
# 1993
# il y a des des horaires dans la semaine où tu peux aller tu ne peux
# <Turn speaker="spk1" startTime="816.922" endTime="822.265">
# <Sync time="816.922"/><tour><motBDL lexeme="IL" phon="il" vs="ss" ms="MS3" cat="P">il</motBDL><motBDL lexeme="Y" phon="i" vs="" ms="003" cat="P">y</motBDL><motBDL lexeme="AVOIR" phon="a" vs="pi" ms="3S" cat="V">a</motBDL><motBDL lexeme="DES" phon="de" vs="" ms="iP" cat="d">des</motBDL><motBDL lexeme="DES" phon="dez" vs="" ms="iP" cat="d">des</motBDL><motBDL lexeme="HORAIRE" phon="o&#641;&#603;&#641;" vs="" ms="FP" cat="M">horaires</motBDL><motBDL lexeme="DANS" phon="d&#593;&#771;" vs="" ms="" cat="p">dans</motBDL><motBDL lexeme="LA" phon="la" vs="rd" ms="FS" cat="d">la</motBDL><motBDL lexeme="SEMAINE" phon="s&#601;m&#603;n" vs="" ms="FS" cat="N">semaine</motBDL><motBDL lexeme="O&#217;" phon="u" vs="" ms="003" cat="P">o&#249;</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="POUVOIR" phon="p&#248;" vs="pi" ms="2S" cat="V">peux</motBDL><motBDL lexeme="ALLER" phon="ale" vs="inf" ms="" cat="V">aller</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="NE" phon="n&#601;" vs="Ng" ms="" cat="A">ne</motBDL><motBDL lexeme="POUVOIR" phon="p&#248;" vs="pi" ms="2S" cat="V">peux</motBDL></tour>
# il y a des des horaires dans la semaine o&#249; tu peux aller tu ne peux
# </Turn>
#
# 1997
# ouais
# <Turn speaker="spk2" startTime="822.508" endTime="822.907">
# <Sync time="822.508"/><tour><motBDL lexeme="OUAIS" phon="we" vs="" ms="" cat="i">ouais</motBDL></tour>
# ouais
# </Turn>
#
# 1999
# hum ouais
# <Turn speaker="spk1" startTime="822.907" endTime="823.538">
# <Sync time="822.907"/><tour><motBDL lexeme="HUM" phon="&#339;m" vs="" ms="" cat="i">hum</motBDL><motBDL lexeme="OUAIS" phon="we" vs="" ms="" cat="i">ouais</motBDL></tour>
# hum ouais
# </Turn>
#
# 2003
# par contre
# <Turn speaker="spk1" startTime="824.07" endTime="825.117">
# <Sync time="824.07"/><tour><motBDL lexeme="PAR" phon="pa&#641;" vs="" ms="" cat="p">par</motBDL><motBDL lexeme="CONTRER" phon="k&#596;&#771;t&#641;" vs="ps" ms="3S" cat="V">contre</motBDL></tour>
# par contre
# <Event desc="disflu" type="pronounce" extent="begin"/>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 2004
# euh
# <Turn speaker="spk1" startTime="824.07" endTime="825.117">
# <Sync time="824.07"/><tour><motBDL lexeme="PAR" phon="pa&#641;" vs="" ms="" cat="p">par</motBDL><motBDL lexeme="CONTRER" phon="k&#596;&#771;t&#641;" vs="ps" ms="3S" cat="V">contre</motBDL></tour>
# par contre
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#
# </Turn>
#
# 2007
# si tu payes plus cher tu peux y
# <Turn speaker="spk1" startTime="825.117" endTime="826.615">
# <Sync time="825.117"/><tour><motBDL lexeme="SI" phon="si" vs="" ms="" cat="p">si</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="PAYER" phon="p&#603;j" vs="ps" ms="2S" cat="V">payes</motBDL><motBDL lexeme="PLUS" phon="ply" vs="" ms="" cat="A">plus</motBDL><motBDL lexeme="CHER" phon="&#643;&#603;&#641;" vs="" ms="MS" cat="Adj">cher</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="POUVOIR" phon="p&#248;z" vs="pi" ms="2S" cat="V">peux</motBDL><motBDL lexeme="Y" phon="i" vs="" ms="003" cat="P">y</motBDL></tour>
# si tu payes plus cher tu peux y
# </Turn>
#
# 2010
# aller quand tu veux
# <Turn speaker="spk2 spk1" startTime="826.615" endTime="828.881">
# <Sync time="826.615"/>
# <Who nb="1"/><tour><motBDL lexeme="ALLER" phon="ale" vs="inf" ms="" cat="V">aller</motBDL><motBDL lexeme="QUAND" phon="k&#593;&#771;" vs="Tp" ms="" cat="A">quand</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="VOULOIR" phon="v&#248;" vs="pI" ms="2S" cat="V">veux</motBDL></tour>
# aller quand tu veux
# <Who nb="2"/>
# tu peux aller ah ok tu vais tu vas
# </Turn>
#
# 2011
# tu peux aller ah ok tu vais tu vas
# <Turn speaker="spk2 spk1" startTime="826.615" endTime="828.881">
# <Sync time="826.615"/>
# <Who nb="1"/><tour><motBDL lexeme="ALLER" phon="ale" vs="inf" ms="" cat="V">aller</motBDL><motBDL lexeme="QUAND" phon="k&#593;&#771;" vs="Tp" ms="" cat="A">quand</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="VOULOIR" phon="v&#248;" vs="pI" ms="2S" cat="V">veux</motBDL></tour>
# aller quand tu veux
# <Who nb="2"/><tour><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="POUVOIR" phon="p&#248;" vs="pi" ms="2S" cat="V">peux</motBDL><motBDL lexeme="ALLER" phon="ale" vs="inf" ms="" cat="V">aller</motBDL><motBDL lexeme="AH" phon="a" vs="" ms="" cat="i">ah</motBDL><motBDL lexeme="OK" phon="oke" vs="" ms="" cat="i">ok</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="ALLER" phon="ve" vs="pi" ms="1S" cat="V">vais</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="ALLER" phon="va" vs="pi" ms="2S" cat="V">vas</motBDL></tour>
# tu peux aller ah ok tu vais tu vas
# </Turn>
#
# 2015
# non tu
# <Turn speaker="spk1" startTime="829.204" endTime="829.66">
# <Sync time="829.204"/><tour><motBDL lexeme="NON" phon="n&#596;&#771;" vs="Ng" ms="" cat="A">non</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL></tour>
# non tu
# </Turn>
#
# 2019
# oui
# <Turn speaker="spk1" startTime="829.964" endTime="830.135">
# <Sync time="829.964"/><tour><motBDL lexeme="OUI" phon="wi" vs="" ms="Mj" cat="N">oui</motBDL></tour>
# oui
# </Turn>
#
# 2023
# si tu vas
# <Turn speaker="spk2" startTime="830.478" endTime="830.938">
# <Sync time="830.478"/><tour><motBDL lexeme="SI" phon="si" vs="" ms="" cat="p">si</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="ALLER" phon="va" vs="pi" ms="2S" cat="V">vas</motBDL></tour>
# si tu vas
# </Turn>
#
# 2025
# tu vas
# <Turn speaker="spk1" startTime="830.938" endTime="832.702">
# <Sync time="830.938"/><tour><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="ALLER" phon="va" vs="pi" ms="2S" cat="V">vas</motBDL></tour>
# tu vas
# <Event desc="rire" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#  quand tu veux
# </Turn>
#
# 2027
# euh
# <Turn speaker="spk1" startTime="830.938" endTime="832.702">
# <Sync time="830.938"/><tour><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="ALLER" phon="va" vs="pi" ms="2S" cat="V">vas</motBDL></tour>
# tu vas
# <Event desc="rire" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/>
#  quand tu veux
# </Turn>
#
# 2028
#  quand tu veux
# <Turn speaker="spk1" startTime="830.938" endTime="832.702">
# <Sync time="830.938"/><tour><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="ALLER" phon="va" vs="pi" ms="2S" cat="V">vas</motBDL></tour>
# tu vas
# <Event desc="rire" type="noise" extent="instantaneous"/>
#
# <Event desc="disflu" type="pronounce" extent="begin"/><tour><motBDL lexeme="EUH" phon="&#601;" vs="" ms="" cat="i">euh</motBDL></tour>
# euh
# <Event desc="disflu" type="pronounce" extent="end"/><tour><motBDL lexeme="QUAND" phon="k&#593;&#771;" vs="Tp" ms="" cat="A">quand</motBDL><motBDL lexeme="TU" phon="ty" vs="ss" ms="iS2" cat="P">tu</motBDL><motBDL lexeme="VOULOIR" phon="v&#248;" vs="pI" ms="2S" cat="V">veux</motBDL></tour>
#  quand tu veux
# </Turn>
#
# 2032
# hum hum
# <Turn speaker="spk2" startTime="832.949" endTime="833.293">
# <Sync time="832.949"/><tour><motBDL lexeme="HUM" phon="&#339;m" vs="" ms="" cat="i">hum</motBDL><motBDL lexeme="HUM" phon="&#339;m" vs="" ms="" cat="i">hum</motBDL></tour>
# hum hum
# </Turn>
#
# 2034
# c'est ça
# <Turn speaker="spk1" startTime="833.293" endTime="833.595">
# <Sync time="833.293"/><tour><motBDL lexeme="CE" phon="s" vs="de" ms="iS3" cat="P">c'</motBDL><motBDL lexeme="&#202;TRE" phon="e" vs="pi" ms="3S" cat="V">est</motBDL><motBDL lexeme="&#199;A" phon="sa" vs="de" ms="003" cat="P">&#231;a</motBDL></tour>
# c'est &#231;a
# </Turn>
#
# 2036
# ha ha
# <Turn speaker="spk1" startTime="833.595" endTime="834.166">
# <Sync time="833.595"/><tour><motBDL lexeme="HA" phon="a" vs="" ms="" cat="i">ha</motBDL><motBDL lexeme="HA" phon="a" vs="" ms="" cat="i">ha</motBDL></tour>
# ha ha
# </Turn>
#
# 2038
# ok
# <Turn speaker="spk1" startTime="834.166" endTime="834.413">
# <Sync time="834.166"/><tour><motBDL lexeme="OK" phon="oke" vs="" ms="" cat="i">ok</motBDL></tour>
# ok
# </Turn>
#
# 2042
# ok
# <Turn speaker="spk1" startTime="835.725" endTime="836.05">
# <Sync time="835.725"/><tour><motBDL lexeme="OK" phon="oke" vs="" ms="" cat="i">ok</motBDL></tour>
# ok
# </Turn>

# %%
#1.2.a. mettre la liste des inconnus dans le fichier inconnus.txt
with codecs.open(fichierExceptions, "a", encoding='utf8') as f:
    for n in set(nouvellesExceptions):
        if not (n in oldExceptions): 
            f.write(n+u";;;;;;")
            f.write("\n")

# %%
nouvellesExceptions
# Out:
# [u'heum',
#  u'chuis',
#  u'ing\xe9nieurie',
#  u'heum',
#  u'france',
#  u'heum',
#  u'heum',
#  u'lea',
#  u'parce',
#  u'propaganda',
#  u'rou',
#  u'propagand',
#  u'propaganda',
#  u'propaguande',
#  u'propaguande',
#  u'interressant',
#  u'heum',
#  u'mad',
#  u'heum',
#  u'heum',
#  u'heum',
#  u'erasmu',
#  u'erasmus',
#  u'bath',
#  u'espa',
#  u'angleterre',
#  u'angleterre',
#  u'stonehedge',
#  u'angleterre',
#  u'bath',
#  u'stonehedge',
#  u'heum',
#  u'manchester',
#  u'liverpool',
#  u'manchester',
#  u'liverpool',
#  u'stonehedge',
#  u'stonhedge',
#  u'stonhedge',
#  u'sardaigne',
#  u'sardaigne',
#  u'stonhedge',
#  u'heum',
#  u'niu',
#  u'stonhedge',
#  u'heum',
#  u'italie',
#  u'stonhedge',
#  u'heum',
#  u'disez',
#  u'giguants',
#  u'appell\xe9',
#  u'heum',
#  u'heum',
#  u'giguants',
#  u'giguants',
#  u'heum',
#  u'giguant',
#  u'heum',
#  u'europe',
#  u'ger',
#  u'nop',
#  u'ouai',
#  u'heum',
#  u'heum',
#  u'heum',
#  u'allemagne',
#  u'heum',
#  u'heum',
#  u'allemagne',
#  u'heum',
#  u'heum',
#  u'dr',
#  u'druidi',
#  u'nop',
#  u'cont',
#  u'discourses',
#  u'heum',
#  u'angleterre',
#  u'heum',
#  u'espagne',
#  u'france',
#  u'\xe9',
#  u'voy',
#  u'parce',
#  u'sardaigne',
#  u'mouais',
#  u'france',
#  u'heum',
#  u'heum',
#  u'gujan',
#  u'mestras',
#  u'arcachon',
#  u'arcachon',
#  u'talence',
#  u'peixotto',
#  u'chuis',
#  u'gujan',
#  u"maint'",
#  u'nant',
#  u'talence',
#  u'tbc',
#  u"p'",
#  u'master',
#  u'mouais',
#  u'l3',
#  u'heum',
#  u'master',
#  u'france',
#  u'italie',
#  u'fac',
#  u'parce',
#  u'heum',
#  u'heum',
#  u'heum',
#  u'heum',
#  u'parce',
#  u'heum',
#  u'parce',
#  u'heum',
#  u'heum',
#  u'parce',
#  u'master',
#  u'm\xe9tieur',
#  u'beh',
#  u"y'",
#  u'sufffisament',
#  u'parce',
#  u'ing\xe9nieurie',
#  u'heum',
#  u'isiom\xe9trique',
#  u'plait',
#  u'heum',
#  u'math',
#  u'\xe9matiques',
#  u"p'",
#  u'tite',
#  u'pessac',
#  u'heum',
#  u'heum',
#  u'parce',
#  u'heum',
#  u'heum',
#  u'heum',
#  u'snowboard',
#  u'c\xf4ute',
#  u'parce',
#  u'heum',
#  u'hotel',
#  u'hotel',
#  u'heum',
#  u'pyr\xe9n\xe9s',
#  u'parce',
#  u'heum',
#  u'sardaigne',
#  u'heum',
#  u'tro',
#  u"maint'",
#  u'nant',
#  u'opertunit\xe9',
#  u'heum',
#  u'heum',
#  u'improvisement',
#  u'heum',
#  u'heum',
#  u'heum',
#  u'parce']
