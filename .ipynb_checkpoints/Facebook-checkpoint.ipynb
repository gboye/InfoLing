# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 2: Mining Facebook: Analyzing Fan Pages, Examining Friendships, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Facebook API Access
#
# Facebook implements OAuth 2.0 as its standard authentication mechanism, but provides a convenient way for you to get an _access token_ for development purposes, and we'll opt to take advantage of that convenience in this notebook. For details on implementing an OAuth flow with Facebook (all from within IPython Notebook), see the \_AppendixB notebook from the [IPython Notebook Dashboard](/).
#
# For this first example, login to your Facebook account and go to https://developers.facebook.com/tools/explorer/ to obtain and set permissions for an access token that you will need to define in the code cell defining the ACCESS_TOKEN variable below.
#
# Be sure to explore the permissions that are available by clicking on the "Get Access Token" button that's on the page and exploring all of the tabs available. For example, you will need to set the "friends_likes" option under the "Friends Data Permissions" since this permission is used by the script below but is not a basic permission and is not enabled by default.
#
# <img src="files/resources/ch02-facebook/images/FB_GraphExplorer_perms.png" width="300px" /><br />

# %%
# Copy and paste in the value you just got from the inline frame into this variable and execute this cell.
# Keep in mind that you could have just gone to https://developers.facebook.com/tools/access_token/
# and retrieved the "User Token" value from the Access Token Tool

ACCESS_TOKEN = 'CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh'

# %% [markdown]
# ## Example 1. Making Graph API requests over HTTP

# %%
import requests # pip install requests
import json

base_url = 'https://graph.facebook.com/me'

# Get 10 likes for 10 friends
fields = 'id,name,friends.limit(25).fields(likes.limit(10))'

url = '%s?fields=%s&access_token=%s' % \
    (base_url, fields, ACCESS_TOKEN,)

# This API is HTTP-based and could be requested in the browser,
# with a command line utlity like curl, or using just about
# any programming language by making a request to the URL.
# Click the hyperlink that appears in your notebook output
# when you execute this code cell to see for yourself...
print url

# Interpret the response as JSON and convert back
# to Python data structures
content = requests.get(url).json()

# Pretty-print the JSON and display it
print json.dumps(content, indent=1)
# Out:
# https://graph.facebook.com/me?fields=id,name,friends.limit(25).fields(likes.limit(10))&access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh
# {
#  "friends": {
#   "paging": {
#    "next": "https://graph.facebook.com/v2.0/10152969331868155/friends?limit=25&fields=likes.limit%2810%29&access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh&offset=25&__after_id=enc_AdC0tZAK2ZAkW6nvYTqD4Yu2pG7dKCEpHB4zm1Y234k5ZB4r6ZCuAIVAi6gAEZA64QnvZCz0zM4GRYbhltdVVZCdxbqfcC6"
#   },
#   "data": [
#    {
#     "id": "1467081977"
#    },
#    {
#     "id": "657556317685570"
#    }
#   ],
#   "summary": {
#    "total_count": 234
#   }
#  },
#  "id": "10152969331868155",
#  "name": "Gilles Boy\u00e9"
# }

# %% [markdown]
# Note: If you attempt to run a query for all of your friends' likes and it appears to hang, it is probably because you have a lot of friends who have a lot of likes. If this happens, you may need to add limits and offsets to the fields in the query as described in Facebook's [field expansion](https://developers.facebook.com/docs/reference/api/field_expansion/) documentation. However, the <code>facebook</code> library that we'll use in the next example handles some of these issues, so it's recommended that you hold off and try it out first. This initial example is just to illustrate that Facebook's API is built on top of HTTP.
#
# A couple of field limit/offset examples that illustrate the possibilities follow:
#
# <code>
# fields = 'id,name,friends.limit(10).fields(likes)'            # Get all likes for 10 friends
# fields = 'id,name,friends.offset(10).limit(10).fields(likes)' # Get all likes for 10 more friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# </code>

# %% [markdown]
# ## Example 2. Querying the Graph API with Python

# %%
import facebook # pip install facebook-sdk
import json

# A helper function to pretty-print Python objects as JSON

def pp(o): 
    print json.dumps(o, indent=1)

# Create a connection to the Graph API with your access token

g = facebook.GraphAPI(ACCESS_TOKEN)

# Execute a few sample queries

print '---------------'
print 'Me'
print '---------------'
pp(g.get_object('me'))
print
print '---------------'
print 'My Friends'
print '---------------'
pp(g.get_connections('me', 'friends'))
print
print '---------------'
print 'Social Web'
print '---------------'
pp(g.request("search", {'q' : 'social web', 'type' : 'page'}))
# Out:
# ---------------
# Me
# ---------------
# {
#  "bio": "\u00d8\u00d8",
#  "first_name": "Gilles",
#  "last_name": "Boy\u00e9",
#  "relationship_status": "In a relationship",
#  "name": "Gilles Boy\u00e9",
#  "locale": "en_US",
#  "gender": "male",
#  "verified": true,
#  "political": "Extr\u00eame centre",
#  "updated_time": "2015-04-05T10:48:29+0000",
#  "languages": [
#   {
#    "id": "103803232991647",
#    "name": "English"
#   },
#   {
#    "id": "113797141964532",
#    "name": "Indonesian"
#   },
#   {
#    "id": "108224912538348",
#    "name": "French"
#   },
#   {
#    "id": "112264595467201",
#    "name": "Fran\u00e7ais"
#   }
#  ],
#  "religion": "Agnostique",
#  "birthday": "04/20/1964",
#  "link": "https://www.facebook.com/app_scoped_user_id/10152969331868155/",
#  "location": {
#   "id": "106251232746712",
#   "name": "Bayonne, France"
#  },
#  "hometown": {
#   "id": "115996171745296",
#   "name": "Bois-Le-Roi, Ile-De-France, France"
#  },
#  "timezone": 2,
#  "education": [
#   {
#    "school": {
#     "id": "106259929412116",
#     "name": "Lyc\u00e9e Fran\u00e7ois Ier, Fontainebleau"
#    },
#    "type": "High School",
#    "year": {
#     "id": "149402035069887",
#     "name": "1981"
#    }
#   },
#   {
#    "with": [
#     {
#      "id": "10204449828468409",
#      "name": "Elodie Rousseau"
#     }
#    ],
#    "school": {
#     "id": "109843702378048",
#     "name": "Universit\u00e9 Michel de Montaigne Bordeaux 3"
#    },
#    "type": "College"
#   },
#   {
#    "concentration": [
#     {
#      "id": "106373759394131",
#      "name": "Computer Science"
#     }
#    ],
#    "type": "College",
#    "school": {
#     "id": "109307965762193",
#     "name": "\u00c9cole centrale Paris"
#    },
#    "year": {
#     "id": "136666673036069",
#     "name": "1987"
#    }
#   },
#   {
#    "concentration": [
#     {
#      "id": "112201402129408",
#      "name": "Linguistics"
#     }
#    ],
#    "type": "Graduate School",
#    "school": {
#     "id": "114835201873664",
#     "name": "Paris Diderot University"
#    },
#    "degree": {
#     "id": "193652043997452",
#     "name": "Doctorat"
#    },
#    "year": {
#     "id": "143018465715205",
#     "name": "2000"
#    }
#   }
#  ],
#  "work": [
#   {
#    "position": {
#     "id": "140320979333437",
#     "name": "Enseignant-chercheur"
#    },
#    "start_date": "2006-09-01",
#    "location": {
#     "id": "115838035093755",
#     "name": "Bordeaux, France"
#    },
#    "employer": {
#     "id": "109455799075143",
#     "name": "Universit\u00e9 Michel de Montaigne Bordeaux 3"
#    }
#   },
#   {
#    "position": {
#     "id": "108143929214316",
#     "name": "Chercheur"
#    },
#    "start_date": "2005-09-01",
#    "location": {
#     "id": "110445852316970",
#     "name": "Toulouse, France"
#    },
#    "end_date": "2006-08-01",
#    "employer": {
#     "id": "110213415670120",
#     "name": "CNRS"
#    }
#   },
#   {
#    "position": {
#     "id": "140320979333437",
#     "name": "Enseignant-chercheur"
#    },
#    "start_date": "2000-09-01",
#    "location": {
#     "id": "115424448472950",
#     "name": "Nancy, France"
#    },
#    "end_date": "2005-08-01",
#    "employer": {
#     "id": "106395986063740",
#     "name": "Universit\u00e9 Nancy 2"
#    }
#   },
#   {
#    "position": {
#     "id": "142187709136442",
#     "name": "ATER"
#    },
#    "start_date": "1997-09-01",
#    "location": {
#     "id": "112658848753555",
#     "name": "Saint-Denis, Ile-De-France, France"
#    },
#    "end_date": "1999-08-01",
#    "employer": {
#     "id": "453854334647303",
#     "name": "Universit\u00e9 Paris 8"
#    }
#   }
#  ],
#  "id": "10152969331868155"
# }
#
# ---------------
# My Friends
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v2.0/10152969331868155/friends?access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh&limit=5000&offset=5000&__after_id=enc_AdC0tZAK2ZAkW6nvYTqD4Yu2pG7dKCEpHB4zm1Y234k5ZB4r6ZCuAIVAi6gAEZA64QnvZCz0zM4GRYbhltdVVZCdxbqfcC6"
#  },
#  "data": [
#   {
#    "name": "Noalig Biteau",
#    "id": "1467081977"
#   },
#   {
#    "name": "Sdl Bordeaux",
#    "id": "657556317685570"
#   }
#  ],
#  "summary": {
#   "total_count": 234
#  }
# }
#
# ---------------
# Social Web
# ---------------
# {
#  "paging": {
#   "cursors": {
#    "after": "NTE4",
#    "before": "MA=="
#   }
#  },
#  "data": [
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "181475575221097",
#      "name": "Photographer"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "144307838980365"
#   },
#   {
#    "category": "Business services",
#    "name": "LS Social Web",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "205510939478893",
#      "name": "Copying & Printing"
#     }
#    ],
#    "id": "515092701968229"
#   },
#   {
#    "category": "Business services",
#    "name": "socialWEB",
#    "category_list": [
#     {
#      "id": "200209719995975",
#      "name": "Business Supply Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "114355558650055"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "SOCIAL WEBSITE",
#    "id": "290608457641244"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SocialWeb.ro",
#    "id": "185753574790507"
#   },
#   {
#    "category": "Tv network",
#    "name": "Ceflix social web tv",
#    "id": "760164607375916"
#   },
#   {
#    "category": "Website",
#    "name": "Social Webshop",
#    "id": "1394913830760636"
#   },
#   {
#    "category": "Community",
#    "name": "Club Social Web, de Paisajes, Plantas y Flores de la Rep. Argentina",
#    "id": "358475911013315"
#   },
#   {
#    "category": "Education",
#    "name": "WebSocial",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "192541364117143"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Website",
#    "id": "210604392401626"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SocialWebMarketing",
#    "id": "226633110719998"
#   },
#   {
#    "category": "Community",
#    "name": "Social WEB",
#    "id": "295703510589892"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Sherpas",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "105830116116453"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Webwork",
#    "id": "1438118799768086"
#   },
#   {
#    "category": "Software",
#    "name": "Social Webshop UK",
#    "id": "367809806695037"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "441220109348770"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webforce",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "128172607258182"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social / Web Marketing Agency - Stir USA | Canada",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "152246029758"
#   },
#   {
#    "category": "Software",
#    "name": "SocialWebshop Poland",
#    "id": "853892051289097"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webs",
#    "id": "174735529355893"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Web Promoter",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "657099161012700"
#   },
#   {
#    "category": "Community organization",
#    "name": "Social Web",
#    "id": "933108596709692"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     }
#    ],
#    "id": "479064558889277"
#   },
#   {
#    "category": "Book",
#    "name": "Mining the Social Web",
#    "id": "146803958708175"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Webmarks",
#    "id": "230470560302996"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "145218172174013"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialWeb",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "669751383086793"
#   },
#   {
#    "category": "App page",
#    "name": "Social Web Reporter",
#    "id": "598817503529463"
#   },
#   {
#    "category": "Community",
#    "name": "Keine Kinderfotos im Social Web",
#    "id": "137058369654806"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Day",
#    "id": "137161799695400"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Cafe",
#    "id": "255596497809113"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Platform",
#    "id": "114016465440871"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Websurf Social Media",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "102106206533278"
#   },
#   {
#    "category": "Community",
#    "name": "Web Social",
#    "id": "231682236924947"
#   },
#   {
#    "category": "App page",
#    "name": "SocialWebbie",
#    "id": "217112891701827"
#   },
#   {
#    "category": "Software",
#    "name": "SocialWebshop Espa\u00f1a",
#    "id": "1565197313702068"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social web design by x10industries",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "330043283780"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Web Agency",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "1574818702754538"
#   },
#   {
#    "category": "Community organization",
#    "name": "Social Web Tech Talk",
#    "id": "173272359544586"
#   },
#   {
#    "category": "Product/service",
#    "name": "On The Webb Social Media Services",
#    "id": "210125749066257"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebSocial",
#    "id": "208290102524008"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Associates",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "327997047315600"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Dzine",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "122698737762622"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Girl",
#    "id": "1425389227704470"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Websoftseo Social",
#    "id": "378379822329057"
#   },
#   {
#    "category": "School",
#    "name": "Social web - \u05e1\u05d5\u05e9\u05d9\u05d0\u05dc \u05d5\u05d5\u05d1",
#    "id": "419507011456285"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Gimme Social Web",
#    "id": "190870261096138"
#   },
#   {
#    "category": "Interest",
#    "name": "Social web",
#    "id": "112879218725926"
#   },
#   {
#    "category": "Arts/humanities website",
#    "name": "Social Web Art",
#    "id": "833575423359366"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead senegal",
#    "id": "344899405678326"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Power",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "835021083188471"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social Web Strategy",
#    "category_list": [
#     {
#      "id": "169056916473899",
#      "name": "Broadcasting & Media Production"
#     },
#     {
#      "id": "201528873201605",
#      "name": "Management Service"
#     }
#    ],
#    "id": "142810595790974"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Innovation",
#    "id": "162028037196792"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SocialWebOS",
#    "id": "358524254168284"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "My Social Web",
#    "id": "76277666156"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "156184496617"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social & Web Marketing",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "172427156148334"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web Thing",
#    "id": "114874051893438"
#   },
#   {
#    "category": "Community",
#    "name": "Social Webs",
#    "id": "159735864118250"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Alliance",
#    "id": "160477007390933"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Web Arena",
#    "id": "1511437179114307"
#   },
#   {
#    "category": "Education",
#    "name": "Social Web Academy",
#    "id": "192046090848741"
#   },
#   {
#    "category": "Company",
#    "name": "Social web consulting",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "438991686226624"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "103944626326539"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Genie Websites",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "876686629019847"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Web Tactics",
#    "category_list": [
#     {
#      "id": "2237",
#      "name": "Small Business"
#     }
#    ],
#    "id": "162973743866087"
#   },
#   {
#    "category": "Website",
#    "name": "SocialWebLike",
#    "id": "101946616632016"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Artwhere Mobile Social Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "46316179114"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web",
#    "id": "502604446522710"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Web.Search.Social",
#    "id": "214631441934914"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Web Ranking",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "470852336273104"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social Dev",
#    "id": "233682666821223"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Adapting Social Web Design & Digital Marketing",
#    "id": "232898900191494"
#   },
#   {
#    "category": "Community",
#    "name": "Social Nurse Web",
#    "id": "641989875880917"
#   },
#   {
#    "category": "Bank/financial institution",
#    "name": "Tsu - Social website",
#    "id": "855999941126568"
#   },
#   {
#    "category": "Internet/software",
#    "name": "22Social",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "107894379351327"
#   },
#   {
#    "category": "Education",
#    "name": "Web G\u00e9n\u00e9ration",
#    "category_list": [
#     {
#      "id": "178669642178193",
#      "name": "Social Services"
#     }
#    ],
#    "id": "151710948332466"
#   },
#   {
#    "category": "Company",
#    "name": "BSocial",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "133669593358394"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "SocialBiz Ireland",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "181475575221097",
#      "name": "Photographer"
#     },
#     {
#      "id": "169056916473899",
#      "name": "Broadcasting & Media Production"
#     }
#    ],
#    "id": "273832482758831"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialTab Web Apps",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ],
#    "id": "271649089705217"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialBase",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "351653524868037"
#   },
#   {
#    "category": "Business services",
#    "name": "On Social Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "746979972011644"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media Siti Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "553637281423867"
#   },
#   {
#    "category": "Website",
#    "name": "VK (social networking website)",
#    "id": "112703008745510"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webshop Italy",
#    "id": "610458242362481"
#   },
#   {
#    "category": "Product/service",
#    "name": "WebSocial",
#    "id": "747003228707421"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web BREAKFAST",
#    "id": "175318852545291"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "iptaque, web social, formation",
#    "id": "241894749184616"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Optragroup - Agence Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "161811347201528",
#      "name": "Lodging"
#     }
#    ],
#    "id": "123000931064408"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Factory",
#    "id": "67783847861"
#   },
#   {
#    "category": "Movie character",
#    "name": "Social website",
#    "id": "206400919559635"
#   },
#   {
#    "category": "News/media website",
#    "name": "Web Marketing et Communication Social Media",
#    "id": "488498934539529"
#   },
#   {
#    "category": "Community organization",
#    "name": "SocialWebConneXion.com",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     },
#     {
#      "id": "152880021441864",
#      "name": "Community Organization"
#     }
#    ],
#    "id": "636570933034875"
#   },
#   {
#    "category": "Community",
#    "name": "SocialWeb",
#    "id": "589464101164823"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Netika - web social",
#    "id": "1528730477394644"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webfluence Social Media & Internet Marketing",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "112879788755706"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web",
#    "id": "456664834354636"
#   },
#   {
#    "category": "Shopping/retail",
#    "name": "Social Web Deals",
#    "id": "225923010951805"
#   },
#   {
#    "category": "Website",
#    "name": "Islamic & Social Website - abswerbd.com",
#    "id": "677061112307489"
#   },
#   {
#    "category": "Local business",
#    "name": "Web1 Social Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "119307778101744"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "webfeuer - Social Media und mehr!",
#    "id": "369613539636"
#   },
#   {
#    "category": "Home improvement",
#    "name": "Websites & Social Media",
#    "category_list": [
#     {
#      "id": "108427109235243",
#      "name": "Home Improvement"
#     }
#    ],
#    "id": "213642188759243"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Life Social Web",
#    "category_list": [
#     {
#      "id": "192119584190796",
#      "name": "Event"
#     },
#     {
#      "id": "108470879231339",
#      "name": "Research Service"
#     }
#    ],
#    "id": "147895125402338"
#   },
#   {
#    "category": "Non-profit organization",
#    "name": "Social web lead ngor yoff",
#    "id": "819160111500449"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Wizard",
#    "id": "169089429771025"
#   },
#   {
#    "category": "Community",
#    "name": "Web & Social Media Marketing",
#    "id": "1599805096975871"
#   },
#   {
#    "category": "Concert venue",
#    "name": "SocialWeb",
#    "id": "186493478082456"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social webs cheats",
#    "id": "227273367442760"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Q and A",
#    "id": "433133770070530"
#   },
#   {
#    "category": "Education",
#    "name": "Social Web Academy",
#    "id": "498691586935473"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webshop FR",
#    "id": "235406569990322"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar  hann mariste",
#    "id": "824163074271203"
#   },
#   {
#    "category": "Community",
#    "name": "Webster Alumni Social Group",
#    "id": "487171701376262"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar ouakam",
#    "id": "605433729566597"
#   },
#   {
#    "category": "Community",
#    "name": "Social web feeds",
#    "id": "1621735518056647"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Anxiety - A Web Series",
#    "id": "107080656067158"
#   },
#   {
#    "category": "Website",
#    "name": "My Social Media Website",
#    "id": "265276823522152"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Web Content",
#    "id": "293898797278"
#   },
#   {
#    "category": "Education",
#    "name": "ITE College West - Nitec in Social Media and Web Development",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "162257397196866"
#   },
#   {
#    "category": "Tv network",
#    "name": "Social RTV Web",
#    "id": "449118198574253"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Web Talks",
#    "id": "316613681700247"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Communication",
#    "category_list": [
#     {
#      "id": "132008380200065",
#      "name": "Image Consultant"
#     }
#    ],
#    "id": "165807746962152"
#   },
#   {
#    "category": "Community",
#    "name": "Social Webinars",
#    "id": "97056087866"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web macht Schule",
#    "id": "640045259452124"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead diass sindia",
#    "id": "816594321715390"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Webs Social Media pvt ltd",
#    "id": "1595712023989998"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar m\u00e9dina",
#    "id": "662546880510024"
#   },
#   {
#    "category": "Local business",
#    "name": "Dot Ingenuity Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "131570646875176"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Promotions",
#    "id": "234335963269949"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar thiaroye kao",
#    "id": "1487671954851143"
#   },
#   {
#    "category": "Company",
#    "name": "Weber Shandwick Social Impact",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "89444069963"
#   },
#   {
#    "category": "Personal website",
#    "name": "THE JAGUAR SOCIAL NETWORK  WEBSITE",
#    "id": "114852928532072"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Dreams: Web Series",
#    "id": "612698088813986"
#   },
#   {
#    "category": "Small business",
#    "name": "Ignite Social Web",
#    "id": "124131750957589"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Milano Social Web",
#    "id": "252633804884736"
#   },
#   {
#    "category": "Artist",
#    "name": "Ion Gonzaga, The Social Web Designer",
#    "id": "120679007979099"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar mermoz sacre coeur",
#    "id": "758697517535830"
#   },
#   {
#    "category": "Tv/movie award",
#    "name": "Social/website",
#    "id": "1592574544312785"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Solutions",
#    "id": "206788172841236"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Caroline Webb - Digital & Social Media",
#    "id": "219957014881658"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social",
#    "id": "481173118576926"
#   },
#   {
#    "category": "Community",
#    "name": "Formation : Valorisez vos travaux de recherche avec le web social",
#    "id": "100632060099568"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social Media Webster",
#    "id": "416689008392125"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar dieupeul derkle",
#    "id": "386488081503891"
#   },
#   {
#    "category": "Education",
#    "name": "Lauren Webb - A Social Studies Life",
#    "category_list": [
#     {
#      "id": "108557642554592",
#      "name": "Educational Service"
#     }
#    ],
#    "id": "500943803329283"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media Web",
#    "id": "432946513540737"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Buys",
#    "id": "645061782205988"
#   },
#   {
#    "category": "Company",
#    "name": "SocialWeb Consulting",
#    "id": "177391935634180"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Strategies",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "8387137434"
#   },
#   {
#    "category": "Local business",
#    "name": "Web Social Marketing",
#    "id": "161192167329576"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Mackey Digital - Web & Social Media Solutions",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "532009816944028"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web Social Media",
#    "id": "208713579252761"
#   },
#   {
#    "category": "Website",
#    "name": "Web Social Tourism",
#    "id": "301608313292038"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media & Websites",
#    "id": "278572212299892"
#   },
#   {
#    "category": "Local business",
#    "name": "Biz Social Webdesign / Web Design by Jenn",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "115395771827453"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Social-Webcam",
#    "id": "138187269563360"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Leading Logic - Web, Social, Marketing, Design",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "136481676384923"
#   },
#   {
#    "category": "Internet/software",
#    "name": "ICTIP - Online Marketing, Social Media Management and Web Development",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "147188657823"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead ziguinchor",
#    "id": "654808337965974"
#   },
#   {
#    "category": "Company",
#    "name": "Webshoutz be social",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "502559819771053"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Schreckgespenster Webdesign & Social Media Marketing",
#    "id": "707284739354883"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Grafdom - Web Design & Social Media",
#    "id": "190124415513"
#   },
#   {
#    "category": "Teacher",
#    "name": "Dise\u00f1o Web Social",
#    "id": "253202708077866"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media & Website Solutions by 108 degrees",
#    "id": "125953907477790"
#   },
#   {
#    "category": "Local business",
#    "name": "WebSocialTraffic",
#    "id": "19939664284"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar parcelles assainies",
#    "id": "871079359593314"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Qweboo \"Control Your Social Web\"",
#    "id": "146142715411167"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "In Social Web",
#    "id": "168072826666497"
#   },
#   {
#    "category": "Internet/software",
#    "name": "etrade.ba | Social Media & Web",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "217376194979375"
#   },
#   {
#    "category": "Business services",
#    "name": "Website Social Media Development",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "522531034450480"
#   },
#   {
#    "category": "Company",
#    "name": "Enova4U Dise\u00f1o Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "218721764817225"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Website Design Tutorials And Social Media Marketing",
#    "id": "418218642781"
#   },
#   {
#    "category": "Community",
#    "name": "WebSocial",
#    "id": "223113717714513"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "Social4Web",
#    "id": "169765039795027"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "G&B Marketing | Web & Social Media",
#    "id": "331604230252618"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web in Fermento - Marketing nel Social Web e NewMedia Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "125310277520246"
#   },
#   {
#    "category": "Professional services",
#    "name": "Free Social Media Webinars",
#    "id": "1388018764754564"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Meta Social Web",
#    "id": "117185225027930"
#   },
#   {
#    "category": "Professional services",
#    "name": "Visibly Connected - Web Design, Social Media Manager, & SEO",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "190805541029564"
#   },
#   {
#    "category": "Personal website",
#    "name": "V Crown Social website",
#    "id": "509251595812044"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Ecosystem",
#    "id": "186923664693877"
#   },
#   {
#    "category": "Local business",
#    "name": "The Webb",
#    "category_list": [
#     {
#      "id": "215343825145859",
#      "name": "Social Club"
#     }
#    ],
#    "id": "260498734104390"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media Networks",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "151931054869702",
#      "name": "Document Service"
#     }
#    ],
#    "id": "266641420128830"
#   },
#   {
#    "category": "Business services",
#    "name": "bSocial",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "365191623584856"
#   },
#   {
#    "category": "Professional services",
#    "name": "RaDiO SoCiAL - Web Radio",
#    "category_list": [
#     {
#      "id": "169056916473899",
#      "name": "Broadcasting & Media Production"
#     }
#    ],
#    "id": "503048753168925"
#   },
#   {
#    "category": "Local business",
#    "name": "Webber Social Club",
#    "category_list": [
#     {
#      "id": "189018581118681",
#      "name": "Sports Club"
#     }
#    ],
#    "id": "111516775554603"
#   },
#   {
#    "category": "Local business",
#    "name": "Webster Hall Club",
#    "category_list": [
#     {
#      "id": "215343825145859",
#      "name": "Social Club"
#     }
#    ],
#    "id": "211396812321665"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Media Marketing Dubai",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "103778059813717"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Goodman's Social Media",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "554490988018741"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Speak Social",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "127692573953699"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Pepper",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "398222010315087"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SocialActive",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "224037851000340"
#   },
#   {
#    "category": "Professional services",
#    "name": "Pub Social",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "1483479818531728"
#   },
#   {
#    "category": "Professional services",
#    "name": "Qtellwebdesign Webdesign Ireland",
#    "category_list": [
#     {
#      "id": "215343825145859",
#      "name": "Social Club"
#     }
#    ],
#    "id": "548614918572488"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Adrenaline",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "159855090738042"
#   },
#   {
#    "category": "Small business",
#    "name": "Socialwebmedia.ca",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "571629912898259"
#   },
#   {
#    "category": "Community",
#    "name": "Social Webs Likes And Fans Service",
#    "id": "817713454916961"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webology",
#    "id": "199369666770042"
#   },
#   {
#    "category": "Company",
#    "name": "Hi Fi Social Web",
#    "id": "196298563744277"
#   },
#   {
#    "category": "Professional services",
#    "name": "Web & Social Solutions",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "577684822294787"
#   },
#   {
#    "category": "Interest",
#    "name": "Social website",
#    "id": "198566960212311"
#   },
#   {
#    "category": "Internet/software",
#    "name": "bluehouse - Die Web & Social Media Agentur",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "223239324395549"
#   },
#   {
#    "category": "Just for fun",
#    "name": "Megalast.webs.com Social",
#    "id": "264097790271896"
#   },
#   {
#    "category": "Community",
#    "name": "ITE College Central - Social Media & Web Development",
#    "id": "120366748050821"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Seclang \"Social Networking Website\"",
#    "id": "127425098113"
#   },
#   {
#    "category": "Community",
#    "name": "B2B Web Social",
#    "id": "1623310654563603"
#   },
#   {
#    "category": "Business services",
#    "name": "Boxless Media - Social Media & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "150063728530867"
#   },
#   {
#    "category": "Community",
#    "name": "Happy Social Web",
#    "id": "1488750614743981"
#   },
#   {
#    "category": "Community",
#    "name": "2015 Weber Parent  Social",
#    "id": "1570944539852459"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media Website",
#    "id": "1409211522669854"
#   },
#   {
#    "category": "Professional services",
#    "name": "WebSpot Social",
#    "id": "175322602545416"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Syndic",
#    "id": "1054014914625758"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SeashoreWeb Social Media Marketing",
#    "id": "106838049410541"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Real-time Social Web",
#    "id": "121363354543881"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar pikine",
#    "id": "1486223964986147"
#   },
#   {
#    "category": "Website",
#    "name": "Webwinkel Social Media",
#    "id": "1421289988163648"
#   },
#   {
#    "category": "University",
#    "name": "Gardner-Webb Department of Social Sciences",
#    "id": "1564396453821191"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "The Social Web Company",
#    "id": "460355617439986"
#   },
#   {
#    "category": "News/media website",
#    "name": "La Psych\u00e9 du Web Social",
#    "id": "226268934063345"
#   },
#   {
#    "category": "Community organization",
#    "name": "Go Long Island - The Social Website for Long Island",
#    "id": "118029078273421"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Urls",
#    "id": "806157402782310"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "DEGRAFIK - Social Media and Website Management",
#    "id": "113648292011480"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Consulting",
#    "id": "248823435257496"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web TV. We socialize your passion",
#    "id": "285679378241848"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web/Social Marketing",
#    "id": "172670552803004"
#   },
#   {
#    "category": "Community",
#    "name": "Social,Web e Digital le migliori news",
#    "id": "290106064511423"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Digital For Dummies | Social, Web & other Technical Stuff",
#    "id": "476313985731653"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Web Online",
#    "id": "815244335205706"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Week Connecticut",
#    "id": "128455980522180"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Labs - Social Media Team",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "1378760945677870"
#   },
#   {
#    "category": "Community",
#    "name": "Webassurance.org - Social Media & Internet for Insurance & Takaful",
#    "id": "132191463490119"
#   },
#   {
#    "category": "Personal blog",
#    "name": "Web-social.marketing",
#    "id": "1469299413303540"
#   },
#   {
#    "category": "Professional services",
#    "name": "Local Social Web",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "292125494205150"
#   },
#   {
#    "category": "Community",
#    "name": "Federated Social Web",
#    "id": "117548264997115"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar grand yoff",
#    "id": "521762104627077"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead Dakar  biscuiterie",
#    "id": "557707754330768"
#   },
#   {
#    "category": "Internet/software",
#    "name": "WebKit - Social Networks, E-commerce, Web Development",
#    "id": "96394316810"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Seek",
#    "id": "936130943068347"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Webmates",
#    "id": "474170526056354"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Bonobo - Web & Social Media",
#    "id": "185366164983180"
#   },
#   {
#    "category": "Local/travel website",
#    "name": "WebJ Social Travel Wave",
#    "id": "868900836508774"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Web Cafe TV",
#    "id": "149184731910179"
#   },
#   {
#    "category": "Community",
#    "name": "Social Responsibility Web TV",
#    "id": "159723424059236"
#   },
#   {
#    "category": "Company",
#    "name": "Social Semantic Web",
#    "id": "36575011414"
#   },
#   {
#    "category": "Community",
#    "name": "Web COmmunities for Statistics for Social Innovation",
#    "id": "1398644970370772"
#   },
#   {
#    "category": "Just for fun",
#    "name": "Social web balls.",
#    "id": "277644225667373"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Real Estate",
#    "id": "164269200441810"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Media Websites",
#    "id": "121361064703333"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Impact Web",
#    "id": "196321800413834"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Paranormal Minds-\"A Social Media Webcast\"",
#    "id": "456473431065014"
#   },
#   {
#    "category": "Website",
#    "name": "Social/News/Culture Website",
#    "id": "1450059198607934"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "SociablWeb - Social Media News, SEO Tips",
#    "id": "446376028729715"
#   },
#   {
#    "category": "App page",
#    "name": "Himbaface social web application",
#    "id": "339474376250286"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media Webinarcamps",
#    "id": "508178575883032"
#   },
#   {
#    "category": "Reference website",
#    "name": "Pink\u00e4berry - Web/Social Media Marketing",
#    "id": "301606476681193"
#   },
#   {
#    "category": "Business services",
#    "name": "Website & Social Media Mangagement",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "795258510484960"
#   },
#   {
#    "category": "Website",
#    "name": "Exploding Web Design and Social",
#    "id": "1592890827596653"
#   },
#   {
#    "category": "App page",
#    "name": "Social Web to Print",
#    "id": "309361589082975"
#   },
#   {
#    "category": "Company",
#    "name": "Right Track Media - Web Design, Social Media, Video",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "883116528376991"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Websites and Social Media Pty Ltd",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "645332448912697"
#   },
#   {
#    "category": "Company",
#    "name": "Sweden Social Web Camp",
#    "id": "290284817827"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar patte d'oie",
#    "id": "1570344376520742"
#   },
#   {
#    "category": "Book",
#    "name": "PR im Social Web",
#    "id": "161347393888030"
#   },
#   {
#    "category": "Community",
#    "name": "Consulente Web Social Marketing",
#    "id": "1569815356573979"
#   },
#   {
#    "category": "Software",
#    "name": "Fimark's Family Reunion Planner Social Web App",
#    "id": "119054884844075"
#   },
#   {
#    "category": "Website",
#    "name": "Mike Mueller: Marketing, Web Design, & Social Media Consultation",
#    "id": "50818804012"
#   },
#   {
#    "category": "Business person",
#    "name": "PaulMatadeen.com for Revolutionary Websites, Social Media, Videos, PR",
#    "id": "278807242146350"
#   },
#   {
#    "category": "News/media website",
#    "name": "The Church Of Nigeria: Anglican Communion - Akure Diocese (Social Webpage)",
#    "id": "143748352345882"
#   },
#   {
#    "category": "Radio station",
#    "name": "WebRadio Social",
#    "id": "172438649562650"
#   },
#   {
#    "category": "Local business",
#    "name": "Dialed-In Local - Nashville SEO, Social Media Marketing, & Web Design",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "782218141856730"
#   },
#   {
#    "category": "Website",
#    "name": "Future of Social Websites",
#    "id": "377594499088941"
#   },
#   {
#    "category": "Local business",
#    "name": "eitbits Webs & Social Media",
#    "id": "132214966858612"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "Wedding Social Networking, Free Wedding Websites",
#    "id": "187276274416"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "East West Websites & Social Media",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
# ...
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "520065534799401"
#   },
#   {
#    "category": "Radio station",
#    "name": "R\u00e1dio Social Web",
#    "id": "357886887644210"
#   },
#   {
#    "category": "Internet/software",
#    "name": "EPhost Inc - web hosting, web design and social media",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "471519355150"
#   },
#   {
#    "category": "Product/service",
#    "name": "Web & Social Media Strategy",
#    "id": "219292161416145"
#   },
#   {
#    "category": "Product/service",
#    "name": "Webmeister Social SEO",
#    "id": "653130718079993"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media Pack from Matt Porter Web Design",
#    "id": "132234360308800"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar jaxaay niakoulrab rufisque",
#    "id": "1466275763633531"
#   },
#   {
#    "category": "Product/service",
#    "name": "@webdesignleads - Web Design & Development Social Leads",
#    "id": "162899293739458"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Micro Manage - Web Design, Social Media",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "1454227451473709"
#   },
#   {
#    "category": "Community",
#    "name": "Marketing Secrets Webinar - Social Media",
#    "id": "166744270013401"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Life - The Web Show",
#    "id": "190526720994424"
#   },
#   {
#    "category": "Website",
#    "name": "MultiWeb Social Media",
#    "id": "421539101336814"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Jayu Web Design & Social Media",
#    "id": "683295505094900"
#   },
#   {
#    "category": "Professional services",
#    "name": "Creative-web Development",
#    "category_list": [
#     {
#      "id": "2517",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "868916846499292"
#   },
#   {
#    "category": "Company",
#    "name": "Zero It | Websites | Development | Smartphone Apps | SEO | Social Media |",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "109692079082500"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Elite Ideas - Websites, Marketing, Social Media",
#    "id": "120959061268900"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Wild West Online Productions - Social Media & Web Video Consultants",
#    "id": "122255047839285"
#   },
#   {
#    "category": "Product/service",
#    "name": "AVXYS - Websites, Social Media boosters, offline ads, real life promotions.",
#    "id": "526393270738637"
#   },
#   {
#    "category": "Product/service",
#    "name": "Eguino Social Web",
#    "id": "114206991977394"
#   },
#   {
#    "category": "Professional services",
#    "name": "SNAP-Social Media Marketing/Web Design",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "492285150843542"
#   },
#   {
#    "category": "Community",
#    "name": "Social Networking Websites",
#    "id": "34136628087"
#   },
#   {
#    "category": "Studio",
#    "name": "LuisGPrieto.com Video Marketing Cinematography 4K Films - Websites - Social",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "169056916473899",
#      "name": "Broadcasting & Media Production"
#     }
#    ],
#    "id": "398409516933256"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web Marketing Tips & Tracks",
#    "id": "330326447014616"
#   },
#   {
#    "category": "Product/service",
#    "name": "OC Media Works - Website Design, Social Media, SEO & Online Marketing",
#    "id": "119488541409785"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media Marketing - Your Website Inside FB",
#    "id": "467525046604604"
#   },
#   {
#    "category": "Business services",
#    "name": "Webdesign, Social media consultancy and Photography for your Business",
#    "id": "1450860541805707"
#   },
#   {
#    "category": "Product/service",
#    "name": "Jasa Pembuatan Website, Jasa SEO Dan Social Media",
#    "id": "199034316834357"
#   },
#   {
#    "category": "Website",
#    "name": "WebSocial.ly",
#    "id": "113759552036905"
#   },
#   {
#    "category": "Company",
#    "name": "Web Infotech Solutions",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "400241243372561"
#   },
#   {
#    "category": "Education",
#    "name": "The Social Mobile WEB Business Conference",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "290193207726357"
#   },
#   {
#    "category": "Just for fun",
#    "name": "Hyper_death social webpage",
#    "id": "912281025462215"
#   },
#   {
#    "category": "Interest",
#    "name": "Social Web Academy",
#    "id": "133517650020227"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "Mind Fire Media Website Design & Social Seo Leigh On Sea",
#    "id": "516740478467752"
#   },
#   {
#    "category": "Professional services",
#    "name": "Kelowna website, social media, SEO, online tourism pro - Tourism SEO",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "151720821568494"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social CR",
#    "id": "162780077207016"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Dise\u00f1o Web, Social Media e-mandinga",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "171948265971"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Consulting Test Page",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "159918207405302"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "CDA - web site design and social media marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "199732070036794",
#      "name": "Artistic Services"
#     }
#    ],
#    "id": "127537383928865"
#   },
#   {
#    "category": "Product/service",
#    "name": "Basic Social Media & Website Consulting",
#    "id": "176180415757198"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Emma Fern\u00e1ndez \u00b7SEO \u00b7 Web \u00b7Social Media",
#    "category_list": [
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     },
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ],
#    "id": "658425767604330"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Modo web & social media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "455357827936421"
#   },
#   {
#    "category": "Professional services",
#    "name": "Avalde Digital - Web Mobile Social Agency",
#    "id": "98306292396"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Likefollower.it - Social & Web Marketing",
#    "id": "493833740703153"
#   },
#   {
#    "category": "Company",
#    "name": "Social Media Marketing Webinars",
#    "id": "540435662760549"
#   },
#   {
#    "category": "Company",
#    "name": "Internet-Rhetorik - Kommunikation im Social Web",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "153169621372946"
#   },
#   {
#    "category": "Education",
#    "name": "Social Media Marketing & Web Communication - Executive Master SDC IULM",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "104917969542058"
#   },
#   {
#    "category": "Church/religious organization",
#    "name": "Kirche im Web 2.0 / Social Media",
#    "id": "161519650568794"
#   },
#   {
#    "category": "Community",
#    "name": "WebSocial Technologies",
#    "id": "160950113952562"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Web Social Solutions di Ilaria Cervelli",
#    "id": "282633258527507"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "V Crown Social website.",
#    "id": "715273168500573"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Network For Webmasters - WebmaisterPro",
#    "id": "207157179328797"
#   },
#   {
#    "category": "Website",
#    "name": "IMCurtain.com | Blogosphere & Social News Website",
#    "id": "317066358470"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Business Social Web Management",
#    "id": "843854045676383"
#   },
#   {
#    "category": "Internet/software",
#    "name": "RE-ad - Caribbean Website, App and Social Media Development",
#    "id": "194459097399555"
#   },
#   {
#    "category": "Business services",
#    "name": "PresentationMultimedia - Social Media, SEO, DVD & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "173932019310961"
#   },
#   {
#    "category": "Internet/software",
#    "name": "DL Web e Social Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "583632948436409"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Whitedrop  Web Marketing Social",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "681921881866837"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Media Marketing and Website Design Agency",
#    "id": "129701130375873"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "The Mobi  Fanpage Guy",
#    "id": "303157799810614"
#   },
#   {
#    "category": "Local business",
#    "name": "Attivia Web Design | Computer Support |  SEO | Social Media Consulting",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "122897294395332"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "La Fine Equipe // Web & Social Media",
#    "id": "154196491442304"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Webinars and Seminars",
#    "id": "640189532715173"
#   },
#   {
#    "category": "Website",
#    "name": "WebCamSocial.com",
#    "id": "193570570659564"
#   },
#   {
#    "category": "Community",
#    "name": "Web Social Fusion",
#    "id": "184400038262157"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Clases de lo social - La Webserie",
#    "id": "280735022054806"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Web Solutions",
#    "id": "182392658453258"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Media Web Development",
#    "id": "125248858533"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Pattern - The Web Mistake",
#    "id": "627093977420952"
#   },
#   {
#    "category": "Business services",
#    "name": "Alice Olgiati Web Editing & Social Media Consultanting",
#    "category_list": [
#     {
#      "id": "2518",
#      "name": "Business Services"
#     }
#    ],
#    "id": "853438371365304"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "GO Social Website Design",
#    "id": "109035149170820"
#   },
#   {
#    "category": "Personal website",
#    "name": "Tchat webcam social",
#    "id": "234440059921976"
#   },
#   {
#    "category": "Community",
#    "name": "Dynamic Diversions Enterprises Social Media and Web Design",
#    "id": "1516556771903871"
#   },
#   {
#    "category": "Local business",
#    "name": "WEB2NULL.at - Social Media WebDesign Agentur",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ],
#    "id": "107423162613389"
#   },
#   {
#    "category": "Website",
#    "name": "Ghanakro: Ghana's Largest Social Network website",
#    "id": "147645865245931"
#   },
#   {
#    "category": "Event planning/event services",
#    "name": "St Josephs Social Club Official Website",
#    "category_list": [
#     {
#      "id": "110290705711626",
#      "name": "Bar"
#     }
#    ],
#    "id": "779768515407764"
#   },
#   {
#    "category": "Business services",
#    "name": "Web Social Media Marketing",
#    "id": "405802852763407"
#   },
#   {
#    "category": "Business person",
#    "name": "Paul Haley - Web Design and Social Media",
#    "id": "229853217188491"
#   },
#   {
#    "category": "Website",
#    "name": "Websites for Member & Social Groups, Clubs, & Associations",
#    "id": "295907960480945"
#   },
#   {
#    "category": "Product/service",
#    "name": "Packetmanxd - Web Design & Social Media",
#    "id": "585427021523043"
#   },
#   {
#    "category": "Book",
#    "name": "Empfehlungsmarketing im Social Web - Das Buch",
#    "id": "343063572502618"
#   },
#   {
#    "category": "Business services",
#    "name": "3YESWEB.com Mobile Local Social Website Marketing",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "580740251986719"
#   },
#   {
#    "category": "Business services",
#    "name": "SocialMedia Designs",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "173876899342866"
#   },
#   {
#    "category": "Local business",
#    "name": "Onefoursix - Specialists in Design, Print, Social Media, and Websites.",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "197888373555475",
#      "name": "Printing Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "453613371345754"
#   },
#   {
#    "category": "Business services",
#    "name": "Mojowriting - Writing, Social Media and Web Management in Loudoun",
#    "id": "135847466456897"
#   },
#   {
#    "category": "Business services",
#    "name": "Imagination Marketing - SEO Website Marketing Social Media Management",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "453192678092536"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Fletcher Web Marketing | SEO | SEM | Social Media | Analytics",
#    "id": "339797189378903"
#   },
#   {
#    "category": "Organization",
#    "name": "SowSkills - Social-Web-Skills for eldery people",
#    "id": "225477664142196"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Mybusinessonline.co.uk - Managed Websites & Social Media Marketing",
#    "id": "1387567281573461"
#   },
#   {
#    "category": "Product/service",
#    "name": "Designs by Desiree Business Solutions",
#    "id": "436943043033766"
#   }
#  ]
# }

# %% [markdown]
# ## Example 3. Results for a Graph API query for Mining the Social Web

# %%
# Get an instance of Mining the Social Web
# Using the page name also works if you know it.
# e.g. 'MiningTheSocialWeb' or 'CrossFit'
#mtsw_id = '146803958708175'
mtsw_id = '35379747362'
pp(g.get_object(mtsw_id))
# Out:
# {
#  "description": "La page Facebookienne de l'association de lettres et sciences du langage de Bordeaux 3",
#  "privacy": "OPEN",
#  "id": "35379747362",
#  "venue": {
#   "latitude": 44.8386,
#   "city": "Bordeaux",
#   "state": "Aquitaine",
#   "longitude": -0.5783,
#   "country": "France"
#  },
#  "name": "Littorale et SCILAB",
#  "link": "www.klubasso.fr/lets",
#  "owner": {
#   "id": "10152962801842293",
#   "name": "Patxi Lecea"
#  },
#  "updated_time": "2014-06-18T19:09:13+0000",
#  "email": "35379747362@groups.facebook.com",
#  "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/y0/r/XCrOg4YmGg4.png"
# }

# %% [markdown]
# ## Example 4. Querying the Graph API for Open Graph objects by their URLs

# %%
# MTSW catalog link
pp(g.get_object('http://shop.oreilly.com/product/0636920030195.do'))

# PCI catalog link
pp(g.get_object('http://shop.oreilly.com/product/9780596529321.do'))
# Out:
# {
#  "id": "http://shop.oreilly.com/product/0636920030195.do",
#  "shares": 269
# }
# {
#  "category": "Book",
#  "about": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "talking_about_count": 0,
#  "description": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "has_added_app": false,
#  "can_post": true,
#  "name": "Programming Collective Intelligence",
#  "link": "http://shop.oreilly.com/product/9780596529321.do",
#  "likes": 18,
#  "parking": {
#   "street": 0,
#   "lot": 0,
#   "valet": 0
#  },
#  "is_community_page": false,
#  "were_here_count": 0,
#  "checkins": 0,
#  "id": "221689464577245",
#  "is_published": true
# }

# %% [markdown]
# ## Example 5. Comparing likes between Coke and Pepsi fan pages

# %%
# Find Pepsi and Coke in search results

pp(g.request('search', {'q' : 'pepsi', 'type' : 'page', 'limit' : 5}))
pp(g.request('search', {'q' : 'coke', 'type' : 'page', 'limit' : 5}))

# Use the ids to query for likes

pepsi_id = '56381779049' # Could also use 'PepsiUS'
coke_id = '40796308305'  # Could also use 'CocaCola'

# A quick way to format integers with commas every 3 digits
def int_format(n): return "{:,}".format(n)

print "Pepsi likes:", int_format(g.get_object(pepsi_id)['likes'])
print "Coke likes:", int_format(g.get_object(coke_id)['likes'])
# Out:
# {
#  "paging": {
#   "cursors": {
#    "after": "NA==",
#    "before": "MA=="
#   },
#   "next": "https://graph.facebook.com/v2.0/search?access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh&q=pepsi&type=page&limit=5&after=NA%3D%3D"
#  },
#  "data": [
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi",
#    "id": "339150749455906"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "PepsiCo",
#    "category_list": [
#     {
#      "id": "2252",
#      "name": "Food/Beverages"
#     }
#    ],
#    "id": "260431051694"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi Alg\u00e9rie",
#    "category_list": [
#     {
#      "id": "2252",
#      "name": "Food/Beverages"
#     }
#    ],
#    "id": "723211741054250"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi MAX",
#    "id": "131381520241235"
#   },
#   {
#    "category": "Sports league",
#    "name": "Pepsi Ipl 8 - 2015 Live Updates",
#    "id": "292288827562122"
#   }
#  ]
# }
# {
#  "paging": {
#   "cursors": {
#    "after": "NA==",
#    "before": "MA=="
#   },
#   "next": "https://graph.facebook.com/v2.0/search?access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh&q=coke&type=page&limit=5&after=NA%3D%3D"
#  },
#  "data": [
#   {
#    "category": "Food/beverages",
#    "name": "Coca-Cola",
#    "id": "789765281096287"
#   },
#   {
#    "category": "Tv show",
#    "name": "Coke Studio",
#    "id": "16944632531"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Coca-Cola Life",
#    "id": "437854099622026"
#   },
#   {
#    "category": "Tv show",
#    "name": "Coke Studio at MTV",
#    "id": "127266094017030"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Coca-Cola Freestyle",
#    "id": "106593592062"
#   }
#  ]
# }
# Pepsi likes: 33,001,653
# Coke likes: 90,319,829

# %% [markdown]
# ## Example 6. Querying a page for its "feed" and "links" connections

# %%
pp(g.get_connections(pepsi_id, 'feed'))
pp(g.get_connections(pepsi_id, 'links'))

pp(g.get_connections(coke_id, 'feed'))
pp(g.get_connections(coke_id, 'links'))
# Out:
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v2.0/56381779049/feed?access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh&limit=25&until=1431779438&__paging_token=enc_AdAu8H1CgXoGRZC0SiMexZBDO9Xd4x0EE1UyPwXZAcbsu6WZA59UnF0ZATS6DTe4YbN4rsR6ZCn6DJ4CI0ek2HO52wkJJL",
#   "previous": "https://graph.facebook.com/v2.0/56381779049/feed?since=1431872200&access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh&limit=25&__paging_token=enc_AdAxSnEtW3J2WH1fX0TQ5dsme07NwZC6Sw8T11uVVOZBgZAjsOs0KBAZBZAt9ZAaKW3cKd6D74ggwDOoZAkY7BXH2uq43Ab&__previous=1"
#  },
#  "data": [
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "1411382579169732",
#     "name": "Denise Forrest"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153464815054050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153464815054050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-17T14:16:40+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2015-05-17T14:16:40+0000",
#    "message": "Is it true  that  Pepsi  is leaving  out   \"under God \" on the new can design ? Please  tell  me  it's  just  another  social  media  lie.",
#    "type": "status",
#    "id": "56381779049_10153464815054050",
#    "status_type": "wall_post"
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "10201737134612563",
#     "name": "Betty Brewer"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153464735409050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153464735409050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-17T13:57:56+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2015-05-17T13:57:56+0000",
#    "message": "What is up with the 16.9 oz bottles?  From 24 to 16.9?  Seriously?  And where I shop they are the same price..  SERIOUSLY????",
#    "type": "status",
#    "id": "56381779049_10153464735409050",
#    "status_type": "wall_post"
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "767994819877865",
#     "name": "Debbie Jenkins"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153464317584050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153464317584050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-17T10:42:36+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2015-05-17T10:42:36+0000",
#    "message": "I was appalled by a recent Pepsi commercial, which I think Exec's with Pepsi didn't think through and if they did approve it, I won't be drinking Pepsi anymore. It's a radio ad about how a group of guys who ends up making a Pizza Delivery Man LATE and get the Pizza for Free!  Hello,  It's concept is surrounded by deceit and DISHONESTY!",
#    "type": "status",
#    "id": "56381779049_10153464317584050",
#    "status_type": "wall_post"
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "10203216151783716",
#     "name": "Carl Eller"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153464142179050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153464142179050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-17T09:36:51+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2015-05-17T09:36:51+0000",
#    "message": "The best soda by far... \ud83d\ude03\ud83d\ude03\ud83d\udc4d\ud83d\udc4d\ud83d\udc4d\ud83d\udc4f\ud83d\udc4f\ud83d\udc4f\ud83d\udc4f",
#    "type": "status",
#    "id": "56381779049_10153464142179050",
#    "status_type": "wall_post"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-b-a.akamaihd.net/hphotos-ak-xpf1/v/t1.0-9/s130x130/11245493_1629322053948417_3917443063228611288_n.jpg?oh=ef134887bb5bb790677d06a08a2ccf0c&oe=55CEE872&__gda__=1438648025_18db4f3952319a7dbb29324c16f7df9f",
#    "is_hidden": false,
#    "from": {
#     "category": "Writer",
#     "name": "Daniel Bellino-Zwicke / Author Page",
#     "id": "1453203138226977"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1629322053948417",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1629322053948417",
#      "name": "Like"
#     },
#     {
#      "link": "/profile.php?id=1453203138226977&and=56381779049",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2015-05-17T04:14:55+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/1453203138226977/photos/o.56381779049/1629322053948417/?type=1",
#    "object_id": "1629322053948417",
#    "created_time": "2015-05-17T04:14:55+0000",
#    "message": "SEGRETO ITALIANO -  Secret Italian Recipes\n\nDaniel Bellino Z\n\nhttp://www.amazon.com/Segreto-Italiano-Italian-Favorite-Cookbook-ebook/dp/B00NDLYP6S",
#    "type": "photo",
#    "id": "56381779049_1629322053948417",
#    "status_type": "added_photos",
#    "icon": "https://www.facebook.com/images/icons/photo.gif"
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "928389987172939",
#     "name": "Daniel Hagedorn"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153463424299050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153463424299050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-17T02:48:21+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2015-05-17T02:48:21+0000",
#    "message": "Bring the summer mix back \ud83d\ude29",
#    "type": "status",
#    "id": "56381779049_10153463424299050",
#    "status_type": "wall_post"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQAf_OqklwzGWwKF&w=130&h=130&url=http%3A%2F%2Fmedia3.policymic.com%2FY2MxZWNmNzZjMSMvazRCRmktV0JmYzB5ZzBELUptU2NzSF8xM0E0PS8xOTEweDEwMDAvc21hcnQvaHR0cHM6Ly9zMy5hbWF6b25hd3MuY29tL3BvbGljeW1pYy1pbWFnZXMvMGI5YjFkODVlYjNmMzc5ZTk3MWU1ZmU0MTIxMTU5NDQ4OGY5YWQ5NjI5NWEwMTMxMzdhZGEwY2Q0YzAyMTdjZC5qcGc%3D.jpg&cfs=1&sx=606&sy=0&sw=1000&sh=1000",
#    "is_hidden": false,
#    "from": {
#     "id": "10152314655136417",
#     "name": "Daniel G Gutierrez"
#    },
#    "name": "What the Ingredients in Coca-Cola and Pepsi Actually Do to Your Body",
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "message_tags": {
#     "165": [
#      {
#       "length": 5,
#       "offset": 165,
#       "type": "page",
#       "id": "282847125124252",
#       "name": "Pepsi"
#      }
#     ],
#     "138": [
#      {
#       "length": 11,
#       "offset": 138,
#       "type": "page",
#       "id": "222652364528162",
#       "name": "Coke~A~COLA"
#      }
#     ]
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/10152314655136417/posts/10152911012641417",
#      "name": "Like"
#     },
#     {
#      "link": "/ajax/add_friend/action.php",
#      "name": "Add Friend"
#     }
#    ],
#    "updated_time": "2015-05-17T02:09:13+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coke~A~COLA",
#       "id": "222652364528162"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "282847125124252"
#      }
#     ]
#    },
#    "link": "http://mic.com/articles/89333/what-the-ingredients-in-coca-cola-and-pepsi-actually-do-to-your-body",
#    "created_time": "2015-05-17T02:09:13+0000",
#    "message": "More random internet articles...  I just want to know if anybody has done a scientific comparison of the health impact of say 2 liters of Coke~A~COLA or 2 liters of Pepsi?  With the price changes, partnerships and additive concerns it seems like a topic to visit now that it feels like a year or so later.",
#    "caption": "mic.com",
#    "type": "link",
#    "id": "10152314655136417_10152911012641417",
#    "status_type": "shared_story",
#    "description": "The science shows it's far worse than we thought."
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "10206595129306616",
#     "name": "Joshua Wayne Spears"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153463270939050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153463270939050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-17T01:44:51+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2015-05-17T01:44:51+0000",
#    "message": "Bring pepsi man back!!!",
#    "type": "status",
#    "id": "56381779049_10153463270939050",
#    "status_type": "wall_post"
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "category": "Recreation/sports website",
#     "name": "Amazin' Avenue",
#     "id": "33367905046"
#    },
#    "message_tags": {
#     "82": [
#      {
#       "length": 13,
#       "offset": 82,
#       "type": "page",
#       "id": "94421890077",
#       "name": "New York Mets"
#      }
#     ],
#     "12": [
#      {
#       "length": 17,
#       "offset": 12,
#       "type": "page",
#       "id": "53927198229",
#       "name": "Curtis Granderson"
#      }
#     ],
#     "64": [
#      {
#       "length": 5,
#       "offset": 64,
#       "type": "page",
#       "id": "282847125124252",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/33367905046/posts/10152749852815047",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/33367905046/posts/10152749852815047",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-17T01:38:35+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Athlete",
#       "name": "Curtis Granderson",
#       "id": "53927198229"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "282847125124252"
#      },
#      {
#       "category": "Sports team",
#       "name": "New York Mets",
#       "id": "94421890077"
#      }
#     ]
#    },
#    "shares": {
#     "count": 2
#    },
#    "created_time": "2015-05-17T01:38:35+0000",
#    "message": "And there's Curtis Granderson driving one off the facing of the Pepsi Porch! 14-1 New York Mets lead it!",
#    "type": "status",
#    "id": "33367905046_10152749852815047",
#    "status_type": "mobile_status_update",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "Nzg1NDU0ODk1NTU2",
#       "before": "Nzk0NzMxNzYwNTgzNzEy"
#      },
#      "next": "https://graph.facebook.com/v2.0/33367905046_10152749852815047/likes?access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh&limit=25&after=Nzg1NDU0ODk1NTU2"
#     },
#     "data": [
#      {
#       "id": "794731760583712",
#       "name": "Tony Viola"
#      },
#      {
#       "id": "228405847355389",
#       "name": "Shmuly Snyder"
#      },
#      {
#       "id": "10205488723522654",
#       "name": "Connie Lipinski Mastroni"
#      },
#      {
#       "id": "771402066217399",
#       "name": "Erik Tonkovich"
#      },
#      {
#       "id": "10152956487795091",
#       "name": "Joshua Landes"
#      },
#      {
#       "id": "10202479395760637",
#       "name": "Billy Gunn"
#      },
#      {
#       "id": "747394668648792",
#       "name": "Frank Badame"
#      },
#      {
#       "id": "1590107241240607",
#       "name": "Thomas Bruszewski"
#      },
#      {
#       "id": "493406997453668",
#       "name": "Medht Ebrahim"
#      },
#      {
#       "id": "10152841040794741",
#       "name": "Gabe Miller"
#      },
#      {
#       "id": "360140620832913",
#       "name": "Marion Prusher"
#      },
#      {
#       "id": "10202936562080091",
#       "name": "John A Grisafi"
#      },
#      {
#       "id": "930367573670667",
#       "name": "Jeff Seiken"
#      },
#      {
#       "id": "10100329788887449",
#       "name": "Glenn D'Auria"
#      },
#      {
#       "id": "1550118311885129",
#       "name": "Steve Smith"
#      },
#      {
#       "id": "10101854561934901",
#       "name": "Mario Santilli"
#      },
#      {
#       "id": "10203776719677308",
#       "name": "Brad Kalmanson"
#      },
#      {
#       "id": "784799214941070",
#       "name": "Johnny Parmenter"
#      },
#      {
#       "id": "10204600029674731",
#       "name": "Eddie Gonzales"
#      },
#      {
#       "id": "500920760033881",
#       "name": "Scotch Kat"
#      },
#      {
#       "id": "10152784413066614",
#       "name": "Nolan Castro"
#      },
#      {
#       "id": "345660805643238",
#       "name": "Mary Laub"
#      },
#      {
#       "id": "1433022840305755",
#       "name": "Nelson Gomez"
#      },
#      {
#       "id": "10101050863123752",
#       "name": "Rachel Yaggy"
#      },
#      {
#       "id": "785454895556",
#       "name": "Zach Hilliard"
#      }
#     ]
#    }
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQArTvK6zbTl3CyP&w=130&h=130&url=https%3A%2F%2Fs.yimg.com%2Fbt%2Fapi%2Fres%2F1.2%2FiRCFZRbvshMPBL2mp_LtEg--%2FYXBwaWQ9eW5ld3M7cT03NTt3PTYwMA--%2Fhttp%3A%2F%2Fmedia.zenfs.com%2Fen-us%2Fvideo%2Fvideo.wtvd.abc.news.com%2F4de601b25b3a1c7e901a0c96e09dad51.cf.png&cfs=1",
#    "is_hidden": false,
#    "from": {
#     "id": "862199713871671",
#     "name": "Maria Eugenia Raxach Minguez"
#    },
#    "name": "Anciano enfermo de c\u00e1ncer llama al 911 (112) porque no ten\u00eda nada para comer",
#    "caption": "es.noticias.yahoo.com",
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/862084837216492",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/862084837216492",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-17T00:39:28+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://es.noticias.yahoo.com/blogs/el-viralero/operadora-del-911-le-lleva-comida-a-un-anciano-hambriento-160414536.html",
#    "created_time": "2015-05-17T00:39:28+0000",
#    "message": "Vale la pena que un gesto de Humanidad como este fuera puesto a luz publica por cadenas de TV como Telemundo o Cnn , estamos llenos todos los dias de noticias que muestran lo peor de los seres humanos , violaciones, robos, asesinatos, accidentes,  ESTE ACTO es digno de ser reconocido publicamente. Y a la  compa\u00f1ia PEPSI COLA LA INVITO tanto A SU GERENCIA, DIRECTIVOS, A QUE TOMEN COMO SUYO A ESTE ANCIANO, QUE EN SITUACION EXTREMA ENTRE OTRAS COSAS PIDIO UNA PEPSI COLA,.\nPEPSI ayuden a este hombre !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!\n\nhttps://es.noticias.yahoo.com/blogs/el-viralero/operadora-del-911-le-lleva-comida-a-un-anciano-hambriento-160414536.html",
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "type": "link",
#    "id": "56381779049_862084837216492",
#    "status_type": "shared_story",
#    "description": "Cuando Marilyn Hinson recibi\u00f3 la llamada en el servicio de emergencias 911 para el cual trabaja, no pod\u00eda dar cr\u00e9dito a sus o\u00eddos. Quien ped\u00eda ayuda no era la v\u00edctima de un accidente o un crimen, ni el due\u00f1o de un perrito atrapado en alg\u00fan lugar, sino un anciano enfermo\u2026y hambriento."
#   },
#   {
#    "picture": "https://scontent.xx.fbcdn.net/hphotos-xap1/v/t1.0-9/s130x130/1798876_10204219042456733_8411582029437594187_n.jpg?oh=d48a0ad523bb0949484132fa7cc9e666&oe=55D2E475",
#    "is_hidden": false,
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "ODcwMTQwNjY5NjcxMTIw",
#       "before": "Nzg0NjUyMzc0ODc5ODQw"
#      }
#     },
#     "data": [
#      {
#       "id": "784652374879840",
#       "name": "Charlene Glaub"
#      },
#      {
#       "id": "10153091428965859",
#       "name": "Anne Marie Haupt"
#      },
#      {
#       "id": "870140669671120",
#       "name": "Dooder Robinson"
#      }
#     ]
#    },
#    "from": {
#     "id": "10203239553410119",
#     "name": "Shaunna Avila McCullough"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10204219042456733",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10204219042456733",
#      "name": "Like"
#     },
#     {
#      "link": "/profile.php?id=1247486447&and=56381779049",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2015-05-17T00:25:25+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10204219042456733&set=o.56381779049&type=1",
#    "object_id": "10204219042456733",
#    "created_time": "2015-05-17T00:25:25+0000",
#    "message": "1984  \"The Jackson 5\" Pepsi poster I had hung up in my room I came across.",
#    "type": "photo",
#    "id": "56381779049_10204219042456733",
#    "status_type": "added_photos",
#    "icon": "https://www.facebook.com/images/icons/photo.gif"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-g-a.akamaihd.net/hphotos-ak-xtf1/v/t1.0-9/s130x130/22188_858729050872953_5604127242785348575_n.jpg?oh=b37b53850f880c5c646f99997ce71236&oe=560D28D9&__gda__=1439363215_180bff9790187131ef333853bf41aeb3",
#    "is_hidden": false,
#    "from": {
#     "id": "785009194911606",
#     "name": "Jenna Trujillo"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/858729050872953",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/858729050872953",
#      "name": "Like"
#     },
#     {
#      "link": "/profile.php?id=100002075996999&and=56381779049",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2015-05-16T23:54:00+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=858729050872953&set=o.56381779049&type=1",
#    "object_id": "858729050872953",
#    "created_time": "2015-05-16T23:54:00+0000",
#    "message": "Pepsi and coke in a coke machine I have never seen that b4...lol",
#    "type": "photo",
#    "id": "56381779049_858729050872953",
#    "status_type": "added_photos",
#    "icon": "https://www.facebook.com/images/icons/photo.gif"
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "10203101813211518",
#     "name": "Bill Eastman"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153462869939050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153462869939050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-16T23:12:08+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2015-05-16T23:12:08+0000",
#    "message": "WHY does @Pepsi always have the bottle caps so tight that you need to get something to help you open it?  I broke some skin while trying to open a 2 liter.  I've also had problems with a 20 ounce bottle at a casino store and asked the clerk and they could not open it either.  I ended up buying a coke product, which was easier to open.",
#    "type": "status",
#    "id": "56381779049_10153462869939050",
#    "status_type": "wall_post"
#   },
#   {
#    "picture": "https://scontent.xx.fbcdn.net/hphotos-xfp1/v/t1.0-9/s130x130/15597_961060913928280_261071501470592994_n.jpg?oh=1f79e5dc67c2c010b1f6b88957dedc31&oe=56063C79",
#    "is_hidden": false,
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTQzNjI0MzI5MzMwMzMxMA==",
#       "before": "MTQzNjI0MzI5MzMwMzMxMA=="
#      }
#     },
#     "data": [
#      {
#       "id": "1436243293303310",
#       "name": "Ryan Andrews"
#      }
#     ]
#    },
#    "from": {
#     "id": "773329322701441",
#     "name": "Keith Ammerman"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/961060913928280",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/961060913928280",
#      "name": "Like"
#     },
#     {
#      "link": "/profile.php?id=100000731421792&and=56381779049",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2015-05-16T22:43:46+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=961060913928280&set=o.56381779049&type=1",
#    "object_id": "961060913928280",
#    "created_time": "2015-05-16T22:43:46+0000",
#    "message": "#BringBackCrystalPEPSI",
#    "type": "photo",
#    "id": "56381779049_961060913928280",
#    "status_type": "added_photos",
#    "icon": "https://www.facebook.com/images/icons/photo.gif"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQDCXabQ51CbM-CC&w=130&h=130&url=http%3A%2F%2Fi.ytimg.com%2Fvi%2FsnPHL_3rzYQ%2Fhqdefault.jpg&cfs=1&sx=50&sy=0&sw=360&sh=360",
#    "is_hidden": false,
#    "from": {
#     "id": "1565066137045466",
#     "name": "Adam Createdman"
#    },
#    "name": "L.A. Beast MEGA-MIX",
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "source": "https://www.youtube.com/embed/snPHL_3rzYQ?autoplay=1",
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1631775823707830",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1631775823707830",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-16T22:30:00+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.youtube.com/watch?v=snPHL_3rzYQ",
#    "created_time": "2015-05-16T22:30:00+0000",
#    "message": "#BringBackCrystalPepsi https://www.youtube.com/watch?v=snPHL_3rzYQ",
#    "caption": "youtube.com",
#    "type": "video",
#    "id": "56381779049_1631775823707830",
#    "status_type": "shared_story",
#    "description": "A song I made using a bunch of sound clips from L.A. Beast's videos. So, technically, this is a song by L.A. Beast."
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQDCXabQ51CbM-CC&w=130&h=130&url=http%3A%2F%2Fi.ytimg.com%2Fvi%2FsnPHL_3rzYQ%2Fhqdefault.jpg&cfs=1&sx=50&sy=0&sw=360&sh=360",
#    "is_hidden": false,
#    "from": {
#     "id": "1565066137045466",
#     "name": "Adam Createdman"
#    },
#    "name": "L.A. Beast MEGA-MIX",
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "source": "https://www.youtube.com/embed/snPHL_3rzYQ?autoplay=1",
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1631775413707871",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1631775413707871",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-16T22:25:53+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.youtube.com/watch?v=snPHL_3rzYQ",
#    "created_time": "2015-05-16T22:25:53+0000",
#    "message": "#BringBackCrystalPepsi https://www.youtube.com/watch?v=snPHL_3rzYQ",
#    "caption": "youtube.com",
#    "type": "video",
#    "id": "56381779049_1631775413707871",
#    "status_type": "shared_story",
#    "description": "A song I made using a bunch of sound clips from L.A. Beast's videos. So, technically, this is a song by L.A. Beast."
#   },
#   {
#    "picture": "https://scontent.xx.fbcdn.net/hphotos-xta1/v/l/t1.0-9/s130x130/11263074_1627809044102153_3717408227556706954_n.jpg?oh=82ab7503149a4790c3596d3d2b5cea1f&oe=55C03DD6",
#    "is_hidden": false,
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "NjYyMDM5MDQzOTE4Nzc2",
#       "before": "NjYyMDM5MDQzOTE4Nzc2"
#      }
#     },
#     "data": [
#      {
#       "id": "662039043918776",
#       "name": "Dana White"
#      }
#     ]
#    },
#    "from": {
#     "id": "1606395862910138",
#     "name": "Donna Whitten"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1627809044102153",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1627809044102153",
#      "name": "Like"
#     },
#     {
#      "link": "/profile.php?id=100006192186669&and=56381779049",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2015-05-16T21:43:55+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=1627809044102153&set=o.56381779049&type=1",
#    "object_id": "1627809044102153",
#    "created_time": "2015-05-16T21:43:55+0000",
#    "message": "They LOVE their pepsi treat!",
#    "type": "photo",
#    "id": "56381779049_1627809044102153",
#    "status_type": "added_photos",
#    "icon": "https://www.facebook.com/images/icons/photo.gif"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQA3tSGOikvMGx1z&w=130&h=130&url=https%3A%2F%2F2dbdd5116ffa30a49aa8-c03f075f8191fb4e60e74b907071aee8.ssl.cf1.rackcdn.com%2F4562700_1431546986.5084_funddescription.jpg&cfs=1&sx=0&sy=171&sw=480&sh=480",
#    "is_hidden": false,
#    "from": {
#     "id": "1565312220399317",
#     "name": "Jessica Wojno"
#    },
#    "name": "Click here to support CLAIM MY SISTER'S REMAINS by Tracey Smith",
#    "caption": "gofundme.com",
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1565308910399648",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1565308910399648",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-16T20:40:29+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "http://www.gofundme.com/aproperrestingplac",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTExOTMxNzYyNDcyMzkw",
#       "before": "MTExOTMxNzYyNDcyMzkw"
#      }
#     },
#     "data": [
#      {
#       "id": "111931762472390",
#       "name": "Gonzalo Martinez"
#      }
#     ]
#    },
#    "created_time": "2015-05-16T20:40:29+0000",
#    "message": "http://www.gofundme.com/aproperrestingplac\nA dear friend of my sisters was found dead in her apartment. Her family does not want to claim her remains, so my sister wants to claim them. Please help or share this post so she has a proper resting place.",
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "type": "link",
#    "id": "56381779049_1565308910399648",
#    "status_type": "shared_story",
#    "description": "Hello my name is Tracey Smith, my best friend of 15 years died unexpectedly in her home at the age of 39. She was a foster child who grew up in the system. She had a very tough life, and now her family doesn\u2019t want anything to do with claiming her remains.  I think she deserves to be at peace and..."
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "850941001582702",
#     "name": "John Atkinson"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153462466339050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153462466339050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-16T19:11:42+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAyMDM2OTQyNjY2NjgwOTU=",
#       "before": "MTAyMDM2OTQyNjY2NjgwOTU="
#      }
#     },
#     "data": [
#      {
#       "id": "10203694266668095",
#       "name": "Grace Rose Giberson"
#      }
#     ]
#    },
#    "created_time": "2015-05-16T19:11:42+0000",
#    "message": "what do you win on specially marked cans I got one , what do you do with it\ntheirs no address or anything on box. just Look Inside specially marked Yankee cans., Know what",
#    "type": "status",
#    "id": "56381779049_10153462466339050",
#    "status_type": "wall_post"
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "850941001582702",
#     "name": "John Atkinson"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153462461079050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153462461079050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-16T19:07:07+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAyMDM2OTQyNjY2NjgwOTU=",
#       "before": "MTAyMDM2OTQyNjY2NjgwOTU="
#      }
#     },
#     "data": [
#      {
#       "id": "10203694266668095",
#       "name": "Grace Rose Giberson"
#      }
#     ]
#    },
#    "created_time": "2015-05-16T19:07:07+0000",
#    "message": "MAY  2015 , Look inside Specially Marked YANKEE CANS (Marked on box)",
#    "type": "status",
#    "id": "56381779049_10153462461079050",
#    "status_type": "wall_post"
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "10204909230705162",
#     "name": "NuNu Eu"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153462427469050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153462427469050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-16T18:46:07+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "place": {
#     "location": {
#      "city": "Atlanta",
#      "zip": "30349",
#      "country": "United States",
#      "longitude": -84.567479461616,
#      "state": "GA",
#      "street": "3025 Merk Rd SW",
#      "latitude": 33.674689754198
#     },
#     "id": "258113407641293",
#     "name": "Wolf Creek Amphitheater"
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAyMDM2OTQyNjY2NjgwOTU=",
#       "before": "MTAyMDM2OTQyNjY2NjgwOTU="
#      }
#     },
#     "data": [
#      {
#       "id": "10203694266668095",
#       "name": "Grace Rose Giberson"
#      }
#     ]
#    },
#    "created_time": "2015-05-16T18:46:07+0000",
#    "message": "Out here at Funk Fest presented by Pepsi!! Enjoying this weather.. waiting in line.. and yes Im Pepsi down.. gatorade and Redbull!!! Cant wait to enjoy this concert!!!",
#    "type": "status",
#    "id": "56381779049_10153462427469050",
#    "status_type": "wall_post"
#   },
#   {
#    "picture": "https://fbcdn-sphotos-a-a.akamaihd.net/hphotos-ak-xft1/v/t1.0-9/s130x130/11059999_827109797378379_9195017910252342333_n.jpg?oh=c1cb6f8f02a462b229abd7ffc192b22d&oe=55D10860&__gda__=1442962546_6df1d438a08946765dc890be1191fcc2",
#    "is_hidden": false,
#    "from": {
#     "id": "609258825830145",
#     "name": "Daniel Zwicke"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/827109797378379",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/827109797378379",
#      "name": "Like"
#     },
#     {
#      "link": "/profile.php?id=100002381008466&and=56381779049",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2015-05-16T17:14:57+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=827109797378379&set=o.56381779049&type=1",
#    "object_id": "827109797378379",
#    "created_time": "2015-05-16T17:14:57+0000",
#    "message": "SUNDAY SAUCE  - When Italian Americans Cook \n\nhttp://www.amazon.com/Sunday-Sauce-When-Italian-Americans-Cook/dp/1490991026/ref=tmm_pap_swatch_0?_encoding=UTF8&sr=&qid=",
#    "type": "photo",
#    "id": "56381779049_827109797378379",
#    "status_type": "added_photos",
#    "icon": "https://www.facebook.com/images/icons/photo.gif"
#   },
#   {
#    "is_hidden": false,
#    "from": {
#     "id": "10202483862711149",
#     "name": "Ca Ko"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153461814529050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153461814529050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2015-05-16T13:03:50+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2015-05-16T13:03:50+0000",
#    "message": "So bummed to hear you discontinued Pepsi Next.  Pepsi has too many calories and goes flat in under an hour.  Diet tastes terrible.  Was so happy to discover Next last year.  Now?  Back to the drawing board.  Switching to flavored carbonated water until Next returns.",
#    "type": "status",
#    "id": "56381779049_10153461814529050",
#    "status_type": "wall_post"
#   },
#   {
#    "picture": "https://scontent.xx.fbcdn.net/hphotos-xap1/v/t1.0-9/p130x130/10689487_10153253835186745_1727779342559862700_n.jpg?oh=4c86151fecd4f9b9a819397687ca5408&oe=55C0E2A2",
#    "is_hidden": false,
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAyMDUyMzkxMDY5OTIwNzg=",
#       "before": "ODM0MDA2NjE2Njk0MTY1"
#      }
#     },
#     "data": [
#      {
#       "id": "834006616694165",
#       "name": "Kenny Smith"
#      },
#      {
#       "id": "732782030093105",
#       "name": "Alyssia Gonzalez"
#      },
#      {
#       "id": "10200328414890437",
#       "name": "Kevin D. Watts"
#      },
#      {
#       "id": "10100255968386067",
#       "name": "Reggie Stewart"
#      },
#      {
#       "id": "10203774712905787",
#       "name": "Lyron Clark"
#      },
#      {
#       "id": "1107604125931692",
#       "name": "Mike Johnson"
#      },
#      {
#       "id": "888997421147693",
#       "name": "Kelvin Davis"
#      },
#      {
#       "id": "10152539358317868",
#       "name": "Melinda Hartsfield"
#      },
#      {
#       "id": "1099209316761904",
#       "name": "Kerri Todd Haubrich"
#      },
#      {
#       "id": "821837454559663",
#       "name": "Kimberly Clark"
#      },
#      {
#       "id": "10201643632412059",
#       "name": "Debra S Smith"
#      },
#      {
#       "id": "10153105469210016",
#       "name": "Lisa Fideler"
#      },
#      {
#       "id": "10205118736108009",
#       "name": "Waltrice Mccall"
#      },
#      {
#       "id": "10204466731285410",
#       "name": "Erica Eli Love King"
#      },
#      {
#       "id": "10205239106992078",
#       "name": "Nesha Lewis"
#      }
#     ]
#    },
#    "from": {
#     "id": "10152906135406745",
#     "name": "Kandi Cane"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "Mw=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "id": "845551125459925",
#        "name": "Ricardo Herrera"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2015-05-16T19:27:42+0000",
#       "message": "LaQwefa!!!!",
#       "id": "10153253835186745_10153254451211745",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "610301055725997",
#        "name": "Sonja Soderberg-Lemmon"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2015-05-17T14:32:57+0000",
#       "message": "I hit two different coke buttons at work Friday, and both dropped a pepsi. Coke addiction not fed.",
#       "id": "10153253835186745_10153256577321745",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "10201643632412059",
#        "name": "Debra S Smith"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2015-05-16T16:55:19+0000",
#       "message": "You so pretty girl",
#       "id": "10153253835186745_10153254231896745",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153253835186745",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10153253835186745",
#      "name": "Like"
#     },
#     {
#      "link": "/profile.php?id=501341744&and=56381779049",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2015-05-17T14:32:57+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10153253835186745&set=o.56381779049&type=1",
#    "object_id": "10153253835186745",
#    "created_time": "2015-05-16T13:03:16+0000",
#    "message": "#reallove",
#    "type": "photo",
#    "id": "56381779049_10153253835186745",
#    "status_type": "added_photos",
#    "icon": "https://www.facebook.com/images/icons/photo.gif"
#   },
#   {
#    "picture": "https://scontent.xx.fbcdn.net/hphotos-xta1/v/t1.0-9/s130x130/10404358_1436705639965927_7132264981104830192_n.jpg?oh=afdc62602a00b03f58f659a9aa7ee9ef&oe=55FEE944",
#    "is_hidden": false,
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "OTg2NTY1ODY4MDIzMTk1",
#       "before": "NzA0NTMyODI5NjYyMzE3"
#      }
#     },
#     "data": [
#      {
#       "id": "704532829662317",
#       "name": "Kristen Metzger"
#      },
#      {
#       "id": "1474177666181970",
#       "name": "Linda Linley"
#      },
#      {
#       "id": "986565868023195",
#       "name": "Amanda Peterson"
#      }
#     ]
#    },
#    "from": {
#     "id": "1436722676630890",
#     "name": "Amanda Woods"
#    },
#    "privacy": {
#     "allow": "",
#     "deny": "",
#     "friends": "",
#     "description": "",
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1436705639965927",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1436705639965927",
#      "name": "Like"
#     },
#     {
#      "link": "/profile.php?id=100008795141657&and=56381779049",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2015-05-16T12:30:38+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=1436705639965927&set=o.56381779049&type=1",
#    "object_id": "1436705639965927",
#    "created_time": "2015-05-16T12:30:38+0000",
#    "message": "He (my son) watches cartoons like this!  Too bad the slogan isn't \"live young\" anymore.  Lol!",
#    "type": "photo",
#    "id": "56381779049_1436705639965927",
#    "status_type": "added_photos",
#    "icon": "https://www.facebook.com/images/icons/photo.gif"
#   }
#  ]
# }
# {
#  "paging": {
#   "cursors": {
#    "after": "TVRBeE5UTTBOVE15TlRZek16a3dOVEE2TVRRek1UUXpPVFkzTmpveU16a3lOREkzT1RZMA==",
#    "before": "TVRBeE5UTTBOVE15TlRZek16a3dOVEE2TVRRek1UUXpPVFkzTmpveU16a3lOREkzT1RZMA=="
#   },
#   "next": "https://graph.facebook.com/v2.0/56381779049/links?access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh&limit=25&after=TVRBeE5UTTBOVE15TlRZek16a3dOVEE2TVRRek1UUXpPVFkzTmpveU16a3lOREkzT1RZMA%3D%3D"
#  },
#  "data": [
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQCaAlX0yhifodts&w=158&h=158&url=fbstaging%3A%2F%2Fgraph.facebook.com%2Fstaging_resources%2FMDExMDE1MzQ1MzI1NjMwOTA1MDo3NTExOTYwMTM%3D",
#    "from": {
#     "category": "Food/beverages",
#     "name": "Pepsi",
#     "id": "56381779049"
#    },
#    "name": "Snap, Tag & Win!",
#    "privacy": {
#     "deny": "",
#     "description": "Public",
#     "value": "EVERYONE",
#     "allow": "",
#     "friends": "",
#     "networks": ""
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MjM=",
#       "before": "NDc="
#      },
#      "next": "https://graph.facebook.com/v2.0/10153453256339050/comments?access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh&limit=25&after=MjM%3D"
#     },
#     "data": [
#      {
#       "from": {
#        "id": "10153541586001959",
#        "name": "Joe Ewert"
#       },
#       "like_count": 7,
#       "can_remove": false,
#       "created_time": "2015-05-13T01:54:10+0000",
#       "message": "If Coke brought back Surge for online purchases only, why not trump them by bringing back Crystal Pepsi to mainstream consumers?\n\nBRING BACK CRYSTAL PEPSI!!!!!!!!!",
#       "id": "10153453256339050_10153454261734050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "10203238903078854",
#        "name": "Chris Musso"
#       },
#       "like_count": 5,
#       "can_remove": false,
#       "created_time": "2015-05-12T14:12:29+0000",
#       "message": "#Bringbackcrystalpepsi",
#       "id": "10153453256339050_10153453263109050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1526663947603829",
#        "name": "Chris Forbes"
#       },
#       "like_count": 4,
#       "can_remove": false,
#       "created_time": "2015-05-12T21:45:22+0000",
#       "message": "#Bringbackcrystalpepsi",
#       "id": "10153453256339050_10153453946259050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "10101583240076197",
#        "name": "Nathaniel Allen"
#       },
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2015-05-12T23:39:15+0000",
#       "message": "Please #BringBackCrystalPepsi \n\nhttps://www.change.org/p/pepsico-bring-back-crystal-pepsi-11",
#       "id": "10153453256339050_10153454092164050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "613178465431740",
#        "name": "Brandon Baldauf"
#       },
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2015-05-12T18:07:36+0000",
#       "message": "",
#       "id": "10153453256339050_10153453629314050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1565066137045466",
#        "name": "Adam Createdman"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-14T19:26:57+0000",
#       "message": "",
#       "id": "10153453256339050_10153457664679050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "830466750305791",
#        "name": "Jen Hatcher"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-13T21:03:14+0000",
#       "message": "bring back pepsi blue and pepsi crystal.",
#       "id": "10153453256339050_10153455760959050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "387739351383185",
#        "name": "Erik Norman"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-13T02:42:34+0000",
#       "message": "#Bringbackcrystalpepsi",
#       "id": "10153453256339050_10153454326014050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "751735438231309",
#        "name": "Robert Jackson"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-12T16:32:50+0000",
#       "message": "#bringbackcrystalpepsi",
#       "id": "10153453256339050_10153453475974050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "613178465431740",
#        "name": "Brandon Baldauf"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-12T18:06:29+0000",
#       "message": "I don't want that, I want Crystal Pepsi!\n#BringBackCrystalPEPSI",
#       "id": "10153453256339050_10153453627214050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "436241066515615",
#        "name": "Mike Terranova"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-14T14:19:56+0000",
#       "message": "Bring back crystal pepsi NOOOWWWW",
#       "id": "10153453256339050_10153457122199050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "400270813457532",
#        "name": "Jeremy Button"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-12T19:37:10+0000",
#       "message": "https://www.facebook.com/hashtag/bringbackcrystalpepsi?hc_location=ufi",
#       "id": "10153453256339050_10153453750969050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1448448035453862",
#        "name": "Ian Stouder"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-14T05:28:06+0000",
#       "message": "#bringbackcrystalpepsi",
#       "id": "10153453256339050_10153456475474050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "1385647185099388",
#        "name": "Brandon Wetzel"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-13T01:42:39+0000",
#       "message": "Bring back crystal Pepsi",
#       "id": "10153453256339050_10153454237434050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "698268320239530",
#        "name": "Jacob Soukup"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-12T23:47:03+0000",
#       "message": "#BringBackCrystalPepsi",
#       "id": "10153453256339050_10153454099934050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "374896399371449",
#        "name": "Jonathan Obenauf"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2015-05-12T15:47:13+0000",
#       "message": "#bringbackcrystalpepsi",
#       "id": "10153453256339050_10153453410064050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "10153536418988438",
#        "name": "Briana Larae Kiser"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2015-05-15T18:07:51+0000",
#       "message": "#BringBackCrystalPepsi",
#       "id": "10153453256339050_10153459671654050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "326253264239119",
#        "name": "Angel Mercado"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2015-05-13T02:03:52+0000",
#       "message": "give me goddam crystal pepsi",
#       "id": "10153453256339050_10153454273389050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "10154545800485445",
#        "name": "Jadi Nicolas"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2015-05-12T16:32:05+0000",
#       "message": "#bringbackcrystalpepsi",
#       "id": "10153453256339050_10153453475044050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "10100875573690501",
#        "name": "Doug Putnam"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2015-05-16T23:31:18+0000",
#       "message": "Pepsi sucks",
#       "id": "10153453256339050_10153462891169050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "827418027309431",
#        "name": "Mowgley Torres"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2015-05-15T07:20:55+0000",
#       "message": "#bringbackcrystalpepsi",
#       "id": "10153453256339050_10153458624394050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "846627215394239",
#        "name": "Ashley Robertson"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2015-05-14T19:55:55+0000",
#       "message": "#bringbackcrystalpepsi",
#       "id": "10153453256339050_10153457705569050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "category": "Society/culture website",
#        "name": "Dating and Marriage",
#        "id": "183541685005070"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2015-05-13T11:40:40+0000",
#       "message": "",
#       "id": "10153453256339050_10153454914569050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "10203523322868939",
#        "name": "Shane M Emerich"
#       },
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2015-05-15T04:51:48+0000",
#       "message": "",
#       "id": "10153453256339050_10153458496384050",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "id": "10202227829958137",
#        "name": "Jane DeWitt"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2015-05-12T15:04:25+0000",
#       "message": "bring back PepsiONE!!!",
#       "id": "10153453256339050_10153453366504050",
#       "user_likes": false
#      }
#     ]
#    },
#    "caption": "MUSIC EXPERIENCES MADE REAL",
#    "link": "https://www.pepsioutoftheblue.com/?utm_source=facebook&utm_medium=cpc&utm_campaign=2015PepsiOOTB",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "NjY5OTQ1Mjc5NzE5NjEz",
#       "before": "MTQ4Nzc3MDcyMTQ3NzI5MQ=="
#      },
#      "next": "https://graph.facebook.com/v2.0/10153453256339050/likes?access_token=CAACEdEose0cBAE0hoGQmV9J0KxNuS8dQOVEaAw9WxvPpGGaWaY3stgyP7BEPZBqwXvxNJCNhKDBvbU93UE9CtepwcKQ6ZBAwz4uirrDqSE0PsJDU627MTDKQAYKIsqfwBLby5ZCxjc3IRBIgbWNHCt4rivBSpZCjZBJ9C0LA0uYqv0uUyy4sl1qh3n7N8bFfsZCO5ysXeZCKZBrMWZCi0FxSh&limit=25&after=NjY5OTQ1Mjc5NzE5NjEz"
#     },
#     "data": [
#      {
#       "id": "1487770721477291",
#       "name": "Daniel Shelton"
#      },
#      {
#       "id": "93260872809",
#       "name": "www.forevermetals.com"
#      },
#      {
#       "id": "795212970490302",
#       "name": "Julie Crisp"
#      },
#      {
#       "id": "721537227889183",
#       "name": "Elio Valverde"
#      },
#      {
#       "id": "10152798364391632",
#       "name": "Catherine J. Fisher-Reagan"
#      },
#      {
#       "id": "755733907800788",
#       "name": "Floyd Nash"
#      },
#      {
#       "id": "463461680466020",
#       "name": "Mary Queen"
#      },
#      {
#       "id": "392840087558516",
#       "name": "Gil Primo Hernandez"
#      },
#      {
#       "id": "874624895896770",
#       "name": "Robert Green"
#      },
#      {
#       "id": "763282403690117",
#       "name": "Ana Maria Valentin"
#      },
#      {
#       "id": "352744958218849",
#       "name": "Boyd Jay Jensen"
#      },
#      {
#       "id": "262329020616032",
#       "name": "Xavier Riley"
#      },
#      {
#       "id": "262452397270191",
#       "name": "Chris Persaud"
#      },
#      {
#       "id": "842223175794573",
#       "name": "Linda Grant"
#      },
#      {
#       "id": "1489840691255533",
#       "name": "David L Knight Jr."
#      },
#      {
#       "id": "1615059682040379",
#       "name": "Jamal Terrell"
#      },
#      {
#       "id": "753136361371562",
#       "name": "Mike A. Matamoros"
#      },
#      {
#       "id": "386963628151783",
#       "name": "Krizanne Anton"
#      },
#      {
#       "id": "705642582812619",
#       "name": "Stephanie Bruce"
#      },
#      {
#       "id": "566254143502688",
#       "name": "Vivian Reyes"
#      },
#      {
#       "id": "10202134314339438",
#       "name": "Maureen Cooney"
#      },
#      {
#       "id": "749870108366858",
#       "name": "Tammi Neal"
#      },
#      {
#       "id": "1003108446386278",
#       "name": "Charlotte Opdenhoff"
#      },
#      {
#       "id": "627997483945691",
#       "name": "Dennis Arel"
#      },
#      {
#       "id": "669945279719613",
#       "name": "Maryann Dyess"
#      }
#     ]
#    },
#    "created_time": "2015-05-12T14:07:55+0000",
#    "message": "Front row fangirling at the iHeartRadio music fest: it could happen. Enter #OutOfTheBlue today for a chance to win tix. pep.si/outoftheblue",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yD/r/aS8ecmYRys0.gif",
#    "id": "10153453256339050",
#    "description": "It's easy: Snap a pic of your favorite Pepsi & tweet it with #OutOfTheBlue #Entry. "
#   }
#  ]
# }
# ---------------------------------------------------------------------------
# GraphAPIError                             Traceback (most recent call last)
# <ipython-input-15-aaa8045b584f> in <module>()
#       2 pp(g.get_connections(pepsi_id, 'links'))
#       3
# ----> 4 pp(g.get_connections(coke_id, 'feed'))
#       5 pp(g.get_connections(coke_id, 'links'))
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/facebook.pyc in get_connections(self, id, connection_name, **args)
#     110     def get_connections(self, id, connection_name, **args):
#     111         """Fetchs the connections for given object."""
# --> 112         return self.request(id + "/" + connection_name, args)
#     113
#     114     def put_object(self, parent_object, connection_name, **data):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/facebook.pyc in request(self, path, args, post_args)
#     296         except urllib2.HTTPError, e:
#     297             response = _parse_json(e.read())
# --> 298             raise GraphAPIError(response)
#     299         except TypeError:
#     300             # Timeout support for Python <2.6
#
# GraphAPIError: Please reduce the amount of data you're asking for, then retry your request

# %% [markdown]
# ## Example 7. Querying for all of your friends' likes

# %%
# First, let's query for all of the likes in your social
# network and store them in a slightly more convenient
# data structure as a dictionary keyed on each friend's
# name. We'll use a dictionary comprehension to iterate
# over the friends and build up the likes in an intuitive
# way, although the new "field expansion" feature could 
# technically do the job in one fell swoop as follows:
#
# g.get_object('me', fields='id,name,friends.fields(id,name,likes)')
#
# See Appendix C for more information on Python tips such as
# dictionary comprehensions

friends = g.get_connections("me", "friends")['data']

likes = { friend['name'] : g.get_connections(friend['id'], "likes")['data'] 
          for friend in friends }

print likes
# Out:
# {u'Sdl Bordeaux': [], u'Noalig Biteau': []}

# %% [markdown]
# ## Example 8. Calculating the most popular likes among your friends

# %%
# Analyze all likes from friendships for frequency

# pip install prettytable
from prettytable import PrettyTable
from collections import Counter
friends_likes = Counter([like['name']
                         for friend in likes 
                           for like in likes[friend]
                               if like.get('name')])

pt = PrettyTable(field_names=['Name', 'Freq'])
pt.align['Name'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(fl) for fl in friends_likes.most_common(10) ]

print 'Top 10 likes amongst friends'
print pt
# Out:
# Top 10 likes amongst friends
# +------+------+
# | Name | Freq |
# +------+------+
# +------+------+

# %% [markdown]
# ## Example 9. Calculating the most popular categories for likes among your friends

# %%
# Analyze all like categories by frequency

friends_likes_categories = Counter([like['category'] 
                                    for friend in likes 
                                      for like in likes[friend]])

pt = PrettyTable(field_names=['Category', 'Freq'])
pt.align['Category'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(flc) for flc in friends_likes_categories.most_common(10) ]

print "Top 10 like categories for friends"
print pt
# Out:
# Top 10 like categories for friends
# +----------+------+
# | Category | Freq |
# +----------+------+
# +----------+------+

# %% [markdown]
# ## Example 10. Calculating the number of likes for each friend and sorting by frequency

# %%
# Build a frequency distribution of number of likes by 
# friend with a dictionary comprehension and sort it in 
# descending order

from operator import itemgetter

num_likes_by_friend = { friend : len(likes[friend]) 
                        for friend in likes }


pt = PrettyTable(field_names=['Friend', 'Num Likes'])
pt.align['Friend'], pt.align['Num Likes'] = 'l', 'r'
[ pt.add_row(nlbf) 
  for nlbf in sorted(num_likes_by_friend.items(), 
                     key=itemgetter(1), 
                     reverse=True) ]

print "Number of likes per friend"
print pt
# Out:
# Number of likes per friend
# +---------------+-----------+
# | Friend        | Num Likes |
# +---------------+-----------+
# | Noalig Biteau |         0 |
# | Sdl Bordeaux  |         0 |
# +---------------+-----------+

# %% [markdown]
# ## Example 11. Finding common likes between an ego and its friendships in a social network

# %%
# Which of your likes are in common with which friends?
my_likes = [ like['name'] 
             for like in g.get_connections("me", "likes")['data'] ]

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((ml,)) for ml in my_likes ]
print "My likes"
print pt

# Use the set intersection as represented by the ampersand
# operator to find common likes.

common_likes = list(set(my_likes) & set(friends_likes))

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((cl,)) for cl in common_likes ]
print
print "My common likes with friends"
print pt
# Out:
# My likes
# +-----------------------------------------------------------------------------+
# | Name                                                                        |
# +-----------------------------------------------------------------------------+
# | Chang Fee Ming                                                              |
# | Au coin des mots                                                            |
# | Carboniferous Times EarthCache Event 2015                                   |
# | Cali Lewis                                                                  |
# | LSF - Langue des Signes Française                                           |
# | The West Wing                                                               |
# | Mafia Wars                                                                  |
# | Kasimega                                                                    |
# | Le Quai'Son Nancy                                                           |
# | iAssociate                                                                  |
# | Cache Village - Boutique de Géocaching                                      |
# | Le rucher de la Prairie                                                     |
# | Lifehacker                                                                  |
# | I fucking love science                                                      |
# | Ma capacité de concentration est si courte que, ... Oh regarde un oiseau !! |
# | Choko Ona                                                                   |
# | Fraistyle                                                                   |
# | Game of Thrones                                                             |
# | Awi's Yellow House                                                          |
# | Perpustakaan Awam Negeri Terengganu                                         |
# | Penang Youth Park Station 3                                                 |
# | Bacots                                                                      |
# | Vernor Vinge                                                                |
# | Craig Shaw Gardner                                                          |
# | Lucía Etxebarria                                                            |
# +-----------------------------------------------------------------------------+
#
# My common likes with friends
# +------+
# | Name |
# +------+
# +------+

# %% [markdown]
# ## Example 12. Calculating the friends most similar to an ego in a social network

# %%
# Which of your friends like things that you like?

similar_friends = [ (friend, friend_like['name']) 
                     for friend, friend_likes in likes.items()
                       for friend_like in friend_likes
                         if friend_like.get('name') in common_likes ]


# Filter out any possible duplicates that could occur

ranked_friends = Counter([ friend for (friend, like) in list(set(similar_friends)) ])


pt = PrettyTable(field_names=["Friend", "Common Likes"])
pt.align["Friend"], pt.align["Common Likes"] = 'l', 'r'
[ pt.add_row(rf) 
  for rf in sorted(ranked_friends.items(), 
                   key=itemgetter(1), 
                   reverse=True) ]
print "My similar friends (ranked)"
print pt

# Also keep in mind that you have the full range of plotting
# capabilities available to you. A quick histogram that shows
# how many friends.

plt.hist(ranked_friends.values())
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')

# Keep in mind that you can customize the binning
# as desired. See http://matplotlib.org/api/pyplot_api.html

# For example...

plt.figure() # Display the previous plot
plt.hist(ranked_friends.values(),
          bins=arange(1,max(ranked_friends.values()),1))
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')
plt.figure() # Display the working plot
# Out:
# My similar friends (ranked)
# +--------+--------------+
# | Friend | Common Likes |
# +--------+--------------+
# +--------+--------------+
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-92c4586daa39> in <module>()
#      25 # how many friends.
#      26
# ---> 27 plt.hist(ranked_friends.values())
#      28 plt.xlabel('Bins (number of friends with shared likes)')
#      29 plt.ylabel('Number of shared likes in each bin')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Example 13. Constructing a graph of mutual friendships

# %%
import networkx as nx # pip install networkx
import requests # pip install requests

friends = [ (friend['id'], friend['name'],)
                for friend in g.get_connections('me', 'friends')['data'] ]

url = 'https://graph.facebook.com/me/mutualfriends/%s?access_token=%s'

mutual_friends = {} 

# This loop spawns a separate request for each iteration, so
# it may take a while. Optimization with a thread pool or similar
# technique would be possible.
for friend_id, friend_name in friends:
    r = requests.get(url % (friend_id, ACCESS_TOKEN,) )
    response_data = json.loads(r.content)['data']
    mutual_friends[friend_name] = [ data['name'] 
                                    for data in response_data ]
    
nxg = nx.Graph()

[ nxg.add_edge('me', mf) for mf in mutual_friends ]

[ nxg.add_edge(f1, f2) 
  for f1 in mutual_friends 
      for f2 in mutual_friends[f1] ]

# Explore what's possible to do with the graph by 
# typing nxg.<tab> or executing a new cell with 
# the following value in it to see some pydoc on nxg
print nxg
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-7814c48586ac> in <module>()
#      14 for friend_id, friend_name in friends:
#      15     r = requests.get(url % (friend_id, ACCESS_TOKEN,) )
# ---> 16     response_data = json.loads(r.content)['data']
#      17     mutual_friends[friend_name] = [ data['name']
#      18                                     for data in response_data ]
#
# KeyError: 'data'

# %% [markdown]
# ## Example 14. Finding and analyzing cliques in a graph of mutual friendships

# %%
# Finding cliques is a hard problem, so this could
# take a while for large graphs.
# See http://en.wikipedia.org/wiki/NP-complete and 
# http://en.wikipedia.org/wiki/Clique_problem.

cliques = [c for c in nx.find_cliques(nxg)]

num_cliques = len(cliques)

clique_sizes = [len(c) for c in cliques]
max_clique_size = max(clique_sizes)
avg_clique_size = sum(clique_sizes) / num_cliques

max_cliques = [c for c in cliques if len(c) == max_clique_size]

num_max_cliques = len(max_cliques)

max_clique_sets = [set(c) for c in max_cliques]
friends_in_all_max_cliques = list(reduce(lambda x, y: x.intersection(y),
                                  max_clique_sets))

print 'Num cliques:', num_cliques
print 'Avg clique size:', avg_clique_size
print 'Max clique size:', max_clique_size
print 'Num max cliques:', num_max_cliques
print
print 'Friends in all max cliques:'
print json.dumps(friends_in_all_max_cliques, indent=1)
print
print 'Max cliques:'
print json.dumps(max_cliques, indent=1)

# %% [markdown]
# ## Example 15. Serializing a NetworkX graph to a file for consumption by D3

# %%
from networkx.readwrite import json_graph

nld = json_graph.node_link_data(nxg)

json.dump(nld, open('resources/ch02-facebook/viz/force.json','w'))

# %% [markdown]
# Note: You may need to implement some filtering on the NetworkX graph before writing it out to a file for display in D3, and for more than dozens of nodes, it may not be reasonable to render a meaningful visualization without some JavaScript hacking on its parameters. View the JavaScript source in [force.html](files/resources/ch02-facebook/viz/force.html) for some of the details.

# %% [markdown]
# ## Example 16. Visualizing a mutual friendship graph with D3

# %%
from IPython.display import IFrame
from IPython.core.display import display

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix.

viz_file = 'files/resources/ch02-facebook/viz/force.html'

display(IFrame(viz_file, '100%', '600px'))
