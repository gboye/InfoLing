# %%
import re
import codecs
import sys
import pickle
#import time

# %%
from __future__ import print_function
def warning(*objs):
    print("WARNING: ", *objs, file=sys.stderr)

# %%
nomFeatures="NGrams-LetterFeatures.csv"
with codecs.open(nomFeatures,"r",encoding="utf8") as stream:
    featureLines=stream.readlines()
letterFeatures={}
for featureLine in featureLines[2:]:
    elements=featureLine.strip().split("\t")
    letterFeatures[elements[0]]=[int(i) for i in elements[1:]]
#letterFeatures

# %%
def vectorizeNGram(ngram):
    vecteurs=[]
    for letter in ngram:
        vecteurs.append(letterFeatures[letter])
    return vecteurs

# %%
#vectorizeNGram("bac")

# %%
nomFichier="texte.txt"
try:
    fichier = codecs.open(nomFichier, "r",encoding="utf8")
except IOError:
    warning("could not open", nomFichier)
    sys.exit()
else:
    text = fichier.readlines()
    fichier.close()

# %%
ngram = 5
pc = [".", ",", ";", ":", "?", "!", "--", "...", u"«", u"»", "(", ")"]

# %%
def normaliserTexte(text,nospace=False):
    normalText=[]
    for line in text:
        for ponct in pc: 
            line=line.replace(ponct,"")
        line=line.replace("'"," ")
        line=line.replace("-"," ")
        if nospace:
            line=re.sub('\s+','',line)
        else:
            line=re.sub('\s+',' ',line)
        normalText.append(line.lower())
    return normalText

def extraireNgrams(text,noclasses=False):
    ngrams=[]
    classes=[]
    for line in text[:]:
        line = line.strip()
    #    print (line)
        espace = line.count(" ")
        i = 0
        while i <= len(line) - ngram - espace:
            if line[i] != " ":
                lettres = 0
                lettreslocales = 0
                ngramLocal=[]
                j = 0
                type = ""
                while lettres < ngram:
                    if line[i + j] != " ":
                        ngramLocal.append(line[i + j])
                        lettres += 1
                        lettreslocales += 1
                    else:
                        type = type + str(lettreslocales) + "_"
                        lettreslocales = 0
                    j += 1
                type = type + str(lettreslocales)
                ngrams.append(ngramLocal)
                classes.append(type)
            i = i + 1
    if noclasses:
        return ngrams
    else:
        return(ngrams, classes)

# %%
trainTexte = normaliserTexte(text)
(ngramTrain,classesTrain)=extraireNgrams(trainTexte)
print (ngramTrain[0],classesTrain[0])
# Out:
# [u'c', u'h', u'a', u'p', u'i'] 5

# %%
ngramTrain2=[]
for n,ngram in enumerate(ngramTrain):
    if n>91200: print (n, "".join(ngram),end=", ")
    ngramTrain2.append(vectorizeNGram(ngram))
# Out:
# 82201 lsitu, 82202 situc, 82203 ituco, 82204 tucon, 82205 ucont, 82206 conti, 82207 ontin, 82208 ntinu, 82209 tinue, 82210 inues, 82211 nuesà, 82212 uesàt, 82213 esàte, 82214 sàtem, 82215 àtemo, 82216 temoq, 82217 emoqu, 82218 moque, 82219 oquer, 82220 querd, 82221 uerde, 82222 erdet, 82223 rdeto, 82224 detoi, 82225 etoim, 82226 toimê, 82227 oimêm, 82228 imême, 82229 mêmet, 82230 êmetu, 82231 metup, 82232 etupo, 82233 tupou, 82234 upour, 82235 pourr, 82236 ourra, 82237 urras, 82238 rrasb, 82239 rasbi, 82240 asbie, 82241 sbien, 82242 bient, 82243 ientô, 82244 entôt, 82245 ntôtt, 82246 tôtte, 82247 ôttem, 82248 ttemo, 82249 temoq, 82250 emoqu, 82251 endéj, 82252 ndéje, 82253 déjeu, 82254 éjeun, 82255 jeuna, 82256 eunan, 82257 unant, 82258 nantd, 82259 antde, 82260 ntdem, 82261 tdema, 82262 demar, 82263 emars, 82264 marsa, 82265 arsay, 82266 rsayc, 82267 sayco, 82268 aycom, 82269 ycomm, 82270 comme, 82271 ommen, 82272 mmenç, 82273 mença, 82274 ençaq, 82275 nçaqu, 82276 çaqua, 82277 aquan, 82278 quand, 82279 uandi, 82280 andil, 82281 ndile, 82282 dilen, 82283 ilenf, 82284 lenfu, 82285 enfut, 82286 nfutà, 82287 futàf, 82288 utàfu, 82289 tàfum, 82290 àfume, 82291 fumer, 82292 umers, 82293 merse, 82294 erses, 82295 rsesc, 82296 sesci, 82297 escig, 82298 sciga, 82299 cigar, 82300 igare, 82301 gares, 82302 aresà, 82303 resàv, 82304 esàvo, 82305 sàvoi, 82306 àvoir, 82307 voirl, 82308 oirle, 82309 irles, 82310 rlesé, 82311 lesév, 82312 esévé, 82313 sévén, 82314 événe, 82315 vénem, 82316 éneme, 82317 nemen, 82318 ement, 82319 ments, 82320 entsd, 82321 ntsde, 82322 tsdes, 82323 sdesa, 82324 desan, 82325 esanu, 82326 sanui, 82327 anuit, 82328 nuits, 82329 uitso, 82330 itsou, 82331 tsous, 82332 sousu, 82333 ousun, 82334 usuns, 82335 sunsi, 82336 unsin, 82337 nsing, 82338 singu, 82339 ingul, 82340 nguli, 82341 gulie, 82342 ulier, 82343 lierj, 82344 ierjo, 82345 erjou, 82346 rjour, 82347 jourc, 82348 ourco, 82349 urcom, 82350 rcomm, 82351 comme, 82352 ommeb, 82353 mmebe, 82354 mebea, 82355 ebeau, 82356 beauc, 82357 eauco, 82358 aucou, 82359 ucoup, 82360 coupd, 82361 oupde, 82362 updeg, 82363 pdegr, 82364 degra, 82365 egran, 82366 grand, 82367 rands, 82368 andse, 82369 ndses, 82370 dsesp, 82371 sespr, 82372 espri, 82373 sprit, 82374 prits, 82375 ritss, 82376 itssa, 82377 tssap, 82378 ssape, 82379 saper, 82380 apers, 82381 persp, 82382 erspi, 82383 rspic, 82384 spica, 82385 picac, 82386 icaci, 82387 cacit, 82388 acité, 82389 citén, 82390 iténé, 82391 ténét, 82392 énéta, 82393 nétai, 82394 était, 82395 taitp, 82396 aitpa, 82397 itpas, 82398 tpass, 82399 passp, 82400 asspo, 82401 sspon, 82402 spont, 82403 ponta, 82404 ontan, 82405 ntané, 82406 tanée, 82407 anéei, 82408 néeil, 82409 éeiln, 82410 eilne, 82411 ilnen, 82412 lnent, 82413 nentr, 82414 entra, 82415 ntrai, 82416 trait, 82417 raitp, 82418 aitpa, 82419 itpas, 82420 tpast, 82421 pasto, 82422 astou, 82423 stout, 82424 toutà, 82425 outàc, 82426 utàco, 82427 tàcou, 82428 àcoup, 82429 coupa, 82430 oupau, 82431 upauf, 82432 paufo, 82433 aufon, 82434 ufond, 82435 fondd, 82436 ondde, 82437 nddes, 82438 ddesc, 82439 desch, 82440 escho, 82441 schos, 82442 chose, 82443 hoses, 82444 osesc, 82445 sesco, 82446 escom, 82447 scomm, 82448 comme, 82449 ommec, 82450 mmech, 82451 meche, 82452 echez, 82453 chezt, 82454 hezto, 82455 eztou, 82456 ztout, 82457 toute, 82458 outes, 82459 utesl, 82460 tesle, 82461 esles, 82462 slesn, 82463 lesna, 82464 esnat, 82465 snatu, 82466 natur, 82467 ature, 82468 tures, 82469 uresd, 82470 resdo, 82471 esdou, 82472 sdoué, 82473 douée, 82474 ouées, 82475 uéesd, 82476 éesde, 82477 esdel, 82478 sdela, 82479 delaf, 82480 elafa, 82481 lafac, 82482 afacu, 82483 facul, 82484 acult, 82485 culté, 82486 ultéd, 82487 ltéde, 82488 tédev, 82489 édevi, 82490 deviv, 82491 evivr, 82492 vivre, 82493 ivreb, 82494 vrebe, 82495 rebea, 82496 ebeau, 82497 beauc, 82498 eauco, 82499 aucou, 82500 ucoup, 82501 coupd, 82502 oupda, 82503 updan, 82504 pdans, 82505 dansl, 82506 ansle, 82507 nslep, 82508 sle ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-70902897bca3> in <module>()
#       2 for n,ngram in enumerate(ngramTrain):
#       3     if n>82200: print (n, "".join(ngram),end=", ")
# ----> 4     ngramTrain2.append(vectorizeNGram(ngram))
#
# <ipython-input-11-662047cdc5d3> in vectorizeNGram(ngram)
#       2     vecteurs=[]
#       3     for letter in ngram:
# ----> 4         vecteurs.append(letterFeatures[letter])
#       5     return vecteurs
#
# KeyError: u'\xa1'

# %%
#testSource=[u"Dans cette histoire, il y a un loup, une chêvre, et un agneau. Tout se passe bien tant que le loup et l'agneau ne sont pas seuls."]

# %%
nomFichier="LesMiserables.txt"
try:
    fichier = codecs.open(nomFichier, "r", "utf-8")
except IOError:
    warning("could not open", nomFichier)
    sys.exit()
else:
    testSource = fichier.readlines()
    fichier.close()

# %%
testTexte=normaliserTexte(testSource,True)
ngramTest=extraireNgrams(testTexte,True)
print (ngramTest[0])
ngramComplete=ngramTrain+ngramTest
textComplete=["".join(x) for x in ngramComplete]
textTrain=["".join(x) for x in ngramTrain]
textTest=["".join(x) for x in ngramTest]
print (len(textComplete),len(textTrain),len(textTest))
print (textComplete[0],textTrain[0],textTest[0])
# Out:
# [u'\ufeff', u't', u'o', u'm', u'e']
# 2327848 100405 2227443
# chapi chapi ﻿tome

# %% [markdown]
# CountVectorizer permet de traiter le texte comme des données numériques
# - analyzer permet de définir le niveau de tokenization (word, char)
# - ngram_range permet de définir les ngrams qui seront extraits (min, max)
#
# La méthode fit_transform permet de déterminer les données numériques (features) qui seront utilisées pour représenter le texte.
#
# Ensuite, on peut utiliser la méthode transform pour représenter un texte en utilisant ces features.

# %%
from sklearn.feature_extraction.text import CountVectorizer
transformVectors = CountVectorizer(analyzer=u'char',ngram_range=(5, 5))
skComplete = transformVectors.fit_transform(textComplete)

# %% [markdown]
# SVM est une des formes d'apprentissage
# - gamma définit le nombre de features qui seront utilisées pour l'apprentissage
# - C ???

# %%
from sklearn import svm
clf = svm.SVC(gamma=0.001, C=100.)

# %% [markdown]
# skTrain est la représentation numérique de textTrain
#
# clf.fit permet de faire l'apprentissage du lien entre les données de skTrain et les étiquettes fournies dataClasses

# %%
# %%time
skTrain=transformVectors.transform(textTrain)
clf.fit(skTrain, classesTrain)
# Out:
# CPU times: user 14min 6s, sys: 18.1 s, total: 14min 24s
# Wall time: 14min 24s

# %%
with open('SVC-Decoupages.pkl', 'wb') as output:
   pickle.dump(clf, output, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# skTest est la représentation numérique de textTest
#
# clf.predict permet de faire la prédiction des étiquettes pour les données de skTest

# %%
skTest=transformVectors.transform(textTest)
prediction=clf.predict(skTest)

# %% [markdown]
# ##interprétation des résultats
#
# ###Découpage des ngrams
#
# découpage des ngrams de test en fonction des étiquettes => resultChunks

# %%
resultChunks=[]
for i,element in enumerate(prediction):
    chunks=[int(n) for n in element.split("_")]
#    print (chunks)
    debut=0
    elementChunks=[]
    for chunk in chunks:
        elementChunks.append(textTest[i][debut:debut+chunk])
#        print (textTest[i][debut:debut+chunk],end=" ")
        debut+=chunk
#    print ()
    resultChunks.append(elementChunks)
#print (resultChunks)

# %% [markdown]
# ###Calcul des votes
#
# calcul des votes pour les séparations entre mots

# %%
testSpaces={}
for i,chunks in enumerate(resultChunks):
    posChunk=0
    for chunk in chunks:
        if posChunk!=0: 
#            print (i+posChunk,chunk)
            if not i+posChunk in testSpaces:
                testSpaces[i+posChunk]=0
            testSpaces[i+posChunk]+=1
        posChunk+=len(chunk)
#testSpaces

# %% [markdown]
# ###Découpage de test
#
# Séparation des mots

# %%
for i,lettre in enumerate(testTexte[200:250]):
    if i in testSpaces:
        # choisir le seuil d'apparition des espaces
        # au dessus de deux types convergents : >2
        # on insère un espace
        if testSpaces[i]>2:
            print ("_",end="")
        # sinon, par exemple, on colle les lettres
        # on pourrait aussi mettre le nombre de votes convergents
        # pour voir ce que ça donne
        else:
            pass
#            print (testSpaces[i],end="")
    print (lettre,end="")
#    time.sleep(1)
# Out:
# monseigneurmademoisellebaptistineétaitunepersonnelonguepâlemincedouceelleréalisaitlidéaldecequexprimelemot«respectable»carilsemblequilsoitnécessairequunefemmesoitmèrepourêtrevénérableellenavaitjamaisétéjolietoutesaviequinavaitétéquunesuitedesaintesoeuvresavaitfiniparmettresurelleunesortedeblancheuretdeclartéetenvieillissantelleavaitgagnécequonpourraitappelerlabeautédelabontécequiavaitétédelamaigreurdanssajeunesseétaitdevenudanssamaturitédelatransparenceetcettediaphanéitélaissaitvoirlangecétaituneâmeplusencorequecenétaituneviergesapersonnesemblaitfaitedombreàpeineassezdecorpspourquilyeûtlàunsexeunpeudematièrecontenantunelueurdegrandsyeuxtoujoursbaissésunprétextepourquuneâmerestesurlaterre_madamemagloireétaitunepetitevieilleblanchegrassereplèteaffairéetoujourshaletanteàcausedesonactivitédabordensuiteàcausedunasthmeàsonarrivéeoninstallammyrielensonpalaisépiscopalavecleshonneursvoulusparlesdécretsimpériauxquiclassentlévêqueimmédiatementaprèslemaréchaldecamplemaireetleprésidentluifirentlapremièrevisiteetluidesoncôtéfitlapremièrevisiteaugénéraletaupréfetlinstallationterminéelavilleattenditsonévêqueàloeuvrechapitreiimonsieurmyrieldevientmonseigneurbienvenulepalaisépiscopaldedigneétaitattenantàlhôpitallepalaisépiscopalétaitunvasteetbelhôtelbâtienpierreaucommencementdusiècledernierparmonseigneurhenripugetdocteurenthéologiedelafacultédeparisabbédesimorelequelétaitévêquededigneen1712cepalaisétaitunvrailogisseigneurialtoutyavaitgrandairlesappartementsdelévêquelessalonsleschambreslacourdhonneurfortlargeavecpromenoirsàarcadesselonlanciennemodeflorentinelesjardinsplantésdemagnifiquesarbresdanslasalleàmangerlongueetsuperbegaleriequiétaitaurezdechausséeetsouvraitsurlesjardinsmonseigneurhenripugetavaitdonnéàmangerencérémoniele29juillet1714àmesseigneurscharlesbrûlartdegenlisarchevêqueprincedembrunantoinedemesgrignycapucinévêquedegrassephilippedevendômegrandprieurdefranceabbéde
