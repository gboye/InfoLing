# %%
from urllib import urlopen
from bs4 import BeautifulSoup
html=urlopen("http://pythonscraping.com/pages/page1.html")
bsObj=BeautifulSoup(html.read())
print bsObj.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
from urllib2 import urlopen, Request, HTTPError, URLError
from bs4 import BeautifulSoup
urlSite="http://www.pythonscraping.com/pages/page1.html"
try:
    html = urlopen(urlSite)
except HTTPError as e: 
    print(e,urlSite)
    #return null, break, or do some other "Plan B"
except URLError as e:
    print (e, urlSite)
else:
    #program continues. Note: If you return or break in the 
    #exception catch, you do not need to use the "else" statement
    if html is None:
        print("URL is not found")
    else:
        #program continues
        bsObj=BeautifulSoup(html)
        try:
            content = bsObj.h1
        except AttributeError as e: 
            print("Tag was not found")
        else:
            if content == None:
                print ("Tag was not found")
            else: 
                print(content)
# Out:
# <h1>An Interesting Title</h1>

# %%
from urllib import urlopen
from bs4 import BeautifulSoup
html=urlopen("http://pythonscraping.com/pages/warandpeace.html")
bsObj=BeautifulSoup(html.read())

#nameList=bsObj.findAll("span", {"class":"green", "class":"red"})
#for name in nameList:
#    print (name.get_text())
    
headerList=bsObj.findAll({"h1","h2","h3","h4"})
for header in headerList:
    print header.get_text()
# Out:
# War and Peace
# Chapter 1

# %%
from urllib import urlopen
from bs4 import BeautifulSoup
import re
urlSite="http://en.wikipedia.org/wiki/Linguistics"
html=urlopen(urlSite)
bsObj=BeautifulSoup(html.read())
#for link in bsObj.findAll("a"):
#    if 'href' in link.attrs: 
#        print(link.attrs['href'])
urlLinks=[]
for link in bsObj.find("div", {"id":"bodyContent"}).findAll("a",href=re.compile("^(/wiki/)((?!:).)*$")):
    if 'href' in link.attrs:
        urlLink=link.attrs['href']
        if not urlLink in urlLinks:
            print(link.attrs['href'])
            urlLinks.append(urlLink)
# Out:
# /wiki/Linguistics_(journal)
# /wiki/Linguist_(disambiguation)
# /wiki/Theoretical_linguistics
# /wiki/Cognitive_linguistics
# /wiki/Generative_grammar
# /wiki/Quantitative_linguistics
# /wiki/Functional_theories_of_grammar
# /wiki/Phonology
# /wiki/Morphology_(linguistics)
# /wiki/Morphophonology
# /wiki/Syntax
# /wiki/Lexis_(linguistics)
# /wiki/Semantics
# /wiki/Pragmatics
# /wiki/Graphemics
# /wiki/Orthography
# /wiki/Semiotics
# /wiki/Linguistic_description
# /wiki/Anthropological_linguistics
# /wiki/Comparative_linguistics
# /wiki/Historical_linguistics
# /wiki/Etymology
# /wiki/Graphetics
# /wiki/Phonetics
# /wiki/Sociolinguistics
# /wiki/Applied_linguistics
# /wiki/Computational_linguistics
# /wiki/Contrastive_linguistics
# /wiki/Evolutionary_linguistics
# /wiki/Forensic_linguistics
# /wiki/Internet_linguistics
# /wiki/Language_acquisition
# /wiki/Second-language_acquisition
# /wiki/Language_assessment
# /wiki/Language_development
# /wiki/Language_education
# /wiki/Linguistic_anthropology
# /wiki/Neurolinguistics
# /wiki/Psycholinguistics
# /wiki/History_of_linguistics
# /wiki/Linguistic_prescription
# /wiki/List_of_linguists
# /wiki/List_of_unsolved_problems_in_linguistics
# /wiki/Science
# /wiki/Language
# /wiki/Form_(disambiguation)
# /wiki/Meaning_(linguistics)
# /wiki/Descriptive_linguistics
# /wiki/P%C4%81%E1%B9%87ini
# /wiki/Sanskrit
# /wiki/Ambiguity
# /wiki/Truth_condition
# /wiki/Grammar
# /wiki/Ferdinand_de_Saussure
# /wiki/Langue_and_parole
# /wiki/Structural_linguistics
# /wiki/Speech
# /wiki/Noam_Chomsky
# /wiki/Linguistic_competence
# /wiki/Discourse_analysis
# /wiki/Conversations
# /wiki/Diachronic_linguistics
# /wiki/Corpus_linguistics
# /wiki/Text_(disambiguation)
# /wiki/Stylistics_(field_of_study)
# /wiki/Discourse
# /wiki/Language_documentation
# /wiki/Lexicography
# /wiki/Parsing
# /wiki/Machine_translation
# /wiki/Translation
# /wiki/Interpreting
# /wiki/Foreign_language
# /wiki/Literary_criticism
# /wiki/Speech-language_pathology
# /wiki/Philology
# /wiki/Synchronic_analysis_(linguistics)
# /wiki/Universal_grammar
# /wiki/French_language
# /wiki/English_language
# /wiki/Dialects
# /wiki/Lexicon
# /wiki/Words
# /wiki/Bound_morphemes
# /wiki/Affixes
# /wiki/Encyclopedia
# /wiki/Dictionary
# /wiki/Neologism
# /wiki/Register_(sociolinguistics)
# /wiki/Vocabulary
# /wiki/Variety_(linguistics)
# /wiki/Language_is_a_dialect_with_an_army_and_navy
# /wiki/Max_Weinreich
# /wiki/Chomsky
# /wiki/Linguistic_sign
# /wiki/Generative_linguistics
# /wiki/Phonemes
# /wiki/Morphemes
# /wiki/Sentence_(linguistics)
# /wiki/Lexical_semantics
# /wiki/Phraseology
# /wiki/Utterance
# /wiki/Speech_acts
# /wiki/Text_(literary_theory)
# /wiki/Linguistic_relativity
# /wiki/World_view
# /wiki/Edward_Sapir
# /wiki/Benjamin_Lee_Whorf
# /wiki/Harry_Hoijer
# /wiki/Leo_Weisgerber
# /wiki/George_Lakoff
# /wiki/Jacques_Derrida
# /wiki/Deconstructivism
# /wiki/Rhetoric
# /wiki/Satire
# /wiki/Irony
# /wiki/Language_module
# /wiki/Human_brain
# /wiki/Formal_grammar
# /wiki/Cooperation
# /wiki/Cultural_evolution
# /wiki/Biological_evolution
# /wiki/Zoologist
# /wiki/Acrolect
# /wiki/Standard_language
# /wiki/Linguistic_imperialism
# /wiki/Censorship
# /wiki/Synchronic_linguistics
# /wiki/Syntagmatic_analysis
# /wiki/Paradigmatic_analysis
# /wiki/Paradigms
# /wiki/Anthropology
# /wiki/Endangered_languages
# /wiki/Spoken_language
# /wiki/Sign_language
# /wiki/Written_language
# /wiki/Culture
# /wiki/Phonological_rule
# /wiki/Sound_change
# /wiki/Speech_error
# /wiki/Pictographic
# /wiki/Dongba
# /wiki/Naxi_language
# /wiki/Homophone
# /wiki/List_of_languages_by_writing_system
# /wiki/Writing
# /wiki/Transcription_(linguistics)
# /wiki/Computer-mediated_communication
# /wiki/Writing_systems
# /wiki/History_of_English_grammars
# /wiki/Tamil_language
# /wiki/Thanjavur
# /wiki/India
# /wiki/Sanskrit_language
# /wiki/Consonant
# /wiki/Vowel
# /wiki/Middle_East
# /wiki/Sibawayh
# /wiki/Plato
# /wiki/Cratylus_(dialogue)
# /wiki/Alexander_the_Great
# /wiki/Musaeum
# /wiki/Alexandria
# /wiki/Greek_language
# /wiki/Art_of_Grammar
# /wiki/Dionysius_Thrax
# /wiki/Middle_Ages
# /wiki/Roger_Ascham
# /wiki/Wolfgang_Ratke
# /wiki/John_Amos_Comenius
# /wiki/Comparative_method
# /wiki/William_Jones_(philologist)
# /wiki/Jacob_Grimm
# /wiki/Wilhelm_von_Humboldt
# /wiki/Structuralism_(linguistics)
# /wiki/Prague_school_(linguistics)
# /wiki/Leonard_Bloomfield
# /wiki/Charles_F._Hockett
# /wiki/Louis_Hjelmslev
# /wiki/%C3%89mile_Benveniste
# /wiki/Roman_Jakobson
# /wiki/Zellig_Harris
# /wiki/Universal_Grammar
# /wiki/Nonterminal_symbol
# /wiki/Terminal_symbol
# /wiki/Disjoint_sets
# /wiki/Phoneme
# /wiki/Agent_(linguistics)
# /wiki/Patient_(linguistics)
# /wiki/Subject_(grammar)
# /wiki/Object_(grammar)
# /wiki/Topic%E2%80%93comment
# /wiki/Topic_(linguistics)
# /wiki/Focus_(linguistics)
# /wiki/Predicate_(grammar)
# /wiki/Cognitivism_(psychology)
# /wiki/Psychology
# /wiki/Cognition
# /wiki/Behaviorism
# /wiki/Ronald_Langacker
# /wiki/Emergentism
# /wiki/Cognitive_grammar
# /wiki/Frame_semantics_(linguistics)
# /wiki/Conceptual_metaphor
# /wiki/Embodied_cognition
# /wiki/Developmental_linguistics
# /wiki/Language_planning
# /wiki/Natural_language_processing
# /wiki/Constructed_language
# /wiki/Speech_synthesis
# /wiki/Speech_recognition
# /wiki/Computer-assisted_translation
# /wiki/Nationality
# /wiki/Interview
# /wiki/Native_language
# /wiki/Lingua_franca
# /wiki/Literary_studies
# /wiki/Text_linguistics
# /wiki/Philosophy_of_language
# /wiki/Ferdinand_De_Saussure
# /wiki/Mikhail_Bakhtin
# /wiki/Michel_Foucault
# /wiki/Franz_Boas
# /wiki/Language_death
# /wiki/Google_Translate
# /wiki/Biolinguistics
# /wiki/Speech-Language_Pathology
# /wiki/Communication_disorders
# /wiki/Human_evolution
# /wiki/Evolution
# /wiki/Forensics
# /wiki/Outline_of_linguistics
# /wiki/Index_of_linguistics_articles
# /wiki/List_of_cognitive_science_topics
# /wiki/International_Linguistics_Olympiad
# /wiki/International_Congress_of_Linguists
# /wiki/List_of_departments_of_linguistics
# /wiki/List_of_summer_schools_of_linguistics
# /wiki/Anthroponymy
# /wiki/Articulatory_phonology
# /wiki/Articulatory_synthesis
# /wiki/Asemic_writing
# /wiki/Axiom_of_categoricity
# /wiki/Biosemiotics
# /wiki/Concept_Mining
# /wiki/Critical_discourse_analysis
# /wiki/Cryptanalysis
# /wiki/Decipherment
# /wiki/Global_language_system
# /wiki/Glottometrics
# /wiki/Grammarian_(Greco-Roman_world)
# /wiki/Integrational_linguistics
# /wiki/Integrationism
# /wiki/Intercultural_competence
# /wiki/International_Linguistic_Olympiad
# /wiki/Language_attrition
# /wiki/Language_engineering
# /wiki/Language_geography
# /wiki/Linguistic_typology
# /wiki/Metacommunicative_competence
# /wiki/Microlinguistics
# /wiki/Onomastics
# /wiki/Reading_(activity)
# /wiki/Rhythm#Linguistics
# /wiki/Second_language_acquisition
# /wiki/Speaker_recognition
# /wiki/Speech_processing
# /wiki/Stratificational_linguistics
# /wiki/Writing_system
# /wiki/David_Crystal
# /wiki/International_Standard_Book_Number
# /wiki/Michael_Halliday
# /wiki/Andr%C3%A9_Martinet
# /wiki/MIT_Press
# /wiki/IRE_Transactions_on_Information_Theory
# /wiki/Digital_object_identifier
# /wiki/Mouton_de_Gruyter
# /wiki/JSTOR
# /wiki/SIL_International
# /wiki/Wiki
# /wiki/DMOZ
# /wiki/List_of_philosophers_of_language
# /wiki/Gorgias
# /wiki/Confucius
# /wiki/Xun_Kuang
# /wiki/Aristotle
# /wiki/Stoicism
# /wiki/Pyrrhonism
# /wiki/Scholasticism
# /wiki/Averroes
# /wiki/Ibn_Khaldun
# /wiki/Thomas_Hobbes
# /wiki/Gottfried_Wilhelm_Leibniz
# /wiki/Johann_Gottfried_Herder
# /wiki/Ludwig_Noire
# /wiki/Fritz_Mauthner
# /wiki/Paul_Ric%C5%93ur
# /wiki/Gottlob_Frege
# /wiki/Paul_Tillich
# /wiki/Zhuang_Zhou
# /wiki/Henri_Bergson
# /wiki/Lev_Vygotsky
# /wiki/Ludwig_Wittgenstein
# /wiki/Philosophical_Investigations
# /wiki/Tractatus_Logico-Philosophicus
# /wiki/Bertrand_Russell
# /wiki/Rudolf_Carnap
# /wiki/Of_Grammatology
# /wiki/Limited_Inc
# /wiki/Gustav_Bergmann
# /wiki/J._L._Austin
# /wiki/Hans-Georg_Gadamer
# /wiki/Saul_Kripke
# /wiki/A._J._Ayer
# /wiki/G._E._M._Anscombe
# /wiki/Jaakko_Hintikka
# /wiki/Michael_Dummett
# /wiki/Donald_Davidson_(philosopher)
# /wiki/Paul_Grice
# /wiki/Gilbert_Ryle
# /wiki/P._F._Strawson
# /wiki/Willard_Van_Orman_Quine
# /wiki/Hilary_Putnam
# /wiki/David_Lewis_(philosopher)
# /wiki/John_Searle
# /wiki/Joxe_Azurmendi
# /wiki/Scott_Soames
# /wiki/Stephen_Yablo
# /wiki/John_Hawthorne
# /wiki/Stephen_Neale
# /wiki/Causal_theory_of_reference
# /wiki/Contrast_theory_of_meaning
# /wiki/Contrastivism
# /wiki/Conventionalism
# /wiki/Cratylism
# /wiki/Deconstruction
# /wiki/Descriptivist_theory_of_names
# /wiki/Direct_reference_theory
# /wiki/Dramatism
# /wiki/Expressivism
# /wiki/Linguistic_determinism
# /wiki/Logical_atomism
# /wiki/Logical_positivism
# /wiki/Mediated_reference_theory
# /wiki/Nominalism
# /wiki/Non-cognitivism
# /wiki/Phallogocentrism
# /wiki/Quietism_(philosophy)
# /wiki/Relevance_theory
# /wiki/Semantic_externalism
# /wiki/Semantic_holism
# /wiki/Structuralism
# /wiki/Supposition_theory
# /wiki/Symbiosism
# /wiki/Theological_noncognitivism
# /wiki/Theory_of_descriptions
# /wiki/Verification_theory
# /wiki/Truth-bearer
# /wiki/Proposition
# /wiki/Use%E2%80%93mention_distinction
# /wiki/Concept
# /wiki/Categorization
# /wiki/Set_(mathematics)
# /wiki/Class_(philosophy)
# /wiki/Intension
# /wiki/Logical_form
# /wiki/Metalanguage
# /wiki/Mental_representation
# /wiki/Principle_of_compositionality
# /wiki/Property_(philosophy)
# /wiki/Sign_(semiotics)
# /wiki/Sense_and_reference
# /wiki/Speech_act
# /wiki/Symbol
# /wiki/Entity
# /wiki/Statement_(logic)
# /wiki/Index_of_philosophy_of_language_articles
# /wiki/Analytic_philosophy
# /wiki/Philosophy_of_information
# /wiki/Philosophical_logic
# /wiki/Formal_semantics_(linguistics)
# /wiki/Social_science
# /wiki/Archaeology
# /wiki/Cultural_anthropology
# /wiki/Social_anthropology
# /wiki/Economics
# /wiki/Geography
# /wiki/Human_geography
# /wiki/Integrated_geography
# /wiki/History
# /wiki/Law
# /wiki/Political_science
# /wiki/International_relations
# /wiki/Public_administration
# /wiki/Public_policy
# /wiki/Social_psychology
# /wiki/Sociology
# /wiki/Criminology
# /wiki/Demography
# /wiki/Rural_sociology
# /wiki/Anthrozoology
# /wiki/Area_studies
# /wiki/Business_studies
# /wiki/Cognitive_science
# /wiki/Communication_studies
# /wiki/Community_studies
# /wiki/Cultural_studies
# /wiki/Development_studies
# /wiki/Education
# /wiki/Environmental_social_science
# /wiki/Environmental_studies
# /wiki/Food_studies
# /wiki/Gender_studies
# /wiki/Global_studies
# /wiki/History_of_technology
# /wiki/Human_ecology
# /wiki/Information_science
# /wiki/International_studies
# /wiki/Media_studies
# /wiki/Philosophy_of_science
# /wiki/Philosophy_and_economics
# /wiki/Philosophy_of_history
# /wiki/Philosophy_of_psychology
# /wiki/Philosophy_of_social_science
# /wiki/Land-use_planning
# /wiki/Regional_planning
# /wiki/Urban_planning
# /wiki/Political_ecology
# /wiki/Political_economy
# /wiki/Public_health
# /wiki/Regional_science
# /wiki/Science,_technology_and_society
# /wiki/Science_studies
# /wiki/History_of_science
# /wiki/Social_work
# /wiki/Humanities
# /wiki/Geisteswissenschaft
# /wiki/Human_science
# /wiki/Index_of_sociology_articles
# /wiki/List_of_social_science_journals
# /wiki/Outline_of_social_science
# /wiki/Integrated_Authority_File
# /wiki/National_Diet_Library
