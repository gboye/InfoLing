# %%
import re
import sys
import codecs

# %%
#f=codecs.open(sys.argv[1],"r", 'latin1')
f=codecs.open("cmudict-0.7b","r", 'utf8')

# %%
vowels=["AA","AA0","AA1","AA2","AE","AE0","AE1",
"AE2","AH","AH0","AH1","AH2","AO","AO0","AO1","AO2",
"AW","AW0","AW1","AW2","AY","AY0","AY1","AY2","EH","EH0",
"EH1","EH2","ER","ER0","ER1","ER2","EY","EY0","EY1","EY2",
"IH","IH0","IH1","IH2","IY","IY0","IY1","IY2","OW","OW0",
"OW1","OW2","OY","OY0","OY1","OY2","UH","UH0","UH1",
"UH2","UW","UW0","UW1","UW2"]
#should i be creating a dico instead?
consonnes=["B","CH","D","DH","F","G","HH","JH","K","L",
"M","N","NG","P","R","S","SH","T","TH","V","W","Y","Z","ZH"]
graphicalVowels=["A","E","I","O","U", "Y"]

# %%
dictionary={}
for line in f:
    if ";;;" not in line: #delete header
        entry=line.split("  ")#every entry contains 2 spaces
        word=entry[0] #word is in first column
        syllabe=entry[1] #beginning of phonetic string in 2nd column
        if syllabe in dictionary:
            dictionary[syllabe].append(word)
        else:
            dictionary[syllabe]=[word]

# %%
spellingDict={}

# %%
for el in list(dictionary.items()):
    syllable=el[0].split()
    words=el[1]
    if syllable[0] in consonnes and syllable[1] in vowels:
        wordsInitialConsonants={}
        for word in words:
            initialConsonants=""
            for letter in word:
                if not letter in graphicalVowels:
                    initialConsonants+=letter
                else:
                    break
            wordsInitialConsonants[word]=initialConsonants
#        print (syllable[0], wordsInitialConsonants)
        for initialC in wordsInitialConsonants:
            if not syllable[0] in spellingDict:
                spellingDict[syllable[0]]=set()
            spellingDict[syllable[0]].add(wordsInitialConsonants[initialC])

# %%
spellingDict
# Out:
# {'HH': {'#H',
#   '-H',
#   'CH',
#   'G',
#   'H',
#   'HJ',
#   'HM',
#   'HMM',
#   'HR',
#   'HRDL',
#   'HRNC',
#   'J',
#   'KH',
#   'WH'},
#  'P': {'#P',
#   '%P',
#   '(P',
#   ')P',
#   '.P',
#   'LB',
#   'LBS',
#   'P',
#   "P'S",
#   'P.',
#   "P.'S",
#   'P.M.',
#   'P.S',
#   'PC',
#   "PC'S",
#   'PCS',
#   'PGM',
#   'PH',
#   'PHD',
#   'PHLC',
#   'PHN',
#   "PJ'S",
#   'PM',
#   'PR',
#   'PRCH',
#   'PRZ',
#   'PT'},
#  'S': {"'S",
#   ';S',
#   'C',
#   "C'",
#   "C'S",
#   'C-C',
#   'C-SP',
#   'C.',
#   "C.'S",
#   'C.D.S',
#   'C.S',
#   'C1',
#   'C2',
#   'C3',
#   'C4',
#   'C5',
#   'CBC',
#   'CBS',
#   'CC',
#   'CCS',
#   'CCTV',
#   'CD',
#   'CDC',
#   'CDR',
#   'CDS',
#   'CF',
#   'CL',
#   'CM',
#   'CNN',
#   "CNN'S",
#   'CNN.C',
#   'CNNFN',
#   'CPS',
#   'CRNK',
#   'CS',
#   'CSP',
#   'CXC',
#   'CXC(1)',
#   'CZ',
#   'PS',
#   'S',
#   'SC',
#   'SCZ',
#   'SF',
#   'SGT',
#   'SR',
#   'SR(1)',
#   'SRD',
#   'SS',
#   'ST-J',
#   'ST.(1)',
#   'STJ',
#   'ST_C',
#   'ST_CH',
#   'ST_CL',
#   'ST_D',
#   'ST_G',
#   'ST_H',
#   'ST_J',
#   'ST_L',
#   'ST_M',
#   'ST_P',
#   'ST_TH',
#   'SW',
#   'SZ',
#   'TS'},
#  'R': {"'R", ')R', 'HR', 'R', 'RH', 'RW', 'WR', 'WRZ', '}R'},
#  'T': {"'T",
#   'PT',
#   'T',
#   "T'",
#   "T'S",
#   'T-B',
#   'T-L',
#   'T-M',
#   'T-SH',
#   'T.',
#   "T.'S",
#   'T.S',
#   'TB',
#   'TC',
#   'TH',
#   'TR',
#   'TRB',
#   'TRN',
#   'TRZ',
#   'TRZC',
#   'TS',
#   "TT'S",
#   'TV',
#   "TV'S",
#   'TV(1)',
#   'TVS',
#   'TW',
#   'T_'},
#  'W': {'', 'H', 'J', 'W', 'W00T', 'WH', 'WL', 'WM'},
#  'V': {'V',
#   "V'S",
#   'V.',
#   "V.'S",
#   'V.S',
#   'VN',
#   'VP',
#   'VRB',
#   'VRD',
#   'VS',
#   'V_S',
#   'W'},
#  'Y': {'', 'H', 'J'},
#  'ZH': {'G', 'J', 'X', 'Z', 'ZH', 'ZS', 'ZSCH'},
#  'Z': {'CS', 'CZ', 'SZ', 'TS', 'X', 'XH', 'Z', "Z'S", 'Z.', "Z.'S", 'ZH'},
#  'CH': {'C', 'CH', 'CHM', 'CHRZ', 'CHS', 'CZ', 'Q', 'T', 'TCH', 'TSCH'},
#  'B': {"'B",
#   '(B',
#   'B',
#   "B'G",
#   "B'N",
#   "B'S",
#   'B-J',
#   "B-J'S",
#   'B.',
#   "B.'S",
#   'B.S',
#   'BBC',
#   "BBC'S",
#   'BBQ',
#   'BBQ(1)',
#   'BH',
#   'BLVD',
#   'BMW',
#   'BRCK',
#   'BT'},
#  'DH': {'TH'},
#  'D': {'"D',
#   '--D',
#   '-D',
#   '.D',
#   'D',
#   "D'",
#   "D'G",
#   "D'S",
#   'D.',
#   "D.'S",
#   'D.S',
#   'DB',
#   'DC',
#   'DDT',
#   'DFW',
#   'DFW(1)',
#   'DH',
#   'DHL',
#   'DK',
#   'DL',
#   'DM',
#   'DMZ',
#   'DN',
#   'DNC',
#   'DQ',
#   'DR',
#   'DR(1)',
#   'DR.(1)',
#   'DS',
#   'DSS',
#   'DSV',
#   'DVD',
#   'DVDS',
#   'DW',
#   'D_C',
#   'D…J¿',
#   'T',
#   'W',
#   "W'S",
#   'W.',
#   "W.'S",
#   'W.S',
#   'WM(1)',
#   'WS',
#   'WS(1)'},
#  'G': {"'G",
#   'G',
#   'GF',
#   'GH',
#   'GMBH',
#   'GPS',
#   'GR',
#   'GRB',
#   'GRZ',
#   'GS',
#   'GSCHW',
#   'GV',
#   'NG',
#   'NGH'},
#  'F': {'.F', 'F', 'FR', 'PF', 'PH'},
#  'K': {"'C",
#   "'K",
#   ',C',
#   ':C',
#   'C',
#   "C'M",
#   'CH',
#   'CHR',
#   'CL',
#   'CMX',
#   'CR',
#   'CT',
#   'GH',
#   'K',
#   "K'S",
#   'K-M',
#   'K.',
#   "K.'S",
#   'KC',
#   'KG',
#   'KGB',
#   'KH',
#   'KJ',
#   'KKK',
#   'KL',
#   'KM',
#   'KN',
#   'KNBC',
#   'KV',
#   'Q',
#   'TK'},
#  'M': {'HM',
#   'M',
#   'MB',
#   'MC',
#   'MCB',
#   'MCBR',
#   'MCC',
#   'MCCH',
#   'MCCHR',
#   'MCCL',
#   'MCCR',
#   'MCD',
#   'MCF',
#   'MCFL',
#   'MCG',
#   'MCGH',
#   'MCGL',
#   'MCGR',
#   'MCGW',
#   'MCH',
#   'MCJ',
#   'MCK',
#   'MCKL',
#   'MCKN',
#   'MCKR',
#   'MCL',
#   'MCM',
#   'MCN',
#   'MCP',
#   'MCPH',
#   'MCQ',
#   'MCR',
#   'MCS',
#   'MCSH',
#   'MCSL',
#   'MCSP',
#   'MCST',
#   'MCSW',
#   'MCT',
#   'MCV',
#   'MCW',
#   'MCWH',
#   'MCWR',
#   'MCZ',
#   'MF',
#   'MKH',
#   'ML',
#   'MM',
#   'MN',
#   'MPG(1)',
#   'MPH(1)',
#   'MR',
#   'MR.',
#   'MRS',
#   'MRS.',
#   'MS',
#   'MS.',
#   'MSGR',
#   'MSSRS',
#   'MSSRS.',
#   'MT'},
#  'L': {'(L', 'L', "L'", 'LH', 'LL', 'LN', 'LTD', 'LW', '{L'},
#  'N': {'GN', 'KN', 'MN', 'N', 'NG', 'PN'},
#  'SH': {'#SH',
#   'C',
#   'CH',
#   'HS',
#   'S',
#   'SC',
#   'SCH',
#   'SH',
#   'SHCH',
#   'SJ',
#   'SZ',
#   'SZCZ',
#   'TSH',
#   'X'},
#  'TH': {'TH'},
#  'JH': {'D',
#   'DJ',
#   'DRZ',
#   'DZ',
#   'DZH',
#   'G',
#   "G'S",
#   "G'V",
#   'G.',
#   "G.'S",
#   'G.S',
#   'GJ',
#   'GMBH(1)',
#   'GNC',
#   'GT',
#   'GW',
#   'J',
#   "J'S",
#   'J.',
#   "J.'S",
#   'JFK',
#   'JH',
#   'JN',
#   'KJ',
#   'Q',
#   'TJ',
#   'ZH'}}
